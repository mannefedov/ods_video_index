# %%
import requests
import json

# %%
API = 'AIzaSyABZTjzLinNS2tLnR2ZLtLvBcwUIC9fneI'

# %%
channel_ids = {'ml_trenings':'UCeq6ZIlvC9SVsfhfKnSvM9w',
              'event_space_by_video':'UCX5g8IOR_tw1OkiFAzAZHaA'}

# %%
playlist_ids = {''}

# %%
url_playlist = 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet%2C+id&playlistId={ID}&key={API_KEY}'

# %%
url = "https://www.googleapis.com/youtube/v3/search?key=AIzaSyABZTjzLinNS2tLnR2ZLtLvBcwUIC9fneI&channelId=UCeq6ZIlvC9SVsfhfKnSvM9w&part=snippet,id&order=date&maxResults=20"

# %%
r = requests.get(url_playlist.format(ID='PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T', API_KEY=API))

# %%
r.status_code
# Out:
# 200

# %%
js = json.loads(r.text)

# %%
js
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/N8YnLnxHFg5XypYrX9kj-LD4eOg"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Q1uDKFQ5A7w8OSFJ-v1Lq-SNY7U"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC41NkI0NEY2RDEwNTU3Q0M2',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nАлексей рассказал, как развивают Школу анализа данных и создают сложную и интересную магистерскую программу. Дополнительно рассказал о критериях поступления в ШАД и материалах, которые могут пригодиться. Бонусом прошелся по онлайн-курсам, подготовленным компанией за последние годы.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 0,
#     'publishedAt': '2018-12-12T09:27:35.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'FEzjzTSHlDs'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#       'width': 640}},
#     'title': 'Обучение машинному обучению и анализу данных утром, днём, вечером, ночью, Алексей Толстиков'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ko3HRUCv_1-r03uLZyt2VFmTQrg"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4yODlGNEE0NkRGMEEzMEQy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nНебольшой рассказ о том, как Поиск анализирует запрос пользователя. Алексей рассказал про то, что такое «расширения запроса», как мы их получаем и какую пользу можно извлечь, применяя эти знания неочевидным образом.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 1,
#     'publishedAt': '2018-12-12T09:29:42.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '2dhwd-dYZhI'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/sddefault.jpg',
#       'width': 640}},
#     'title': 'Как понять пользователя с полуслова? Алексей Иванин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5kC5XLsTmUhvnmAmXpDXldORrws"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4wMTcyMDhGQUE4NTIzM0Y5',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nОсновные технические вызовы, которые приходилось преодолевать в Mapbox. Краткий обзор полученных результатов и планов на будущее.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 2,
#     'publishedAt': '2018-12-12T09:32:25.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '-HwjbfQ80WY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Computer vision: слабое железо не приговор, Александр Матвеенко'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6BG9ptDX77DbBHiLQ87BU5DHq4w"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC41MjE1MkI0OTQ2QzJGNzNG',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nАндрей рассказал, как в Яндекс адаптировали голосовые технологии для работы в устройстве, где нет кнопок, но есть 7 микрофонов. В первую очередь он рассказал про распознавание речи и голосовую активацию. А ещё — про голосовую биометрию и (анти)спуфинг.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 3,
#     'publishedAt': '2018-12-12T09:34:49.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'q_Vc0c4CXqU'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Как научить себя слушать: голосовые технологии в Яндекс.Станции, Андрей Андрухович'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/QeeXBHbCgjlJ1JgdJHUq-rv5wdw"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4wOTA3OTZBNzVEMTUzOTMy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nБез понимания, что находится вокруг и где именно, беспилотному автомобилю не обойтись. Виктор рассказал, как в Яндекс решают задачу распознавания других участников дорожного движения в трёхмерном облаке точек, чем эта задача отличается от распознавания объектов на изображении и как извлечь пользу из совместного использования разных типов сенсоров.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 4,
#     'publishedAt': '2018-12-12T09:36:11.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'sARwqGY5l44'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/sddefault.jpg',
#       'width': 640}},
#     'title': 'Методы распознавания 3D-объектов для беспилотных автомобилей, Виктор Отлига'}}],
#  'kind': 'youtube#playlistItemListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 5}}

# %%
js['items'][0]['snippet']['description']
# Out:
# 'Сергей Злобин рассказывает про задачу классификации космических объектов (Kaggle PLAsTiCC Astronomical Classification), в кото...'

# %%
# Out:
# [{'duration': 4.501,
#   'start': 6.109,
#   'text': 'всем привет меня зовут сергей злобин я'},
#  {'duration': 2.85, 'start': 9.93, 'text': 'решал'},
#  {'duration': 3.9, 'start': 10.61, 'text': 'конце прошлого года проходила'},
#  {'duration': 3.87, 'start': 12.78, 'text': 'соревнование'},
#  {'duration': 5.109, 'start': 14.51, 'text': 'написано пластик астрономика'},
#  {'duration': 7.49,
#   'start': 16.65,
#   'text': 'классификация и расскажу как наша'},
#  {'duration': 6.771,
#   'start': 19.619,
#   'text': 'команда его решала ну для начала покажу'},
#  {'duration': 8.2, 'start': 24.14, 'text': 'итоговый leader board это уже'},
#  {'duration': 11.67,
#   'start': 26.39,
#   'text': 'приватный вот 13 строчка это наша'},
#  {'duration': 11.4,
#   'start': 32.34,
#   'text': 'команда вот выделена первые 12 мест были'},
#  {'duration': 10.39,
#   'start': 38.06,
#   'text': 'золотая медаль и и чуть чуть было бы на'},
#  {'duration': 6.87,
#   'start': 43.74,
#   'text': 'самом деле очень обидно потому что видно'},
#  {'duration': 4.8,
#   'start': 48.45,
#   'text': 'что проиграли мы достаточно вот в'},
#  {'duration': 4.71,
#   'start': 50.61,
#   'text': 'четвертом знаки буквально при этом если'},
#  {'duration': 4.32,
#   'start': 53.25,
#   'text': 'посмотрю принципе для карла нормальная'},
#  {'duration': 6.05,
#   'start': 55.32,
#   'text': 'ситуация что там во втором-третьем знаке'},
#  {'duration': 3.8,
#   'start': 57.57,
#   'text': 'до но если посмотреть распределение'},
#  {'duration': 7.71,
#   'start': 61.82,
#   'text': 'этого скоро то принципе там даже не во'},
#  {'duration': 7.531, 'start': 65.999, 'text': 'втором знаки дело вот 068'},
#  {'duration': 6.759,
#   'start': 69.53,
#   'text': 'лучше первое место оказалось причем на'},
#  {'duration': 5.46,
#   'start': 73.53,
#   'text': 'публичном лидер борде мы были 12 но'},
#  {'duration': 5.301,
#   'start': 76.289,
#   'text': 'случился как видно тут тоже видно что'},
#  {'duration': 5.579,
#   'start': 78.99,
#   'text': 'небольшой шейков случился на приватном'},
#  {'duration': 7.87, 'start': 81.59, 'text': 'петербурге ну все равно'},
#  {'duration': 7.141,
#   'start': 84.569,
#   'text': 'опыт был очень интересный и мы наверное'},
#  {'duration': 9.06,
#   'start': 89.46,
#   'text': 'сделали максимум того что могли на тот'},
#  {'duration': 8.899,
#   'start': 91.71,
#   'text': 'момент наша команда состояла из трех'},
#  {'duration': 4.6, 'start': 98.52, 'text': 'участников причем команда была'},
#  {'duration': 7.491, 'start': 100.609, 'text': 'интернациональная'},
#  {'duration': 7.65,
#   'start': 103.12,
#   'text': 'вот был у нас студент из австралии по'},
#  {'duration': 5.52,
#   'start': 108.1,
#   'text': 'моему такой деньги не на самом деле не'},
#  {'duration': 4.94,
#   'start': 110.77,
#   'text': 'признаны потому что он там что-то очень'},
#  {'duration': 4.8, 'start': 113.62, 'text': 'быстро все мутил'},
#  {'duration': 6.45,
#   'start': 115.71,
#   'text': 'мофт энкодеры гауссовские процессы'},
#  {'duration': 6.78, 'start': 118.42, 'text': 'какие-то по классификации'},
#  {'duration': 5.23,
#   'start': 122.16,
#   'text': 'но есть на минус у него что он такое'},
#  {'duration': 5.66,
#   'start': 125.2,
#   'text': 'больше был на исследование ориентирована'},
#  {'duration': 9.66,
#   'start': 127.39,
#   'text': 'мы хотели максимальный результат'},
#  {'duration': 9.16,
#   'start': 130.86,
#   'text': 'также была девушка физики которая на'},
#  {'duration': 7.98,
#   'start': 137.05,
#   'text': 'русскоязычная изменить родом из минска'},
#  {'duration': 9.3,
#   'start': 140.02,
#   'text': 'мы сейчас живет в ирландии зовут таня на'},
#  {'duration': 6.33,
#   'start': 145.03,
#   'text': 'как для него них блондинкам ну и также я'},
#  {'duration': 3.96,
#   'start': 149.32,
#   'text': 'ходил команду но я к ним присоединилась'},
#  {'duration': 4.35,
#   'start': 151.36,
#   'text': 'чуть позже там они начали вместе решали'},
#  {'duration': 8.46,
#   'start': 153.28,
#   'text': 'я за две недели к ним присоединился до'},
#  {'duration': 8.91,
#   'start': 155.71,
#   'text': 'конца ну немного расскажу что ввести в'},
#  {'duration': 9.24,
#   'start': 161.74,
#   'text': 'курс дела про задачу сейчас в чили'},
#  {'duration': 9.589,
#   'start': 164.62,
#   'text': 'строится телескоп новый так уже все там'},
#  {'duration': 3.229, 'start': 170.98, 'text': 'строительство заканчивается'},
#  {'duration': 7.09,
#   'start': 174.42,
#   'text': 'расшифровываться этого состоялась'},
#  {'duration': 6.39,
#   'start': 177.31,
#   'text': 'синоптик сего телескоп типа как нового'},
#  {'duration': 4.11,
#   'start': 181.51,
#   'text': 'поколения что лили телескоп у него там'},
#  {'duration': 6.99,
#   'start': 183.7,
#   'text': 'угол зрения там несколько раз больше чем'},
#  {'duration': 7.97,
#   'start': 185.62,
#   'text': 'у телескопа хаббла и планируется что там'},
#  {'duration': 6.03,
#   'start': 190.69,
#   'text': 'сутки будет 20 до 40 терабайт информации'},
#  {'duration': 8.74,
#   'start': 193.59,
#   'text': 'естественно надо abbott автоматически'},
#  {'duration': 7.8,
#   'start': 196.72,
#   'text': 'обрабатывать если интересно там можно'},
#  {'duration': 4.62,
#   'start': 202.33,
#   'text': 'деть прочитать про них ну скоро уже'},
#  {'duration': 6.32,
#   'start': 204.52,
#   'text': 'я так понимаю нужно там если не в этом'},
#  {'duration': 3.89,
#   'start': 206.95,
#   'text': 'на следующем году они должны запустится'},
#  {'duration': 7.42,
#   'start': 211.64,
#   'text': 'теперь какие данные были в задаче ну они'},
#  {'duration': 5.43,
#   'start': 217.59,
#   'text': 'наблюдают за астрономическими объектами'},
#  {'duration': 9.21,
#   'start': 219.06,
#   'text': 'например за какой-то звездой и получают'},
#  {'duration': 7.59,
#   'start': 223.02,
#   'text': 'сигналы в 6 диапазонах там есть как'},
#  {'duration': 5.939,
#   'start': 228.27,
#   'text': 'оптический диапазон типа красного и'},
#  {'duration': 5.81,
#   'start': 230.61,
#   'text': 'зеленого есть кто-то который не видно'},
#  {'duration': 6.241,
#   'start': 234.209,
#   'text': 'глазом типа ультом ультрафиолет'},
#  {'duration': 8.4,
#   'start': 236.42,
#   'text': 'какой-нибудь 6 фильтров стоит у них'},
#  {'duration': 8.96,
#   'start': 240.45,
#   'text': 'телескопе и течение нескольких дней они'},
#  {'duration': 8.01,
#   'start': 244.82,
#   'text': 'наблюдают ну они передвигают к миру и'},
#  {'duration': 7.96,
#   'start': 249.41,
#   'text': 'собирает информацию про каждый объект'},
#  {'duration': 6.36,
#   'start': 252.83,
#   'text': 'вот пример на графике какой получается'},
#  {'duration': 7.65, 'start': 257.37, 'text': 'картинка'},
#  {'duration': 6.75,
#   'start': 259.19,
#   'text': 'что интересно еще сейчас тут видно что'},
#  {'duration': 4.68, 'start': 265.02, 'text': 'есть дырки'},
#  {'duration': 8.71,
#   'start': 265.94,
#   'text': 'это соответствует тому что объект не'},
#  {'duration': 6.3,
#   'start': 269.7,
#   'text': 'всегда виден земли бывает сезоны когда'},
#  {'duration': 5.88, 'start': 274.65, 'text': 'он не виден там типа'},
#  {'duration': 8.37,
#   'start': 276.0,
#   'text': 'не не круглый год его видно на это'},
#  {'duration': 9.509,
#   'start': 280.53,
#   'text': 'данном графике представлены видно что'},
#  {'duration': 12.21,
#   'start': 284.37,
#   'text': 'есть пик какой-то да потом идет спад это'},
#  {'duration': 9.451,
#   'start': 290.039,
#   'text': 'пример сверхновой звезды и кроме данных'},
#  {'duration': 6.78,
#   'start': 296.58,
#   'text': 'таких на каждый объект еще прилагались'},
#  {'duration': 8.36,
#   'start': 299.49,
#   'text': 'каждому мета-данные в обучающей выборке'},
#  {'duration': 4.49, 'start': 303.36, 'text': 'было 14 классов объектов'},
#  {'duration': 4.72,
#   'start': 307.94,
#   'text': 'указывалось расстояние до объекта'},
#  {'duration': 4.45, 'start': 311.06, 'text': 'координаты на небе'},
#  {'duration': 6.39,
#   'start': 312.66,
#   'text': 'где его наблюдали координаты на самом'},
#  {'duration': 4.58,
#   'start': 315.51,
#   'text': 'деле и так понимаю никто толком не стал'},
#  {'duration': 7.08, 'start': 319.05, 'text': 'использовать'},
#  {'duration': 10.15,
#   'start': 320.09,
#   'text': 'поэтому был такой флаг как deep дрилем'},
#  {'duration': 5.17,
#   'start': 326.13,
#   'text': 'feels и то есть участки неба за которыми'},
#  {'duration': 4.23, 'start': 330.24, 'text': 'не'},
#  {'duration': 7.28,
#   'start': 331.3,
#   'text': 'более пристально наблюдает и более'},
#  {'duration': 8.909,
#   'start': 334.47,
#   'text': 'больше как бы не передвигает камеру там'},
#  {'duration': 7.049,
#   'start': 338.58,
#   'text': 'больше там в этом месте задерживаются и'},
#  {'duration': 7.961, 'start': 343.379, 'text': 'метаданных еще была такая'},
#  {'duration': 10.57,
#   'start': 345.629,
#   'text': 'астрономическая штука как новые смыслы и'},
#  {'duration': 8.52,
#   'start': 351.34,
#   'text': 'это как свет вымирает пока доходя до'},
#  {'duration': 11.101,
#   'start': 356.199,
#   'text': 'земли это через космическую пыль кита'},
#  {'duration': 10.44,
#   'start': 359.86,
#   'text': 'мтс их единицах астрономических на самом'},
#  {'duration': 5.519,
#   'start': 367.3,
#   'text': 'деле вот предыдущий слайд это было'},
#  {'duration': 5.7,
#   'start': 370.3,
#   'text': 'пример делать гибельный филси да когда'},
#  {'duration': 4.981,
#   'start': 372.819,
#   'text': 'за объектом пристально блюдо it но за'},
#  {'duration': 6.09,
#   'start': 376.0,
#   'text': 'большинством объектов наблюдает не так'},
#  {'duration': 6.66,
#   'start': 377.8,
#   'text': 'пристально и картинка получается вот на'},
#  {'duration': 5.94,
#   'start': 382.09,
#   'text': 'этой картинке уже не так все очевидно я'},
#  {'duration': 9.079,
#   'start': 384.46,
#   'text': 'так думаю как вот на торе что там сверху'},
#  {'duration': 8.34,
#   'start': 388.03,
#   'text': 'users терновый был вот это называется'},
#  {'duration': 6.611,
#   'start': 393.539,
#   'text': 'white фасаде по области их на самом деле'},
#  {'duration': 4.859,
#   'start': 396.37,
#   'text': 'было и обучающей выборке этим более в'},
#  {'duration': 5.069, 'start': 400.15, 'text': 'тестовой большинство'},
#  {'duration': 7.821,
#   'start': 401.229,
#   'text': 'и как бы задача осложнялась также в этих'},
#  {'duration': 3.831,
#   'start': 405.219,
#   'text': 'областях вот эти вертикальные палочки'},
#  {'duration': 7.93,
#   'start': 409.289,
#   'text': 'это ошибка измерения и в этих областях'},
#  {'duration': 7.621,
#   'start': 413.469,
#   'text': 'ошибка измерения тоже больше чем ddf'},
#  {'duration': 7.141,
#   'start': 417.219,
#   'text': 'областях но это кстати не сказал график'},
#  {'duration': 5.549, 'start': 421.09, 'text': 'это по дням внизу дни не там'},
#  {'duration': 5.1, 'start': 424.36, 'text': 'высчитываются от какого-то там'},
#  {'duration': 3.39,
#   'start': 426.639,
#   'text': 'бодро специального которое в астрономии'},
#  {'duration': 7.73, 'start': 429.46, 'text': 'принято'},
#  {'duration': 10.341,
#   'start': 430.029,
#   'text': 'но дня и сигналы яркость звезды по оси y'},
#  {'duration': 6.65, 'start': 437.19, 'text': 'поехали дальше'},
#  {'duration': 7.859, 'start': 440.37, 'text': 'метрика соревнования было'},
#  {'duration': 7.12,
#   'start': 443.84,
#   'text': 'мультилок лосс но такой вот взвешенный'},
#  {'duration': 5.94,
#   'start': 448.229,
#   'text': 'пересвеченные потому что ну во первых у'},
#  {'duration': 6.929,
#   'start': 450.96,
#   'text': 'соединялось что были более редкие классы'},
#  {'duration': 8.331,
#   'start': 454.169,
#   'text': 'и были те классы которые чаще'},
#  {'duration': 9.201,
#   'start': 457.889,
#   'text': 'встречались они носили одинаковый вклад'},
#  {'duration': 4.59, 'start': 462.5, 'text': 'в том том числе были еще'},
#  {'duration': 8.08,
#   'start': 467.18,
#   'text': 'искусственно добавлены веса на классы'},
#  {'duration': 6.48,
#   'start': 470.27,
#   'text': 'такие же ты причем получилось смешно что'},
#  {'duration': 5.01, 'start': 475.26, 'text': 'организаторы такие'},
#  {'duration': 6.91,
#   'start': 476.75,
#   'text': 'сказали мы вам их не дадим типа как'},
#  {'duration': 5.67,
#   'start': 480.27,
#   'text': 'секрет но через несколько некоторое'},
#  {'duration': 3.99,
#   'start': 483.66,
#   'text': 'время там народ на карле просто их'},
#  {'duration': 4.05,
#   'start': 485.94,
#   'text': 'вычислил там они и оказались все ли'},
#  {'duration': 4.739,
#   'start': 487.65,
#   'text': 'почти все были единицы и утра классы'},
#  {'duration': 6.679,
#   'start': 489.99,
#   'text': 'были двоечки то есть бы им больше'},
#  {'duration': 4.28, 'start': 492.389, 'text': 'предпочтение отдавалось'},
#  {'duration': 4.299, 'start': 497.18, 'text': 'что хорошо в этой'},
#  {'duration': 4.5,
#   'start': 499.47,
#   'text': 'метрики соревнования что это прям можно'},
#  {'duration': 5.671,
#   'start': 501.479,
#   'text': 'было ее засовывать как лосс в'},
#  {'duration': 4.47,
#   'start': 503.97,
#   'text': 'оптимизатор и прям эту функцию и'},
#  {'duration': 7.35,
#   'start': 507.15,
#   'text': 'оптимизировать там то есть не надо'},
#  {'duration': 9.81,
#   'start': 508.44,
#   'text': 'ничего выдумывать дополнительным теперь'},
#  {'duration': 7.919,
#   'start': 514.5,
#   'text': 'немножко про выборки обучающая выборка'},
#  {'duration': 6.75,
#   'start': 518.25,
#   'text': 'было около 8000 объекта в принципе не'},
#  {'duration': 5.431, 'start': 522.419, 'text': 'так много для обучения'},
#  {'duration': 6.06,
#   'start': 525.0,
#   'text': 'хочется сюда побольше поэтому чуть позже'},
#  {'duration': 5.91,
#   'start': 527.85,
#   'text': 'расскажу как с этим боролись а вот тесто'},
#  {'duration': 5.31,
#   'start': 531.06,
#   'text': 'выборка была огромная 33 с половиной'},
#  {'duration': 4.64,
#   'start': 533.76,
#   'text': 'миллионов объектов и занимала там 19'},
#  {'duration': 6.11,
#   'start': 536.37,
#   'text': 'гигабайта кольце с ваш ник который не'},
#  {'duration': 4.08, 'start': 538.4, 'text': 'нигде не открывался там и'},
#  {'duration': 6.33,
#   'start': 544.29,
#   'text': 'затрудняло вот этот большое количество'},
#  {'duration': 5.94,
#   'start': 547.17,
#   'text': 'теста вы раки затрудняло там еще тем что'},
#  {'duration': 4.649,
#   'start': 550.62,
#   'text': 'но если хочешь какие-то там признаки но'},
#  {'duration': 5.099,
#   'start': 553.11,
#   'text': 'обычно считали какие-то признаки ее'},
#  {'duration': 5.611,
#   'start': 555.269,
#   'text': 'сохраняли их куда ты уже вычисленные'},
#  {'duration': 6.481,
#   'start': 558.209,
#   'text': 'ну что вычислить эти признаки зачастую'},
#  {'duration': 7.23,
#   'start': 560.88,
#   'text': 'требовать старом нисколько не часов даже'},
#  {'duration': 7.399,
#   'start': 564.69,
#   'text': 'одни и там если прям тем более'},
#  {'duration': 8.789,
#   'start': 568.11,
#   'text': 'пересчете на 1 ц по утрам поэтому'},
#  {'duration': 5.951,
#   'start': 572.089,
#   'text': 'старались либо на графической видеокарте'},
#  {'duration': 3.541, 'start': 576.899, 'text': 'где можно запускать'},
#  {'duration': 5.549,
#   'start': 578.04,
#   'text': 'что там если можно было оптимизировать'},
#  {'duration': 3.53,
#   'start': 580.44,
#   'text': 'если нельзя китану какие-то признаки как'},
#  {'duration': 3.031, 'start': 583.589, 'text': 'бы не'},
#  {'duration': 5.07,
#   'start': 583.97,
#   'text': 'нельзя было оптимизировать ли мы не'},
#  {'duration': 6.24, 'start': 586.62, 'text': 'умели просто считали'},
#  {'duration': 6.34,
#   'start': 589.04,
#   'text': 'в угол облаке арендовали машину в 20'},
#  {'duration': 6.44,
#   'start': 592.86,
#   'text': 'четырьмя ядрами и там несколько часов'},
#  {'duration': 3.92,
#   'start': 595.38,
#   'text': 'они считала и считались то есть там'},
#  {'duration': 11.519,
#   'start': 600.05,
#   'text': 'такая деятельность была было 14 классов'},
#  {'duration': 4.2,
#   'start': 608.55,
#   'text': 'как быть тех которые данные выборки'},
#  {'duration': 3.341, 'start': 611.569, 'text': 'обучающие'},
#  {'duration': 4.97,
#   'start': 612.75,
#   'text': 'них были вот анонимные кодовые названия'},
#  {'duration': 6.77,
#   'start': 614.91,
#   'text': 'типа там шесть пятнадцать шестнадцать и'},
#  {'duration': 6.96,
#   'start': 617.72,
#   'text': 'так далее 95 и на графике показано'},
#  {'duration': 3.0, 'start': 621.68, 'text': 'распределение'},
#  {'duration': 4.95,
#   'start': 624.74,
#   'text': 'собственно количество объектов в'},
#  {'duration': 7.529,
#   'start': 627.3,
#   'text': 'обучающей выборки по этим классом'},
#  {'duration': 7.54,
#   'start': 629.69,
#   'text': 'что интересном там с помощью этих'},
#  {'duration': 4.531,
#   'start': 634.829,
#   'text': 'метаданных можно было разбить на'},
#  {'duration': 5.789,
#   'start': 637.23,
#   'text': 'галактические объекты которые нашей'},
#  {'duration': 5.339,
#   'start': 639.36,
#   'text': 'галактики млечный путь и те которые не в'},
#  {'duration': 6.241,
#   'start': 643.019,
#   'text': 'нашей галактике вот эту экстра экстра'},
#  {'duration': 8.791,
#   'start': 644.699,
#   'text': 'галактика и прям вот эти классы'},
#  {'duration': 6.269,
#   'start': 649.26,
#   'text': 'ну исходя исходя из информации объект'},
#  {'duration': 4.01,
#   'start': 653.49,
#   'text': 'галактики наш или или ним наши можно'},
#  {'duration': 7.56,
#   'start': 655.529,
#   'text': 'фактически половину было судить'},
#  {'duration': 8.949,
#   'start': 657.5,
#   'text': 'количество классов подходящих среди'},
#  {'duration': 5.791,
#   'start': 663.089,
#   'text': 'классов были такие классы тоже были'},
#  {'duration': 5.25,
#   'start': 666.449,
#   'text': 'канонизированы и не даны стараюсь люди'},
#  {'duration': 5.64,
#   'start': 668.88,
#   'text': 'их вычислить точно там было несколько'},
#  {'duration': 5.071,
#   'start': 671.699,
#   'text': 'типов сверхновых были переменных звезд'},
#  {'duration': 4.95, 'start': 674.52, 'text': 'и микролинзирование такому'},
#  {'duration': 5.82,
#   'start': 676.77,
#   'text': 'астрономический эффект что-то еще было'},
#  {'duration': 8.58,
#   'start': 679.47,
#   'text': 'но на самом деле в буквально на днях они'},
#  {'duration': 8.4,
#   'start': 682.59,
#   'text': 'открыли прям те данные на кота которая'},
#  {'duration': 6.72,
#   'start': 688.05,
#   'text': 'там у них раскрыли свои данные можно'},
#  {'duration': 7.16,
#   'start': 690.99,
#   'text': 'почитать какие там именно классы были'},
#  {'duration': 7.26,
#   'start': 694.77,
#   'text': 'ну как бы без знания астрономии особо'},
#  {'duration': 7.71,
#   'start': 698.15,
#   'text': 'тем более для нашей задачи особого'},
#  {'duration': 6.24,
#   'start': 702.03,
#   'text': 'смысла нет это разбирать и кстати'},
#  {'duration': 5.02,
#   'start': 705.86,
#   'text': 'зануления неподходящий классов по'},
#  {'duration': 4.17,
#   'start': 708.27,
#   'text': 'признаку просто галактики галактики о'},
#  {'duration': 5.16,
#   'start': 710.88,
#   'text': 'начале забыл как бы от например то'},
#  {'duration': 6.03,
#   'start': 712.44,
#   'text': 'сделать и просто потому что как правило'},
#  {'duration': 6.48,
#   'start': 716.04,
#   'text': 'все таки 0 не выдает классификатор там'},
#  {'duration': 7.08,
#   'start': 718.47,
#   'text': 'выдает там 006 какой-нибудь и просто да'},
#  {'duration': 4.98,
#   'start': 722.52,
#   'text': 'даже зануление они подходящих объектов'},
#  {'duration': 5.34,
#   'start': 725.55,
#   'text': 'дала выигрыш такой неплохой на лидер'},
#  {'duration': 4.98,
#   'start': 727.5,
#   'text': 'морде не забывать это делать либо она'},
#  {'duration': 4.77,
#   'start': 730.89,
#   'text': 'таки это отдельная классификатор его'},
#  {'duration': 9.12,
#   'start': 732.48,
#   'text': 'писать для этих галактики и экстра'},
#  {'duration': 7.71,
#   'start': 735.66,
#   'text': 'галактики и пошли дальше мы принципе с'},
#  {'duration': 6.59,
#   'start': 741.6,
#   'text': 'точки зрения моделях ничего особо не'},
#  {'duration': 9.75,
#   'start': 743.37,
#   'text': 'выдумали все использовали like gpm это'},
#  {'duration': 6.48,
#   'start': 748.19,
#   'text': 'градиентный бусик отобьем и какой-то'},
#  {'duration': 4.83, 'start': 753.12, 'text': 'момент еще был'},
#  {'duration': 8.41,
#   'start': 754.67,
#   'text': 'нейронная сеть просто полна связную на 4'},
#  {'duration': 9.78,
#   'start': 757.95,
#   'text': 'скрытых слоя принципе вначале они давали'},
#  {'duration': 8.61,
#   'start': 763.08,
#   'text': 'примерно одно и то же качество и неплохо'},
#  {'duration': 8.3,
#   'start': 767.73,
#   'text': 'даже их было видеть в какой-то момент'},
#  {'duration': 4.34,
#   'start': 771.69,
#   'text': 'чем по мере улучшения признаков наших'},
#  {'duration': 7.59,
#   'start': 776.18,
#   'text': 'flagyl бьем хорошо улучшался нейрон'},
#  {'duration': 4.35,
#   'start': 781.26,
#   'text': 'носить намного хуже я подозреваю что'},
#  {'duration': 4.81,
#   'start': 783.77,
#   'text': 'надо было еще специальным образом'},
#  {'duration': 5.7,
#   'start': 785.61,
#   'text': 'готовить для нейронной сети там эти'},
#  {'duration': 3.28,
#   'start': 788.58,
#   'text': 'признаки не так проста как logic games'},
#  {'duration': 3.399, 'start': 791.31, 'text': 'королем'},
#  {'duration': 5.28,
#   'start': 791.86,
#   'text': 'но в результате как-то времени на это не'},
#  {'duration': 4.341,
#   'start': 794.709,
#   'text': 'было мы сделали ставку на вычислено'},
#  {'duration': 4.98,
#   'start': 797.14,
#   'text': 'признаки добавления признаков и'},
#  {'duration': 7.599,
#   'start': 799.05,
#   'text': 'использования logic дома и готовое'},
#  {'duration': 6.11,
#   'start': 802.12,
#   'text': 'решение нейросеть у нас не маслом ну мы'},
#  {'duration': 6.18, 'start': 806.649, 'text': 'делали'},
#  {'duration': 6.88,
#   'start': 808.23,
#   'text': 'обучались на 5 фондах обычно по крайней'},
#  {'duration': 5.721,
#   'start': 812.829,
#   'text': 'мере для отбора признаков каких то'},
#  {'duration': 6.36,
#   'start': 815.11,
#   'text': 'проверки гипотез а ближе к концу'},
#  {'duration': 6.279,
#   'start': 818.55,
#   'text': 'совмещены делали на 10 photos было чуть'},
#  {'duration': 6.57, 'start': 821.47, 'text': 'чуть получше из-за этого ну и'},
#  {'duration': 7.32, 'start': 824.829, 'text': 'и итоговый наш'},
#  {'duration': 10.44,
#   'start': 828.04,
#   'text': 'score public был 0 800 15 для сравнения'},
#  {'duration': 10.261,
#   'start': 832.149,
#   'text': 'первое место было 0 670 то есть конечно'},
#  {'duration': 8.789,
#   'start': 838.48,
#   'text': 'мы далеко не дотянули но тоже не тоже'},
#  {'duration': 8.27,
#   'start': 842.41,
#   'text': 'неплохо блин да как такового особо нас'},
#  {'duration': 6.06,
#   'start': 847.269,
#   'text': 'не было мы просто обучили 2 2 модели'},
#  {'duration': 6.55,
#   'start': 850.68,
#   'text': 'чуть-чуть разные признаки имеют разные'},
#  {'duration': 4.641,
#   'start': 853.329,
#   'text': 'параметрами и вот 003 нам это чуть-чуть'},
#  {'duration': 4.289, 'start': 857.23, 'text': 'докинул'},
#  {'duration': 5.85,
#   'start': 857.97,
#   'text': 'ну тоже неплохо бы на больше уже времени'},
#  {'duration': 6.711,
#   'start': 861.519,
#   'text': 'не хватило на самом деле потому что мы'},
#  {'duration': 4.41,
#   'start': 863.82,
#   'text': 'последние дни уже все это доделываем'},
#  {'duration': 5.409,
#   'start': 870.24,
#   'text': 'скелет наше решение все-таки был'},
#  {'duration': 7.261,
#   'start': 872.589,
#   'text': 'вычисление признаков я сейчас немножко'},
#  {'duration': 5.3,
#   'start': 875.649,
#   'text': 'расскажу как как мы их считали было'},
#  {'duration': 4.5, 'start': 879.85, 'text': 'шесть каналов'},
#  {'duration': 4.151,
#   'start': 880.949,
#   'text': '6 фильтром можно считать по каждому'},
#  {'duration': 4.049, 'start': 884.35, 'text': 'каналу'},
#  {'duration': 4.89,
#   'start': 885.1,
#   'text': 'какие-то признаки можно там все по по'},
#  {'duration': 4.171, 'start': 888.399, 'text': 'всем месте как-то их считать'},
#  {'duration': 5.87,
#   'start': 889.99,
#   'text': 'агрегировать вначале естественно все там'},
#  {'duration': 3.29, 'start': 892.57, 'text': 'считали на стандартных'},
#  {'duration': 5.23,
#   'start': 895.87,
#   'text': 'стандартные признаки на вот временных'},
#  {'duration': 6.86,
#   'start': 898.49,
#   'text': 'рядов и потом минимум максимум медиана'},
#  {'duration': 4.25, 'start': 901.1, 'text': 'средняя дисперсии асимметрия'},
#  {'duration': 6.03, 'start': 905.77, 'text': 'потом все стали искать'},
#  {'duration': 5.59, 'start': 909.55, 'text': 'библиотеки в том числе'},
#  {'duration': 7.11,
#   'start': 911.8,
#   'text': 'астрономические библиотеки на которые'},
#  {'duration': 6.44,
#   'start': 915.14,
#   'text': 'могли бы помочь в итоге мы остановились'},
#  {'duration': 5.47, 'start': 918.91, 'text': 'вот изюм'},
#  {'duration': 5.32,
#   'start': 921.58,
#   'text': 'библиотека довольно много фич оттуда и'},
#  {'duration': 7.59,
#   'start': 924.38,
#   'text': 'пара fitch и спилить эти пиццы нас'},
#  {'duration': 10.35,
#   'start': 926.9,
#   'text': 'оказалось еще после того как вот эти'},
#  {'duration': 6.95,
#   'start': 931.97,
#   'text': 'прошли где особо думать не надо стали'},
#  {'duration': 5.46, 'start': 937.25, 'text': 'заниматься'},
#  {'duration': 9.33,
#   'start': 938.92,
#   'text': 'викинг за вами ficken клевых то есть'},
#  {'duration': 5.54,
#   'start': 942.71,
#   'text': 'зная примерную форму кривой пытаться ее'},
#  {'duration': 7.75,
#   'start': 948.52,
#   'text': 'под подогнать под эту кривую посчитать'},
#  {'duration': 6.42,
#   'start': 952.73,
#   'text': 'какие параметры кривой очень важно не'},
#  {'duration': 4.65,
#   'start': 956.27,
#   'text': 'только параметры кривой засовывать как'},
#  {'duration': 4.26, 'start': 959.15, 'text': 'признак ну и'},
#  {'duration': 5.07,
#   'start': 960.92,
#   'text': 'то ошибку аппроксимации которые при этом'},
#  {'duration': 5.66,
#   'start': 963.41,
#   'text': 'получилось чтоб это лишнее то мне'},
#  {'duration': 6.48, 'start': 965.99, 'text': 'засунуть ну и наконец более'},
#  {'duration': 6.24,
#   'start': 969.07,
#   'text': 'признаки которая чиста таки она знает'},
#  {'duration': 5.52,
#   'start': 972.47,
#   'text': 'астрономию почитать предметную область'},
#  {'duration': 7.78,
#   'start': 975.31,
#   'text': 'частности такой признак это звездная'},
#  {'duration': 6.0,
#   'start': 977.99,
#   'text': 'величина чуть позже расскажу стараясь'},
#  {'duration': 2.7, 'start': 983.09, 'text': 'так как'},
#  {'duration': 4.64,
#   'start': 983.99,
#   'text': 'обучающую баркова не очень большая'},
#  {'duration': 7.55, 'start': 985.79, 'text': 'старались много признаков'},
#  {'duration': 6.52,
#   'start': 988.63,
#   'text': 'не держать и постоянно их отбирали'},
#  {'duration': 4.36, 'start': 993.34, 'text': 'полезные признаки'},
#  {'duration': 8.81,
#   'start': 995.15,
#   'text': 'в итоге оказалось около 80 признаков у'},
#  {'duration': 6.26,
#   'start': 997.7,
#   'text': 'нас в конце концов мы остановились'},
#  {'duration': 9.66,
#   'start': 1004.35,
#   'text': 'использование пир mutation impotence это'},
#  {'duration': 7.65,
#   'start': 1008.77,
#   'text': 'время библиотека ели 5 это когда меняешь'},
#  {'duration': 4.99,
#   'start': 1014.01,
#   'text': 'случайно значение какого-то столбца и'},
#  {'duration': 5.48,
#   'start': 1016.42,
#   'text': 'смотришь как это влияет на результат но'},
#  {'duration': 5.43,
#   'start': 1019.0,
#   'text': 'естественно про кросс валидации мы тоже'},
#  {'duration': 4.24,
#   'start': 1021.9,
#   'text': 'контролер контролировали себя на ты же'},
#  {'duration': 8.25, 'start': 1024.43, 'text': 'не всегда это коррелировало'},
#  {'duration': 8.46,
#   'start': 1026.14,
#   'text': 'с лидер бурным но тем ни менее теперь'},
#  {'duration': 6.32,
#   'start': 1032.68,
#   'text': 'немножко расскажу про астрономические'},
#  {'duration': 5.94,
#   'start': 1034.6,
#   'text': 'вот почему полезно оказалось знать'},
#  {'duration': 6.61, 'start': 1039.0, 'text': 'предметную область'},
#  {'duration': 9.0,
#   'start': 1040.54,
#   'text': 'вначале засветила хороший признак вот'},
#  {'duration': 5.06,
#   'start': 1045.61,
#   'text': 'этот может узнает грегор сенковский из'},
#  {'duration': 5.88, 'start': 1049.54, 'text': 'польши'},
#  {'duration': 6.88,
#   'start': 1050.67,
#   'text': 'это расстояние между надежным пакетным'},
#  {'duration': 6.18,
#   'start': 1055.42,
#   'text': 'сигналами этом не сказал о сигналов еще'},
#  {'duration': 6.93,
#   'start': 1057.55,
#   'text': 'есть флаг насколько надежно он где т.д.'},
#  {'duration': 4.52,
#   'start': 1061.6,
#   'text': 'редактировано построений на нам на фоне'},
#  {'duration': 4.92, 'start': 1064.48, 'text': 'неба'},
#  {'duration': 5.59,
#   'start': 1066.12,
#   'text': 'вот это соответствует примерно если это'},
#  {'duration': 4.41,
#   'start': 1069.4,
#   'text': 'сверхновая это примерно какой-то'},
#  {'duration': 5.16,
#   'start': 1071.71,
#   'text': 'соответствовать ширине вот этого пиковым'},
#  {'duration': 5.36,
#   'start': 1073.81,
#   'text': 'сверхновой поэтому это очень полезной'},
#  {'duration': 5.43, 'start': 1076.87, 'text': 'оказалась величина'},
#  {'duration': 6.39,
#   'start': 1079.17,
#   'text': 'другая полезная величина это вот как я'},
#  {'duration': 11.49,
#   'start': 1082.3,
#   'text': 'уже горел магнитуда звездная величина'},
#  {'duration': 11.26,
#   'start': 1085.56,
#   'text': 'тут формула я представлена это то есть'},
#  {'duration': 4.65,
#   'start': 1093.79,
#   'text': 'так и исходу вы вряд ли приду если не'},
#  {'duration': 5.22,
#   'start': 1096.82,
#   'text': 'почитать их невозможно при наверно'},
#  {'duration': 5.76,
#   'start': 1098.44,
#   'text': 'придумать практически но нас связано с'},
#  {'duration': 3.33, 'start': 1102.04, 'text': 'законом что яркость обратно'},
#  {'duration': 4.38,
#   'start': 1104.2,
#   'text': 'пропорциональна квадрату расстояния'},
#  {'duration': 7.44,
#   'start': 1105.37,
#   'text': 'потому что вот этот диск мод величина'},
#  {'duration': 7.88,
#   'start': 1108.58,
#   'text': 'dice мод это логарифм то же расстояние'},
#  {'duration': 3.65, 'start': 1112.81, 'text': 'до звезды и'},
#  {'duration': 8.26,
#   'start': 1116.49,
#   'text': 'с коэффициентом 5 поэтому тут получается'},
#  {'duration': 5.66,
#   'start': 1120.28,
#   'text': 'что этот закон то есть вот dice мод он'},
#  {'duration': 3.6, 'start': 1124.75, 'text': 'был прям'},
#  {'duration': 4.42,
#   'start': 1125.94,
#   'text': 'метаданных то есть это не не про не'},
#  {'duration': 7.53,
#   'start': 1128.35,
#   'text': 'расстояние это логарифм расстояние там с'},
#  {'duration': 8.55,
#   'start': 1130.36,
#   'text': 'кем-то коэффициентом и наконец еще'},
#  {'duration': 5.48,
#   'start': 1135.88,
#   'text': 'полезным в капсом коне в самом конце мы'},
#  {'duration': 5.28, 'start': 1138.91, 'text': 'то не посчитала'},
#  {'duration': 4.75, 'start': 1141.36, 'text': 'астрономические цвета ты это'},
#  {'duration': 5.4,
#   'start': 1144.19,
#   'text': 'разность вот этих magnitude между'},
#  {'duration': 5.12,
#   'start': 1146.11,
#   'text': 'некоторыми каналами и например зеленым и'},
#  {'duration': 3.99, 'start': 1149.59, 'text': 'красным'},
#  {'duration': 5.049,
#   'start': 1151.23,
#   'text': 'там между никогда некоторыми другими'},
#  {'duration': 4.76,
#   'start': 1153.58,
#   'text': 'парами это на самом деле промежуточный'},
#  {'duration': 4.801, 'start': 1156.279, 'text': 'шаг там при вычислении'},
#  {'duration': 6.73,
#   'start': 1158.34,
#   'text': 'в странами называется как коррекция'},
#  {'duration': 6.589,
#   'start': 1161.08,
#   'text': 'сигналов на сама как коррекция нам'},
#  {'duration': 5.459,
#   'start': 1165.07,
#   'text': 'ничего не докинул а вот эта штука нам'},
#  {'duration': 6.041,
#   'start': 1167.669,
#   'text': 'такие новые причем мы ее буквально'},
#  {'duration': 7.291,
#   'start': 1170.529,
#   'text': 'посчитали там за 6 часов до окончания'},
#  {'duration': 5.969,
#   'start': 1173.71,
#   'text': 'соревнований а я на там где-то он чуть'},
#  {'duration': 9.9,
#   'start': 1177.82,
#   'text': 'ли не 002 накинула такие астрономические'},
#  {'duration': 9.901,
#   'start': 1179.679,
#   'text': 'цвета но вот эта картинка сверхновых раз'},
#  {'duration': 2.61,
#   'start': 1187.72,
#   'text': 'там было несколько типов сверхновых'},
#  {'duration': 3.0, 'start': 1189.58, 'text': 'соревнований'},
#  {'duration': 4.469,
#   'start': 1190.33,
#   'text': 'это просто картинка из интернета чтобы'},
#  {'duration': 5.959,
#   'start': 1192.58,
#   'text': 'показать что они принципе это все похожи'},
#  {'duration': 7.13, 'start': 1194.799, 'text': 'и чем они отличаются'},
#  {'duration': 7.181,
#   'start': 1198.539,
#   'text': 'но отличаются вот это магнитуда'},
#  {'duration': 7.531,
#   'start': 1201.929,
#   'text': 'собственно у них разные который про'},
#  {'duration': 8.01,
#   'start': 1205.72,
#   'text': 'которые на прошлом станет ст-1 говорил и'},
#  {'duration': 7.53,
#   'start': 1209.46,
#   'text': 'вот этой вот эта ширина пика и у них'},
#  {'duration': 6.299,
#   'start': 1213.73,
#   'text': 'чуть разное да если в них и посчитать'},
#  {'duration': 7.149,
#   'start': 1216.99,
#   'text': 'некоторые более экзотические там с двумя'},
#  {'duration': 4.98,
#   'start': 1220.029,
#   'text': 'горбами да какими то почему на'},
#  {'duration': 4.351, 'start': 1224.139, 'text': 'сверхновых ну'},
#  {'duration': 6.571,
#   'start': 1225.009,
#   'text': 'упор делали потому что они больше всего'},
#  {'duration': 9.679,
#   'start': 1228.49,
#   'text': 'путались и на них можно было больше'},
#  {'duration': 12.15,
#   'start': 1231.58,
#   'text': 'всего заработать очков поехать дальше'},
#  {'duration': 7.571,
#   'start': 1238.169,
#   'text': 'теперь немножко про подгонку кривых я'},
#  {'duration': 2.97,
#   'start': 1243.73,
#   'text': 'лично начал просто ступа с гауссовского'},
#  {'duration': 3.809, 'start': 1245.74, 'text': 'распределения'},
#  {'duration': 4.05,
#   'start': 1246.7,
#   'text': 'над параметр вот этот дисперсия'},
#  {'duration': 5.25, 'start': 1249.549, 'text': 'оценивает ширину пикой'},
#  {'duration': 9.62,
#   'start': 1250.75,
#   'text': 'и принципе это уже тоже мне добавила'},
#  {'duration': 9.0,
#   'start': 1254.799,
#   'text': 'немножко также сделал как сверхновых'},
#  {'duration': 7.269,
#   'start': 1260.37,
#   'text': 'только на логарифме с этих сигналов'},
#  {'duration': 6.451,
#   'start': 1263.799,
#   'text': 'яркости подъем и спад чтоб оценить'},
#  {'duration': 7.01,
#   'start': 1267.639,
#   'text': 'наклон вот эти которые вот на прошлом'},
#  {'duration': 4.399, 'start': 1270.25, 'text': 'сойди злодеем показывал'},
#  {'duration': 5.471, 'start': 1274.859, 'text': 'также из статьи'},
#  {'duration': 7.37,
#   'start': 1277.809,
#   'text': 'борьба zen это много на самом деле'},
#  {'duration': 7.049,
#   'start': 1280.33,
#   'text': 'авторов такое параметрическое уравнение'},
#  {'duration': 4.81, 'start': 1285.179, 'text': 'тут часть есть часть которая'},
#  {'duration': 4.77,
#   'start': 1287.379,
#   'text': 'соответствует подъему сигналов'},
#  {'duration': 8.701,
#   'start': 1289.989,
#   'text': 'сверхновых и часть которая затухание'},
#  {'duration': 8.97,
#   'start': 1292.149,
#   'text': 'сигнала и ну и вот когда после подгонки'},
#  {'duration': 6.179,
#   'start': 1298.69,
#   'text': 'кривой можно вот эти параметры получить'},
#  {'duration': 7.26,
#   'start': 1301.119,
#   'text': 'которые как потом засунуть их уже как'},
#  {'duration': 6.24,
#   'start': 1304.869,
#   'text': 'признак пробовали другие кривые в том'},
#  {'duration': 3.92,
#   'start': 1308.379,
#   'text': 'числе вот с двумя пиками как я показывал'},
#  {'duration': 5.31, 'start': 1311.109, 'text': 'на прошлом слайде'},
#  {'duration': 11.74,
#   'start': 1312.299,
#   'text': 'сожалению нам не помогло точно не знаем'},
#  {'duration': 8.61,
#   'start': 1316.419,
#   'text': 'почему да еще был такой загадочный класс'},
#  {'duration': 4.59, 'start': 1324.039, 'text': '99'},
#  {'duration': 6.6,
#   'start': 1325.029,
#   'text': 'его не было в обучающей выборке то есть'},
#  {'duration': 6.091,
#   'start': 1328.629,
#   'text': 'это надо было как бы идея такая что'},
#  {'duration': 5.071,
#   'start': 1331.629,
#   'text': 'нужно сделать надежную модель которая не'},
#  {'duration': 5.939,
#   'start': 1334.72,
#   'text': 'только основном среди известно классов'},
#  {'duration': 6.0,
#   'start': 1336.7,
#   'text': 'скажет что вот этот класс она еще скажет'},
#  {'duration': 5.94,
#   'start': 1340.659,
#   'text': 'что что это может быть что-то другое'},
#  {'duration': 6.809,
#   'start': 1342.7,
#   'text': 'такая идея ну так как обучающей выборке'},
#  {'duration': 7.621,
#   'start': 1346.599,
#   'text': 'нет чуть делать там не очень понятно и'},
#  {'duration': 7.35,
#   'start': 1349.509,
#   'text': 'на форуме обсуждали и многие результате'},
#  {'duration': 7.459,
#   'start': 1354.22,
#   'text': 'остановились вот участник оливер'},
#  {'duration': 8.101,
#   'start': 1356.859,
#   'text': 'придумал такую форму надо взять просто'},
#  {'duration': 7.75,
#   'start': 1361.679,
#   'text': 'вероятности других классов вычесть их из'},
#  {'duration': 7.73,
#   'start': 1364.96,
#   'text': 'единиц и перемножить и это в какой-то'},
#  {'duration': 5.07,
#   'start': 1369.429,
#   'text': 'мере будет оценка вот этого класса 99'},
#  {'duration': 3.909,
#   'start': 1372.69,
#   'text': 'единственно что вот этот коэффициент'},
#  {'duration': 4.4,
#   'start': 1374.499,
#   'text': 'надо эмпирически подбирать по лидер'},
#  {'duration': 2.3, 'start': 1376.599, 'text': 'бурду'},
#  {'duration': 3.4,
#   'start': 1379.3,
#   'text': 'то есть распределение вот этого сколько'},
#  {'duration': 2.82, 'start': 1382.13, 'text': 'там этих'},
#  {'duration': 5.72,
#   'start': 1382.7,
#   'text': 'класс авианосца 9 на тесто выборки'},
#  {'duration': 10.26,
#   'start': 1384.95,
#   'text': 'неизвестны вот просто петербург probing'},
#  {'duration': 9.03,
#   'start': 1388.42,
#   'text': 'помогал да еще была более загадочная'},
#  {'duration': 6.33,
#   'start': 1395.21,
#   'text': 'формула появилась среди не соревнования'},
#  {'duration': 6.49,
#   'start': 1397.45,
#   'text': 'участника скорпов он использовал тут'},
#  {'duration': 6.06,
#   'start': 1401.54,
#   'text': 'средние медианы и максимум и заставил из'},
#  {'duration': 4.92,
#   'start': 1403.94,
#   'text': 'них вот такую хитрую формулу как он'},
#  {'duration': 5.97, 'start': 1407.6, 'text': 'пишет что он получил от'},
#  {'duration': 8.7,
#   'start': 1408.86,
#   'text': 'генетическим алгоритмом в подробности не'},
#  {'duration': 10.11,
#   'start': 1413.57,
#   'text': 'вдавался и и вот он это я прям же'},
#  {'duration': 10.79,
#   'start': 1417.56,
#   'text': 'записал как он записал а тут эта строчка'},
#  {'duration': 8.94,
#   'start': 1423.68,
#   'text': 'я просто у просите упростил немножко'},
#  {'duration': 8.58,
#   'start': 1428.35,
#   'text': 'чтобы было по чуть понятнее ну физически'},
#  {'duration': 4.31,
#   'start': 1432.62,
#   'text': 'смысла не очень ясен она работала причем'},
#  {'duration': 7.0,
#   'start': 1438.76,
#   'text': 'ждем работа лучше той форму вот по'},
#  {'duration': 5.49,
#   'start': 1441.92,
#   'text': 'крайней мере вот на наших тех моделях'},
#  {'duration': 4.74,
#   'start': 1445.76,
#   'text': 'что мы делали на чуть лучше работал кто'},
#  {'duration': 4.44,
#   'start': 1447.41,
#   'text': 'то писал что у него типа не прочие'},
#  {'duration': 4.5,
#   'start': 1450.5,
#   'text': 'практически ничего не изменилось или'},
#  {'duration': 4.56,
#   'start': 1451.85,
#   'text': 'даже стало чуть уже у нас несколько раз'},
#  {'duration': 4.83, 'start': 1455.0, 'text': 'во лидировали эту формулу'},
#  {'duration': 6.87,
#   'start': 1456.41,
#   'text': 'она нас постоянно там может на 001 там'},
#  {'duration': 6.81,
#   'start': 1459.83,
#   'text': 'ли 002 чуть лучше давала мы остановились'},
#  {'duration': 4.37,
#   'start': 1463.28,
#   'text': 'на ней теперь я хотел просто показать'},
#  {'duration': 5.34, 'start': 1466.64, 'text': 'ещё'},
#  {'duration': 5.29,
#   'start': 1467.65,
#   'text': 'победитель соревнования он по-другому'},
#  {'duration': 4.16, 'start': 1471.98, 'text': 'подошел'},
#  {'duration': 7.56,
#   'start': 1472.94,
#   'text': 'точнее подошел то он также только'},
#  {'duration': 6.55,
#   'start': 1476.14,
#   'text': 'придумал другую формулу и каким-то'},
#  {'duration': 4.92,
#   'start': 1480.5,
#   'text': 'образом он догадался что вот этот класс'},
#  {'duration': 6.93,
#   'start': 1482.69,
#   'text': '99 он как-то связан со сверхновыми'},
#  {'duration': 8.04,
#   'start': 1485.42,
#   'text': 'и вот эти классы 4250 2 6 1 95'},
#  {'duration': 5.189,
#   'start': 1489.62,
#   'text': 'классы сверхновых там разные типы и он'},
#  {'duration': 4.5, 'start': 1493.46, 'text': 'просто взял и'},
#  {'duration': 7.291,
#   'start': 1494.809,
#   'text': 'как ты взвесил эти вероятности этих'},
#  {'duration': 6.99,
#   'start': 1497.96,
#   'text': 'классов и это и мы вот очень сильно если'},
#  {'duration': 8.01,
#   'start': 1502.1,
#   'text': 'посмотреть как он пишет что ему это вот'},
#  {'duration': 8.79,
#   'start': 1504.95,
#   'text': 'на 005 до кино но на самом деле мало кто'},
#  {'duration': 6.33,
#   'start': 1510.11,
#   'text': 'догадался до этого ну то есть эти люди'},
#  {'duration': 3.84,
#   'start': 1513.74,
#   'text': 'только топик от победе мы что-то сделали'},
#  {'duration': 4.08, 'start': 1516.44, 'text': 'такое нетривиальное'},
#  {'duration': 7.32,
#   'start': 1517.58,
#   'text': 'ну нет нет нет не так как все вот как мы'},
#  {'duration': 7.53,
#   'start': 1520.52,
#   'text': 'как например на стадии когда после того'},
#  {'duration': 7.409,
#   'start': 1524.9,
#   'text': 'как сейчас еще раскрыли навести на'},
#  {'duration': 8.22,
#   'start': 1528.05,
#   'text': 'данные можно посчитать там как без'},
#  {'duration': 7.141,
#   'start': 1532.309,
#   'text': 'классно 99 и фактически получилось что'},
#  {'duration': 4.83,
#   'start': 1536.27,
#   'text': 'этот колдун первое место он реально на'},
#  {'duration': 4.979,
#   'start': 1539.45,
#   'text': 'втором месте если как бы не учитывать'},
#  {'duration': 6.78,
#   'start': 1541.1,
#   'text': 'класс 99 то есть снять следующее за ним'},
#  {'duration': 5.731,
#   'start': 1544.429,
#   'text': 'участники они вы были на первом месте то'},
#  {'duration': 8.1,
#   'start': 1547.88,
#   'text': 'есть фактически трюк ему позволил на'},
#  {'duration': 8.6,
#   'start': 1550.16,
#   'text': 'первыми строить так как данных мало мы'},
#  {'duration': 4.11,
#   'start': 1555.98,
#   'text': 'решили сделать аргументацию данных'},
#  {'duration': 4.81, 'start': 1558.76, 'text': 'облака'},
#  {'duration': 6.9,
#   'start': 1560.09,
#   'text': 'было дано ошибка измерения вертикальная'},
#  {'duration': 7.88,
#   'start': 1563.57,
#   'text': 'палочка которая показывал вначале это'},
#  {'duration': 8.569,
#   'start': 1566.99,
#   'text': 'будет было специально дано flux'},
#  {'duration': 4.109, 'start': 1571.45, 'text': 'ошибка измерения мы просто'},
#  {'duration': 6.78,
#   'start': 1575.62,
#   'text': 'раздули в начале в 10 раз выборку потом'},
#  {'duration': 6.75, 'start': 1578.48, 'text': 'в 30 раз ближе к концу'},
#  {'duration': 6.4,
#   'start': 1582.4,
#   'text': 'просто нормальным распределением с этой'},
#  {'duration': 7.25,
#   'start': 1585.23,
#   'text': 'ошибкой подкорректировали сигналы и это'},
#  {'duration': 6.68, 'start': 1588.8, 'text': 'действительно улучшило'},
#  {'duration': 3.0, 'start': 1592.48, 'text': 'score'},
#  {'duration': 8.551,
#   'start': 1597.539,
#   'text': 'но ближе к концу соревнования где то за'},
#  {'duration': 8.61,
#   'start': 1600.629,
#   'text': 'неделю мы застряли в районе 0 85 то есть'},
#  {'duration': 6.48,
#   'start': 1606.09,
#   'text': 'уже там с двумя горбами какими-то'},
#  {'duration': 6.17,
#   'start': 1609.239,
#   'text': 'вычисляли признаки там еще че-то там'},
#  {'duration': 5.25, 'start': 1612.57, 'text': 'делали ничего не помогало'},
#  {'duration': 6.52,
#   'start': 1615.409,
#   'text': 'поняли что мы видимо уже все там'},
#  {'duration': 9.659,
#   'start': 1617.82,
#   'text': 'переучились на обучающей уборку объектов'},
#  {'duration': 9.36,
#   'start': 1621.929,
#   'text': 'мало и решили раздуть еще больше десяти'},
#  {'duration': 7.02,
#   'start': 1627.479,
#   'text': 'раз до 30 но при этом мы осознали'},
#  {'duration': 7.26,
#   'start': 1631.289,
#   'text': 'до нас дошло наконец что вот этот'},
#  {'duration': 8.04,
#   'start': 1634.499,
#   'text': 'ddf который я говорил области их в'},
#  {'duration': 7.35,
#   'start': 1638.549,
#   'text': 'обучающей выборке владеть процентов в'},
#  {'duration': 6.541,
#   'start': 1642.539,
#   'text': 'тестовый только один процент поэтому мы'},
#  {'duration': 5.311,
#   'start': 1645.899,
#   'text': 'раздали так что вот эти ddf региона вы и'},
#  {'duration': 3.39,
#   'start': 1649.08,
#   'text': 'практически только в одном фланге'},
#  {'duration': 7.049, 'start': 1651.21, 'text': 'оставили из 30'},
#  {'duration': 7.86,
#   'start': 1652.47,
#   'text': 'и таким образом мы выровняли примерно то'},
#  {'duration': 4.081,
#   'start': 1658.259,
#   'text': 'что в тост с таким был и отвагу'},
#  {'duration': 5.549,
#   'start': 1660.33,
#   'text': 'монтированы с точки зрения ddf по'},
#  {'duration': 6.179,
#   'start': 1662.34,
#   'text': 'крайней мере так же стали просто я'},
#  {'duration': 7.941,
#   'start': 1665.879,
#   'text': 'открыл манула вот как-то уменьшить'},
#  {'duration': 9.51,
#   'start': 1668.519,
#   'text': 'переобучение влад живем и стали пытаться'},
#  {'duration': 6.099,
#   'start': 1673.82,
#   'text': 'следовать советам и это при этом она'},
#  {'duration': 4.71,
#   'start': 1678.029,
#   'text': 'кросс валидации было чуть хуже там они'},
#  {'duration': 7.26,
#   'start': 1679.919,
#   'text': 'не сильно зато намного лучше на лидер'},
#  {'duration': 6.841,
#   'start': 1682.739,
#   'text': 'бурге вот то есть мы уменьшили глубину'},
#  {'duration': 4.71,
#   'start': 1687.179,
#   'text': 'дерево чувство листьев и вот это'},
#  {'duration': 6.809,
#   'start': 1689.58,
#   'text': 'интересный параметр макс бен там по'},
#  {'duration': 8.72,
#   'start': 1691.889,
#   'text': 'дефолту 255 если его довольно сильно'},
#  {'duration': 4.22,
#   'start': 1696.389,
#   'text': 'уменьшить то тоже хороший был выигрыш'},
#  {'duration': 8.19,
#   'start': 1701.76,
#   'text': 'что у нас не получилось вот питер там у'},
#  {'duration': 8.61,
#   'start': 1705.06,
#   'text': 'тела в тайн кадры принципе картинки'},
#  {'duration': 6.6,
#   'start': 1709.95,
#   'text': 'караки картинки красивые были но как'},
#  {'duration': 4.89,
#   'start': 1713.67,
#   'text': 'результат это на результате никак не'},
#  {'duration': 4.71, 'start': 1716.55, 'text': 'сказалось много пробовали'},
#  {'duration': 6.45,
#   'start': 1718.56,
#   'text': 'параметрических кривых из разных статей'},
#  {'duration': 7.05,
#   'start': 1721.26,
#   'text': 'там таня прошерстила много статей как'},
#  {'duration': 7.14,
#   'start': 1725.01,
#   'text': 'такими кривыми дома аппроксимировать в'},
#  {'duration': 5.09,
#   'start': 1728.31,
#   'text': 'астрономии тоже ничего дополнительно нам'},
#  {'duration': 4.47, 'start': 1732.15, 'text': 'не докинул'},
#  {'duration': 6.82,
#   'start': 1733.4,
#   'text': 'пытались питер опять же там гауссовские'},
#  {'duration': 5.46,
#   'start': 1736.62,
#   'text': 'просто процессы исследовал это у нее там'},
#  {'duration': 4.59,
#   'start': 1740.22,
#   'text': 'не сошлось хотя вот потом дальше'},
#  {'duration': 5.91, 'start': 1742.08, 'text': 'расскажу победителя'},
#  {'duration': 6.3, 'start': 1744.81, 'text': 'это было он их использовал'},
#  {'duration': 6.71,
#   'start': 1747.99,
#   'text': 'ну не смогли ничего сделать классом 99'},
#  {'duration': 7.46,
#   'start': 1751.11,
#   'text': 'вот проводит такая интересная штука есть'},
#  {'duration': 5.32,
#   'start': 1754.7,
#   'text': 'и и классификация это когда есть много'},
#  {'duration': 7.27, 'start': 1758.57, 'text': 'положительный пример'},
#  {'duration': 7.74,
#   'start': 1760.02,
#   'text': 'примеров и немного не размечен есть не'},
#  {'duration': 4.35,
#   'start': 1765.84,
#   'text': 'очень большое количество примеров как бы'},
#  {'duration': 6.66,
#   'start': 1767.76,
#   'text': 'размечены есть много не размеченных'},
#  {'duration': 9.12,
#   'start': 1770.19,
#   'text': 'примеров и как как как вот можно'},
#  {'duration': 8.13,
#   'start': 1774.42,
#   'text': 'неизвестный класс вылавливать но ничего'},
#  {'duration': 5.46,
#   'start': 1779.31,
#   'text': 'не дало так подозреваю дало потому что'},
#  {'duration': 5.04,
#   'start': 1782.55,
#   'text': 'вот они специально так сделали около 99'},
#  {'duration': 7.5,
#   'start': 1784.77,
#   'text': 'что он все-таки похож на сверхновые то'},
#  {'duration': 8.79,
#   'start': 1787.59,
#   'text': 'есть я вот открыл просто буквально два'},
#  {'duration': 6.74,
#   'start': 1792.27,
#   'text': 'три дня назад опубликовали там там были'},
#  {'duration': 2.63, 'start': 1796.38, 'text': 'сверхновая'},
#  {'duration': 5.59,
#   'start': 1800.39,
#   'text': 'ну что мы это сделали правильно это'},
#  {'duration': 4.08,
#   'start': 1803.52,
#   'text': 'объединились в команду потому что я'},
#  {'duration': 3.81,
#   'start': 1805.98,
#   'text': 'думаю каждый из нас будет такого'},
#  {'duration': 5.4,
#   'start': 1807.6,
#   'text': 'результата в одиночку не достиг и вообще'},
#  {'duration': 6.51,
#   'start': 1809.79,
#   'text': 'полезно очень обсуждать ну интересно же'},
#  {'duration': 6.76,
#   'start': 1813.0,
#   'text': 'как бы обсуждать чудила дальше мы читали'},
#  {'duration': 7.36,
#   'start': 1816.3,
#   'text': 'много статей на как люди раньше'},
#  {'duration': 6.6,
#   'start': 1819.76,
#   'text': 'к этой проблеме подбирались что уже'},
#  {'duration': 6.99,
#   'start': 1823.66,
#   'text': 'сделано какие могут быть признаки'},
#  {'duration': 8.82,
#   'start': 1826.36,
#   'text': 'полезны задавали вопросы на форуме и'},
#  {'duration': 8.34,
#   'start': 1830.65,
#   'text': 'когда и вдс лаки задавали нам отвечали'},
#  {'duration': 5.4,
#   'start': 1835.18,
#   'text': 'зачастую нам помогал им ну естественно'},
#  {'duration': 4.32, 'start': 1838.99, 'text': 'много чего пробовать надо'},
#  {'duration': 5.76,
#   'start': 1840.58,
#   'text': 'говорю что много-много чайник не'},
#  {'duration': 5.72,
#   'start': 1843.31,
#   'text': 'получилось но что то что то было в итоге'},
#  {'duration': 6.27,
#   'start': 1846.34,
#   'text': 'эффект и не сдаваться до конца вот'},
#  {'duration': 6.13,
#   'start': 1849.03,
#   'text': 'потому что буквально за последние три'},
#  {'duration': 5.85,
#   'start': 1852.61,
#   'text': 'дня мы там очень сильно улучшились когда'},
#  {'duration': 6.84,
#   'start': 1855.16,
#   'text': 'мы осознали наши ошибки и даже последний'},
#  {'duration': 6.63,
#   'start': 1858.46,
#   'text': 'день таня с этими астрономическими'},
#  {'duration': 9.0,
#   'start': 1862.0,
#   'text': 'цветами таки для мучила и это нам тоже'},
#  {'duration': 9.21,
#   'start': 1865.09,
#   'text': 'помогло и расскажу еще один слайд у меня'},
#  {'duration': 4.28,
#   'start': 1871.0,
#   'text': 'как победитель решал этой задачей его'},
#  {'duration': 5.06, 'start': 1874.3, 'text': 'зовут кайл бун'},
#  {'duration': 5.77,
#   'start': 1875.28,
#   'text': 'на самом деле похоже на то что мы делали'},
#  {'duration': 4.18, 'start': 1879.36, 'text': 'только у него'},
#  {'duration': 4.65,
#   'start': 1881.05,
#   'text': 'у нас и стать самым астрономы поэтому он'},
#  {'duration': 5.66,
#   'start': 1883.54,
#   'text': 'еще в там катушки в теме этой всей и'},
#  {'duration': 3.5, 'start': 1885.7, 'text': 'занимается сверхновыми'},
#  {'duration': 6.311,
#   'start': 1890.929,
#   'text': 'так что немножко не удивительно что но'},
#  {'duration': 6.781,
#   'start': 1894.179,
#   'text': 'тем не менее он в одиночку смог это'},
#  {'duration': 4.74,
#   'start': 1897.24,
#   'text': 'сделать он сделал аргументировал в 40'},
#  {'duration': 4.65, 'start': 1900.96, 'text': 'раз в лучшую'},
#  {'duration': 9.03,
#   'start': 1901.98,
#   'text': 'обучающую выборку и худшие качества'},
#  {'duration': 8.67,
#   'start': 1905.61,
#   'text': 'дайте ddf пробудив эти хорошие кривые'},
#  {'duration': 5.37,
#   'start': 1911.01,
#   'text': 'я часть точек убирал чтобы это было'},
#  {'duration': 4.26,
#   'start': 1914.28,
#   'text': 'стало больше похоже на тесто выборка'},
#  {'duration': 5.21,
#   'start': 1916.38,
#   'text': 'у него так и получилось использовать'},
#  {'duration': 3.05, 'start': 1918.54, 'text': 'миасские процессы'},
#  {'duration': 6.88,
#   'start': 1922.34,
#   'text': 'интерполяции кривых что ли если такой'},
#  {'duration': 8.61,
#   'start': 1925.35,
#   'text': 'вот пример собственно как и как это он'},
#  {'duration': 7.41,
#   'start': 1929.22,
#   'text': 'его картинка интерполяцией помощью'},
#  {'duration': 4.77,
#   'start': 1933.96,
#   'text': 'гауссовских почему гауссовский у него'},
#  {'duration': 3.06,
#   'start': 1936.63,
#   'text': 'там купишь что он был двумерное делал'},
#  {'duration': 3.75, 'start': 1938.73, 'text': 'там то есть еще и'},
#  {'duration': 8.46,
#   'start': 1939.69,
#   'text': 'сигналы как бы тоже входит вот эти'},
#  {'duration': 9.8,
#   'start': 1942.48,
#   'text': 'каналы у него было около 200 признаков'},
#  {'duration': 5.94,
#   'start': 1948.15,
#   'text': 'как на исходных данных сигналов таки на'},
#  {'duration': 6.1,
#   'start': 1952.28,
#   'text': 'предсказанных после гауссовского'},
#  {'duration': 8.04,
#   'start': 1954.09,
#   'text': 'процесса и просто у него лак db модель'},
#  {'duration': 9.24,
#   'start': 1958.38,
#   'text': 'на 5 фондовых было ну раз уж я сказал'},
#  {'duration': 7.5,
#   'start': 1962.13,
#   'text': 'что слизь если и класс 99 убрать то он'},
#  {'duration': 3.99,
#   'start': 1967.62,
#   'text': 'бы проиграл 2 место второе место'},
#  {'duration': 5.789,
#   'start': 1969.63,
#   'text': 'все-таки более такой традиционный у них'},
#  {'duration': 6.36,
#   'start': 1971.61,
#   'text': 'было с точки зрения когда у них там 9'},
#  {'duration': 5.491, 'start': 1975.419, 'text': 'моделей было не со стыками'},
#  {'duration': 5.88, 'start': 1977.97, 'text': 'и основная модель у них было'},
#  {'duration': 7.05,
#   'start': 1980.91,
#   'text': 'рекуррентная сеть на самом деле'},
#  {'duration': 9.209,
#   'start': 1983.85,
#   'text': 'ред это понимала к тому кто вот отличный'},
#  {'duration': 6.87,
#   'start': 1987.96,
#   'text': 'от ладьи модели там использовал и танина'},
#  {'duration': 4.531, 'start': 1993.059, 'text': 'рекуррентные сети rio city'},
#  {'duration': 5.839,
#   'start': 1994.83,
#   'text': 'сделали модель там тоже выложили можно'},
#  {'duration': 3.079, 'start': 1997.59, 'text': 'посмотреть интересно'},
#  {'duration': 10.62,
#   'start': 2002.039,
#   'text': 'спасибо за внимание спасибо вопросы а'},
#  {'duration': 4.689,
#   'start': 2013.86,
#   'text': 'можешь поподробнее рассказать про'},
#  {'duration': 6.21,
#   'start': 2016.12,
#   'text': 'аргументация то есть но вот у него были'},
#  {'duration': 7.291,
#   'start': 2018.549,
#   'text': 'табличные данные и как он выполнил в эти'},
#  {'duration': 9.329,
#   'start': 2022.33,
#   'text': 'аугментации как вот это победители да но'},
#  {'duration': 11.549,
#   'start': 2025.84,
#   'text': 'он я честно говоря сам еще на самом деле'},
#  {'duration': 9.331,
#   'start': 2031.659,
#   'text': 'он обещал выложить код и по-видимому там'},
#  {'duration': 7.951,
#   'start': 2037.389,
#   'text': 'можно будет посмотреть на самом деле я'},
#  {'duration': 6.509,
#   'start': 2040.99,
#   'text': 'видел вот и другие писали ним там второе'},
#  {'duration': 7.049,
#   'start': 2045.34,
#   'text': 'место они монтировали полон 30 процентов'},
#  {'duration': 7.561,
#   'start': 2047.499,
#   'text': 'выкидывали этих сигналов но они еще при'},
#  {'duration': 4.46,
#   'start': 2052.389,
#   'text': 'этом там очень осторожно там с'},
#  {'duration': 4.14,
#   'start': 2055.06,
#   'text': 'остальными признан с остальными'},
#  {'duration': 7.83,
#   'start': 2056.849,
#   'text': 'данными обходились там просто есть'},
#  {'duration': 5.479,
#   'start': 2059.2,
#   'text': 'всякие там faded активности сигналов там'},
#  {'duration': 4.93,
#   'start': 2065.28,
#   'text': 'красное смещение и так далее надо их'},
#  {'duration': 3.75,
#   'start': 2068.53,
#   'text': 'тоже как-то либо аргументировать там'},
#  {'duration': 4.139,
#   'start': 2070.21,
#   'text': 'либо как-то чтобы они правдоподобные'},
#  {'duration': 3.66,
#   'start': 2072.28,
#   'text': 'были то есть мы мы довольно тупым и'},
#  {'duration': 3.411,
#   'start': 2074.349,
#   'text': 'просто вот по нормальному распределению'},
#  {'duration': 5.76, 'start': 2075.94, 'text': 'по ошибке'},
#  {'duration': 6.369,
#   'start': 2077.76,
#   'text': 'как ещё можно делать но вот лучше читать'},
#  {'duration': 5.429,
#   'start': 2081.7,
#   'text': 'потому что я как бы подробно не могу'},
#  {'duration': 5.911,
#   'start': 2084.129,
#   'text': 'рассказать ещё победители было 200 фич а'},
#  {'duration': 6.151,
#   'start': 2087.129,
#   'text': 'у вас сколько у нас около 80 потому что'},
#  {'duration': 6.99,
#   'start': 2090.04,
#   'text': 'мы старались не переучиться старались'},
#  {'duration': 5.97,
#   'start': 2093.28,
#   'text': 'уменьшать количество fitch отбирать фичи'},
#  {'duration': 6.27,
#   'start': 2097.03,
#   'text': 'если они как бы не помогают скоро мы их'},
#  {'duration': 8.13,
#   'start': 2099.25,
#   'text': 'убирали то есть я просто списал что 200'},
#  {'duration': 6.299,
#   'start': 2103.3,
#   'text': 'он подробно там решение написанного в'},
#  {'duration': 5.34,
#   'start': 2107.38,
#   'text': 'коде наверное можно почитать него если'},
#  {'duration': 6.031,
#   'start': 2109.599,
#   'text': 'интересно ну то есть он взял все фичи он'},
#  {'duration': 5.57,
#   'start': 2112.72,
#   'text': 'не стал фильтровать да про про'},
#  {'duration': 7.49,
#   'start': 2115.63,
#   'text': 'фильтрацию ничего не писал в этом'},
#  {'duration': 8.16,
#   'start': 2118.29,
#   'text': 'брать топи своем совершении как как он'},
#  {'duration': 8.25,
#   'start': 2123.12,
#   'text': 'там viral не набирал я не знаю еще'},
#  {'duration': 11.57,
#   'start': 2126.45,
#   'text': 'вопросы остались какие то идеи которые'},
#  {'duration': 6.65,
#   'start': 2131.37,
#   'text': 'не успели реализовать такую немножко'},
#  {'duration': 6.19,
#   'start': 2138.59,
#   'text': 'хорошего просто но самом деле мне'},
#  {'duration': 5.4,
#   'start': 2142.11,
#   'text': 'кажется мы вот с гауссовским процессами'},
#  {'duration': 5.3,
#   'start': 2144.78,
#   'text': 'возились возились было ощущение что они'},
#  {'duration': 7.65,
#   'start': 2147.51,
#   'text': 'вот что-то могут дать там и на форуме'},
#  {'duration': 9.58,
#   'start': 2150.08,
#   'text': 'принципе писали там что вот есть'},
#  {'duration': 11.52,
#   'start': 2155.16,
#   'text': 'известный участника c 7 себе найду его'},
#  {'duration': 7.65,
#   'start': 2159.66,
#   'text': 'фотку и он тоже писал что вот ближе к'},
#  {'duration': 4.68, 'start': 2166.68, 'text': 'концу там'},
#  {'duration': 7.95,
#   'start': 2167.31,
#   'text': 'теплом гауссовским процессы это круто но'},
#  {'duration': 5.4,
#   'start': 2171.36,
#   'text': 'уже времени на из время на исходе и типа'},
#  {'duration': 4.2,
#   'start': 2175.26,
#   'text': 'меня тоже ничего не получилось также у'},
#  {'duration': 5.4,
#   'start': 2176.76,
#   'text': 'нас как бы вы че ты что-то питер делал'},
#  {'duration': 6.45,
#   'start': 2179.46,
#   'text': 'дьявол но времени не хватило хотя вроде'},
#  {'duration': 6.51,
#   'start': 2182.16,
#   'text': 'действительно они были многообещающие то'},
#  {'duration': 4.28,
#   'start': 2185.91,
#   'text': 'есть что-то еще там как бы даже не знаем'},
#  {'duration': 4.47, 'start': 2188.67, 'text': 'сходу'},
#  {'duration': 4.69,
#   'start': 2190.19,
#   'text': 'потому что of tanks ударном тоже сад n'},
#  {'duration': 3.72,
#   'start': 2193.14,
#   'text': 'кадром надежды мало было потому что то'},
#  {'duration': 5.15,
#   'start': 2194.88,
#   'text': 'не получилось вот глазки процессы это'},
#  {'duration': 3.17, 'start': 2196.86, 'text': 'нам спасибо'},
#  {'duration': 3.1,
#   'start': 2202.57,
#   'text': 'скажите пожалуйста как на ваш взгляд'},
#  {'duration': 2.88, 'start': 2204.65, 'text': 'всегда ли'},
#  {'duration': 4.35,
#   'start': 2205.67,
#   'text': 'одной из приоритетных задач на оставить'},
#  {'duration': 4.829,
#   'start': 2207.53,
#   'text': 'поиск камфорных классов исходить из них'},
#  {'duration': 5.72,
#   'start': 2210.02,
#   'text': 'или не всегда это целесообразно будущем'},
#  {'duration': 7.201,
#   'start': 2212.359,
#   'text': 'то есть ответ краткосрочный эффект'},
#  {'duration': 7.39,
#   'start': 2215.74,
#   'text': 'опорных классов да то что вот как раз он'},
#  {'duration': 6.93,
#   'start': 2219.56,
#   'text': 'исходил только и сверхновых а на самом'},
#  {'duration': 5.07,
#   'start': 2223.13,
#   'text': 'деле это мы просто смотрели я таня'},
#  {'duration': 4.879,
#   'start': 2226.49,
#   'text': 'просила вставить а че ты решил не'},
#  {'duration': 6.09, 'start': 2228.2, 'text': 'вставлять постоянно рисовали'},
#  {'duration': 5.021,
#   'start': 2231.369,
#   'text': 'матрицу вот confusion matrix модем как'},
#  {'duration': 2.88,
#   'start': 2234.29,
#   'text': 'они показ и путаются и принципе было'},
#  {'duration': 2.79, 'start': 2236.39, 'text': 'видно что'},
#  {'duration': 6.21,
#   'start': 2237.17,
#   'text': 'сверхновая между собой путаются в'},
#  {'duration': 7.23,
#   'start': 2239.18,
#   'text': 'основном то есть поэтому форма как бы на'},
#  {'duration': 5.16,
#   'start': 2243.38,
#   'text': 'них делали потому что ну все остальные'},
#  {'duration': 7.35,
#   'start': 2246.41,
#   'text': 'классы более-менее по вот тем признакам'},
#  {'duration': 7.01,
#   'start': 2248.54,
#   'text': 'которых по стандартным там по из этих'},
#  {'duration': 4.41,
#   'start': 2253.76,
#   'text': 'целей умы других библиотек и они'},
#  {'duration': 4.33,
#   'start': 2255.55,
#   'text': 'более-менее как-то вот они и хорошее'},
#  {'duration': 5.27,
#   'start': 2258.17,
#   'text': 'качество уже было поэтому ему добивали'},
#  {'duration': 3.56, 'start': 2259.88, 'text': 'вот эти сверхновые в основном'}]

# %%
url_channel_playlist = 'https://www.googleapis.com/youtube/v3/playlists?part=snippet&channelId={CHANNEL_ID}&key={API_KEY}&maxResults=49&pageToken=CDEQAA'

# %%
r = requests.get(url_channel_playlist.format(CHANNEL_ID=channel_ids['event_space_by_video'], API_KEY=API))

# %%
js2 = json.loads(r.text)

# %%
js2['nextPageToken']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-9a3c04f7323d> in <module>
# ----> 1 js2['nextPageToken']
#
# KeyError: 'nextPageToken'

# %%
pl1 = [js['items'][i]  for i in range(len(js['items'])) if 'data' in js['items'][i]['snippet']['title'].lower()]

# %%
pl2 = [js2['items'][i] for i in range(len(js2['items'])) if 'data' in js2['items'][i]['snippet']['title'].lower()]

# %%
pl1[0]
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/laqnYl6IyfWaWiZK5Qk-HM-TNtY"',
#  'id': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#  'kind': 'youtube#playlist',
#  'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#   'channelTitle': 'EventSpaceBy Video',
#   'description': '',
#   'localized': {'description': '', 'title': 'Data Ёлка в Минске 2018'},
#   'publishedAt': '2018-12-12T09:27:21.000Z',
#   'thumbnails': {'default': {'height': 90,
#     'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#     'width': 480},
#    'maxres': {'height': 720,
#     'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#     'width': 1280},
#    'medium': {'height': 180,
#     'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#     'width': 320},
#    'standard': {'height': 480,
#     'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#     'width': 640}},
#   'title': 'Data Ёлка в Минске 2018'}}

# %%
import pandas as pd

# %%
# ?pd.DataFrame

# %%
pl1
# Out:
# [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/laqnYl6IyfWaWiZK5Qk-HM-TNtY"',
#   'id': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Data Ёлка в Минске 2018'},
#    'publishedAt': '2018-12-12T09:27:21.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#      'width': 640}},
#    'title': 'Data Ёлка в Минске 2018'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rzbXRXRg70iajhRD_2QxEelyxn4"',
#   'id': 'PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#    'localized': {'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#     'title': 'Open Data Science November Meetup'},
#    'publishedAt': '2018-11-08T13:12:35.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science November Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wJA8gAcH47HcbXg_00edw92E_e8"',
#   'id': 'PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science September Meetup'},
#    'publishedAt': '2018-09-17T12:07:32.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science September Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3dnACfSlP4xFuZ0Zr8IgGREGJmI"',
#   'id': 'PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Data Fest² Minsk 2018'},
#    'publishedAt': '2018-06-04T13:50:17.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/sddefault.jpg',
#      'width': 640}},
#    'title': 'Data Fest² Minsk 2018'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/d8dermSzyxN9XwaGrNSS_J9gqX8"',
#   'id': 'PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Open Data Science April Meetup'},
#    'publishedAt': '2018-04-19T07:01:41.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science April Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BPse8qYbI_ofaVafYf1AYHsMyYo"',
#   'id': 'PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science March Meetup #2'},
#    'publishedAt': '2018-03-27T10:40:51.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science March Meetup #2'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zccfrD6MnPR1va5nSsamdY_MBzs"',
#   'id': 'PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Open Data Science March Meetup'},
#    'publishedAt': '2018-03-12T13:00:40.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science March Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FCNp3pv_lCnNT6atgQcpzM-yLJQ"',
#   'id': 'PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science December Meetup'},
#    'publishedAt': '2018-01-08T15:19:58.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science December Meetup'}}]

# %%
data = [(item['id'], item['snippet']['title'], item['snippet']['publishedAt'], 
         item['snippet']['channelTitle']) for item in pl1+pl2]

# %%
df = pd.DataFrame(data, columns=['id', 'title', 'publishedAt', 'channelTitle'])

# %%
df
# Out:
#                                     id                               title  \
# 0   PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T             Data Ёлка в Минске 2018
# 1   PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh   Open Data Science November Meetup
# 2   PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT  Open Data Science September Meetup
# 3   PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_               Data Fest² Minsk 2018
# 4   PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk      Open Data Science April Meetup
# 5   PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y   Open Data Science March Meetup #2
# 6   PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke      Open Data Science March Meetup
# 7   PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG   Open Data Science December Meetup
# 8   PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1    Open Data Science October Meetup
# 9   PLpVeA1tdgfCCLSWY6fIfZe64U9K39tgQm          Open Data Science Meetup#1
# 10  PLpVeA1tdgfCCpxs5GTQ2G3xfyqw3xwh4p              Data Fest Belarus 2017
#
#                  publishedAt        channelTitle
# 0   2018-12-12T09:27:21.000Z  EventSpaceBy Video
# 1   2018-11-08T13:12:35.000Z  EventSpaceBy Video
# 2   2018-09-17T12:07:32.000Z  EventSpaceBy Video
# 3   2018-06-04T13:50:17.000Z  EventSpaceBy Video
# 4   2018-04-19T07:01:41.000Z  EventSpaceBy Video
# 5   2018-03-27T10:40:51.000Z  EventSpaceBy Video
# 6   2018-03-12T13:00:40.000Z  EventSpaceBy Video
# 7   2018-01-08T15:19:58.000Z  EventSpaceBy Video
# 8   2017-11-08T13:02:53.000Z  EventSpaceBy Video
# 9   2017-08-25T15:02:20.000Z  EventSpaceBy Video
# 10  2017-05-22T15:25:24.000Z  EventSpaceBy Video

# %%
url_playlist = 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet%2C+id&playlistId={ID}&key={API_KEY}&maxResults=49'

# %%
r = requests.get(url_playlist.format(ID='PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T', API_KEY=API))

# %%
js_videos = json.loads(r.text)

# %%
len(js_videos['items'])
# Out:
# 5

# %%
from time import sleep

# %%
video_items = []
for IDX in df['id']:
    print(IDX)
    sleep(3)
    r = requests.get(url_playlist.format(ID=IDX, API_KEY=API))
    jss = [json.loads(r.text)]
    while 'nextPageToken' in json.loads(r.text):
        r = requests.get(url_playlist.format(ID=IDX, API_KEY=API) + \
                         '&nextPageToken={}'.format(json.loads(r.text)['nextPageToken']))
        jss.append(json.loads(r.text))
    
    for js in jss:
        for item in js['items']:
            video_items.append((item['id'], item['snippet']['title'], item['snippet']['publishedAt'],
                               item['snippet']['description'], item['snippet']['resourceId']['videoId']))
# Out:
# PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T
# PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh
# PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT
# PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_
# PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk
# PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y
# PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke
# PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG
# PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1
# PLpVeA1tdgfCCLSWY6fIfZe64U9K39tgQm
# PLpVeA1tdgfCCpxs5GTQ2G3xfyqw3xwh4p

# %%
df_vid = pd.DataFrame(video_items, columns=['id', 'title', 'publishedAt', 'description', 'youtube_id'])

# %%
df_vid.to_csv('ods_video_index.csv', index=None)

# %%
df_vid.columns
# Out:
# Index(['id', 'title', 'publishedAt', 'description', 'youtube_id'], dtype='object')

# %%
transcripts = []
for idx in df_vid['youtube_id']:
    print(idx)
    sleep(2)
    transcripts.append(YouTubeTranscriptApi.get_transcript(idx))
# Out:
# FEzjzTSHlDs
# 2dhwd-dYZhI
# -HwjbfQ80WY
# q_Vc0c4CXqU
# sARwqGY5l44
# r7OuZ2aOHH0
# x3I0yR-_hZs
# MMYYXADsavM
# 20KEvvhiFLo
# -jtqT5DihPc
# _1EZOtu77w0
# v7aank8k7w8
# gpzEQujiTwg
# 6ZlfYm2xgtY
# H6zZGNAF2pU
# v6Wv01GJQnI
# ldAJHmT7hgY
# GkuAU-RRG5o
# cpv3VF_olGw
# Dlih_a2-4gU
# vxkZ0JULC88
# VoBrYyeV-iA
# N8Yvn9MDD0g
# AWAJiv5ZCPY
# K3Q9gfrCGkI
# 53--DNGmHng
# PjTVS9n2yLQ
# uK4hPD12YmI
# HuJyLIis6ts
# oEZSg79e03I
# hqxLSXMgaF4
# TwIi7zoiiPs
# OFOp_zmljfg
# 4Xbz_wKX2Gw
# 5oqdfBqok94
# 80QO8TjuDBE
# 2_I2x0KV_z4
# Ozm0bEi5KaI
# n_mZYbVtVEM
# 607N7GuTKzg
# xglXoAIxzkc
# kzkJNpSSaNE
# xZ6YSVrTBuY
# 63WTkPr2mSw
# l43hszLm-SU
# dCIM1EZ1WX4
# AYK7_RGZ4Vw
# mVmcL7gmZVo
# 7VRAWuf-bFs
# a_Bh0lLq36E
# 3kbm-Doo89Y
# 9vYkwD0feb4
# vZjm28HmqUY
# d_-y7v-qHVE
# ZBwxRww_EYo
# ERROR:youtube_transcript_api._api:Could not get the transcript for the video https://www.youtube.com/watch?v=ZBwxRww_EYo! Most likely subtitles have been disabled by the uploader or the video is no longer available.
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/youtube_transcript_api/_api.py in get_transcript(video_id)
#      72         try:
# ---> 73             return _TranscriptParser(_TranscriptFetcher(video_id).fetch()).parse()
#      74         except Exception:
#
# /usr/local/lib/python3.5/dist-packages/youtube_transcript_api/_api.py in parse(self)
#     120             }
# --> 121             for xml_element in ElementTree.fromstring(self.plain_data)
#     122         ]
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in XML(text, parser)
#    1332         parser = XMLParser(target=TreeBuilder())
# -> 1333     parser.feed(text)
#    1334     return parser.close()
#
# ParseError: not well-formed (invalid token): line 1, column 968
#
# During handling of the above exception, another exception occurred:
#
# CouldNotRetrieveTranscript                Traceback (most recent call last)
# <ipython-input-132-53d7283d9c43> in <module>
#       3     print(idx)
#       4     sleep(2)
# ----> 5     transcripts.append(YouTubeTranscriptApi.get_transcript(idx))
#
# /usr/local/lib/python3.5/dist-packages/youtube_transcript_api/_api.py in get_transcript(video_id)
#      78                 )
#      79             )
# ---> 80             raise YouTubeTranscriptApi.CouldNotRetrieveTranscript(video_id)
#      81
#      82
#
# CouldNotRetrieveTranscript: Could not get the transcript for the video https://www.youtube.com/watch?v=ZBwxRww_EYo! Most likely subtitles have been disabled by the uploader or the video is no longer available.

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript('QbujATVCmAM')

# %%
len(transcripts)
# Out:
# 54

# %%
id2trans = {}
for i, idx in enumerate(transcripts):
    id2trans[df_vid['youtube_id'][i]] = idx

# %%
import pickle
pickle.dump(id2trans, open('id2transcripts.pkl', 'wb'))

# %%
transcripts[1]
# Out:
# [{'duration': 5.141,
#   'start': 4.609,
#   'text': 'добрый день меня зовут алексей я являюсь'},
#  {'duration': 4.53,
#   'start': 7.83,
#   'text': 'разработчиком минской группы разработки'},
#  {'duration': 4.71,
#   'start': 9.75,
#   'text': 'факторов в свою очередь мы входе в более'},
#  {'duration': 5.1,
#   'start': 12.36,
#   'text': 'крупное подразделение такой как служба'},
#  {'duration': 4.71,
#   'start': 14.46,
#   'text': 'релевантности лингвистики где более 50'},
#  {'duration': 2.819,
#   'start': 17.46,
#   'text': 'разработчиков большая часть которая'},
#  {'duration': 3.72, 'start': 19.17, 'text': 'находится в москве'},
#  {'duration': 5.91,
#   'start': 20.279,
#   'text': 'но нас всех объединяет единая задача это'},
#  {'duration': 5.67,
#   'start': 22.89,
#   'text': 'делать поиск лучше эта задача сама по'},
#  {'duration': 4.83,
#   'start': 26.189,
#   'text': 'себе не тривиальная исследовательская'},
#  {'duration': 6.06,
#   'start': 28.56,
#   'text': 'для этого компания нам предоставляет все'},
#  {'duration': 5.88,
#   'start': 31.019,
#   'text': 'возможные ресурсы у нас даже в рамках'},
#  {'duration': 4.83,
#   'start': 34.62,
#   'text': 'компании есть своя квота для того чтобы'},
#  {'duration': 4.5,
#   'start': 36.899,
#   'text': 'другие службы нам не мешали хотя с'},
#  {'duration': 3.66,
#   'start': 39.45,
#   'text': 'разговоров с ним я понял что они считают'},
#  {'duration': 6.451,
#   'start': 41.399,
#   'text': 'что это сделано чтобы мы им не мешали'},
#  {'duration': 7.01,
#   'start': 43.11,
#   'text': 'при этом у нас идет постоянно какое-то'},
#  {'duration': 5.189, 'start': 47.85, 'text': 'внутреннее обучение семинары'},
#  {'duration': 4.99,
#   'start': 50.12,
#   'text': 'неограниченный там много материалов'},
#  {'duration': 4.381,
#   'start': 53.039,
#   'text': 'внутри сети находится кроме того куча'},
#  {'duration': 4.08,
#   'start': 55.11,
#   'text': 'международных конференций только на'},
#  {'duration': 5.36,
#   'start': 57.42,
#   'text': 'следующий год уже на нашу службу'},
#  {'duration': 6.42,
#   'start': 59.19,
#   'text': 'запланирована 19 международных поездок'},
#  {'duration': 6.4,
#   'start': 62.78,
#   'text': 'сегодня же я расскажу вам пример того'},
#  {'duration': 6.299,
#   'start': 65.61,
#   'text': 'как один из способов как мы улучшали'},
#  {'duration': 6.2,
#   'start': 69.18,
#   'text': 'наш поиск как мы делаем вы бы лучше за'},
#  {'duration': 5.85,
#   'start': 71.909,
#   'text': 'счет такой вещи как расширение запроса'},
#  {'duration': 5.41,
#   'start': 75.38,
#   'text': 'давайте с того начнем вообще что такое'},
#  {'duration': 5.131,
#   'start': 77.759,
#   'text': 'запрос ну принято считать что запрос это'},
#  {'duration': 4.439,
#   'start': 80.79,
#   'text': 'обращение пользователя к индексу'},
#  {'duration': 5.46,
#   'start': 82.89,
#   'text': 'с какой-то своей проблемой за решением'},
#  {'duration': 5.611,
#   'start': 85.229,
#   'text': 'совсем другое дело это как он эту самую'},
#  {'duration': 4.559,
#   'start': 88.35,
#   'text': 'проблему формулирует как правило это до'},
#  {'duration': 5.58,
#   'start': 90.84,
#   'text': 'пяти слов словах могут встречаться'},
#  {'duration': 5.731,
#   'start': 92.909,
#   'text': 'опечатки и ошибки аббревиатуры и что'},
#  {'duration': 4.62,
#   'start': 96.42,
#   'text': 'более сложная мысль не всегда закончена'},
#  {'duration': 5.04,
#   'start': 98.64,
#   'text': 'то есть даже не человек не всегда может'},
#  {'duration': 6.509,
#   'start': 101.04,
#   'text': 'понять что же собственно хотят сейчас'},
#  {'duration': 5.85,
#   'start': 103.68,
#   'text': 'найти в рассмотрим пример турция что еще'},
#  {'duration': 3.481,
#   'start': 107.549,
#   'text': 'ты ищет о том что это за страна'},
#  {'duration': 3.39,
#   'start': 109.53,
#   'text': 'либо может быть какие-то локальные'},
#  {'duration': 3.479,
#   'start': 111.03,
#   'text': 'новости региона либо сейчас там'},
#  {'duration': 4.04,
#   'start': 112.92,
#   'text': 'пользователь рассматривает куда ему'},
#  {'duration': 5.551, 'start': 114.509, 'text': 'летом поехать отдохнуть'},
#  {'duration': 5.08,
#   'start': 116.96,
#   'text': 'давайте схематично изобразим как весь'},
#  {'duration': 5.04,
#   'start': 120.06,
#   'text': 'поиск работает вот у нас есть некий'},
#  {'duration': 3.48,
#   'start': 122.04,
#   'text': 'запрос по этому запросу в сети мы первым'},
#  {'duration': 2.729, 'start': 125.1, 'text': 'делом'},
#  {'duration': 4.859,
#   'start': 125.52,
#   'text': 'находим все документы которые возможно'},
#  {'duration': 4.501,
#   'start': 127.829,
#   'text': 'были бы пользователю интересны и уже на'},
#  {'duration': 2.621,
#   'start': 130.379,
#   'text': 'следующем этапе мы эти документы'},
#  {'duration': 3.88, 'start': 132.33, 'text': 'отбираем'},
#  {'duration': 5.88,
#   'start': 133.0,
#   'text': 'сортируем и показываем потом человек'},
#  {'duration': 5.49,
#   'start': 136.21,
#   'text': 'смотрит на это и если мы все нравится'},
#  {'duration': 5.34,
#   'start': 138.88,
#   'text': 'нашел он решения на свою проблему он'},
#  {'duration': 4.74,
#   'start': 141.7,
#   'text': 'заканчивает иначе он уточняет этот'},
#  {'duration': 3.75,
#   'start': 144.22,
#   'text': 'запрос и начинает все заново так вот'},
#  {'duration': 3.48,
#   'start': 146.44,
#   'text': 'наша основная задача сделать так чтобы'},
#  {'duration': 3.87,
#   'start': 147.97,
#   'text': 'вот эти вот обратных циклов то есть'},
#  {'duration': 3.08,
#   'start': 149.92,
#   'text': 'уточнение этих запросов было как можно'},
#  {'duration': 4.11, 'start': 151.84, 'text': 'меньше'},
#  {'duration': 4.72,
#   'start': 153.0,
#   'text': 'так рассмотрим первый этап поиска'},
#  {'duration': 4.8,
#   'start': 155.95,
#   'text': 'документов здесь наша главная задача'},
#  {'duration': 5.22,
#   'start': 157.72,
#   'text': 'ничего не упустить то есть найти все'},
#  {'duration': 4.44,
#   'start': 160.75,
#   'text': 'документы которые возможно пользователю'},
#  {'duration': 5.37,
#   'start': 162.94,
#   'text': 'были интересны как это делается при'},
#  {'duration': 5.42,
#   'start': 165.19,
#   'text': 'помощи запросов расширения запросов'},
#  {'duration': 6.24,
#   'start': 168.31,
#   'text': 'возьмем исправим там все опечатки'},
#  {'duration': 6.82,
#   'start': 170.61,
#   'text': 'раскроем там все аббревиатуры добавим к'},
#  {'duration': 5.13,
#   'start': 174.55,
#   'text': 'слова синонимы определим какой-то тип'},
#  {'duration': 5.73,
#   'start': 177.43,
#   'text': 'запроса и в зависимости от этого добавим'},
#  {'duration': 6.42,
#   'start': 179.68,
#   'text': 'наименование там его пункта где он живет'},
#  {'duration': 7.44,
#   'start': 183.16,
#   'text': 'либо каких то ключевых слов как скачать'},
#  {'duration': 6.33,
#   'start': 186.1,
#   'text': 'купить посмотреть и так далее в итоге у'},
#  {'duration': 4.8,
#   'start': 190.6,
#   'text': 'нас маленький запрос превратился в'},
#  {'duration': 5.55,
#   'start': 192.43,
#   'text': 'большой стала картинка выглядит вот так'},
#  {'duration': 4.8,
#   'start': 195.4,
#   'text': 'и шину и поэтому мы ищем все документы'},
#  {'duration': 4.86,
#   'start': 197.98,
#   'text': 'что сейчас утверждается утверждается что'},
#  {'duration': 4.62,
#   'start': 200.2,
#   'text': 'это делать мы имеем очень классно ну то'},
#  {'duration': 5.0,
#   'start': 202.84,
#   'text': 'есть вот реально нету таких документов'},
#  {'duration': 5.88,
#   'start': 204.82,
#   'text': 'которые бы мы сейчас не нашли почти нету'},
#  {'duration': 4.899,
#   'start': 207.84,
#   'text': 'остается переходим к следующей задаче'},
#  {'duration': 4.38,
#   'start': 210.7,
#   'text': 'следующая задача это правильно их'},
#  {'duration': 3.291,
#   'start': 212.739,
#   'text': 'отранжировать и вывести только самые'},
#  {'duration': 3.24, 'start': 215.08, 'text': 'полезные для него'},
#  {'duration': 4.03,
#   'start': 216.03,
#   'text': 'как это сделать вспомним пример с'},
#  {'duration': 4.62,
#   'start': 218.32,
#   'text': 'турцией что ему показывать опять же'},
#  {'duration': 4.59,
#   'start': 220.06,
#   'text': 'какой из вариантов выбрать как сделать'},
#  {'duration': 3.329,
#   'start': 222.94,
#   'text': 'так чтобы он потом не посмотрел на'},
#  {'duration': 3.51,
#   'start': 224.65,
#   'text': 'выдачу сказать не ребят но я же совсем'},
#  {'duration': 5.22,
#   'start': 226.269,
#   'text': 'другой имел ввиду что ж вы творите и'},
#  {'duration': 6.419,
#   'start': 228.16,
#   'text': 'уточнять запрос мы это сделаем сами за'},
#  {'duration': 6.121,
#   'start': 231.489,
#   'text': 'него какая идея вот есть один его запрос'},
#  {'duration': 5.791,
#   'start': 234.579,
#   'text': 'превратим его запрос в несколько'},
#  {'duration': 5.28,
#   'start': 237.61,
#   'text': 'десятков альтернативных и по каждому из'},
#  {'duration': 5.25,
#   'start': 240.37,
#   'text': 'них сами еще поищем и в зависимости от'},
#  {'duration': 4.8,
#   'start': 242.89,
#   'text': 'этого сформируем выдачу то есть мы'},
#  {'duration': 4.32,
#   'start': 245.62,
#   'text': 'сделаем такие более умные расширения'},
#  {'duration': 5.31,
#   'start': 247.69,
#   'text': 'рассмотрим на примере первого человека'},
#  {'duration': 6.57,
#   'start': 249.94,
#   'text': 'мы сами за пользователя поищем и когда'},
#  {'duration': 5.31,
#   'start': 253.0,
#   'text': 'он появился и как беде он появился и'},
#  {'duration': 3.27,
#   'start': 256.51,
#   'text': 'возможно даже вспомним что первые люди'},
#  {'duration': 4.53, 'start': 258.31, 'text': 'были в игре престолов'},
#  {'duration': 4.639,
#   'start': 259.78,
#   'text': 'потом результаты всего этого соберем и'},
#  {'duration': 4.32, 'start': 262.84, 'text': 'уже потом'},
#  {'duration': 4.871,
#   'start': 264.419,
#   'text': 'выведем это пользователю что такое вес'},
#  {'duration': 4.77,
#   'start': 267.16,
#   'text': 'расширения вес расширения условно это'},
#  {'duration': 5.07,
#   'start': 269.29,
#   'text': 'вероятность того что пользователю было'},
#  {'duration': 6.18,
#   'start': 271.93,
#   'text': 'бы еще интересно увидеть вот результат'},
#  {'duration': 6.39,
#   'start': 274.36,
#   'text': 'по вот этому расширению первый подход'},
#  {'duration': 5.97,
#   'start': 278.11,
#   'text': 'увидел свет в четырнадцатом году мы'},
#  {'duration': 6.47,
#   'start': 280.75,
#   'text': 'тогда заимствовали идеи рекомендательных'},
#  {'duration': 5.809,
#   'start': 284.08,
#   'text': 'систем именно построим такую табличку'},
#  {'duration': 5.199,
#   'start': 287.22,
#   'text': 'строками и и будут все наши запросы'},
#  {'duration': 4.181,
#   'start': 289.889,
#   'text': 'столбцы соответственно это сайты на'},
#  {'duration': 4.62,
#   'start': 292.419,
#   'text': 'пересечении поставим некую статистику'},
#  {'duration': 5.129,
#   'start': 294.07,
#   'text': 'рассчитанную по результатам того как'},
#  {'duration': 4.35,
#   'start': 297.039,
#   'text': 'часто пользователи по такому-то запросу'},
#  {'duration': 7.711,
#   'start': 299.199,
#   'text': 'переходят на этот сайт как много времени'},
#  {'duration': 8.191,
#   'start': 301.389,
#   'text': 'там проводят и так далее потом мы можем'},
#  {'duration': 4.97,
#   'start': 306.91,
#   'text': 'сейчас близость двух запросов определять'},
#  {'duration': 5.28,
#   'start': 309.58,
#   'text': 'просто как косинус на и расстояние между'},
#  {'duration': 5.05,
#   'start': 311.88,
#   'text': 'двумя векторами рассмотрим вот этот'},
#  {'duration': 4.74,
#   'start': 314.86,
#   'text': 'немного шуточный пример словно если'},
#  {'duration': 4.28,
#   'start': 316.93,
#   'text': 'пользователь будет искать как ему без'},
#  {'duration': 3.539, 'start': 319.6, 'text': 'особых усилий получить диплом'},
#  {'duration': 4.45,
#   'start': 321.21,
#   'text': 'автоматических его запросу будут'},
#  {'duration': 3.121,
#   'start': 323.139,
#   'text': 'добавлены про карьерный рост личностное'},
#  {'duration': 2.939, 'start': 325.66, 'text': 'развитие'},
#  {'duration': 4.17,
#   'start': 326.26,
#   'text': 'что в своем результате немного понизит'},
#  {'duration': 3.421,
#   'start': 328.599,
#   'text': 'нерелевантные сайты как белорусский'},
#  {'duration': 3.989,
#   'start': 330.43,
#   'text': 'государственный университет получить'},
#  {'duration': 4.709,
#   'start': 332.02,
#   'text': 'диплом там не так уж просто но при этом'},
#  {'duration': 4.171,
#   'start': 334.419,
#   'text': 'более сомнительно учебные заведения'},
#  {'duration': 4.291,
#   'start': 336.729,
#   'text': 'поднимутся вверх более того мы даже'},
#  {'duration': 3.75,
#   'start': 338.59,
#   'text': 'сможем предсказать будущее место работы'},
#  {'duration': 2.78, 'start': 341.02, 'text': 'такого пользователя с таким-то'},
#  {'duration': 4.74, 'start': 342.34, 'text': 'отношением'},
#  {'duration': 5.53,
#   'start': 343.8,
#   'text': 'ну ладно а если посмотреть реальный'},
#  {'duration': 3.87,
#   'start': 347.08,
#   'text': 'пример то когда вы ищете не можете'},
#  {'duration': 4.11, 'start': 349.33, 'text': 'вспомнить например мультик про'},
#  {'duration': 4.17,
#   'start': 350.95,
#   'text': 'робота-уборщика параллельно к вашему'},
#  {'duration': 3.57,
#   'start': 353.44,
#   'text': 'запросу будут добавлены следующее'},
#  {'duration': 4.62,
#   'start': 355.12,
#   'text': 'расширение сразу и про робот мультик'},
#  {'duration': 6.15,
#   'start': 357.01,
#   'text': 'робот валли сразу и про то что его'},
#  {'duration': 6.59,
#   'start': 359.74,
#   'text': 'посмотреть и вот ваш запрос результат'},
#  {'duration': 6.03,
#   'start': 363.16,
#   'text': 'окажется окажется достаточно хорошим'},
#  {'duration': 4.899,
#   'start': 366.33,
#   'text': 'какие здесь есть недостатки недостатки в'},
#  {'duration': 3.78,
#   'start': 369.19,
#   'text': 'том что вот эту самую таблицу мы можем'},
#  {'duration': 4.381,
#   'start': 371.229,
#   'text': 'строить только для тех запросов где у'},
#  {'duration': 5.69,
#   'start': 372.97,
#   'text': 'нас много статистики то есть для более'},
#  {'duration': 5.52,
#   'start': 375.61,
#   'text': 'редких запросов мы построить ее не можем'},
#  {'duration': 4.66,
#   'start': 378.66,
#   'text': 'следующий тип расширений появился уже в'},
#  {'duration': 5.13,
#   'start': 381.13,
#   'text': 'пятнадцатом году здесь давайте строить'},
#  {'duration': 5.58,
#   'start': 383.32,
#   'text': 'граф вот у нас есть запрос от него мы'},
#  {'duration': 4.17,
#   'start': 386.26,
#   'text': 'перелили посмотрим все сайты которые на'},
#  {'duration': 3.93,
#   'start': 388.9,
#   'text': 'которые пользователи по этому запросу'},
#  {'duration': 4.47,
#   'start': 390.43,
#   'text': 'переходили следующем вот уровням мы'},
#  {'duration': 3.53, 'start': 392.83, 'text': 'построим все запросы с которых'},
#  {'duration': 3.59, 'start': 394.9, 'text': 'переходили на эти сайты'},
#  {'duration': 4.549,
#   'start': 396.36,
#   'text': 'вот вот эти запросы обведенный в рамку'},
#  {'duration': 5.37,
#   'start': 398.49,
#   'text': 'мы скажем да будут они расширениями и'},
#  {'duration': 5.651,
#   'start': 400.909,
#   'text': 'после этого присвоим каждому ребру'},
#  {'duration': 4.559,
#   'start': 403.86,
#   'text': 'вес условно вероятность перехода запроса'},
#  {'duration': 3.53,
#   'start': 406.56,
#   'text': 'на сайт ну и соответственно что на этот'},
#  {'duration': 4.5,
#   'start': 408.419,
#   'text': 'сайт перешли по какому-то запросу'},
#  {'duration': 5.799,
#   'start': 410.09,
#   'text': 'расширению и рассчитаем вот таким вот'},
#  {'duration': 4.8,
#   'start': 412.919,
#   'text': 'образом вес если кто знаком с блуждания'},
#  {'duration': 5.071,
#   'start': 415.889,
#   'text': 'мина графах то это просто вероятность'},
#  {'duration': 4.13,
#   'start': 417.719,
#   'text': 'перейти с отсюда вот сюда сумма по всем'},
#  {'duration': 3.09, 'start': 420.96, 'text': 'путям'},
#  {'duration': 4.09,
#   'start': 421.849,
#   'text': 'это тоже оказывается очень круто'},
#  {'duration': 2.88,
#   'start': 424.05,
#   'text': 'работает здесь примерно запрос первый'},
#  {'duration': 2.79, 'start': 425.939, 'text': 'человек в космосе'},
#  {'duration': 4.019,
#   'start': 426.93,
#   'text': 'вам сразу будет одно из расширений'},
#  {'duration': 4.201,
#   'start': 428.729,
#   'text': 'добавлен сразу же готовый ответ что'},
#  {'duration': 3.69,
#   'start': 430.949,
#   'text': 'приведет к тому что результат очень'},
#  {'duration': 3.509,
#   'start': 432.93,
#   'text': 'классные вы сразу получаете объектный'},
#  {'duration': 6.231,
#   'start': 434.639,
#   'text': 'ответ и можете дальше уже ничего не'},
#  {'duration': 7.021,
#   'start': 436.439,
#   'text': 'искать подведем промежуточные итоги'},
#  {'duration': 5.5,
#   'start': 440.87,
#   'text': 'сейчас у нас есть для каждого расширения'},
#  {'duration': 6.12,
#   'start': 443.46,
#   'text': 'регулярно обновляемые таблицы каждая'},
#  {'duration': 5.639,
#   'start': 446.37,
#   'text': 'примерно на 100 миллиард строк кроме'},
#  {'duration': 4.649,
#   'start': 449.58,
#   'text': 'того каждый день мы регистрируем по 200'},
#  {'duration': 5.101,
#   'start': 452.009,
#   'text': 'миллионов обращений к этому таблицы что'},
#  {'duration': 5.611,
#   'start': 454.229,
#   'text': 'от общего количества означает что более'},
#  {'duration': 3.869,
#   'start': 457.11,
#   'text': 'половины запросов попадают и для более'},
#  {'duration': 3.99, 'start': 459.84, 'text': 'плане запросов у нас уже есть'},
#  {'duration': 6.9,
#   'start': 460.979,
#   'text': 'рассчитанной расширение и это работает'},
#  {'duration': 6.059,
#   'start': 463.83,
#   'text': 'очень быстро что же можно улучшать но'},
#  {'duration': 3.9,
#   'start': 467.879,
#   'text': 'давайте сделаем так чтоб у нас не'},
#  {'duration': 5.49,
#   'start': 469.889,
#   'text': 'половина запросов умело расширения а'},
#  {'duration': 5.221,
#   'start': 471.779,
#   'text': 'сделаем чтобы все запросы собственно мы'},
#  {'duration': 5.82,
#   'start': 475.379,
#   'text': 'начали эксперименты с нейронными сетями'},
#  {'duration': 6.27,
#   'start': 477.0,
#   'text': 'и решили сделать так возьмем сиамскую'},
#  {'duration': 4.861,
#   'start': 481.199,
#   'text': 'сеть у нас уже есть готовые таблицы'},
#  {'duration': 6.54,
#   'start': 483.27,
#   'text': 'запросов расширений и весов и таким вот'},
#  {'duration': 5.969,
#   'start': 486.06,
#   'text': 'образом и и обучим что после этого мы'},
#  {'duration': 4.169,
#   'start': 489.81,
#   'text': 'говорим давайте последний слой нейронной'},
#  {'duration': 5.88,
#   'start': 492.029,
#   'text': 'сети перед косинусов с перед косинусом'},
#  {'duration': 5.581,
#   'start': 493.979,
#   'text': 'это нашим bedding для самых частых'},
#  {'duration': 4.201,
#   'start': 497.909,
#   'text': 'расширений мы все этим бединге'},
#  {'duration': 5.159,
#   'start': 499.56,
#   'text': 'рассчитаем и положим некий и в некий'},
#  {'duration': 4.169,
#   'start': 502.11,
#   'text': 'яндекс и теперь приходящий запрос'},
#  {'duration': 3.961,
#   'start': 504.719,
#   'text': 'пользователя мы его пропускаем через'},
#  {'duration': 6.75,
#   'start': 506.279,
#   'text': 'весь получаемый беден и ищем к ближайших'},
#  {'duration': 7.38,
#   'start': 508.68,
#   'text': 'среди нашего индекса все круто у нас 100'},
#  {'duration': 5.581,
#   'start': 513.029,
#   'text': 'процентов запросов имеют расширение при'},
#  {'duration': 4.649,
#   'start': 516.06,
#   'text': 'этом регулярно обновляется таблицы'},
#  {'duration': 3.7,
#   'start': 518.61,
#   'text': 'расширения на их учатся до учи ваются'},
#  {'duration': 5.501, 'start': 520.709, 'text': 'нейросети'},
#  {'duration': 6.24,
#   'start': 522.31,
#   'text': 'и это все очень быстро работает но'},
#  {'duration': 5.46,
#   'start': 526.21,
#   'text': 'давайте попробуем из этого еще выжить'},
#  {'duration': 5.46,
#   'start': 528.55,
#   'text': 'чего-нибудь предположим что каждый на'},
#  {'duration': 5.49,
#   'start': 531.67,
#   'text': 'сайт достаточно хорошо характеризует'},
#  {'duration': 4.17,
#   'start': 534.01,
#   'text': 'характеризуется тем с каких запросов на'},
#  {'duration': 3.84, 'start': 537.16, 'text': 'него переходят люди'},
#  {'duration': 4.58,
#   'start': 538.18,
#   'text': 'а сейчас смотрите для каждого из'},
#  {'duration': 4.8,
#   'start': 541.0,
#   'text': 'запросов у нас уже есть embedding'},
#  {'duration': 5.05,
#   'start': 542.76,
#   'text': 'давайте считать что им bedding нашего'},
#  {'duration': 6.09,
#   'start': 545.8,
#   'text': 'сайта это ничто иное как взвешенная'},
#  {'duration': 5.31,
#   'start': 547.81,
#   'text': 'сумма запросов сейчас работает схема так'},
#  {'duration': 2.82, 'start': 551.89, 'text': 'у нас'},
#  {'duration': 3.36,
#   'start': 553.12,
#   'text': 'надо определить насколько хорошо'},
#  {'duration': 3.42, 'start': 554.71, 'text': 'соответствует запрос сайту'},
#  {'duration': 7.07,
#   'start': 556.48,
#   'text': 'мы считаем их им бединге и считаем'},
#  {'duration': 7.56,
#   'start': 558.13,
#   'text': 'косинус между ними соберем все вместе мы'},
#  {'duration': 4.63, 'start': 563.55, 'text': 'основном основными остаются'},
#  {'duration': 4.95,
#   'start': 565.69,
#   'text': 'пользователей именно они переходят по'},
#  {'duration': 4.47,
#   'start': 568.18,
#   'text': 'сайтам кликают что-то ищут мы это все'},
#  {'duration': 4.53,
#   'start': 570.64,
#   'text': 'аккуратно собираем и строим таблицы'},
#  {'duration': 4.32,
#   'start': 572.65,
#   'text': 'расширений на этих таблицах расширений'},
#  {'duration': 3.63, 'start': 575.17, 'text': 'регулярно обучаются нейросети'},
#  {'duration': 4.83,
#   'start': 576.97,
#   'text': 'из которых мы потом рассчитываем бединге'},
#  {'duration': 5.31,
#   'start': 578.8,
#   'text': 'запросов и сайтов все это улучшает наше'},
#  {'duration': 4.11,
#   'start': 581.8,
#   'text': 'ранжирование улучшает поиск все круг'},
#  {'duration': 4.35,
#   'start': 584.11,
#   'text': 'замкнулся яндексом по себе улучшается'},
#  {'duration': 4.5,
#   'start': 585.91,
#   'text': 'можно ничего не делать ну ладно на самом'},
#  {'duration': 5.01,
#   'start': 588.46,
#   'text': 'деле тут еще есть что дальше делать с'},
#  {'duration': 4.26,
#   'start': 590.41,
#   'text': 'точки зрения расширений мы можем'},
#  {'duration': 4.08, 'start': 593.47, 'text': 'смотреть какие-то более'},
#  {'duration': 4.919,
#   'start': 594.67,
#   'text': 'персонализированные расширения можем уже'},
#  {'duration': 3.93,
#   'start': 597.55,
#   'text': 'анализировать не просто клики а брать'},
#  {'duration': 4.101,
#   'start': 599.589,
#   'text': 'какие-то большие корпуса текстов и из'},
#  {'duration': 5.13,
#   'start': 601.48,
#   'text': 'них искать какие расширения придумывать'},
#  {'duration': 5.77,
#   'start': 603.69,
#   'text': 'ну и придумать какие-то более сложные'},
#  {'duration': 5.91,
#   'start': 606.61,
#   'text': 'блуждания на графах но вообще как я'},
#  {'duration': 5.31,
#   'start': 609.46,
#   'text': 'говорил изначально расширение это только'},
#  {'duration': 3.81,
#   'start': 612.52,
#   'text': 'одно из небольших направлений того что'},
#  {'duration': 3.39,
#   'start': 614.77,
#   'text': 'мы делаем на самом деле постоянно'},
#  {'duration': 5.67,
#   'start': 616.33,
#   'text': 'тестируются внедряются ищутся новые'},
#  {'duration': 6.179,
#   'start': 618.16,
#   'text': 'нейросетевые модели мы пытаемся понять'},
#  {'duration': 3.87,
#   'start': 622.0,
#   'text': 'что делают пользователи как делают'},
#  {'duration': 4.671,
#   'start': 624.339,
#   'text': 'пользователи чтобы предсказать их'},
#  {'duration': 5.969,
#   'start': 625.87,
#   'text': 'будущее поведение запросы кроме того'},
#  {'duration': 4.87,
#   'start': 629.01,
#   'text': 'последние годы нарастает все больше и'},
#  {'duration': 3.541,
#   'start': 631.839,
#   'text': 'больше совместное сотрудничество с'},
#  {'duration': 2.79,
#   'start': 633.88,
#   'text': 'другими группами с другими службами'},
#  {'duration': 2.94, 'start': 635.38, 'text': 'потому что казалось'},
#  {'duration': 3.44,
#   'start': 636.67,
#   'text': 'у них тоже много классных моделей'},
#  {'duration': 6.54,
#   'start': 638.32,
#   'text': 'которые можно использовать для улучшения'},
#  {'duration': 7.479,
#   'start': 640.11,
#   'text': 'поиска мы вообще идей много направлений'},
#  {'duration': 4.8,
#   'start': 644.86,
#   'text': 'много кроме того насколько зная наша'},
#  {'duration': 4.5,
#   'start': 647.589,
#   'text': 'группа будет очередной раз расширяться'},
#  {'duration': 4.63,
#   'start': 649.66,
#   'text': 'так что тем кому интересно решение'},
#  {'duration': 3.731, 'start': 652.089, 'text': 'хороших задач и по'},
#  {'duration': 5.33,
#   'start': 654.29,
#   'text': 'смотреть на то как у нас все устроено'},
#  {'duration': 7.29, 'start': 655.82, 'text': 'изнутри милости просим спасибо'},
#  {'duration': 5.62, 'start': 659.62, 'text': '[аплодисменты]'},
#  {'duration': 3.84,
#   'start': 663.11,
#   'text': 'я даже не знаю после того как на первом'},
#  {'duration': 4.349,
#   'start': 665.24,
#   'text': 'слайде об обязанностях было указано'},
#  {'duration': 7.29,
#   'start': 666.95,
#   'text': 'доедать полдник зазывать кого-то в такое'},
#  {'duration': 7.101,
#   'start': 669.589,
#   'text': 'жуткое место это цинично тем не менее'},
#  {'duration': 8.099,
#   'start': 674.24,
#   'text': 'давайте попытаемся дать какие-нибудь'},
#  {'duration': 7.48,
#   'start': 676.69,
#   'text': 'более цельные вопросы здравствуйте'},
#  {'duration': 4.011,
#   'start': 682.339,
#   'text': 'спасибо за доклад вы скажете в стамбул'},
#  {'duration': 3.33,
#   'start': 684.17,
#   'text': 'садик где вы обучаете не ранку на'},
#  {'duration': 4.78, 'start': 686.35, 'text': 'ботинках'},
#  {'duration': 5.459,
#   'start': 687.5,
#   'text': 'в смысле обучаете бмп денги и до запросы'},
#  {'duration': 3.3,
#   'start': 691.13,
#   'text': 'расширения почему предполагается что к'},
#  {'duration': 2.94,
#   'start': 692.959,
#   'text': 'еще нас на расстояние между запросом'},
#  {'duration': 4.14,
#   'start': 694.43,
#   'text': 'расширения будут близко но одинаковые'},
#  {'duration': 4.651,
#   'start': 695.899,
#   'text': 'похожие запросы расширение и запроса'},
#  {'duration': 4.38,
#   'start': 698.57,
#   'text': 'будут близко но если они похожи на самом'},
#  {'duration': 4.409,
#   'start': 700.55,
#   'text': 'деле ну знаете на самом деле когда мы'},
#  {'duration': 4.1,
#   'start': 702.95,
#   'text': 'работаем даже не с большими объемами'},
#  {'duration': 4.771,
#   'start': 704.959,
#   'text': 'данными а с гигантскими объемами данными'},
#  {'duration': 5.71,
#   'start': 707.05,
#   'text': 'часто единственный правильный ответ это'},
#  {'duration': 5.01,
#   'start': 709.73,
#   'text': 'потому что это работает не все не все'},
#  {'duration': 4.17,
#   'start': 712.76,
#   'text': 'моменты можно объяснить но здесь как бы'},
#  {'duration': 3.63, 'start': 714.74, 'text': 'понятно почему потому что наше'},
#  {'duration': 4.38,
#   'start': 716.93,
#   'text': 'расширение она собственно является'},
#  {'duration': 4.62,
#   'start': 718.37,
#   'text': 'альтернативным запросам поэтому мы таким'},
#  {'duration': 6.51,
#   'start': 721.31,
#   'text': 'вот образом их обучаем чтобы за'},
#  {'duration': 6.089,
#   'start': 722.99,
#   'text': 'расширение запрос похожи были с близко'},
#  {'duration': 4.62, 'start': 727.82, 'text': 'находились то есть мы'},
#  {'duration': 6.061,
#   'start': 729.079,
#   'text': 'сеть сейчас мопед наши запросы в некое'},
#  {'duration': 4.92,
#   'start': 732.44,
#   'text': 'пространство мерная ну и здесь мы его'},
#  {'duration': 4.559,
#   'start': 735.14,
#   'text': 'так строим так чтобы близкий запросу нас'},
#  {'duration': 4.229,
#   'start': 737.36,
#   'text': 'находились собственно по себе близко так'},
#  {'duration': 6.14,
#   'start': 739.699,
#   'text': 'расширении и запросы имеют одинаковую'},
#  {'duration': 4.25, 'start': 741.589, 'text': 'природу она так и получается'},
#  {'duration': 6.13,
#   'start': 746.199,
#   'text': 'приближается вы в качестве расширения мы'},
#  {'duration': 5.43,
#   'start': 749.149,
#   'text': 'берем самые часто задаваемые вопросы'},
#  {'duration': 4.591,
#   'start': 752.329,
#   'text': 'скажем так то есть польза как больше'},
#  {'duration': 4.561,
#   'start': 754.579,
#   'text': 'считается что пользователь вот поискал'},
#  {'duration': 3.99,
#   'start': 756.92,
#   'text': 'там про роботов уборщиков провале'},
#  {'duration': 3.66,
#   'start': 759.14,
#   'text': 'посмотреть провале мы видим что он'},
#  {'duration': 4.65,
#   'start': 760.91,
#   'text': 'условно переходил все время в одно и то'},
#  {'duration': 5.34,
#   'start': 762.8,
#   'text': 'же место значит это достаточно близкие'},
#  {'duration': 4.11,
#   'start': 765.56,
#   'text': 'сами по себе запросы и вот посмотреть'},
#  {'duration': 5.939, 'start': 768.14, 'text': 'вале и просто вали этой будет'},
#  {'duration': 6.09,
#   'start': 769.67,
#   'text': 'расширениями то есть за прошение это'},
#  {'duration': 3.861,
#   'start': 774.079,
#   'text': 'появляются это как самые часто'},
#  {'duration': 5.85, 'start': 775.76, 'text': 'задаваемые вопросы'},
#  {'duration': 5.47,
#   'start': 777.94,
#   'text': 'можно еще один вопрос посмотрите там вы'},
#  {'duration': 3.69,
#   'start': 781.61,
#   'text': 'говорили что вот человек а точнее дайте'},
#  {'duration': 4.2,
#   'start': 783.41,
#   'text': 'запросу вот используете ли вы информацию'},
#  {'duration': 4.92,
#   'start': 785.3,
#   'text': 'уточнение то есть вот перед этим человек'},
#  {'duration': 4.32, 'start': 787.61, 'text': 'сделку это заброс потом ему не'},
#  {'duration': 3.03,
#   'start': 790.22,
#   'text': 'понравилась он уточнил что то вот'},
#  {'duration': 2.13,
#   'start': 791.93,
#   'text': 'использовать любой предыдущий информацию'},
#  {'duration': 2.46, 'start': 793.25, 'text': 'от начали'},
#  {'duration': 3.9, 'start': 794.06, 'text': 'так значит это вот тут вот'},
#  {'duration': 3.74,
#   'start': 795.71,
#   'text': 'рассматривается в самом конце где мы'},
#  {'duration': 4.32, 'start': 797.96, 'text': 'хотим моделировать поведение'},
#  {'duration': 5.47,
#   'start': 799.45,
#   'text': 'пользователей и если такие исследования'},
#  {'duration': 4.74,
#   'start': 802.28,
#   'text': 'если такие результаты ответ да то есть'},
#  {'duration': 3.84,
#   'start': 804.92,
#   'text': 'мы учитываем это что смотрел раньше'},
#  {'duration': 3.39,
#   'start': 807.02,
#   'text': 'пользователей то что он смотрел и как'},
#  {'duration': 6.62,
#   'start': 808.76,
#   'text': 'себя вообще в целом ведут люди чтобы'},
#  {'duration': 4.97,
#   'start': 810.41,
#   'text': 'перед тем как получить результат спасибо'},
#  {'duration': 6.04,
#   'start': 817.87,
#   'text': 'спасибо алексей вопрос по поводу'},
#  {'duration': 4.72,
#   'start': 820.78,
#   'text': 'построением митингов для каких языков вы'},
#  {'duration': 3.12,
#   'start': 823.91,
#   'text': 'их поддерживаете ли у вас им деньги на'},
#  {'duration': 5.34, 'start': 825.5, 'text': 'все языки сразу мультиязыковый'},
#  {'duration': 5.31,
#   'start': 827.03,
#   'text': 'какие-нибудь может какие то вы хотите'},
#  {'duration': 4.89,
#   'start': 830.84,
#   'text': 'выложить в открытый доступ например для'},
#  {'duration': 4.89,
#   'start': 832.34,
#   'text': 'каких-то языков ну вот про про эту часть'},
#  {'duration': 4.44, 'start': 835.73, 'text': 'интересные как соответственно'},
#  {'duration': 4.37,
#   'start': 837.23,
#   'text': 'обрабатываются запросы содержащие мульти'},
#  {'duration': 5.1, 'start': 840.17, 'text': 'языковой запросу'},
#  {'duration': 5.35,
#   'start': 841.6,
#   'text': 'так но сразу про открытый доступ это'},
#  {'duration': 4.17,
#   'start': 845.27,
#   'text': 'наверно вопрос немножко не ко мне потому'},
#  {'duration': 2.97,
#   'start': 846.95,
#   'text': 'что я к этому отношения не не имея'},
#  {'duration': 6.66, 'start': 849.44, 'text': 'жуткого'},
#  {'duration': 8.85,
#   'start': 849.92,
#   'text': 'далее далее что мы делаем модели сейчас'},
#  {'duration': 4.14,
#   'start': 856.1,
#   'text': 'у нас модели которые мульти языковые то'},
#  {'duration': 4.5, 'start': 858.77, 'text': 'есть они там основываются'},
#  {'duration': 4.71,
#   'start': 860.24,
#   'text': 'основная идея в том что в русскоязычном'},
#  {'duration': 3.81,
#   'start': 863.27,
#   'text': 'поиски считается даже если вы запрос'},
#  {'duration': 3.6,
#   'start': 864.95,
#   'text': 'вели на английском получить релевантный'},
#  {'duration': 3.93,
#   'start': 867.08,
#   'text': 'хороший документ на русском вас тоже'},
#  {'duration': 3.57,
#   'start': 868.55,
#   'text': 'абсолютно строит поэтому мы там бы как'},
#  {'duration': 2.4,
#   'start': 871.01,
#   'text': 'бы нам хотелось чтобы эти запросы'},
#  {'duration': 4.92, 'start': 872.12, 'text': 'расширения они все таки в одно'},
#  {'duration': 8.82,
#   'start': 873.41,
#   'text': 'пространство попадали вот поэтому здесь'},
#  {'duration': 8.57,
#   'start': 877.04,
#   'text': 'ответу штат одно пространство и ну'},
#  {'duration': 3.38, 'start': 882.23, 'text': 'наверно этот вид на бы вопросу'},
#  {'duration': 4.18,
#   'start': 886.5,
#   'text': 'здравствуйте мне вопрос по этому слайду'},
#  {'duration': 6.391,
#   'start': 889.149,
#   'text': 'и и можете еще следующий показатель'},
#  {'duration': 6.719,
#   'start': 890.68,
#   'text': 'конечно а хорошо пожалуйста вернитесь'},
#  {'duration': 4.41, 'start': 895.54, 'text': 'предыдущему то есть по сути'},
#  {'duration': 5.011,
#   'start': 897.399,
#   'text': 'именно данную модель вы тренируете так'},
#  {'duration': 4.41,
#   'start': 899.95,
#   'text': 'то есть вот эти веса и этой и то есть'},
#  {'duration': 3.299,
#   'start': 902.41,
#   'text': 'какие-то значения целевой функцию'},
#  {'duration': 2.07,
#   'start': 904.36,
#   'text': 'которую вы пытаетесь минимизировать с'},
#  {'duration': 3.271, 'start': 905.709, 'text': 'помощью данным'},
#  {'duration': 4.89,
#   'start': 906.43,
#   'text': 'да вот именно подвисает могу сразу'},
#  {'duration': 5.609,
#   'start': 908.98,
#   'text': 'сказать то что очень хорошим лучше всего'},
#  {'duration': 5.16,
#   'start': 911.32,
#   'text': 'работают веса из коллаборативный'},
#  {'duration': 3.99,
#   'start': 914.589,
#   'text': 'фильтрации потому что за счет того что'},
#  {'duration': 4.59,
#   'start': 916.48,
#   'text': 'они там симметричные получаются вот'},
#  {'duration': 4.111,
#   'start': 918.579,
#   'text': 'именно вот это вот мы тренируем тогда'},
#  {'duration': 5.67,
#   'start': 921.07,
#   'text': 'вопрос давайте вернемся к следующему'},
#  {'duration': 5.87,
#   'start': 922.69,
#   'text': 'слою смотрите вы используете кнн нам а'},
#  {'duration': 6.469, 'start': 926.74, 'text': 'вы не пытались'},
#  {'duration': 6.19, 'start': 928.56, 'text': 'скажем так строить авторизацию'},
#  {'duration': 3.161, 'start': 933.209, 'text': 'непосредственно в модель'},
#  {'duration': 4.98,
#   'start': 934.75,
#   'text': 'тренировочную модели и таким образом'},
#  {'duration': 5.7,
#   'start': 936.37,
#   'text': 'сделать and went чайный так называемый'},
#  {'duration': 3.93,
#   'start': 939.73,
#   'text': 'взяла в том дело в том что вот вы'},
#  {'duration': 3.449, 'start': 942.07, 'text': 'используете к.м.н. в качестве'},
#  {'duration': 2.96,
#   'start': 943.66,
#   'text': 'альтернативы можно использовать допустим'},
#  {'duration': 4.26, 'start': 945.519, 'text': 'меньше'},
#  {'duration': 6.969,
#   'start': 946.62,
#   'text': 'как кластере за алгоритм кластеризации'},
#  {'duration': 6.12,
#   'start': 949.779,
#   'text': 'его можно его можно реализовать как'},
#  {'duration': 4.201,
#   'start': 953.589,
#   'text': 'рекуррентный модуль в сети и таким'},
#  {'duration': 3.75,
#   'start': 955.899,
#   'text': 'образом вы можете сделать тренировку'},
#  {'duration': 3.6,
#   'start': 957.79,
#   'text': 'intent то есть на практике по крайней'},
#  {'duration': 3.601,
#   'start': 959.649,
#   'text': 'мере для компьютерного зрения такие'},
#  {'duration': 2.97,
#   'start': 961.39,
#   'text': 'модели работают лучше мы не пытались'},
#  {'duration': 3.0, 'start': 963.25, 'text': 'что-нибудь подобное'},
#  {'duration': 5.339,
#   'start': 964.36,
#   'text': 'раба работы работают лучше в смысле'},
#  {'duration': 6.18,
#   'start': 966.25,
#   'text': 'работают быстрее или что нет лучше и'},
#  {'duration': 5.461,
#   'start': 969.699,
#   'text': 'лучше в смысле конечно не дает лучший'},
#  {'duration': 6.24,
#   'start': 972.43,
#   'text': 'результат на выходе конечно тренировка'},
#  {'duration': 6.03,
#   'start': 975.16,
#   'text': 'их чуть чуть сложнее но тем не менее ну'},
#  {'duration': 4.14,
#   'start': 978.67,
#   'text': 'скажем так вот то что вот у нас вот этот'},
#  {'duration': 3.87, 'start': 981.19, 'text': 'вот хейсканен яндекс'},
#  {'duration': 4.38,
#   'start': 982.81,
#   'text': 'он разработан вот специально нами и под'},
#  {'duration': 4.8,
#   'start': 985.06,
#   'text': 'нас потому что там получается немного'},
#  {'duration': 5.04,
#   'start': 987.19,
#   'text': 'специфичного образа рекомендательный вот'},
#  {'duration': 4.229,
#   'start': 989.86,
#   'text': 'эти вот вектор а то есть мы там'},
#  {'duration': 4.62,
#   'start': 992.23,
#   'text': 'рассчитываем условно какой-то момент нам'},
#  {'duration': 5.131,
#   'start': 994.089,
#   'text': 'обрезаем у нас для каждых ненулевых'},
#  {'duration': 4.349,
#   'start': 996.85,
#   'text': 'весов всего 10 штук и поэтому нас'},
#  {'duration': 4.739,
#   'start': 999.22,
#   'text': 'получается достаточно специфичный кнр'},
#  {'duration': 5.07,
#   'start': 1001.199,
#   'text': 'который рассчитан на миллионы запросов в'},
#  {'duration': 5.13,
#   'start': 1003.959,
#   'text': 'день в день и то что вы предлагаете но'},
#  {'duration': 4.081,
#   'start': 1006.269,
#   'text': 'это как бы этот индекс в том числе'},
#  {'duration': 2.25, 'start': 1009.089, 'text': 'делала не наша служба'},
#  {'duration': 3.39,
#   'start': 1010.35,
#   'text': 'то есть у нас есть специальные люди'},
#  {'duration': 4.11,
#   'start': 1011.339,
#   'text': 'которые вот этими вещами занимаются но'},
#  {'duration': 4.079,
#   'start': 1013.74,
#   'text': 'возможно это будет интересно возможно'},
#  {'duration': 3.621,
#   'start': 1015.449,
#   'text': 'это получится но то что есть сейчас и то'},
#  {'duration': 3.381, 'start': 1017.819, 'text': 'что мы видим и так до'},
#  {'duration': 4.29,
#   'start': 1019.07,
#   'text': 'достаточно хороший результат и поэтому'},
#  {'duration': 11.46,
#   'start': 1021.2,
#   'text': 'пока нету смысла на что то другое'},
#  {'duration': 12.69,
#   'start': 1023.36,
#   'text': 'переходите добрый день такой вопрос'},
#  {'duration': 5.789,
#   'start': 1032.66,
#   'text': 'спасибо за доклад современные поисковики'},
#  {'duration': 4.44, 'start': 1036.05, 'text': 'работают очень хорошо и когда'},
#  {'duration': 3.811,
#   'start': 1038.449,
#   'text': 'рассказываю о том как они работают часто'},
#  {'duration': 3.93,
#   'start': 1040.49,
#   'text': 'приводят канонические примеры например'},
#  {'duration': 4.65,
#   'start': 1042.26,
#   'text': 'тексты запрос мы ожидаем текстовый ответ'},
#  {'duration': 4.5,
#   'start': 1044.42,
#   'text': 'ну как турция там ссылка сайт еще что то'},
#  {'duration': 4.53,
#   'start': 1046.91,
#   'text': 'но вот есть области в которых они все'},
#  {'duration': 6.12,
#   'start': 1048.92,
#   'text': 'еще не очень работают например поиск'},
#  {'duration': 6.6,
#   'start': 1051.44,
#   'text': 'мемчик of то есть я ввожу например мем с'},
#  {'duration': 5.43,
#   'start': 1055.04,
#   'text': 'дрейком про уравнения и ответы обычно не'},
#  {'duration': 4.2,
#   'start': 1058.04,
#   'text': 'очень хорошие вот ведутся ли направления'},
#  {'duration': 4.55,
#   'start': 1060.47,
#   'text': 'ведутся ли работы в таких важных'},
#  {'duration': 2.78, 'start': 1062.24, 'text': 'направлениях'},
#  {'duration': 5.57, 'start': 1065.8, 'text': '[аплодисменты]'},
#  {'duration': 4.3,
#   'start': 1068.72,
#   'text': 'ну потому что действительно результаты'},
#  {'duration': 6.74,
#   'start': 1071.37,
#   'text': 'часто не релевантны хотя знаю что так'},
#  {'duration': 10.67, 'start': 1073.02, 'text': 'умеем есть например смотрите'},
#  {'duration': 5.58,
#   'start': 1078.11,
#   'text': 'работы ведутся и как я понимаю самый'},
#  {'duration': 4.35,
#   'start': 1084.11,
#   'text': 'самое перспективное направление в этом'},
#  {'duration': 4.53, 'start': 1086.73, 'text': 'это пытаться делать какой-то'},
#  {'duration': 4.81,
#   'start': 1088.46,
#   'text': 'персонализированный пояс то есть если вы'},
#  {'duration': 3.69,
#   'start': 1091.26,
#   'text': 'начнёте искать мемчики начинайте будет'},
#  {'duration': 3.33,
#   'start': 1093.27,
#   'text': 'какой-то момент на них кликать потом в'},
#  {'duration': 4.17,
#   'start': 1094.95,
#   'text': 'от этого уже не отвертитесь да вы же'},
#  {'duration': 4.95,
#   'start': 1096.6,
#   'text': 'захотите увидеть там условно какую-то'},
#  {'duration': 9.39,
#   'start': 1099.12,
#   'text': 'турции уже придется восстанавливать'},
#  {'duration': 9.69,
#   'start': 1101.55,
#   'text': 'условно репутацию глазах яндекса вот это'},
#  {'duration': 4.62,
#   'start': 1108.51,
#   'text': 'вот основное на чем ведется ну такой же'},
#  {'duration': 4.14,
#   'start': 1111.24,
#   'text': 'наверно вы могли встретить и когда буду'},
#  {'duration': 3.99,
#   'start': 1113.13,
#   'text': 'вы какие-то там по программированию'},
#  {'duration': 3.93,
#   'start': 1115.38,
#   'text': 'запросы выводите тоже могут иногда'},
#  {'duration': 4.14,
#   'start': 1117.12,
#   'text': 'попадаться ответы которые больше'},
#  {'duration': 4.32,
#   'start': 1119.31,
#   'text': 'интересны более широкому они более узким'},
#  {'duration': 4.59,
#   'start': 1121.26,
#   'text': 'кругом людей но и все вот это вот здесь'},
#  {'duration': 6.0,
#   'start': 1123.63,
#   'text': 'будет достигаться за счет персонализации'},
#  {'duration': 7.62,
#   'start': 1125.85,
#   'text': 'то есть вот будут когда-нибудь работать'},
#  {'duration': 7.76,
#   'start': 1129.63,
#   'text': 'доживете до того что мемчики просто 0'},
#  {'duration': 6.93,
#   'start': 1133.47,
#   'text': 'запрос да я настаиваю на том чтобы дать'},
#  {'duration': 8.86,
#   'start': 1137.39,
#   'text': 'человеку подарок за потенциальный лучший'},
#  {'duration': 8.07,
#   'start': 1140.4,
#   'text': 'вопрос все и там под елкой есть подарки'},
#  {'duration': 3.9,
#   'start': 1146.25,
#   'text': 'вы давай сейчас надо давай давай не'},
#  {'duration': 3.63, 'start': 1148.47, 'text': 'стесняясь и еще коллеги есть'},
#  {'duration': 3.72,
#   'start': 1150.15,
#   'text': 'какой-нибудь вопрос который может тоже'},
#  {'duration': 9.69, 'start': 1152.1, 'text': 'претендовать на веселье'},
#  {'duration': 10.05,
#   'start': 1153.87,
#   'text': 'а вижу сейчас подойду спасибо за доклад'},
#  {'duration': 5.28, 'start': 1161.79, 'text': 'у меня как бы ну немного тоже'},
#  {'duration': 6.09,
#   'start': 1163.92,
#   'text': 'руки вопрос была полгода назад хай по'},
#  {'duration': 5.19,
#   'start': 1167.07,
#   'text': 'поводу открытых документов google а вот'},
#  {'duration': 5.73,
#   'start': 1170.01,
#   'text': 'и все сразу же полетели в запросы'},
#  {'duration': 5.49,
#   'start': 1172.26,
#   'text': 'яндекса и как сказалось это на ваших'},
#  {'duration': 4.77,
#   'start': 1175.74,
#   'text': 'данных и какая вообще статистика есть'},
#  {'duration': 4.68,
#   'start': 1177.75,
#   'text': 'потому что как бы есть у вас ребята'},
#  {'duration': 3.87,
#   'start': 1180.51,
#   'text': 'выкладывают публичный доступ аналитики'},
#  {'duration': 4.77,
#   'start': 1182.43,
#   'text': 'по разным там вещам вот недавно про'},
#  {'duration': 4.71,
#   'start': 1184.38,
#   'text': 'биток как он летает сейчас вот если'},
#  {'duration': 5.0,
#   'start': 1187.2,
#   'text': 'какая то инфа по поводу того как'},
#  {'duration': 4.86,
#   'start': 1189.09,
#   'text': 'сказалось на вашей работе именно'},
#  {'duration': 4.03,
#   'start': 1192.2,
#   'text': 'пользовательское отношении в поиске'},
#  {'duration': 4.74,
#   'start': 1193.95,
#   'text': 'публичных документов потому что у гугла'},
#  {'duration': 4.41,
#   'start': 1196.23,
#   'text': 'пока не очень дела были в этот момент и'},
#  {'duration': 3.41,
#   'start': 1198.69,
#   'text': 'очень много запросов именно с беларуси'},
#  {'duration': 5.31, 'start': 1200.64, 'text': 'пошло'},
#  {'duration': 5.62,
#   'start': 1202.1,
#   'text': 'нина как кажется что на ответ на ваш'},
#  {'duration': 4.65,
#   'start': 1205.95,
#   'text': 'вопрос это должно быть к это полноценное'},
#  {'duration': 5.58,
#   'start': 1207.72,
#   'text': 'исследование как всем нервном каких-то'},
#  {'duration': 4.98,
#   'start': 1210.6,
#   'text': 'особых выбросах влогах или еще чего то'},
#  {'duration': 3.93,
#   'start': 1213.3,
#   'text': 'необычного навряд ли было замечено'},
#  {'duration': 3.42,
#   'start': 1215.58,
#   'text': 'то есть это знаете это наверное вот этот'},
#  {'duration': 3.35,
#   'start': 1217.23,
#   'text': 'вот момент он был широко очень известен'},
#  {'duration': 5.25, 'start': 1219.0, 'text': 'но в очень узких кругах'},
#  {'duration': 8.53,
#   'start': 1220.58,
#   'text': 'поэтому проблема у яндекса были с этим'},
#  {'duration': 6.15,
#   'start': 1224.25,
#   'text': 'по итогу я ничего такого не знаю по'},
#  {'duration': 4.53,
#   'start': 1229.11,
#   'text': 'крайней мере у меня к сотрудникам'},
#  {'duration': 4.83,
#   'start': 1230.4,
#   'text': 'достаточно травления было секс это'},
#  {'duration': 3.12,
#   'start': 1233.64,
#   'text': 'довольно странный способ получить'},
#  {'duration': 4.35,
#   'start': 1235.23,
#   'text': 'подарок потому что катить бочку на'},
#  {'duration': 9.83,
#   'start': 1236.76,
#   'text': 'яндекс здесь не надо давайте на минуту'},
#  {'duration': 11.1,
#   'start': 1239.58,
#   'text': 'последний вопрос ладно не буду говорить'},
#  {'duration': 5.83,
#   'start': 1246.59,
#   'text': 'этот вопрос кровь у доктора недавно было'},
#  {'duration': 4.05,
#   'start': 1250.68,
#   'text': 'исследование возможно конечно не просто'},
#  {'duration': 4.53,
#   'start': 1252.42,
#   'text': 'захотели попиариться но не без этого вот'},
#  {'duration': 3.84, 'start': 1254.73, 'text': 'о том что гугловский поиск'},
#  {'duration': 3.81,
#   'start': 1256.95,
#   'text': 'персонализируется даже если в этом'},
#  {'duration': 4.08,
#   'start': 1258.57,
#   'text': 'отовсюду разлогиньтесь заходите под на'},
#  {'duration': 5.67,
#   'start': 1260.76,
#   'text': 'нем нам но не то что персонализируется'},
#  {'duration': 7.86,
#   'start': 1262.65,
#   'text': 'там примерно похожее были проценты не'},
#  {'duration': 6.0,
#   'start': 1266.43,
#   'text': 'уникальных не идентичных запросов у'},
#  {'duration': 3.15,
#   'start': 1270.51,
#   'text': 'пользователей когда они даже разладились'},
#  {'duration': 2.49, 'start': 1272.43, 'text': 'там всякие анонимные режиму'},
#  {'duration': 3.36,
#   'start': 1273.66,
#   'text': 'использовались о такой то есть их'},
#  {'duration': 5.67,
#   'start': 1274.92,
#   'text': 'отслеживать не на железном уровня можно'},
#  {'duration': 4.98,
#   'start': 1277.02,
#   'text': 'ли в яндекс плиски как-то но где я ехал'},
#  {'duration': 3.21,
#   'start': 1280.59,
#   'text': 'бы не знаю и там используя яндекс'},
#  {'duration': 4.04,
#   'start': 1282.0,
#   'text': 'браузер например совершенно точно'},
#  {'duration': 4.58,
#   'start': 1283.8,
#   'text': 'получить не персонализированный запрос'},
#  {'duration': 4.54,
#   'start': 1286.04,
#   'text': 'если там разлогиниться и все такое но'},
#  {'duration': 7.65,
#   'start': 1288.38,
#   'text': 'возможность неэтичного пас поэтому и так'},
#  {'duration': 5.45,
#   'start': 1290.58,
#   'text': 'типа может сказать без комментариев'},
#  {'duration': 5.03,
#   'start': 1296.98,
#   'text': 'но смотрите во первых персонализация'},
#  {'duration': 4.95,
#   'start': 1299.83,
#   'text': 'персонализации это такая вещь которая'},
#  {'duration': 4.51,
#   'start': 1302.01,
#   'text': 'достаточно много статей то есть условно'},
#  {'duration': 6.06,
#   'start': 1304.78,
#   'text': 'вот вы сейчас ищите со своего браузера'},
#  {'duration': 6.3,
#   'start': 1306.52,
#   'text': 'там купить купить купить ну что-нибудь'},
#  {'duration': 4.95,
#   'start': 1310.84,
#   'text': 'ищите там купить условно сковородке до'},
#  {'duration': 3.599,
#   'start': 1312.82,
#   'text': 'вам понятно это будет купить сковородке'},
#  {'duration': 2.639, 'start': 1315.79, 'text': 'в минске'},
#  {'duration': 4.351,
#   'start': 1316.419,
#   'text': 'именно они в санкт-петербурге где-то и'},
#  {'duration': 3.541,
#   'start': 1318.429,
#   'text': 'что то мне подсказывает если вы зайдете'},
#  {'duration': 3.39, 'start': 1320.77, 'text': 'через приватный режим'},
#  {'duration': 5.01,
#   'start': 1321.97,
#   'text': 'по крайней мере город ваш все равно'},
#  {'duration': 5.85,
#   'start': 1324.16,
#   'text': 'будет ну тем же самым потому что это'},
#  {'duration': 5.64,
#   'start': 1326.98,
#   'text': 'определяется ну совсем не с чем-то'},
#  {'duration': 4.38,
#   'start': 1330.01,
#   'text': 'связано то есть с такой точки зрения ваш'},
#  {'duration': 4.14,
#   'start': 1332.62,
#   'text': 'пояс все равно сковородке вы найдете в'},
#  {'duration': 5.07,
#   'start': 1334.39,
#   'text': 'минске что-то уже дальше что касается'},
#  {'duration': 5.22,
#   'start': 1336.76,
#   'text': 'сессий но опять же этим чуть не мы'},
#  {'duration': 3.959,
#   'start': 1339.46,
#   'text': 'занимаемся но мне кажется то что сессии'},
#  {'duration': 3.09, 'start': 1341.98, 'text': 'уже будут совсем другие'},
#  {'duration': 5.611,
#   'start': 1343.419,
#   'text': 'это чтобы раньше до этого там что-то'},
#  {'duration': 6.0,
#   'start': 1345.07,
#   'text': 'искали но на уровне города останется на'},
#  {'duration': 7.84,
#   'start': 1349.03,
#   'text': 'уровне того что вы делали раньше этого'},
#  {'duration': 14.58, 'start': 1351.07, 'text': 'не должно быть спасибо'},
#  {'duration': 8.78, 'start': 1356.87, 'text': '[аплодисменты]'}]
