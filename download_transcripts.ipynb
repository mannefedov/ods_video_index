# %%
import requests
import json
import pickle
import pandas as pd
from time import sleep

# %% [markdown]
# ## Каналы, которые нужно скачать полностью

# %%
API = 'AIzaSyABZTjzLinNS2tLnR2ZLtLvBcwUIC9fneI'

# %%
channel_ids = {'Тренировки ML':'UCeq6ZIlvC9SVsfhfKnSvM9w',
               'Компьютерные науки':'UCKFojzto0n4Ab3CRQRZ2zYA',
               'event_space_by_video':'UCX5g8IOR_tw1OkiFAzAZHaA'
              }

# %%
url = "https://www.googleapis.com/youtube/v3/channels?key={API_KEY}&id={CHANNEL_ID}&part=snippet,id,contentDetails"
url_playlist = 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet%2C+id&playlistId={ID}&key={API_KEY}&maxResults=49'

# %%
r = requests.get(url.format(CHANNEL_ID=channel_ids['Тренировки ML'], API_KEY=API))

pl_id = json.loads(r.text)['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
r = requests.get(url_playlist.format(ID=pl_id, API_KEY=API))
jss = [json.loads(r.text)]

# %%
jj = 0
while 'nextPageToken' in json.loads(r.text):
    jj += 1
    print(jj)
    
    r = requests.get(url_playlist.format(ID=pl_id, API_KEY=API) + \
                     '&pageToken={}'.format(json.loads(r.text)['nextPageToken']))
    jss.append(json.loads(r.text))
    sleep(10)
# Out:
# 1
# 2
# 3

# %%
video_items = []
for js in jss:
        for item in js['items']:
            video_items.append((item['snippet']['resourceId']['videoId'], 'Тренировки ML', item['snippet']['title'], item['snippet']['publishedAt'],
                               item['snippet']['description']))

# %%
len(set(video_items))
# Out:
# 159

# %%
len(video_items[0])
# Out:
# 5

# %%
df_vid_cs = pd.DataFrame(list(set(video_items)), columns=['youtube_id', 'channel', 'title', 'publishedAt', 'description'])

# %%
df_vid_ml = pd.DataFrame(list(set(video_items)), columns=['youtube_id', 'channel', 'title', 'publishedAt', 'description'])

# %%
df_vid_es = pd.DataFrame(list(set(video_items)), columns=['youtube_id', 'channel', 'title', 'publishedAt', 'description'])

# %%
df_vid = pd.concat([df_vid_cs, df_vid_ml, df_vid_es], axis=0, ignore_index=True)

# %%
df_vid
# Out:
#       youtube_id               channel  \
# 0    46nnbxEZNw8    Компьютерные науки
# 1    RnUcRYAbWtY    Компьютерные науки
# 2    frLW8UVp_Ik    Компьютерные науки
# 3    7lerRDCZrhU    Компьютерные науки
# 4    Zco55S3RNU0    Компьютерные науки
# 5    3JpkBRJmo6Y    Компьютерные науки
# 6    uWWQClHVwEc    Компьютерные науки
# 7    fBVMLqi29XQ    Компьютерные науки
# 8    JJCO7eWCy-M    Компьютерные науки
# 9    egjoKTAYi7g    Компьютерные науки
# 10   h-vbysp1Tso    Компьютерные науки
# 11   N7R3hmvguyE    Компьютерные науки
# 12   EIvdPxBYSGY    Компьютерные науки
# 13   fghcOhTo3JE    Компьютерные науки
# 14   K1zNA_rneKY    Компьютерные науки
# 15   Qy2mTjHctSY    Компьютерные науки
# 16   3V9t0rXBIic    Компьютерные науки
# 17   pVFX3V0Q2Rg    Компьютерные науки
# 18   f4SUx8Ol9Fo    Компьютерные науки
# 19   aK0Tedo_X4o    Компьютерные науки
# 20   4jXTdvH3PFQ    Компьютерные науки
# 21   nUuv7fa7EFw    Компьютерные науки
# 22   O5MxQ00VVYs    Компьютерные науки
# 23   CGpm1ve6VAM    Компьютерные науки
# 24   DazqqLqeeAg    Компьютерные науки
# 25   RgydqzdFHm0    Компьютерные науки
# 26   lDWaUGoLfiU    Компьютерные науки
# 27   -WWAcltTlRw    Компьютерные науки
# 28   p8CMXUZWZ80    Компьютерные науки
# 29   7GVnkCKyFxA    Компьютерные науки
# ..           ...                   ...
# 884  OFOp_zmljfg  Event Space by Video
# 885  9vYkwD0feb4  Event Space by Video
# 886  PjTVS9n2yLQ  Event Space by Video
# 887  2dhwd-dYZhI  Event Space by Video
# 888  r7OuZ2aOHH0  Event Space by Video
# 889  dCIM1EZ1WX4  Event Space by Video
# 890  kzkJNpSSaNE  Event Space by Video
# 891  AWAJiv5ZCPY  Event Space by Video
# 892  TwIi7zoiiPs  Event Space by Video
# 893  n_mZYbVtVEM  Event Space by Video
# 894  ZBwxRww_EYo  Event Space by Video
# 895  FEzjzTSHlDs  Event Space by Video
# 896  v7aank8k7w8  Event Space by Video
# 897  uK4hPD12YmI  Event Space by Video
# 898  xZ6YSVrTBuY  Event Space by Video
# 899  gpzEQujiTwg  Event Space by Video
# 900  H6zZGNAF2pU  Event Space by Video
# 901  oEZSg79e03I  Event Space by Video
# 902  5oqdfBqok94  Event Space by Video
# 903  xglXoAIxzkc  Event Space by Video
# 904  d_-y7v-qHVE  Event Space by Video
# 905  x3I0yR-_hZs  Event Space by Video
# 906  l43hszLm-SU  Event Space by Video
# 907  q_Vc0c4CXqU  Event Space by Video
# 908  -jtqT5DihPc  Event Space by Video
# 909  _1EZOtu77w0  Event Space by Video
# 910  VoBrYyeV-iA  Event Space by Video
# 911  Ozm0bEi5KaI  Event Space by Video
# 912  20KEvvhiFLo  Event Space by Video
# 913  vZjm28HmqUY  Event Space by Video
#
#                                                  title  \
# 0    068. Как извлечь из сырых данных пользу для му...
# 1      001. Прикладные задачи оптимизации – М.В. Бацын
# 2    005. Тематическое моделирование на пути к разв...
# 3                      Запись тренировки ML 29.07.2017
# 4    058. Круглый стол «Как анализ данных меняет м...
# 5    018. Астрономия в эпоху больших обзоров неба –...
# 6    003 Запись трансляции научно-технического семи...
# 7    009. Коллективный поиск: подходы к изучению со...
# 8      DataFest 5 - Lumiere hall 2 - Запись трансляции
# 9               002. Что такое ШАД – Станислав Федотов
# 10   Canary deployment, мониторинг и тестирование м...
# 11   088. Как построить собственную систему аналити...
# 12   006. Методы анализа электроэнцефалограмм и маг...
# 13   011. Исследование связности в мозге на основе ...
# 14   007. An Improved Query Time for Succinct Dynam...
# 15   Yandex+CERN: 3 Years of Data Science and Parti...
# 16   05. Learning to make reward-guided decisions. ...
# 17               015. What's Behind BLAST - Gene Myers
# 18   022. Efficient Algorithms for Shortest Partial...
# 19          007. Нелинейная регрессия - К.В. Воронцов
# 20   013. Sequence Comparison in the Time of Deluge...
# 21           006. Extremal set theory  — Péter Frankl
# 22   066. «Многорукие бандиты» в рекомендациях – Ми...
# 23   Запись трансляции конференции Data Fest. Основ...
# 24   Запись трансляции конференции Data & Science: ...
# 25   011. Proof of the Pósa−Seymour Conjecture - En...
# 26   Deep Neural Networks for Fast Object Detection...
# 27   001. Основы перечислительной комбинаторики - А...
# 28   093. Опыт Thomson Reuters  основные кейсы и у...
# 29   038. Аренда облачных мощностей для начинающих ...
# ..                                                 ...
# 884        Automatic Speech Recognition, Илья Едренкин
# 885               Mike Korobov - Explain me like I'm 5
# 886  Data Fest² Minsk 2018: Денис Пирштук, Трекинг ...
# 887  Как понять пользователя с полуслова? Алексей ...
# 888  Александр Сологуб – 45 место в Kaggle TGS Salt...
# 889  Eugene Babakhin - My path from Data Science ne...
# 890  Опыт применения DL в соревновании по сегментац...
# 891  Data Fest² Minsk 2018: Александр Радионов, Дос...
# 892  Data Fest² Minsk 2018: Евгений Нижибицкий, Изо...
# 893  Введение в нейронные сети на базе Microsoft Co...
# 894                             Data Fest Belarus 2017
# 895  Обучение машинному обучению и анализу данных у...
# 896  Алексей Натекин – Как сделать самое нестандар...
# 897  Data Fest² Minsk 2018: Юрий Кашницкий, О некот...
# 898  ODS Meetup#1 - Descriptive search at Spotify, ...
# 899  Дмитрий Федоров - Ускорение нейронных сетей с ...
# 900    Data Fest² Minsk 2018 Открытие Data Fest2 Minsk
# 901  Data Fest² Minsk 2018: Артур Степаненко, Как и...
# 902  Deal or No Deal? End-to-End Learning for Negot...
# 903  Архитектура и практика использования Jupyter n...
# 904  Vitalii Radchenko - Sentiment analysis: best p...
# 905  Юрий Зеленский и Вадим Нарейко – 287 место в...
# 906  ODS Meetup#1 - Kaggle Amazon contest: первый ...
# 907  Как научить себя слушать: голосовые технологии...
# 908  Селим Сефербеков – 3 место в Kaggle TGS Salt I...
# 909  Алексей Юркевич - На что обратить внимание дат...
# 910  Data Fest² Minsk 2018: Дмитрий Палевский, Как ...
# 911              ML tutorial for NLP,  Алексей Натекин
# 912  Евгений Бабахин – 1 место в Kaggle TGS Salt I...
# 913  Petr Ermakov - From Jupyter notebook to produc...
#
#                   publishedAt  \
# 0    2018-07-03T15:05:30.000Z
# 1    2015-04-10T12:07:26.000Z
# 2    2016-09-27T13:08:21.000Z
# 3    2017-07-29T10:48:27.000Z
# 4    2018-02-21T12:11:45.000Z
# 5    2016-12-26T08:21:33.000Z
# 6    2016-05-24T19:02:02.000Z
# 7    2014-11-21T18:34:06.000Z
# 8    2018-04-28T18:07:51.000Z
# 9    2017-04-20T15:17:49.000Z
# 10   2018-10-31T15:45:37.000Z
# 11   2018-10-31T15:47:26.000Z
# 12   2016-12-19T13:22:29.000Z
# 13   2016-09-27T13:16:40.000Z
# 14   2014-10-31T14:42:57.000Z
# 15   2015-10-23T10:40:21.000Z
# 16   2017-08-14T13:18:37.000Z
# 17   2014-11-05T16:38:21.000Z
# 18   2014-11-05T16:43:12.000Z
# 19   2014-12-22T14:27:27.000Z
# 20   2014-11-05T15:52:41.000Z
# 21   2017-09-26T17:03:18.000Z
# 22   2018-07-03T15:19:56.000Z
# 23   2016-09-10T21:21:15.000Z
# 24   2016-12-17T14:56:06.000Z
# 25   2014-11-17T14:23:47.000Z
# 26   2015-10-23T10:53:42.000Z
# 27   2014-11-11T15:15:10.000Z
# 28   2018-11-29T10:45:30.000Z
# 29   2016-10-07T09:33:04.000Z
# ..                        ...
# 884  2018-04-19T07:04:35.000Z
# 885  2017-05-22T16:00:28.000Z
# 886  2018-06-04T13:51:25.000Z
# 887  2018-12-12T09:29:42.000Z
# 888  2018-11-08T13:14:52.000Z
# 889  2017-05-22T15:30:25.000Z
# 890  2017-11-08T13:10:00.000Z
# 891  2018-06-08T06:54:36.000Z
# 892  2018-06-04T13:51:52.000Z
# 893  2018-01-08T15:21:56.000Z
# 894  2017-05-22T16:22:55.000Z
# 895  2018-12-12T09:27:35.000Z
# 896  2018-09-17T12:09:41.000Z
# 897  2018-06-04T13:51:52.000Z
# 898  2017-08-25T15:03:26.000Z
# 899  2018-09-17T12:12:12.000Z
# 900  2018-06-04T13:51:52.000Z
# 901  2018-06-04T13:51:52.000Z
# 902  2018-03-27T10:41:56.000Z
# 903  2017-11-08T13:07:17.000Z
# 904  2017-05-22T16:14:19.000Z
# 905  2018-11-08T13:16:24.000Z
# 906  2017-08-25T15:03:26.000Z
# 907  2018-12-12T09:34:49.000Z
# 908  2018-11-08T13:18:07.000Z
# 909  2018-09-17T12:07:53.000Z
# 910  2018-06-04T13:51:52.000Z
# 911  2018-01-08T15:20:18.000Z
# 912  2018-11-08T13:17:48.000Z
# 913  2017-05-22T16:02:11.000Z
#
#                                            description
# 0    В рамках конференции «Data&Science: маркетинг»...
# 1
# 2
# 3    Описание:\nРим Шаяхметов — Предсказание сердеч...
# 4    В рамках конференции Яндекса «Большие данные в...
# 5    За последние 15 лет благодаря появлению больши...
# 6    24 мая в московском офисе Яндекса выступит оди...
# 7    Традиционная модель интернет поиска себя исчер...
# 8    Программа:\n\n00:02:30 Pitch-сессия\nУчастники...
# 9    Станислав расскажет о правилах поступления и о...
# 10   PyData Moscow, 13 октября 2018\n\nВ докладе на...
# 11   PyData Moscow, 13 октября 2018\n\n- Что должно...
# 12
# 13
# 14
# 15   Yandex School of Data Analysis Conference\nMac...
# 16   Deep Learning: Theory, Algorithms, and Applica...
# 17
# 18
# 19   Курс "Машинное обучение" является одним из осн...
# 20
# 21
# 22   «Многорукие бандиты» — это метод тестирования ...
# 23   Смотрите трансляцию событий Прикладного потока...
# 24   Data & Science — серия конференций, на которых...
# 25   In 1974 Paul Seymour conjectured that any grap...
# 26   Yandex School of Data Analysis Conference\nMac...
# 27     курс: "Дискретный анализ и теория вероятностей"
# 28   В докладе речь идет об опыте крупной IT-корпор...
# 29
# ..                                                 ...
# 884
# 885  ELI5 is a Python library which allows to visua...
# 886  Поток II\n\nДенис Пирштук, Head of Data Scienc...
# 887  Data Елка в Минске – 08.12.2018\nby Yandex & O...
# 888  ODS November Meetup – 07.10.2018\n\nПри поддер...
# 889  Overview of what Kaggle is, its pros and cons ...
# 890  Партнеры сообщества: компания JUNO и Юрий Мель...
# 891  Поток I \n\nАлександр Радионов, руководитель с...
# 892  Поток II\n\nЕвгений Нижибицкий, руководитель н...
# 893
# 894  What is #datafestby?\n\nData Fest is an inform...
# 895  Data Елка в Минске – 08.12.2018\nby Yandex & O...
# 896  Основатель ODS Алексей Натекин выступил с расс...
# 897  Поток II\n\nЮрий Кашницкий, Data Scientist ком...
# 898
# 899  В докладе рассмотрены примеры имплементаций не...
# 900
# 901  Поток II\n\nАртур Степаненко, независимый подр...
# 902  Наш специальный гость из Facebook AI Research ...
# 903  Партнеры сообщества: компания JUNO и Юрий Мель...
# 904  Sentiment analysis is a very interesting task ...
# 905  ODS November Meetup – 07.10.2018\n\nПри поддер...
# 906
# 907  Data Елка в Минске – 08.12.2018\nby Yandex & O...
# 908  ODS November Meetup – 07.10.2018\n\nПри поддер...
# 909  Алексей рассказал, на что стоит обратить внима...
# 910  Поток I\n\nДмитрий Палевский, Data Scientist @...
# 911
# 912  ODS November Meetup – 07.10.2018\n\nПри поддер...
# 913  In his speech Petr will overview the long way ...
#
# [914 rows x 5 columns]

# %%
df_vid['url'] = df_vid['youtube_id'].apply(lambda x: 'https://www.youtube.com/watch?v='+x)

# %%
df_vid.to_csv('ods_videos.csv', index=None)

# %%
playlist_ids = {''}

# %%
url_playlist = 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet%2C+id&playlistId={ID}&key={API_KEY}'

# %%
url = "https://www.googleapis.com/youtube/v3/search?key=AIzaSyABZTjzLinNS2tLnR2ZLtLvBcwUIC9fneI&channelId=UCeq6ZIlvC9SVsfhfKnSvM9w&part=snippet,id&order=date&maxResults=20"

# %%
r = requests.get(url_playlist.format(ID='PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T', API_KEY=API))

# %%
r.status_code
# Out:
# 200

# %%
js = json.loads(r.text)

# %%
js
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/N8YnLnxHFg5XypYrX9kj-LD4eOg"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Q1uDKFQ5A7w8OSFJ-v1Lq-SNY7U"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC41NkI0NEY2RDEwNTU3Q0M2',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nАлексей рассказал, как развивают Школу анализа данных и создают сложную и интересную магистерскую программу. Дополнительно рассказал о критериях поступления в ШАД и материалах, которые могут пригодиться. Бонусом прошелся по онлайн-курсам, подготовленным компанией за последние годы.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 0,
#     'publishedAt': '2018-12-12T09:27:35.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'FEzjzTSHlDs'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#       'width': 640}},
#     'title': 'Обучение машинному обучению и анализу данных утром, днём, вечером, ночью, Алексей Толстиков'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ko3HRUCv_1-r03uLZyt2VFmTQrg"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4yODlGNEE0NkRGMEEzMEQy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nНебольшой рассказ о том, как Поиск анализирует запрос пользователя. Алексей рассказал про то, что такое «расширения запроса», как мы их получаем и какую пользу можно извлечь, применяя эти знания неочевидным образом.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 1,
#     'publishedAt': '2018-12-12T09:29:42.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '2dhwd-dYZhI'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/2dhwd-dYZhI/sddefault.jpg',
#       'width': 640}},
#     'title': 'Как понять пользователя с полуслова? Алексей Иванин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5kC5XLsTmUhvnmAmXpDXldORrws"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4wMTcyMDhGQUE4NTIzM0Y5',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nОсновные технические вызовы, которые приходилось преодолевать в Mapbox. Краткий обзор полученных результатов и планов на будущее.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 2,
#     'publishedAt': '2018-12-12T09:32:25.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '-HwjbfQ80WY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/-HwjbfQ80WY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Computer vision: слабое железо не приговор, Александр Матвеенко'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6BG9ptDX77DbBHiLQ87BU5DHq4w"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC41MjE1MkI0OTQ2QzJGNzNG',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nАндрей рассказал, как в Яндекс адаптировали голосовые технологии для работы в устройстве, где нет кнопок, но есть 7 микрофонов. В первую очередь он рассказал про распознавание речи и голосовую активацию. А ещё — про голосовую биометрию и (анти)спуфинг.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 3,
#     'publishedAt': '2018-12-12T09:34:49.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'q_Vc0c4CXqU'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/q_Vc0c4CXqU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Как научить себя слушать: голосовые технологии в Яндекс.Станции, Андрей Андрухович'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/QeeXBHbCgjlJ1JgdJHUq-rv5wdw"',
#    'id': 'UExwVmVBMXRkZ2ZDQjAta3VpOEZSSkR6TzBmOThhTzA1VC4wOTA3OTZBNzVEMTUzOTMy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Data Елка в Минске – 08.12.2018\nby Yandex & ODS Minsk\n\nБез понимания, что находится вокруг и где именно, беспилотному автомобилю не обойтись. Виктор рассказал, как в Яндекс решают задачу распознавания других участников дорожного движения в трёхмерном облаке точек, чем эта задача отличается от распознавания объектов на изображении и как извлечь пользу из совместного использования разных типов сенсоров.',
#     'playlistId': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#     'position': 4,
#     'publishedAt': '2018-12-12T09:36:11.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'sARwqGY5l44'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/sARwqGY5l44/sddefault.jpg',
#       'width': 640}},
#     'title': 'Методы распознавания 3D-объектов для беспилотных автомобилей, Виктор Отлига'}}],
#  'kind': 'youtube#playlistItemListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 5}}

# %%
js['items'][0]['snippet']['description']
# Out:
# 'Сергей Злобин рассказывает про задачу классификации космических объектов (Kaggle PLAsTiCC Astronomical Classification), в кото...'

# %%
# Out:
# [{'duration': 4.501,
#   'start': 6.109,
#   'text': 'всем привет меня зовут сергей злобин я'},
#  {'duration': 2.85, 'start': 9.93, 'text': 'решал'},
#  {'duration': 3.9, 'start': 10.61, 'text': 'конце прошлого года проходила'},
#  {'duration': 3.87, 'start': 12.78, 'text': 'соревнование'},
#  {'duration': 5.109, 'start': 14.51, 'text': 'написано пластик астрономика'},
#  {'duration': 7.49,
#   'start': 16.65,
#   'text': 'классификация и расскажу как наша'},
#  {'duration': 6.771,
#   'start': 19.619,
#   'text': 'команда его решала ну для начала покажу'},
#  {'duration': 8.2, 'start': 24.14, 'text': 'итоговый leader board это уже'},
#  {'duration': 11.67,
#   'start': 26.39,
#   'text': 'приватный вот 13 строчка это наша'},
#  {'duration': 11.4,
#   'start': 32.34,
#   'text': 'команда вот выделена первые 12 мест были'},
#  {'duration': 10.39,
#   'start': 38.06,
#   'text': 'золотая медаль и и чуть чуть было бы на'},
#  {'duration': 6.87,
#   'start': 43.74,
#   'text': 'самом деле очень обидно потому что видно'},
#  {'duration': 4.8,
#   'start': 48.45,
#   'text': 'что проиграли мы достаточно вот в'},
#  {'duration': 4.71,
#   'start': 50.61,
#   'text': 'четвертом знаки буквально при этом если'},
#  {'duration': 4.32,
#   'start': 53.25,
#   'text': 'посмотрю принципе для карла нормальная'},
#  {'duration': 6.05,
#   'start': 55.32,
#   'text': 'ситуация что там во втором-третьем знаке'},
#  {'duration': 3.8,
#   'start': 57.57,
#   'text': 'до но если посмотреть распределение'},
#  {'duration': 7.71,
#   'start': 61.82,
#   'text': 'этого скоро то принципе там даже не во'},
#  {'duration': 7.531, 'start': 65.999, 'text': 'втором знаки дело вот 068'},
#  {'duration': 6.759,
#   'start': 69.53,
#   'text': 'лучше первое место оказалось причем на'},
#  {'duration': 5.46,
#   'start': 73.53,
#   'text': 'публичном лидер борде мы были 12 но'},
#  {'duration': 5.301,
#   'start': 76.289,
#   'text': 'случился как видно тут тоже видно что'},
#  {'duration': 5.579,
#   'start': 78.99,
#   'text': 'небольшой шейков случился на приватном'},
#  {'duration': 7.87, 'start': 81.59, 'text': 'петербурге ну все равно'},
#  {'duration': 7.141,
#   'start': 84.569,
#   'text': 'опыт был очень интересный и мы наверное'},
#  {'duration': 9.06,
#   'start': 89.46,
#   'text': 'сделали максимум того что могли на тот'},
#  {'duration': 8.899,
#   'start': 91.71,
#   'text': 'момент наша команда состояла из трех'},
#  {'duration': 4.6, 'start': 98.52, 'text': 'участников причем команда была'},
#  {'duration': 7.491, 'start': 100.609, 'text': 'интернациональная'},
#  {'duration': 7.65,
#   'start': 103.12,
#   'text': 'вот был у нас студент из австралии по'},
#  {'duration': 5.52,
#   'start': 108.1,
#   'text': 'моему такой деньги не на самом деле не'},
#  {'duration': 4.94,
#   'start': 110.77,
#   'text': 'признаны потому что он там что-то очень'},
#  {'duration': 4.8, 'start': 113.62, 'text': 'быстро все мутил'},
#  {'duration': 6.45,
#   'start': 115.71,
#   'text': 'мофт энкодеры гауссовские процессы'},
#  {'duration': 6.78, 'start': 118.42, 'text': 'какие-то по классификации'},
#  {'duration': 5.23,
#   'start': 122.16,
#   'text': 'но есть на минус у него что он такое'},
#  {'duration': 5.66,
#   'start': 125.2,
#   'text': 'больше был на исследование ориентирована'},
#  {'duration': 9.66,
#   'start': 127.39,
#   'text': 'мы хотели максимальный результат'},
#  {'duration': 9.16,
#   'start': 130.86,
#   'text': 'также была девушка физики которая на'},
#  {'duration': 7.98,
#   'start': 137.05,
#   'text': 'русскоязычная изменить родом из минска'},
#  {'duration': 9.3,
#   'start': 140.02,
#   'text': 'мы сейчас живет в ирландии зовут таня на'},
#  {'duration': 6.33,
#   'start': 145.03,
#   'text': 'как для него них блондинкам ну и также я'},
#  {'duration': 3.96,
#   'start': 149.32,
#   'text': 'ходил команду но я к ним присоединилась'},
#  {'duration': 4.35,
#   'start': 151.36,
#   'text': 'чуть позже там они начали вместе решали'},
#  {'duration': 8.46,
#   'start': 153.28,
#   'text': 'я за две недели к ним присоединился до'},
#  {'duration': 8.91,
#   'start': 155.71,
#   'text': 'конца ну немного расскажу что ввести в'},
#  {'duration': 9.24,
#   'start': 161.74,
#   'text': 'курс дела про задачу сейчас в чили'},
#  {'duration': 9.589,
#   'start': 164.62,
#   'text': 'строится телескоп новый так уже все там'},
#  {'duration': 3.229, 'start': 170.98, 'text': 'строительство заканчивается'},
#  {'duration': 7.09,
#   'start': 174.42,
#   'text': 'расшифровываться этого состоялась'},
#  {'duration': 6.39,
#   'start': 177.31,
#   'text': 'синоптик сего телескоп типа как нового'},
#  {'duration': 4.11,
#   'start': 181.51,
#   'text': 'поколения что лили телескоп у него там'},
#  {'duration': 6.99,
#   'start': 183.7,
#   'text': 'угол зрения там несколько раз больше чем'},
#  {'duration': 7.97,
#   'start': 185.62,
#   'text': 'у телескопа хаббла и планируется что там'},
#  {'duration': 6.03,
#   'start': 190.69,
#   'text': 'сутки будет 20 до 40 терабайт информации'},
#  {'duration': 8.74,
#   'start': 193.59,
#   'text': 'естественно надо abbott автоматически'},
#  {'duration': 7.8,
#   'start': 196.72,
#   'text': 'обрабатывать если интересно там можно'},
#  {'duration': 4.62,
#   'start': 202.33,
#   'text': 'деть прочитать про них ну скоро уже'},
#  {'duration': 6.32,
#   'start': 204.52,
#   'text': 'я так понимаю нужно там если не в этом'},
#  {'duration': 3.89,
#   'start': 206.95,
#   'text': 'на следующем году они должны запустится'},
#  {'duration': 7.42,
#   'start': 211.64,
#   'text': 'теперь какие данные были в задаче ну они'},
#  {'duration': 5.43,
#   'start': 217.59,
#   'text': 'наблюдают за астрономическими объектами'},
#  {'duration': 9.21,
#   'start': 219.06,
#   'text': 'например за какой-то звездой и получают'},
#  {'duration': 7.59,
#   'start': 223.02,
#   'text': 'сигналы в 6 диапазонах там есть как'},
#  {'duration': 5.939,
#   'start': 228.27,
#   'text': 'оптический диапазон типа красного и'},
#  {'duration': 5.81,
#   'start': 230.61,
#   'text': 'зеленого есть кто-то который не видно'},
#  {'duration': 6.241,
#   'start': 234.209,
#   'text': 'глазом типа ультом ультрафиолет'},
#  {'duration': 8.4,
#   'start': 236.42,
#   'text': 'какой-нибудь 6 фильтров стоит у них'},
#  {'duration': 8.96,
#   'start': 240.45,
#   'text': 'телескопе и течение нескольких дней они'},
#  {'duration': 8.01,
#   'start': 244.82,
#   'text': 'наблюдают ну они передвигают к миру и'},
#  {'duration': 7.96,
#   'start': 249.41,
#   'text': 'собирает информацию про каждый объект'},
#  {'duration': 6.36,
#   'start': 252.83,
#   'text': 'вот пример на графике какой получается'},
#  {'duration': 7.65, 'start': 257.37, 'text': 'картинка'},
#  {'duration': 6.75,
#   'start': 259.19,
#   'text': 'что интересно еще сейчас тут видно что'},
#  {'duration': 4.68, 'start': 265.02, 'text': 'есть дырки'},
#  {'duration': 8.71,
#   'start': 265.94,
#   'text': 'это соответствует тому что объект не'},
#  {'duration': 6.3,
#   'start': 269.7,
#   'text': 'всегда виден земли бывает сезоны когда'},
#  {'duration': 5.88, 'start': 274.65, 'text': 'он не виден там типа'},
#  {'duration': 8.37,
#   'start': 276.0,
#   'text': 'не не круглый год его видно на это'},
#  {'duration': 9.509,
#   'start': 280.53,
#   'text': 'данном графике представлены видно что'},
#  {'duration': 12.21,
#   'start': 284.37,
#   'text': 'есть пик какой-то да потом идет спад это'},
#  {'duration': 9.451,
#   'start': 290.039,
#   'text': 'пример сверхновой звезды и кроме данных'},
#  {'duration': 6.78,
#   'start': 296.58,
#   'text': 'таких на каждый объект еще прилагались'},
#  {'duration': 8.36,
#   'start': 299.49,
#   'text': 'каждому мета-данные в обучающей выборке'},
#  {'duration': 4.49, 'start': 303.36, 'text': 'было 14 классов объектов'},
#  {'duration': 4.72,
#   'start': 307.94,
#   'text': 'указывалось расстояние до объекта'},
#  {'duration': 4.45, 'start': 311.06, 'text': 'координаты на небе'},
#  {'duration': 6.39,
#   'start': 312.66,
#   'text': 'где его наблюдали координаты на самом'},
#  {'duration': 4.58,
#   'start': 315.51,
#   'text': 'деле и так понимаю никто толком не стал'},
#  {'duration': 7.08, 'start': 319.05, 'text': 'использовать'},
#  {'duration': 10.15,
#   'start': 320.09,
#   'text': 'поэтому был такой флаг как deep дрилем'},
#  {'duration': 5.17,
#   'start': 326.13,
#   'text': 'feels и то есть участки неба за которыми'},
#  {'duration': 4.23, 'start': 330.24, 'text': 'не'},
#  {'duration': 7.28,
#   'start': 331.3,
#   'text': 'более пристально наблюдает и более'},
#  {'duration': 8.909,
#   'start': 334.47,
#   'text': 'больше как бы не передвигает камеру там'},
#  {'duration': 7.049,
#   'start': 338.58,
#   'text': 'больше там в этом месте задерживаются и'},
#  {'duration': 7.961, 'start': 343.379, 'text': 'метаданных еще была такая'},
#  {'duration': 10.57,
#   'start': 345.629,
#   'text': 'астрономическая штука как новые смыслы и'},
#  {'duration': 8.52,
#   'start': 351.34,
#   'text': 'это как свет вымирает пока доходя до'},
#  {'duration': 11.101,
#   'start': 356.199,
#   'text': 'земли это через космическую пыль кита'},
#  {'duration': 10.44,
#   'start': 359.86,
#   'text': 'мтс их единицах астрономических на самом'},
#  {'duration': 5.519,
#   'start': 367.3,
#   'text': 'деле вот предыдущий слайд это было'},
#  {'duration': 5.7,
#   'start': 370.3,
#   'text': 'пример делать гибельный филси да когда'},
#  {'duration': 4.981,
#   'start': 372.819,
#   'text': 'за объектом пристально блюдо it но за'},
#  {'duration': 6.09,
#   'start': 376.0,
#   'text': 'большинством объектов наблюдает не так'},
#  {'duration': 6.66,
#   'start': 377.8,
#   'text': 'пристально и картинка получается вот на'},
#  {'duration': 5.94,
#   'start': 382.09,
#   'text': 'этой картинке уже не так все очевидно я'},
#  {'duration': 9.079,
#   'start': 384.46,
#   'text': 'так думаю как вот на торе что там сверху'},
#  {'duration': 8.34,
#   'start': 388.03,
#   'text': 'users терновый был вот это называется'},
#  {'duration': 6.611,
#   'start': 393.539,
#   'text': 'white фасаде по области их на самом деле'},
#  {'duration': 4.859,
#   'start': 396.37,
#   'text': 'было и обучающей выборке этим более в'},
#  {'duration': 5.069, 'start': 400.15, 'text': 'тестовой большинство'},
#  {'duration': 7.821,
#   'start': 401.229,
#   'text': 'и как бы задача осложнялась также в этих'},
#  {'duration': 3.831,
#   'start': 405.219,
#   'text': 'областях вот эти вертикальные палочки'},
#  {'duration': 7.93,
#   'start': 409.289,
#   'text': 'это ошибка измерения и в этих областях'},
#  {'duration': 7.621,
#   'start': 413.469,
#   'text': 'ошибка измерения тоже больше чем ddf'},
#  {'duration': 7.141,
#   'start': 417.219,
#   'text': 'областях но это кстати не сказал график'},
#  {'duration': 5.549, 'start': 421.09, 'text': 'это по дням внизу дни не там'},
#  {'duration': 5.1, 'start': 424.36, 'text': 'высчитываются от какого-то там'},
#  {'duration': 3.39,
#   'start': 426.639,
#   'text': 'бодро специального которое в астрономии'},
#  {'duration': 7.73, 'start': 429.46, 'text': 'принято'},
#  {'duration': 10.341,
#   'start': 430.029,
#   'text': 'но дня и сигналы яркость звезды по оси y'},
#  {'duration': 6.65, 'start': 437.19, 'text': 'поехали дальше'},
#  {'duration': 7.859, 'start': 440.37, 'text': 'метрика соревнования было'},
#  {'duration': 7.12,
#   'start': 443.84,
#   'text': 'мультилок лосс но такой вот взвешенный'},
#  {'duration': 5.94,
#   'start': 448.229,
#   'text': 'пересвеченные потому что ну во первых у'},
#  {'duration': 6.929,
#   'start': 450.96,
#   'text': 'соединялось что были более редкие классы'},
#  {'duration': 8.331,
#   'start': 454.169,
#   'text': 'и были те классы которые чаще'},
#  {'duration': 9.201,
#   'start': 457.889,
#   'text': 'встречались они носили одинаковый вклад'},
#  {'duration': 4.59, 'start': 462.5, 'text': 'в том том числе были еще'},
#  {'duration': 8.08,
#   'start': 467.18,
#   'text': 'искусственно добавлены веса на классы'},
#  {'duration': 6.48,
#   'start': 470.27,
#   'text': 'такие же ты причем получилось смешно что'},
#  {'duration': 5.01, 'start': 475.26, 'text': 'организаторы такие'},
#  {'duration': 6.91,
#   'start': 476.75,
#   'text': 'сказали мы вам их не дадим типа как'},
#  {'duration': 5.67,
#   'start': 480.27,
#   'text': 'секрет но через несколько некоторое'},
#  {'duration': 3.99,
#   'start': 483.66,
#   'text': 'время там народ на карле просто их'},
#  {'duration': 4.05,
#   'start': 485.94,
#   'text': 'вычислил там они и оказались все ли'},
#  {'duration': 4.739,
#   'start': 487.65,
#   'text': 'почти все были единицы и утра классы'},
#  {'duration': 6.679,
#   'start': 489.99,
#   'text': 'были двоечки то есть бы им больше'},
#  {'duration': 4.28, 'start': 492.389, 'text': 'предпочтение отдавалось'},
#  {'duration': 4.299, 'start': 497.18, 'text': 'что хорошо в этой'},
#  {'duration': 4.5,
#   'start': 499.47,
#   'text': 'метрики соревнования что это прям можно'},
#  {'duration': 5.671,
#   'start': 501.479,
#   'text': 'было ее засовывать как лосс в'},
#  {'duration': 4.47,
#   'start': 503.97,
#   'text': 'оптимизатор и прям эту функцию и'},
#  {'duration': 7.35,
#   'start': 507.15,
#   'text': 'оптимизировать там то есть не надо'},
#  {'duration': 9.81,
#   'start': 508.44,
#   'text': 'ничего выдумывать дополнительным теперь'},
#  {'duration': 7.919,
#   'start': 514.5,
#   'text': 'немножко про выборки обучающая выборка'},
#  {'duration': 6.75,
#   'start': 518.25,
#   'text': 'было около 8000 объекта в принципе не'},
#  {'duration': 5.431, 'start': 522.419, 'text': 'так много для обучения'},
#  {'duration': 6.06,
#   'start': 525.0,
#   'text': 'хочется сюда побольше поэтому чуть позже'},
#  {'duration': 5.91,
#   'start': 527.85,
#   'text': 'расскажу как с этим боролись а вот тесто'},
#  {'duration': 5.31,
#   'start': 531.06,
#   'text': 'выборка была огромная 33 с половиной'},
#  {'duration': 4.64,
#   'start': 533.76,
#   'text': 'миллионов объектов и занимала там 19'},
#  {'duration': 6.11,
#   'start': 536.37,
#   'text': 'гигабайта кольце с ваш ник который не'},
#  {'duration': 4.08, 'start': 538.4, 'text': 'нигде не открывался там и'},
#  {'duration': 6.33,
#   'start': 544.29,
#   'text': 'затрудняло вот этот большое количество'},
#  {'duration': 5.94,
#   'start': 547.17,
#   'text': 'теста вы раки затрудняло там еще тем что'},
#  {'duration': 4.649,
#   'start': 550.62,
#   'text': 'но если хочешь какие-то там признаки но'},
#  {'duration': 5.099,
#   'start': 553.11,
#   'text': 'обычно считали какие-то признаки ее'},
#  {'duration': 5.611,
#   'start': 555.269,
#   'text': 'сохраняли их куда ты уже вычисленные'},
#  {'duration': 6.481,
#   'start': 558.209,
#   'text': 'ну что вычислить эти признаки зачастую'},
#  {'duration': 7.23,
#   'start': 560.88,
#   'text': 'требовать старом нисколько не часов даже'},
#  {'duration': 7.399,
#   'start': 564.69,
#   'text': 'одни и там если прям тем более'},
#  {'duration': 8.789,
#   'start': 568.11,
#   'text': 'пересчете на 1 ц по утрам поэтому'},
#  {'duration': 5.951,
#   'start': 572.089,
#   'text': 'старались либо на графической видеокарте'},
#  {'duration': 3.541, 'start': 576.899, 'text': 'где можно запускать'},
#  {'duration': 5.549,
#   'start': 578.04,
#   'text': 'что там если можно было оптимизировать'},
#  {'duration': 3.53,
#   'start': 580.44,
#   'text': 'если нельзя китану какие-то признаки как'},
#  {'duration': 3.031, 'start': 583.589, 'text': 'бы не'},
#  {'duration': 5.07,
#   'start': 583.97,
#   'text': 'нельзя было оптимизировать ли мы не'},
#  {'duration': 6.24, 'start': 586.62, 'text': 'умели просто считали'},
#  {'duration': 6.34,
#   'start': 589.04,
#   'text': 'в угол облаке арендовали машину в 20'},
#  {'duration': 6.44,
#   'start': 592.86,
#   'text': 'четырьмя ядрами и там несколько часов'},
#  {'duration': 3.92,
#   'start': 595.38,
#   'text': 'они считала и считались то есть там'},
#  {'duration': 11.519,
#   'start': 600.05,
#   'text': 'такая деятельность была было 14 классов'},
#  {'duration': 4.2,
#   'start': 608.55,
#   'text': 'как быть тех которые данные выборки'},
#  {'duration': 3.341, 'start': 611.569, 'text': 'обучающие'},
#  {'duration': 4.97,
#   'start': 612.75,
#   'text': 'них были вот анонимные кодовые названия'},
#  {'duration': 6.77,
#   'start': 614.91,
#   'text': 'типа там шесть пятнадцать шестнадцать и'},
#  {'duration': 6.96,
#   'start': 617.72,
#   'text': 'так далее 95 и на графике показано'},
#  {'duration': 3.0, 'start': 621.68, 'text': 'распределение'},
#  {'duration': 4.95,
#   'start': 624.74,
#   'text': 'собственно количество объектов в'},
#  {'duration': 7.529,
#   'start': 627.3,
#   'text': 'обучающей выборки по этим классом'},
#  {'duration': 7.54,
#   'start': 629.69,
#   'text': 'что интересном там с помощью этих'},
#  {'duration': 4.531,
#   'start': 634.829,
#   'text': 'метаданных можно было разбить на'},
#  {'duration': 5.789,
#   'start': 637.23,
#   'text': 'галактические объекты которые нашей'},
#  {'duration': 5.339,
#   'start': 639.36,
#   'text': 'галактики млечный путь и те которые не в'},
#  {'duration': 6.241,
#   'start': 643.019,
#   'text': 'нашей галактике вот эту экстра экстра'},
#  {'duration': 8.791,
#   'start': 644.699,
#   'text': 'галактика и прям вот эти классы'},
#  {'duration': 6.269,
#   'start': 649.26,
#   'text': 'ну исходя исходя из информации объект'},
#  {'duration': 4.01,
#   'start': 653.49,
#   'text': 'галактики наш или или ним наши можно'},
#  {'duration': 7.56,
#   'start': 655.529,
#   'text': 'фактически половину было судить'},
#  {'duration': 8.949,
#   'start': 657.5,
#   'text': 'количество классов подходящих среди'},
#  {'duration': 5.791,
#   'start': 663.089,
#   'text': 'классов были такие классы тоже были'},
#  {'duration': 5.25,
#   'start': 666.449,
#   'text': 'канонизированы и не даны стараюсь люди'},
#  {'duration': 5.64,
#   'start': 668.88,
#   'text': 'их вычислить точно там было несколько'},
#  {'duration': 5.071,
#   'start': 671.699,
#   'text': 'типов сверхновых были переменных звезд'},
#  {'duration': 4.95, 'start': 674.52, 'text': 'и микролинзирование такому'},
#  {'duration': 5.82,
#   'start': 676.77,
#   'text': 'астрономический эффект что-то еще было'},
#  {'duration': 8.58,
#   'start': 679.47,
#   'text': 'но на самом деле в буквально на днях они'},
#  {'duration': 8.4,
#   'start': 682.59,
#   'text': 'открыли прям те данные на кота которая'},
#  {'duration': 6.72,
#   'start': 688.05,
#   'text': 'там у них раскрыли свои данные можно'},
#  {'duration': 7.16,
#   'start': 690.99,
#   'text': 'почитать какие там именно классы были'},
#  {'duration': 7.26,
#   'start': 694.77,
#   'text': 'ну как бы без знания астрономии особо'},
#  {'duration': 7.71,
#   'start': 698.15,
#   'text': 'тем более для нашей задачи особого'},
#  {'duration': 6.24,
#   'start': 702.03,
#   'text': 'смысла нет это разбирать и кстати'},
#  {'duration': 5.02,
#   'start': 705.86,
#   'text': 'зануления неподходящий классов по'},
#  {'duration': 4.17,
#   'start': 708.27,
#   'text': 'признаку просто галактики галактики о'},
#  {'duration': 5.16,
#   'start': 710.88,
#   'text': 'начале забыл как бы от например то'},
#  {'duration': 6.03,
#   'start': 712.44,
#   'text': 'сделать и просто потому что как правило'},
#  {'duration': 6.48,
#   'start': 716.04,
#   'text': 'все таки 0 не выдает классификатор там'},
#  {'duration': 7.08,
#   'start': 718.47,
#   'text': 'выдает там 006 какой-нибудь и просто да'},
#  {'duration': 4.98,
#   'start': 722.52,
#   'text': 'даже зануление они подходящих объектов'},
#  {'duration': 5.34,
#   'start': 725.55,
#   'text': 'дала выигрыш такой неплохой на лидер'},
#  {'duration': 4.98,
#   'start': 727.5,
#   'text': 'морде не забывать это делать либо она'},
#  {'duration': 4.77,
#   'start': 730.89,
#   'text': 'таки это отдельная классификатор его'},
#  {'duration': 9.12,
#   'start': 732.48,
#   'text': 'писать для этих галактики и экстра'},
#  {'duration': 7.71,
#   'start': 735.66,
#   'text': 'галактики и пошли дальше мы принципе с'},
#  {'duration': 6.59,
#   'start': 741.6,
#   'text': 'точки зрения моделях ничего особо не'},
#  {'duration': 9.75,
#   'start': 743.37,
#   'text': 'выдумали все использовали like gpm это'},
#  {'duration': 6.48,
#   'start': 748.19,
#   'text': 'градиентный бусик отобьем и какой-то'},
#  {'duration': 4.83, 'start': 753.12, 'text': 'момент еще был'},
#  {'duration': 8.41,
#   'start': 754.67,
#   'text': 'нейронная сеть просто полна связную на 4'},
#  {'duration': 9.78,
#   'start': 757.95,
#   'text': 'скрытых слоя принципе вначале они давали'},
#  {'duration': 8.61,
#   'start': 763.08,
#   'text': 'примерно одно и то же качество и неплохо'},
#  {'duration': 8.3,
#   'start': 767.73,
#   'text': 'даже их было видеть в какой-то момент'},
#  {'duration': 4.34,
#   'start': 771.69,
#   'text': 'чем по мере улучшения признаков наших'},
#  {'duration': 7.59,
#   'start': 776.18,
#   'text': 'flagyl бьем хорошо улучшался нейрон'},
#  {'duration': 4.35,
#   'start': 781.26,
#   'text': 'носить намного хуже я подозреваю что'},
#  {'duration': 4.81,
#   'start': 783.77,
#   'text': 'надо было еще специальным образом'},
#  {'duration': 5.7,
#   'start': 785.61,
#   'text': 'готовить для нейронной сети там эти'},
#  {'duration': 3.28,
#   'start': 788.58,
#   'text': 'признаки не так проста как logic games'},
#  {'duration': 3.399, 'start': 791.31, 'text': 'королем'},
#  {'duration': 5.28,
#   'start': 791.86,
#   'text': 'но в результате как-то времени на это не'},
#  {'duration': 4.341,
#   'start': 794.709,
#   'text': 'было мы сделали ставку на вычислено'},
#  {'duration': 4.98,
#   'start': 797.14,
#   'text': 'признаки добавления признаков и'},
#  {'duration': 7.599,
#   'start': 799.05,
#   'text': 'использования logic дома и готовое'},
#  {'duration': 6.11,
#   'start': 802.12,
#   'text': 'решение нейросеть у нас не маслом ну мы'},
#  {'duration': 6.18, 'start': 806.649, 'text': 'делали'},
#  {'duration': 6.88,
#   'start': 808.23,
#   'text': 'обучались на 5 фондах обычно по крайней'},
#  {'duration': 5.721,
#   'start': 812.829,
#   'text': 'мере для отбора признаков каких то'},
#  {'duration': 6.36,
#   'start': 815.11,
#   'text': 'проверки гипотез а ближе к концу'},
#  {'duration': 6.279,
#   'start': 818.55,
#   'text': 'совмещены делали на 10 photos было чуть'},
#  {'duration': 6.57, 'start': 821.47, 'text': 'чуть получше из-за этого ну и'},
#  {'duration': 7.32, 'start': 824.829, 'text': 'и итоговый наш'},
#  {'duration': 10.44,
#   'start': 828.04,
#   'text': 'score public был 0 800 15 для сравнения'},
#  {'duration': 10.261,
#   'start': 832.149,
#   'text': 'первое место было 0 670 то есть конечно'},
#  {'duration': 8.789,
#   'start': 838.48,
#   'text': 'мы далеко не дотянули но тоже не тоже'},
#  {'duration': 8.27,
#   'start': 842.41,
#   'text': 'неплохо блин да как такового особо нас'},
#  {'duration': 6.06,
#   'start': 847.269,
#   'text': 'не было мы просто обучили 2 2 модели'},
#  {'duration': 6.55,
#   'start': 850.68,
#   'text': 'чуть-чуть разные признаки имеют разные'},
#  {'duration': 4.641,
#   'start': 853.329,
#   'text': 'параметрами и вот 003 нам это чуть-чуть'},
#  {'duration': 4.289, 'start': 857.23, 'text': 'докинул'},
#  {'duration': 5.85,
#   'start': 857.97,
#   'text': 'ну тоже неплохо бы на больше уже времени'},
#  {'duration': 6.711,
#   'start': 861.519,
#   'text': 'не хватило на самом деле потому что мы'},
#  {'duration': 4.41,
#   'start': 863.82,
#   'text': 'последние дни уже все это доделываем'},
#  {'duration': 5.409,
#   'start': 870.24,
#   'text': 'скелет наше решение все-таки был'},
#  {'duration': 7.261,
#   'start': 872.589,
#   'text': 'вычисление признаков я сейчас немножко'},
#  {'duration': 5.3,
#   'start': 875.649,
#   'text': 'расскажу как как мы их считали было'},
#  {'duration': 4.5, 'start': 879.85, 'text': 'шесть каналов'},
#  {'duration': 4.151,
#   'start': 880.949,
#   'text': '6 фильтром можно считать по каждому'},
#  {'duration': 4.049, 'start': 884.35, 'text': 'каналу'},
#  {'duration': 4.89,
#   'start': 885.1,
#   'text': 'какие-то признаки можно там все по по'},
#  {'duration': 4.171, 'start': 888.399, 'text': 'всем месте как-то их считать'},
#  {'duration': 5.87,
#   'start': 889.99,
#   'text': 'агрегировать вначале естественно все там'},
#  {'duration': 3.29, 'start': 892.57, 'text': 'считали на стандартных'},
#  {'duration': 5.23,
#   'start': 895.87,
#   'text': 'стандартные признаки на вот временных'},
#  {'duration': 6.86,
#   'start': 898.49,
#   'text': 'рядов и потом минимум максимум медиана'},
#  {'duration': 4.25, 'start': 901.1, 'text': 'средняя дисперсии асимметрия'},
#  {'duration': 6.03, 'start': 905.77, 'text': 'потом все стали искать'},
#  {'duration': 5.59, 'start': 909.55, 'text': 'библиотеки в том числе'},
#  {'duration': 7.11,
#   'start': 911.8,
#   'text': 'астрономические библиотеки на которые'},
#  {'duration': 6.44,
#   'start': 915.14,
#   'text': 'могли бы помочь в итоге мы остановились'},
#  {'duration': 5.47, 'start': 918.91, 'text': 'вот изюм'},
#  {'duration': 5.32,
#   'start': 921.58,
#   'text': 'библиотека довольно много фич оттуда и'},
#  {'duration': 7.59,
#   'start': 924.38,
#   'text': 'пара fitch и спилить эти пиццы нас'},
#  {'duration': 10.35,
#   'start': 926.9,
#   'text': 'оказалось еще после того как вот эти'},
#  {'duration': 6.95,
#   'start': 931.97,
#   'text': 'прошли где особо думать не надо стали'},
#  {'duration': 5.46, 'start': 937.25, 'text': 'заниматься'},
#  {'duration': 9.33,
#   'start': 938.92,
#   'text': 'викинг за вами ficken клевых то есть'},
#  {'duration': 5.54,
#   'start': 942.71,
#   'text': 'зная примерную форму кривой пытаться ее'},
#  {'duration': 7.75,
#   'start': 948.52,
#   'text': 'под подогнать под эту кривую посчитать'},
#  {'duration': 6.42,
#   'start': 952.73,
#   'text': 'какие параметры кривой очень важно не'},
#  {'duration': 4.65,
#   'start': 956.27,
#   'text': 'только параметры кривой засовывать как'},
#  {'duration': 4.26, 'start': 959.15, 'text': 'признак ну и'},
#  {'duration': 5.07,
#   'start': 960.92,
#   'text': 'то ошибку аппроксимации которые при этом'},
#  {'duration': 5.66,
#   'start': 963.41,
#   'text': 'получилось чтоб это лишнее то мне'},
#  {'duration': 6.48, 'start': 965.99, 'text': 'засунуть ну и наконец более'},
#  {'duration': 6.24,
#   'start': 969.07,
#   'text': 'признаки которая чиста таки она знает'},
#  {'duration': 5.52,
#   'start': 972.47,
#   'text': 'астрономию почитать предметную область'},
#  {'duration': 7.78,
#   'start': 975.31,
#   'text': 'частности такой признак это звездная'},
#  {'duration': 6.0,
#   'start': 977.99,
#   'text': 'величина чуть позже расскажу стараясь'},
#  {'duration': 2.7, 'start': 983.09, 'text': 'так как'},
#  {'duration': 4.64,
#   'start': 983.99,
#   'text': 'обучающую баркова не очень большая'},
#  {'duration': 7.55, 'start': 985.79, 'text': 'старались много признаков'},
#  {'duration': 6.52,
#   'start': 988.63,
#   'text': 'не держать и постоянно их отбирали'},
#  {'duration': 4.36, 'start': 993.34, 'text': 'полезные признаки'},
#  {'duration': 8.81,
#   'start': 995.15,
#   'text': 'в итоге оказалось около 80 признаков у'},
#  {'duration': 6.26,
#   'start': 997.7,
#   'text': 'нас в конце концов мы остановились'},
#  {'duration': 9.66,
#   'start': 1004.35,
#   'text': 'использование пир mutation impotence это'},
#  {'duration': 7.65,
#   'start': 1008.77,
#   'text': 'время библиотека ели 5 это когда меняешь'},
#  {'duration': 4.99,
#   'start': 1014.01,
#   'text': 'случайно значение какого-то столбца и'},
#  {'duration': 5.48,
#   'start': 1016.42,
#   'text': 'смотришь как это влияет на результат но'},
#  {'duration': 5.43,
#   'start': 1019.0,
#   'text': 'естественно про кросс валидации мы тоже'},
#  {'duration': 4.24,
#   'start': 1021.9,
#   'text': 'контролер контролировали себя на ты же'},
#  {'duration': 8.25, 'start': 1024.43, 'text': 'не всегда это коррелировало'},
#  {'duration': 8.46,
#   'start': 1026.14,
#   'text': 'с лидер бурным но тем ни менее теперь'},
#  {'duration': 6.32,
#   'start': 1032.68,
#   'text': 'немножко расскажу про астрономические'},
#  {'duration': 5.94,
#   'start': 1034.6,
#   'text': 'вот почему полезно оказалось знать'},
#  {'duration': 6.61, 'start': 1039.0, 'text': 'предметную область'},
#  {'duration': 9.0,
#   'start': 1040.54,
#   'text': 'вначале засветила хороший признак вот'},
#  {'duration': 5.06,
#   'start': 1045.61,
#   'text': 'этот может узнает грегор сенковский из'},
#  {'duration': 5.88, 'start': 1049.54, 'text': 'польши'},
#  {'duration': 6.88,
#   'start': 1050.67,
#   'text': 'это расстояние между надежным пакетным'},
#  {'duration': 6.18,
#   'start': 1055.42,
#   'text': 'сигналами этом не сказал о сигналов еще'},
#  {'duration': 6.93,
#   'start': 1057.55,
#   'text': 'есть флаг насколько надежно он где т.д.'},
#  {'duration': 4.52,
#   'start': 1061.6,
#   'text': 'редактировано построений на нам на фоне'},
#  {'duration': 4.92, 'start': 1064.48, 'text': 'неба'},
#  {'duration': 5.59,
#   'start': 1066.12,
#   'text': 'вот это соответствует примерно если это'},
#  {'duration': 4.41,
#   'start': 1069.4,
#   'text': 'сверхновая это примерно какой-то'},
#  {'duration': 5.16,
#   'start': 1071.71,
#   'text': 'соответствовать ширине вот этого пиковым'},
#  {'duration': 5.36,
#   'start': 1073.81,
#   'text': 'сверхновой поэтому это очень полезной'},
#  {'duration': 5.43, 'start': 1076.87, 'text': 'оказалась величина'},
#  {'duration': 6.39,
#   'start': 1079.17,
#   'text': 'другая полезная величина это вот как я'},
#  {'duration': 11.49,
#   'start': 1082.3,
#   'text': 'уже горел магнитуда звездная величина'},
#  {'duration': 11.26,
#   'start': 1085.56,
#   'text': 'тут формула я представлена это то есть'},
#  {'duration': 4.65,
#   'start': 1093.79,
#   'text': 'так и исходу вы вряд ли приду если не'},
#  {'duration': 5.22,
#   'start': 1096.82,
#   'text': 'почитать их невозможно при наверно'},
#  {'duration': 5.76,
#   'start': 1098.44,
#   'text': 'придумать практически но нас связано с'},
#  {'duration': 3.33, 'start': 1102.04, 'text': 'законом что яркость обратно'},
#  {'duration': 4.38,
#   'start': 1104.2,
#   'text': 'пропорциональна квадрату расстояния'},
#  {'duration': 7.44,
#   'start': 1105.37,
#   'text': 'потому что вот этот диск мод величина'},
#  {'duration': 7.88,
#   'start': 1108.58,
#   'text': 'dice мод это логарифм то же расстояние'},
#  {'duration': 3.65, 'start': 1112.81, 'text': 'до звезды и'},
#  {'duration': 8.26,
#   'start': 1116.49,
#   'text': 'с коэффициентом 5 поэтому тут получается'},
#  {'duration': 5.66,
#   'start': 1120.28,
#   'text': 'что этот закон то есть вот dice мод он'},
#  {'duration': 3.6, 'start': 1124.75, 'text': 'был прям'},
#  {'duration': 4.42,
#   'start': 1125.94,
#   'text': 'метаданных то есть это не не про не'},
#  {'duration': 7.53,
#   'start': 1128.35,
#   'text': 'расстояние это логарифм расстояние там с'},
#  {'duration': 8.55,
#   'start': 1130.36,
#   'text': 'кем-то коэффициентом и наконец еще'},
#  {'duration': 5.48,
#   'start': 1135.88,
#   'text': 'полезным в капсом коне в самом конце мы'},
#  {'duration': 5.28, 'start': 1138.91, 'text': 'то не посчитала'},
#  {'duration': 4.75, 'start': 1141.36, 'text': 'астрономические цвета ты это'},
#  {'duration': 5.4,
#   'start': 1144.19,
#   'text': 'разность вот этих magnitude между'},
#  {'duration': 5.12,
#   'start': 1146.11,
#   'text': 'некоторыми каналами и например зеленым и'},
#  {'duration': 3.99, 'start': 1149.59, 'text': 'красным'},
#  {'duration': 5.049,
#   'start': 1151.23,
#   'text': 'там между никогда некоторыми другими'},
#  {'duration': 4.76,
#   'start': 1153.58,
#   'text': 'парами это на самом деле промежуточный'},
#  {'duration': 4.801, 'start': 1156.279, 'text': 'шаг там при вычислении'},
#  {'duration': 6.73,
#   'start': 1158.34,
#   'text': 'в странами называется как коррекция'},
#  {'duration': 6.589,
#   'start': 1161.08,
#   'text': 'сигналов на сама как коррекция нам'},
#  {'duration': 5.459,
#   'start': 1165.07,
#   'text': 'ничего не докинул а вот эта штука нам'},
#  {'duration': 6.041,
#   'start': 1167.669,
#   'text': 'такие новые причем мы ее буквально'},
#  {'duration': 7.291,
#   'start': 1170.529,
#   'text': 'посчитали там за 6 часов до окончания'},
#  {'duration': 5.969,
#   'start': 1173.71,
#   'text': 'соревнований а я на там где-то он чуть'},
#  {'duration': 9.9,
#   'start': 1177.82,
#   'text': 'ли не 002 накинула такие астрономические'},
#  {'duration': 9.901,
#   'start': 1179.679,
#   'text': 'цвета но вот эта картинка сверхновых раз'},
#  {'duration': 2.61,
#   'start': 1187.72,
#   'text': 'там было несколько типов сверхновых'},
#  {'duration': 3.0, 'start': 1189.58, 'text': 'соревнований'},
#  {'duration': 4.469,
#   'start': 1190.33,
#   'text': 'это просто картинка из интернета чтобы'},
#  {'duration': 5.959,
#   'start': 1192.58,
#   'text': 'показать что они принципе это все похожи'},
#  {'duration': 7.13, 'start': 1194.799, 'text': 'и чем они отличаются'},
#  {'duration': 7.181,
#   'start': 1198.539,
#   'text': 'но отличаются вот это магнитуда'},
#  {'duration': 7.531,
#   'start': 1201.929,
#   'text': 'собственно у них разные который про'},
#  {'duration': 8.01,
#   'start': 1205.72,
#   'text': 'которые на прошлом станет ст-1 говорил и'},
#  {'duration': 7.53,
#   'start': 1209.46,
#   'text': 'вот этой вот эта ширина пика и у них'},
#  {'duration': 6.299,
#   'start': 1213.73,
#   'text': 'чуть разное да если в них и посчитать'},
#  {'duration': 7.149,
#   'start': 1216.99,
#   'text': 'некоторые более экзотические там с двумя'},
#  {'duration': 4.98,
#   'start': 1220.029,
#   'text': 'горбами да какими то почему на'},
#  {'duration': 4.351, 'start': 1224.139, 'text': 'сверхновых ну'},
#  {'duration': 6.571,
#   'start': 1225.009,
#   'text': 'упор делали потому что они больше всего'},
#  {'duration': 9.679,
#   'start': 1228.49,
#   'text': 'путались и на них можно было больше'},
#  {'duration': 12.15,
#   'start': 1231.58,
#   'text': 'всего заработать очков поехать дальше'},
#  {'duration': 7.571,
#   'start': 1238.169,
#   'text': 'теперь немножко про подгонку кривых я'},
#  {'duration': 2.97,
#   'start': 1243.73,
#   'text': 'лично начал просто ступа с гауссовского'},
#  {'duration': 3.809, 'start': 1245.74, 'text': 'распределения'},
#  {'duration': 4.05,
#   'start': 1246.7,
#   'text': 'над параметр вот этот дисперсия'},
#  {'duration': 5.25, 'start': 1249.549, 'text': 'оценивает ширину пикой'},
#  {'duration': 9.62,
#   'start': 1250.75,
#   'text': 'и принципе это уже тоже мне добавила'},
#  {'duration': 9.0,
#   'start': 1254.799,
#   'text': 'немножко также сделал как сверхновых'},
#  {'duration': 7.269,
#   'start': 1260.37,
#   'text': 'только на логарифме с этих сигналов'},
#  {'duration': 6.451,
#   'start': 1263.799,
#   'text': 'яркости подъем и спад чтоб оценить'},
#  {'duration': 7.01,
#   'start': 1267.639,
#   'text': 'наклон вот эти которые вот на прошлом'},
#  {'duration': 4.399, 'start': 1270.25, 'text': 'сойди злодеем показывал'},
#  {'duration': 5.471, 'start': 1274.859, 'text': 'также из статьи'},
#  {'duration': 7.37,
#   'start': 1277.809,
#   'text': 'борьба zen это много на самом деле'},
#  {'duration': 7.049,
#   'start': 1280.33,
#   'text': 'авторов такое параметрическое уравнение'},
#  {'duration': 4.81, 'start': 1285.179, 'text': 'тут часть есть часть которая'},
#  {'duration': 4.77,
#   'start': 1287.379,
#   'text': 'соответствует подъему сигналов'},
#  {'duration': 8.701,
#   'start': 1289.989,
#   'text': 'сверхновых и часть которая затухание'},
#  {'duration': 8.97,
#   'start': 1292.149,
#   'text': 'сигнала и ну и вот когда после подгонки'},
#  {'duration': 6.179,
#   'start': 1298.69,
#   'text': 'кривой можно вот эти параметры получить'},
#  {'duration': 7.26,
#   'start': 1301.119,
#   'text': 'которые как потом засунуть их уже как'},
#  {'duration': 6.24,
#   'start': 1304.869,
#   'text': 'признак пробовали другие кривые в том'},
#  {'duration': 3.92,
#   'start': 1308.379,
#   'text': 'числе вот с двумя пиками как я показывал'},
#  {'duration': 5.31, 'start': 1311.109, 'text': 'на прошлом слайде'},
#  {'duration': 11.74,
#   'start': 1312.299,
#   'text': 'сожалению нам не помогло точно не знаем'},
#  {'duration': 8.61,
#   'start': 1316.419,
#   'text': 'почему да еще был такой загадочный класс'},
#  {'duration': 4.59, 'start': 1324.039, 'text': '99'},
#  {'duration': 6.6,
#   'start': 1325.029,
#   'text': 'его не было в обучающей выборке то есть'},
#  {'duration': 6.091,
#   'start': 1328.629,
#   'text': 'это надо было как бы идея такая что'},
#  {'duration': 5.071,
#   'start': 1331.629,
#   'text': 'нужно сделать надежную модель которая не'},
#  {'duration': 5.939,
#   'start': 1334.72,
#   'text': 'только основном среди известно классов'},
#  {'duration': 6.0,
#   'start': 1336.7,
#   'text': 'скажет что вот этот класс она еще скажет'},
#  {'duration': 5.94,
#   'start': 1340.659,
#   'text': 'что что это может быть что-то другое'},
#  {'duration': 6.809,
#   'start': 1342.7,
#   'text': 'такая идея ну так как обучающей выборке'},
#  {'duration': 7.621,
#   'start': 1346.599,
#   'text': 'нет чуть делать там не очень понятно и'},
#  {'duration': 7.35,
#   'start': 1349.509,
#   'text': 'на форуме обсуждали и многие результате'},
#  {'duration': 7.459,
#   'start': 1354.22,
#   'text': 'остановились вот участник оливер'},
#  {'duration': 8.101,
#   'start': 1356.859,
#   'text': 'придумал такую форму надо взять просто'},
#  {'duration': 7.75,
#   'start': 1361.679,
#   'text': 'вероятности других классов вычесть их из'},
#  {'duration': 7.73,
#   'start': 1364.96,
#   'text': 'единиц и перемножить и это в какой-то'},
#  {'duration': 5.07,
#   'start': 1369.429,
#   'text': 'мере будет оценка вот этого класса 99'},
#  {'duration': 3.909,
#   'start': 1372.69,
#   'text': 'единственно что вот этот коэффициент'},
#  {'duration': 4.4,
#   'start': 1374.499,
#   'text': 'надо эмпирически подбирать по лидер'},
#  {'duration': 2.3, 'start': 1376.599, 'text': 'бурду'},
#  {'duration': 3.4,
#   'start': 1379.3,
#   'text': 'то есть распределение вот этого сколько'},
#  {'duration': 2.82, 'start': 1382.13, 'text': 'там этих'},
#  {'duration': 5.72,
#   'start': 1382.7,
#   'text': 'класс авианосца 9 на тесто выборки'},
#  {'duration': 10.26,
#   'start': 1384.95,
#   'text': 'неизвестны вот просто петербург probing'},
#  {'duration': 9.03,
#   'start': 1388.42,
#   'text': 'помогал да еще была более загадочная'},
#  {'duration': 6.33,
#   'start': 1395.21,
#   'text': 'формула появилась среди не соревнования'},
#  {'duration': 6.49,
#   'start': 1397.45,
#   'text': 'участника скорпов он использовал тут'},
#  {'duration': 6.06,
#   'start': 1401.54,
#   'text': 'средние медианы и максимум и заставил из'},
#  {'duration': 4.92,
#   'start': 1403.94,
#   'text': 'них вот такую хитрую формулу как он'},
#  {'duration': 5.97, 'start': 1407.6, 'text': 'пишет что он получил от'},
#  {'duration': 8.7,
#   'start': 1408.86,
#   'text': 'генетическим алгоритмом в подробности не'},
#  {'duration': 10.11,
#   'start': 1413.57,
#   'text': 'вдавался и и вот он это я прям же'},
#  {'duration': 10.79,
#   'start': 1417.56,
#   'text': 'записал как он записал а тут эта строчка'},
#  {'duration': 8.94,
#   'start': 1423.68,
#   'text': 'я просто у просите упростил немножко'},
#  {'duration': 8.58,
#   'start': 1428.35,
#   'text': 'чтобы было по чуть понятнее ну физически'},
#  {'duration': 4.31,
#   'start': 1432.62,
#   'text': 'смысла не очень ясен она работала причем'},
#  {'duration': 7.0,
#   'start': 1438.76,
#   'text': 'ждем работа лучше той форму вот по'},
#  {'duration': 5.49,
#   'start': 1441.92,
#   'text': 'крайней мере вот на наших тех моделях'},
#  {'duration': 4.74,
#   'start': 1445.76,
#   'text': 'что мы делали на чуть лучше работал кто'},
#  {'duration': 4.44,
#   'start': 1447.41,
#   'text': 'то писал что у него типа не прочие'},
#  {'duration': 4.5,
#   'start': 1450.5,
#   'text': 'практически ничего не изменилось или'},
#  {'duration': 4.56,
#   'start': 1451.85,
#   'text': 'даже стало чуть уже у нас несколько раз'},
#  {'duration': 4.83, 'start': 1455.0, 'text': 'во лидировали эту формулу'},
#  {'duration': 6.87,
#   'start': 1456.41,
#   'text': 'она нас постоянно там может на 001 там'},
#  {'duration': 6.81,
#   'start': 1459.83,
#   'text': 'ли 002 чуть лучше давала мы остановились'},
#  {'duration': 4.37,
#   'start': 1463.28,
#   'text': 'на ней теперь я хотел просто показать'},
#  {'duration': 5.34, 'start': 1466.64, 'text': 'ещё'},
#  {'duration': 5.29,
#   'start': 1467.65,
#   'text': 'победитель соревнования он по-другому'},
#  {'duration': 4.16, 'start': 1471.98, 'text': 'подошел'},
#  {'duration': 7.56,
#   'start': 1472.94,
#   'text': 'точнее подошел то он также только'},
#  {'duration': 6.55,
#   'start': 1476.14,
#   'text': 'придумал другую формулу и каким-то'},
#  {'duration': 4.92,
#   'start': 1480.5,
#   'text': 'образом он догадался что вот этот класс'},
#  {'duration': 6.93,
#   'start': 1482.69,
#   'text': '99 он как-то связан со сверхновыми'},
#  {'duration': 8.04,
#   'start': 1485.42,
#   'text': 'и вот эти классы 4250 2 6 1 95'},
#  {'duration': 5.189,
#   'start': 1489.62,
#   'text': 'классы сверхновых там разные типы и он'},
#  {'duration': 4.5, 'start': 1493.46, 'text': 'просто взял и'},
#  {'duration': 7.291,
#   'start': 1494.809,
#   'text': 'как ты взвесил эти вероятности этих'},
#  {'duration': 6.99,
#   'start': 1497.96,
#   'text': 'классов и это и мы вот очень сильно если'},
#  {'duration': 8.01,
#   'start': 1502.1,
#   'text': 'посмотреть как он пишет что ему это вот'},
#  {'duration': 8.79,
#   'start': 1504.95,
#   'text': 'на 005 до кино но на самом деле мало кто'},
#  {'duration': 6.33,
#   'start': 1510.11,
#   'text': 'догадался до этого ну то есть эти люди'},
#  {'duration': 3.84,
#   'start': 1513.74,
#   'text': 'только топик от победе мы что-то сделали'},
#  {'duration': 4.08, 'start': 1516.44, 'text': 'такое нетривиальное'},
#  {'duration': 7.32,
#   'start': 1517.58,
#   'text': 'ну нет нет нет не так как все вот как мы'},
#  {'duration': 7.53,
#   'start': 1520.52,
#   'text': 'как например на стадии когда после того'},
#  {'duration': 7.409,
#   'start': 1524.9,
#   'text': 'как сейчас еще раскрыли навести на'},
#  {'duration': 8.22,
#   'start': 1528.05,
#   'text': 'данные можно посчитать там как без'},
#  {'duration': 7.141,
#   'start': 1532.309,
#   'text': 'классно 99 и фактически получилось что'},
#  {'duration': 4.83,
#   'start': 1536.27,
#   'text': 'этот колдун первое место он реально на'},
#  {'duration': 4.979,
#   'start': 1539.45,
#   'text': 'втором месте если как бы не учитывать'},
#  {'duration': 6.78,
#   'start': 1541.1,
#   'text': 'класс 99 то есть снять следующее за ним'},
#  {'duration': 5.731,
#   'start': 1544.429,
#   'text': 'участники они вы были на первом месте то'},
#  {'duration': 8.1,
#   'start': 1547.88,
#   'text': 'есть фактически трюк ему позволил на'},
#  {'duration': 8.6,
#   'start': 1550.16,
#   'text': 'первыми строить так как данных мало мы'},
#  {'duration': 4.11,
#   'start': 1555.98,
#   'text': 'решили сделать аргументацию данных'},
#  {'duration': 4.81, 'start': 1558.76, 'text': 'облака'},
#  {'duration': 6.9,
#   'start': 1560.09,
#   'text': 'было дано ошибка измерения вертикальная'},
#  {'duration': 7.88,
#   'start': 1563.57,
#   'text': 'палочка которая показывал вначале это'},
#  {'duration': 8.569,
#   'start': 1566.99,
#   'text': 'будет было специально дано flux'},
#  {'duration': 4.109, 'start': 1571.45, 'text': 'ошибка измерения мы просто'},
#  {'duration': 6.78,
#   'start': 1575.62,
#   'text': 'раздули в начале в 10 раз выборку потом'},
#  {'duration': 6.75, 'start': 1578.48, 'text': 'в 30 раз ближе к концу'},
#  {'duration': 6.4,
#   'start': 1582.4,
#   'text': 'просто нормальным распределением с этой'},
#  {'duration': 7.25,
#   'start': 1585.23,
#   'text': 'ошибкой подкорректировали сигналы и это'},
#  {'duration': 6.68, 'start': 1588.8, 'text': 'действительно улучшило'},
#  {'duration': 3.0, 'start': 1592.48, 'text': 'score'},
#  {'duration': 8.551,
#   'start': 1597.539,
#   'text': 'но ближе к концу соревнования где то за'},
#  {'duration': 8.61,
#   'start': 1600.629,
#   'text': 'неделю мы застряли в районе 0 85 то есть'},
#  {'duration': 6.48,
#   'start': 1606.09,
#   'text': 'уже там с двумя горбами какими-то'},
#  {'duration': 6.17,
#   'start': 1609.239,
#   'text': 'вычисляли признаки там еще че-то там'},
#  {'duration': 5.25, 'start': 1612.57, 'text': 'делали ничего не помогало'},
#  {'duration': 6.52,
#   'start': 1615.409,
#   'text': 'поняли что мы видимо уже все там'},
#  {'duration': 9.659,
#   'start': 1617.82,
#   'text': 'переучились на обучающей уборку объектов'},
#  {'duration': 9.36,
#   'start': 1621.929,
#   'text': 'мало и решили раздуть еще больше десяти'},
#  {'duration': 7.02,
#   'start': 1627.479,
#   'text': 'раз до 30 но при этом мы осознали'},
#  {'duration': 7.26,
#   'start': 1631.289,
#   'text': 'до нас дошло наконец что вот этот'},
#  {'duration': 8.04,
#   'start': 1634.499,
#   'text': 'ddf который я говорил области их в'},
#  {'duration': 7.35,
#   'start': 1638.549,
#   'text': 'обучающей выборке владеть процентов в'},
#  {'duration': 6.541,
#   'start': 1642.539,
#   'text': 'тестовый только один процент поэтому мы'},
#  {'duration': 5.311,
#   'start': 1645.899,
#   'text': 'раздали так что вот эти ddf региона вы и'},
#  {'duration': 3.39,
#   'start': 1649.08,
#   'text': 'практически только в одном фланге'},
#  {'duration': 7.049, 'start': 1651.21, 'text': 'оставили из 30'},
#  {'duration': 7.86,
#   'start': 1652.47,
#   'text': 'и таким образом мы выровняли примерно то'},
#  {'duration': 4.081,
#   'start': 1658.259,
#   'text': 'что в тост с таким был и отвагу'},
#  {'duration': 5.549,
#   'start': 1660.33,
#   'text': 'монтированы с точки зрения ddf по'},
#  {'duration': 6.179,
#   'start': 1662.34,
#   'text': 'крайней мере так же стали просто я'},
#  {'duration': 7.941,
#   'start': 1665.879,
#   'text': 'открыл манула вот как-то уменьшить'},
#  {'duration': 9.51,
#   'start': 1668.519,
#   'text': 'переобучение влад живем и стали пытаться'},
#  {'duration': 6.099,
#   'start': 1673.82,
#   'text': 'следовать советам и это при этом она'},
#  {'duration': 4.71,
#   'start': 1678.029,
#   'text': 'кросс валидации было чуть хуже там они'},
#  {'duration': 7.26,
#   'start': 1679.919,
#   'text': 'не сильно зато намного лучше на лидер'},
#  {'duration': 6.841,
#   'start': 1682.739,
#   'text': 'бурге вот то есть мы уменьшили глубину'},
#  {'duration': 4.71,
#   'start': 1687.179,
#   'text': 'дерево чувство листьев и вот это'},
#  {'duration': 6.809,
#   'start': 1689.58,
#   'text': 'интересный параметр макс бен там по'},
#  {'duration': 8.72,
#   'start': 1691.889,
#   'text': 'дефолту 255 если его довольно сильно'},
#  {'duration': 4.22,
#   'start': 1696.389,
#   'text': 'уменьшить то тоже хороший был выигрыш'},
#  {'duration': 8.19,
#   'start': 1701.76,
#   'text': 'что у нас не получилось вот питер там у'},
#  {'duration': 8.61,
#   'start': 1705.06,
#   'text': 'тела в тайн кадры принципе картинки'},
#  {'duration': 6.6,
#   'start': 1709.95,
#   'text': 'караки картинки красивые были но как'},
#  {'duration': 4.89,
#   'start': 1713.67,
#   'text': 'результат это на результате никак не'},
#  {'duration': 4.71, 'start': 1716.55, 'text': 'сказалось много пробовали'},
#  {'duration': 6.45,
#   'start': 1718.56,
#   'text': 'параметрических кривых из разных статей'},
#  {'duration': 7.05,
#   'start': 1721.26,
#   'text': 'там таня прошерстила много статей как'},
#  {'duration': 7.14,
#   'start': 1725.01,
#   'text': 'такими кривыми дома аппроксимировать в'},
#  {'duration': 5.09,
#   'start': 1728.31,
#   'text': 'астрономии тоже ничего дополнительно нам'},
#  {'duration': 4.47, 'start': 1732.15, 'text': 'не докинул'},
#  {'duration': 6.82,
#   'start': 1733.4,
#   'text': 'пытались питер опять же там гауссовские'},
#  {'duration': 5.46,
#   'start': 1736.62,
#   'text': 'просто процессы исследовал это у нее там'},
#  {'duration': 4.59,
#   'start': 1740.22,
#   'text': 'не сошлось хотя вот потом дальше'},
#  {'duration': 5.91, 'start': 1742.08, 'text': 'расскажу победителя'},
#  {'duration': 6.3, 'start': 1744.81, 'text': 'это было он их использовал'},
#  {'duration': 6.71,
#   'start': 1747.99,
#   'text': 'ну не смогли ничего сделать классом 99'},
#  {'duration': 7.46,
#   'start': 1751.11,
#   'text': 'вот проводит такая интересная штука есть'},
#  {'duration': 5.32,
#   'start': 1754.7,
#   'text': 'и и классификация это когда есть много'},
#  {'duration': 7.27, 'start': 1758.57, 'text': 'положительный пример'},
#  {'duration': 7.74,
#   'start': 1760.02,
#   'text': 'примеров и немного не размечен есть не'},
#  {'duration': 4.35,
#   'start': 1765.84,
#   'text': 'очень большое количество примеров как бы'},
#  {'duration': 6.66,
#   'start': 1767.76,
#   'text': 'размечены есть много не размеченных'},
#  {'duration': 9.12,
#   'start': 1770.19,
#   'text': 'примеров и как как как вот можно'},
#  {'duration': 8.13,
#   'start': 1774.42,
#   'text': 'неизвестный класс вылавливать но ничего'},
#  {'duration': 5.46,
#   'start': 1779.31,
#   'text': 'не дало так подозреваю дало потому что'},
#  {'duration': 5.04,
#   'start': 1782.55,
#   'text': 'вот они специально так сделали около 99'},
#  {'duration': 7.5,
#   'start': 1784.77,
#   'text': 'что он все-таки похож на сверхновые то'},
#  {'duration': 8.79,
#   'start': 1787.59,
#   'text': 'есть я вот открыл просто буквально два'},
#  {'duration': 6.74,
#   'start': 1792.27,
#   'text': 'три дня назад опубликовали там там были'},
#  {'duration': 2.63, 'start': 1796.38, 'text': 'сверхновая'},
#  {'duration': 5.59,
#   'start': 1800.39,
#   'text': 'ну что мы это сделали правильно это'},
#  {'duration': 4.08,
#   'start': 1803.52,
#   'text': 'объединились в команду потому что я'},
#  {'duration': 3.81,
#   'start': 1805.98,
#   'text': 'думаю каждый из нас будет такого'},
#  {'duration': 5.4,
#   'start': 1807.6,
#   'text': 'результата в одиночку не достиг и вообще'},
#  {'duration': 6.51,
#   'start': 1809.79,
#   'text': 'полезно очень обсуждать ну интересно же'},
#  {'duration': 6.76,
#   'start': 1813.0,
#   'text': 'как бы обсуждать чудила дальше мы читали'},
#  {'duration': 7.36,
#   'start': 1816.3,
#   'text': 'много статей на как люди раньше'},
#  {'duration': 6.6,
#   'start': 1819.76,
#   'text': 'к этой проблеме подбирались что уже'},
#  {'duration': 6.99,
#   'start': 1823.66,
#   'text': 'сделано какие могут быть признаки'},
#  {'duration': 8.82,
#   'start': 1826.36,
#   'text': 'полезны задавали вопросы на форуме и'},
#  {'duration': 8.34,
#   'start': 1830.65,
#   'text': 'когда и вдс лаки задавали нам отвечали'},
#  {'duration': 5.4,
#   'start': 1835.18,
#   'text': 'зачастую нам помогал им ну естественно'},
#  {'duration': 4.32, 'start': 1838.99, 'text': 'много чего пробовать надо'},
#  {'duration': 5.76,
#   'start': 1840.58,
#   'text': 'говорю что много-много чайник не'},
#  {'duration': 5.72,
#   'start': 1843.31,
#   'text': 'получилось но что то что то было в итоге'},
#  {'duration': 6.27,
#   'start': 1846.34,
#   'text': 'эффект и не сдаваться до конца вот'},
#  {'duration': 6.13,
#   'start': 1849.03,
#   'text': 'потому что буквально за последние три'},
#  {'duration': 5.85,
#   'start': 1852.61,
#   'text': 'дня мы там очень сильно улучшились когда'},
#  {'duration': 6.84,
#   'start': 1855.16,
#   'text': 'мы осознали наши ошибки и даже последний'},
#  {'duration': 6.63,
#   'start': 1858.46,
#   'text': 'день таня с этими астрономическими'},
#  {'duration': 9.0,
#   'start': 1862.0,
#   'text': 'цветами таки для мучила и это нам тоже'},
#  {'duration': 9.21,
#   'start': 1865.09,
#   'text': 'помогло и расскажу еще один слайд у меня'},
#  {'duration': 4.28,
#   'start': 1871.0,
#   'text': 'как победитель решал этой задачей его'},
#  {'duration': 5.06, 'start': 1874.3, 'text': 'зовут кайл бун'},
#  {'duration': 5.77,
#   'start': 1875.28,
#   'text': 'на самом деле похоже на то что мы делали'},
#  {'duration': 4.18, 'start': 1879.36, 'text': 'только у него'},
#  {'duration': 4.65,
#   'start': 1881.05,
#   'text': 'у нас и стать самым астрономы поэтому он'},
#  {'duration': 5.66,
#   'start': 1883.54,
#   'text': 'еще в там катушки в теме этой всей и'},
#  {'duration': 3.5, 'start': 1885.7, 'text': 'занимается сверхновыми'},
#  {'duration': 6.311,
#   'start': 1890.929,
#   'text': 'так что немножко не удивительно что но'},
#  {'duration': 6.781,
#   'start': 1894.179,
#   'text': 'тем не менее он в одиночку смог это'},
#  {'duration': 4.74,
#   'start': 1897.24,
#   'text': 'сделать он сделал аргументировал в 40'},
#  {'duration': 4.65, 'start': 1900.96, 'text': 'раз в лучшую'},
#  {'duration': 9.03,
#   'start': 1901.98,
#   'text': 'обучающую выборку и худшие качества'},
#  {'duration': 8.67,
#   'start': 1905.61,
#   'text': 'дайте ddf пробудив эти хорошие кривые'},
#  {'duration': 5.37,
#   'start': 1911.01,
#   'text': 'я часть точек убирал чтобы это было'},
#  {'duration': 4.26,
#   'start': 1914.28,
#   'text': 'стало больше похоже на тесто выборка'},
#  {'duration': 5.21,
#   'start': 1916.38,
#   'text': 'у него так и получилось использовать'},
#  {'duration': 3.05, 'start': 1918.54, 'text': 'миасские процессы'},
#  {'duration': 6.88,
#   'start': 1922.34,
#   'text': 'интерполяции кривых что ли если такой'},
#  {'duration': 8.61,
#   'start': 1925.35,
#   'text': 'вот пример собственно как и как это он'},
#  {'duration': 7.41,
#   'start': 1929.22,
#   'text': 'его картинка интерполяцией помощью'},
#  {'duration': 4.77,
#   'start': 1933.96,
#   'text': 'гауссовских почему гауссовский у него'},
#  {'duration': 3.06,
#   'start': 1936.63,
#   'text': 'там купишь что он был двумерное делал'},
#  {'duration': 3.75, 'start': 1938.73, 'text': 'там то есть еще и'},
#  {'duration': 8.46,
#   'start': 1939.69,
#   'text': 'сигналы как бы тоже входит вот эти'},
#  {'duration': 9.8,
#   'start': 1942.48,
#   'text': 'каналы у него было около 200 признаков'},
#  {'duration': 5.94,
#   'start': 1948.15,
#   'text': 'как на исходных данных сигналов таки на'},
#  {'duration': 6.1,
#   'start': 1952.28,
#   'text': 'предсказанных после гауссовского'},
#  {'duration': 8.04,
#   'start': 1954.09,
#   'text': 'процесса и просто у него лак db модель'},
#  {'duration': 9.24,
#   'start': 1958.38,
#   'text': 'на 5 фондовых было ну раз уж я сказал'},
#  {'duration': 7.5,
#   'start': 1962.13,
#   'text': 'что слизь если и класс 99 убрать то он'},
#  {'duration': 3.99,
#   'start': 1967.62,
#   'text': 'бы проиграл 2 место второе место'},
#  {'duration': 5.789,
#   'start': 1969.63,
#   'text': 'все-таки более такой традиционный у них'},
#  {'duration': 6.36,
#   'start': 1971.61,
#   'text': 'было с точки зрения когда у них там 9'},
#  {'duration': 5.491, 'start': 1975.419, 'text': 'моделей было не со стыками'},
#  {'duration': 5.88, 'start': 1977.97, 'text': 'и основная модель у них было'},
#  {'duration': 7.05,
#   'start': 1980.91,
#   'text': 'рекуррентная сеть на самом деле'},
#  {'duration': 9.209,
#   'start': 1983.85,
#   'text': 'ред это понимала к тому кто вот отличный'},
#  {'duration': 6.87,
#   'start': 1987.96,
#   'text': 'от ладьи модели там использовал и танина'},
#  {'duration': 4.531, 'start': 1993.059, 'text': 'рекуррентные сети rio city'},
#  {'duration': 5.839,
#   'start': 1994.83,
#   'text': 'сделали модель там тоже выложили можно'},
#  {'duration': 3.079, 'start': 1997.59, 'text': 'посмотреть интересно'},
#  {'duration': 10.62,
#   'start': 2002.039,
#   'text': 'спасибо за внимание спасибо вопросы а'},
#  {'duration': 4.689,
#   'start': 2013.86,
#   'text': 'можешь поподробнее рассказать про'},
#  {'duration': 6.21,
#   'start': 2016.12,
#   'text': 'аргументация то есть но вот у него были'},
#  {'duration': 7.291,
#   'start': 2018.549,
#   'text': 'табличные данные и как он выполнил в эти'},
#  {'duration': 9.329,
#   'start': 2022.33,
#   'text': 'аугментации как вот это победители да но'},
#  {'duration': 11.549,
#   'start': 2025.84,
#   'text': 'он я честно говоря сам еще на самом деле'},
#  {'duration': 9.331,
#   'start': 2031.659,
#   'text': 'он обещал выложить код и по-видимому там'},
#  {'duration': 7.951,
#   'start': 2037.389,
#   'text': 'можно будет посмотреть на самом деле я'},
#  {'duration': 6.509,
#   'start': 2040.99,
#   'text': 'видел вот и другие писали ним там второе'},
#  {'duration': 7.049,
#   'start': 2045.34,
#   'text': 'место они монтировали полон 30 процентов'},
#  {'duration': 7.561,
#   'start': 2047.499,
#   'text': 'выкидывали этих сигналов но они еще при'},
#  {'duration': 4.46,
#   'start': 2052.389,
#   'text': 'этом там очень осторожно там с'},
#  {'duration': 4.14,
#   'start': 2055.06,
#   'text': 'остальными признан с остальными'},
#  {'duration': 7.83,
#   'start': 2056.849,
#   'text': 'данными обходились там просто есть'},
#  {'duration': 5.479,
#   'start': 2059.2,
#   'text': 'всякие там faded активности сигналов там'},
#  {'duration': 4.93,
#   'start': 2065.28,
#   'text': 'красное смещение и так далее надо их'},
#  {'duration': 3.75,
#   'start': 2068.53,
#   'text': 'тоже как-то либо аргументировать там'},
#  {'duration': 4.139,
#   'start': 2070.21,
#   'text': 'либо как-то чтобы они правдоподобные'},
#  {'duration': 3.66,
#   'start': 2072.28,
#   'text': 'были то есть мы мы довольно тупым и'},
#  {'duration': 3.411,
#   'start': 2074.349,
#   'text': 'просто вот по нормальному распределению'},
#  {'duration': 5.76, 'start': 2075.94, 'text': 'по ошибке'},
#  {'duration': 6.369,
#   'start': 2077.76,
#   'text': 'как ещё можно делать но вот лучше читать'},
#  {'duration': 5.429,
#   'start': 2081.7,
#   'text': 'потому что я как бы подробно не могу'},
#  {'duration': 5.911,
#   'start': 2084.129,
#   'text': 'рассказать ещё победители было 200 фич а'},
#  {'duration': 6.151,
#   'start': 2087.129,
#   'text': 'у вас сколько у нас около 80 потому что'},
#  {'duration': 6.99,
#   'start': 2090.04,
#   'text': 'мы старались не переучиться старались'},
#  {'duration': 5.97,
#   'start': 2093.28,
#   'text': 'уменьшать количество fitch отбирать фичи'},
#  {'duration': 6.27,
#   'start': 2097.03,
#   'text': 'если они как бы не помогают скоро мы их'},
#  {'duration': 8.13,
#   'start': 2099.25,
#   'text': 'убирали то есть я просто списал что 200'},
#  {'duration': 6.299,
#   'start': 2103.3,
#   'text': 'он подробно там решение написанного в'},
#  {'duration': 5.34,
#   'start': 2107.38,
#   'text': 'коде наверное можно почитать него если'},
#  {'duration': 6.031,
#   'start': 2109.599,
#   'text': 'интересно ну то есть он взял все фичи он'},
#  {'duration': 5.57,
#   'start': 2112.72,
#   'text': 'не стал фильтровать да про про'},
#  {'duration': 7.49,
#   'start': 2115.63,
#   'text': 'фильтрацию ничего не писал в этом'},
#  {'duration': 8.16,
#   'start': 2118.29,
#   'text': 'брать топи своем совершении как как он'},
#  {'duration': 8.25,
#   'start': 2123.12,
#   'text': 'там viral не набирал я не знаю еще'},
#  {'duration': 11.57,
#   'start': 2126.45,
#   'text': 'вопросы остались какие то идеи которые'},
#  {'duration': 6.65,
#   'start': 2131.37,
#   'text': 'не успели реализовать такую немножко'},
#  {'duration': 6.19,
#   'start': 2138.59,
#   'text': 'хорошего просто но самом деле мне'},
#  {'duration': 5.4,
#   'start': 2142.11,
#   'text': 'кажется мы вот с гауссовским процессами'},
#  {'duration': 5.3,
#   'start': 2144.78,
#   'text': 'возились возились было ощущение что они'},
#  {'duration': 7.65,
#   'start': 2147.51,
#   'text': 'вот что-то могут дать там и на форуме'},
#  {'duration': 9.58,
#   'start': 2150.08,
#   'text': 'принципе писали там что вот есть'},
#  {'duration': 11.52,
#   'start': 2155.16,
#   'text': 'известный участника c 7 себе найду его'},
#  {'duration': 7.65,
#   'start': 2159.66,
#   'text': 'фотку и он тоже писал что вот ближе к'},
#  {'duration': 4.68, 'start': 2166.68, 'text': 'концу там'},
#  {'duration': 7.95,
#   'start': 2167.31,
#   'text': 'теплом гауссовским процессы это круто но'},
#  {'duration': 5.4,
#   'start': 2171.36,
#   'text': 'уже времени на из время на исходе и типа'},
#  {'duration': 4.2,
#   'start': 2175.26,
#   'text': 'меня тоже ничего не получилось также у'},
#  {'duration': 5.4,
#   'start': 2176.76,
#   'text': 'нас как бы вы че ты что-то питер делал'},
#  {'duration': 6.45,
#   'start': 2179.46,
#   'text': 'дьявол но времени не хватило хотя вроде'},
#  {'duration': 6.51,
#   'start': 2182.16,
#   'text': 'действительно они были многообещающие то'},
#  {'duration': 4.28,
#   'start': 2185.91,
#   'text': 'есть что-то еще там как бы даже не знаем'},
#  {'duration': 4.47, 'start': 2188.67, 'text': 'сходу'},
#  {'duration': 4.69,
#   'start': 2190.19,
#   'text': 'потому что of tanks ударном тоже сад n'},
#  {'duration': 3.72,
#   'start': 2193.14,
#   'text': 'кадром надежды мало было потому что то'},
#  {'duration': 5.15,
#   'start': 2194.88,
#   'text': 'не получилось вот глазки процессы это'},
#  {'duration': 3.17, 'start': 2196.86, 'text': 'нам спасибо'},
#  {'duration': 3.1,
#   'start': 2202.57,
#   'text': 'скажите пожалуйста как на ваш взгляд'},
#  {'duration': 2.88, 'start': 2204.65, 'text': 'всегда ли'},
#  {'duration': 4.35,
#   'start': 2205.67,
#   'text': 'одной из приоритетных задач на оставить'},
#  {'duration': 4.829,
#   'start': 2207.53,
#   'text': 'поиск камфорных классов исходить из них'},
#  {'duration': 5.72,
#   'start': 2210.02,
#   'text': 'или не всегда это целесообразно будущем'},
#  {'duration': 7.201,
#   'start': 2212.359,
#   'text': 'то есть ответ краткосрочный эффект'},
#  {'duration': 7.39,
#   'start': 2215.74,
#   'text': 'опорных классов да то что вот как раз он'},
#  {'duration': 6.93,
#   'start': 2219.56,
#   'text': 'исходил только и сверхновых а на самом'},
#  {'duration': 5.07,
#   'start': 2223.13,
#   'text': 'деле это мы просто смотрели я таня'},
#  {'duration': 4.879,
#   'start': 2226.49,
#   'text': 'просила вставить а че ты решил не'},
#  {'duration': 6.09, 'start': 2228.2, 'text': 'вставлять постоянно рисовали'},
#  {'duration': 5.021,
#   'start': 2231.369,
#   'text': 'матрицу вот confusion matrix модем как'},
#  {'duration': 2.88,
#   'start': 2234.29,
#   'text': 'они показ и путаются и принципе было'},
#  {'duration': 2.79, 'start': 2236.39, 'text': 'видно что'},
#  {'duration': 6.21,
#   'start': 2237.17,
#   'text': 'сверхновая между собой путаются в'},
#  {'duration': 7.23,
#   'start': 2239.18,
#   'text': 'основном то есть поэтому форма как бы на'},
#  {'duration': 5.16,
#   'start': 2243.38,
#   'text': 'них делали потому что ну все остальные'},
#  {'duration': 7.35,
#   'start': 2246.41,
#   'text': 'классы более-менее по вот тем признакам'},
#  {'duration': 7.01,
#   'start': 2248.54,
#   'text': 'которых по стандартным там по из этих'},
#  {'duration': 4.41,
#   'start': 2253.76,
#   'text': 'целей умы других библиотек и они'},
#  {'duration': 4.33,
#   'start': 2255.55,
#   'text': 'более-менее как-то вот они и хорошее'},
#  {'duration': 5.27,
#   'start': 2258.17,
#   'text': 'качество уже было поэтому ему добивали'},
#  {'duration': 3.56, 'start': 2259.88, 'text': 'вот эти сверхновые в основном'}]

# %%
url_channel_playlist = 'https://www.googleapis.com/youtube/v3/playlists?part=snippet&channelId={CHANNEL_ID}&key={API_KEY}&maxResults=49&pageToken=CDEQAA'

# %%
r = requests.get(url_channel_playlist.format(CHANNEL_ID=channel_ids['event_space_by_video'], API_KEY=API))

# %%
js = json.loads(r.text)

# %%
js2
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RlsFXRgOsdEWDVDsmMcPTkvetw8"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oKhTy77dq7V-LahfdjjdFGTzeuY"',
#    'id': 'PLpVeA1tdgfCBEoAuv31Pc8LIZ1rEGXmRS',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Flo Talks: Design System'},
#     'publishedAt': '2019-02-06T09:55:25.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/UfVAa4PC6Z0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/UfVAa4PC6Z0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/UfVAa4PC6Z0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/UfVAa4PC6Z0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/UfVAa4PC6Z0/sddefault.jpg',
#       'width': 640}},
#     'title': 'Flo Talks: Design System'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/CJDUU-iPkFiOrcER1wL_NhViU2o"',
#    'id': 'PLpVeA1tdgfCAk0ssvWcU0YwiodYY_Oxci',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'FB DevC + CocoaHeads Meetup'},
#     'publishedAt': '2019-01-24T12:15:57.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/w951ONVqpjk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/w951ONVqpjk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/w951ONVqpjk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/w951ONVqpjk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/w951ONVqpjk/sddefault.jpg',
#       'width': 640}},
#     'title': 'FB DevC + CocoaHeads Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JQIE8sErzEgEdrwI2As-wlyyM64"',
#    'id': 'PLpVeA1tdgfCBG0jL06pYg3IMJx9KRBXuM',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Salesforce Meetup #5'},
#     'publishedAt': '2018-12-17T13:25:18.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/S_Zhg4ti29w/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/S_Zhg4ti29w/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/S_Zhg4ti29w/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/S_Zhg4ti29w/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/S_Zhg4ti29w/sddefault.jpg',
#       'width': 640}},
#     'title': 'Salesforce Meetup #5'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/laqnYl6IyfWaWiZK5Qk-HM-TNtY"',
#    'id': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Data Ёлка в Минске 2018'},
#     'publishedAt': '2018-12-12T09:27:21.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#       'width': 640}},
#     'title': 'Data Ёлка в Минске 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/VuHYO0FjbeOSlBjfK7BoDW9rf94"',
#    'id': 'PLpVeA1tdgfCDL8yiDcHSAZuxhbozTRcLd',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': "In Product Manager's Shoes #5"},
#     'publishedAt': '2018-12-06T12:32:30.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/qcbwKxoHA8o/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/qcbwKxoHA8o/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/qcbwKxoHA8o/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/qcbwKxoHA8o/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/qcbwKxoHA8o/sddefault.jpg',
#       'width': 640}},
#     'title': "In Product Manager's Shoes #5"}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/gVV8ht-UDpeYgELGZX_bopXVVvc"',
#    'id': 'PLpVeA1tdgfCCL8Bmwe0rDhgAx6mys0vtZ',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'JFuture 2018'},
#     'publishedAt': '2018-11-19T14:05:47.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/J2caMt80zUk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/J2caMt80zUk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/J2caMt80zUk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/J2caMt80zUk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/J2caMt80zUk/sddefault.jpg',
#       'width': 640}},
#     'title': 'JFuture 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PEMk4ROWLnWl-DHO24ofh64qtCQ"',
#    'id': 'PLpVeA1tdgfCCOxYPCPNGS10y6UyUyI_jv',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Android Academy'},
#     'publishedAt': '2018-11-19T13:47:58.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/hxjWLQxg3KU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/hxjWLQxg3KU/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/hxjWLQxg3KU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/hxjWLQxg3KU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Android Academy'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yFEYWsxP3t32gCyqJ4GJNNVZ9lE"',
#    'id': 'PLpVeA1tdgfCAXJEZbpmj_gF7ZygBr2V27',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'ByGIS Meetup #10'},
#     'publishedAt': '2018-11-11T12:18:24.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/KyQw4RM6L5Q/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/KyQw4RM6L5Q/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/KyQw4RM6L5Q/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/KyQw4RM6L5Q/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/KyQw4RM6L5Q/sddefault.jpg',
#       'width': 640}},
#     'title': 'ByGIS Meetup #10'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rzbXRXRg70iajhRD_2QxEelyxn4"',
#    'id': 'PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#     'localized': {'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#      'title': 'Open Data Science November Meetup'},
#     'publishedAt': '2018-11-08T13:12:35.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science November Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/pBwxT7KL8q_0AcDVyFP5jaCXoNg"',
#    'id': 'PLpVeA1tdgfCDoWM3Dqc0ojCgp9L3XOnMC',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Python meetup by Point Nine'},
#     'publishedAt': '2018-10-29T12:15:58.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/98duTsLkG-8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/98duTsLkG-8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/98duTsLkG-8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/98duTsLkG-8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/98duTsLkG-8/sddefault.jpg',
#       'width': 640}},
#     'title': 'Python meetup by Point Nine'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TZ055OFfiym1L6AjLeCDk7dnzuY"',
#    'id': 'PLpVeA1tdgfCCL-oU0IEmhHaFcm2mctZ6Z',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Bioinformatics & Proteomics meetups'},
#     'publishedAt': '2018-10-25T08:50:56.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/YfumbuzpEN8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/YfumbuzpEN8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/YfumbuzpEN8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/YfumbuzpEN8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/YfumbuzpEN8/sddefault.jpg',
#       'width': 640}},
#     'title': 'Bioinformatics & Proteomics meetups'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/m-MBzKROhnNbm5KCGcGGjQEfCgw"',
#    'id': 'PLpVeA1tdgfCDF4TfW6f7FFEeLAWULL2Ry',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'MobileOptimized is the annual tech conference dedicated to mobile development.',
#     'localized': {'description': 'MobileOptimized is the annual tech conference dedicated to mobile development.',
#      'title': 'MobileOptimized 2018 Minsk'},
#     'publishedAt': '2018-10-18T13:31:23.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/ShrEO3oo3jg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/ShrEO3oo3jg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/ShrEO3oo3jg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/ShrEO3oo3jg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/ShrEO3oo3jg/sddefault.jpg',
#       'width': 640}},
#     'title': 'MobileOptimized 2018 Minsk'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ovTJcPJDbGawqF6jTHTtod3OO8I"',
#    'id': 'PLpVeA1tdgfCD7CRJ49gsRfwZPr9w-kS0O',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Video Partner - SEMrush https://www.semrush.com/company/',
#     'localized': {'description': 'Video Partner - SEMrush https://www.semrush.com/company/',
#      'title': 'GoWayFest 2018 Minsk'},
#     'publishedAt': '2018-10-17T14:41:48.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/-GBMFPegqgw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/-GBMFPegqgw/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/-GBMFPegqgw/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/-GBMFPegqgw/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/-GBMFPegqgw/sddefault.jpg',
#       'width': 640}},
#     'title': 'GoWayFest 2018 Minsk'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2Y0wBS8_Q9E1ndZM4SowF2pFeUU"',
#    'id': 'PLpVeA1tdgfCDEEh-jSpKgi0Oir3FMZVtb',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Salesforce Meetup #4'},
#     'publishedAt': '2018-10-09T09:27:45.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/zl-nXVt7MXE/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/zl-nXVt7MXE/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/zl-nXVt7MXE/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/zl-nXVt7MXE/sddefault.jpg',
#       'width': 640}},
#     'title': 'Salesforce Meetup #4'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/s3EiimLJYNsqvyYP1dLYb2SeKvg"',
#    'id': 'PLpVeA1tdgfCBPVz9KXXzH_qiuI7nUxcyP',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': "In Product Manager's Shoes / Fall Issue"},
#     'publishedAt': '2018-09-24T08:33:51.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/CHeSrv4MHVw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/CHeSrv4MHVw/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/CHeSrv4MHVw/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/CHeSrv4MHVw/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/CHeSrv4MHVw/sddefault.jpg',
#       'width': 640}},
#     'title': "In Product Manager's Shoes / Fall Issue"}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/URXREGTvEvbHtk6rbMZeF6K5lck"',
#    'id': 'PLpVeA1tdgfCCuMnZmiSvG7KAyD7j23Uhm',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Встреча с космонавтами, популяризаторами космонавтики и энтузиастами космических исследований',
#     'localized': {'description': 'Встреча с космонавтами, популяризаторами космонавтики и энтузиастами космических исследований',
#      'title': 'SPACE Community Day | XXXI ASE Planetary Congress'},
#     'publishedAt': '2018-09-19T11:48:07.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/p0zrtUjIiFo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/p0zrtUjIiFo/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/p0zrtUjIiFo/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/p0zrtUjIiFo/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/p0zrtUjIiFo/sddefault.jpg',
#       'width': 640}},
#     'title': 'SPACE Community Day | XXXI ASE Planetary Congress'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wJA8gAcH47HcbXg_00edw92E_e8"',
#    'id': 'PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Open Data Science September Meetup'},
#     'publishedAt': '2018-09-17T12:07:32.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science September Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/E4akMc7YTBIwSkw7bHQtQFcxmfA"',
#    'id': 'PLpVeA1tdgfCDhSFPIjrG1a-OXTBnsRxD4',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'byGIS meetup #9'},
#     'publishedAt': '2018-09-05T13:12:09.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/-TRZu96pGw8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/-TRZu96pGw8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/-TRZu96pGw8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/-TRZu96pGw8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/-TRZu96pGw8/sddefault.jpg',
#       'width': 640}},
#     'title': 'byGIS meetup #9'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ha8qnykC1vLUaT6ElpNVxdUZ-kY"',
#    'id': 'PLpVeA1tdgfCDqh0zhbqUNvyxcAT3Vo9IY',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'FuncBy Meetup #10'},
#     'publishedAt': '2018-08-20T14:33:19.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/fmexvnhfG-w/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/fmexvnhfG-w/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/fmexvnhfG-w/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/fmexvnhfG-w/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/fmexvnhfG-w/sddefault.jpg',
#       'width': 640}},
#     'title': 'FuncBy Meetup #10'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/9voLbEqi_JFX4NXZuiNDpAvdhHg"',
#    'id': 'PLpVeA1tdgfCCDWF2Kc7qiNdr4pBYZka0W',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'MUUG Meetups'},
#     'publishedAt': '2018-08-09T09:31:37.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/vekq2UPBPUo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/vekq2UPBPUo/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/vekq2UPBPUo/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/vekq2UPBPUo/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/vekq2UPBPUo/sddefault.jpg',
#       'width': 640}},
#     'title': 'MUUG Meetups'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wUERvXpe0RpudSIFMdKCeNpfFwk"',
#    'id': 'PLpVeA1tdgfCA_B6D5PfM8uYeY6GiumMIJ',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'GDG Minsk July meetup'},
#     'publishedAt': '2018-07-26T13:00:46.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Bo9VaIqZEGs/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Bo9VaIqZEGs/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Bo9VaIqZEGs/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Bo9VaIqZEGs/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Bo9VaIqZEGs/sddefault.jpg',
#       'width': 640}},
#     'title': 'GDG Minsk July meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ox5zt3uLSqnOVfaPp1pqViQwAhw"',
#    'id': 'PLpVeA1tdgfCDsxDaVun46BgarMhUKmRDM',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Salesforce Meetup #3'},
#     'publishedAt': '2018-07-23T14:52:57.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/CnWjeX66v2U/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/CnWjeX66v2U/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/CnWjeX66v2U/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/CnWjeX66v2U/sddefault.jpg',
#       'width': 640}},
#     'title': 'Salesforce Meetup #3'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2D8zKssPlP1Zf0qNNMNyxao7ocI"',
#    'id': 'PLpVeA1tdgfCCDg3rvpp1l3A6J7U7TIzFy',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'ByGIS meetup #8'},
#     'publishedAt': '2018-07-04T14:47:50.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/pj7_DQypL-U/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/pj7_DQypL-U/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/pj7_DQypL-U/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/pj7_DQypL-U/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/pj7_DQypL-U/sddefault.jpg',
#       'width': 640}},
#     'title': 'ByGIS meetup #8'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/aUsGKwQRbvvG2Een5fzXB49av6s"',
#    'id': 'PLpVeA1tdgfCD5Ugk21ZXJntGK3kETclqZ',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Women Techmakers Meetup #2'},
#     'publishedAt': '2018-06-18T11:23:05.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/LczYORChDck/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/LczYORChDck/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/LczYORChDck/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/LczYORChDck/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/LczYORChDck/sddefault.jpg',
#       'width': 640}},
#     'title': 'Women Techmakers Meetup #2'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3dnACfSlP4xFuZ0Zr8IgGREGJmI"',
#    'id': 'PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Data Fest² Minsk 2018'},
#     'publishedAt': '2018-06-04T13:50:17.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Data Fest² Minsk 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Rvd2veDbu9X1FH5xodQnXo1uFyM"',
#    'id': 'PLpVeA1tdgfCCqX488H9JxA_bMUCaltiym',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'CocoaHeads Meetup'},
#     'publishedAt': '2018-05-29T06:09:59.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/PyAoUDMXb7U/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/PyAoUDMXb7U/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/PyAoUDMXb7U/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/PyAoUDMXb7U/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/PyAoUDMXb7U/sddefault.jpg',
#       'width': 640}},
#     'title': 'CocoaHeads Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1eql_XshXeRG2yPdO-nQpNuYkVc"',
#    'id': 'PLpVeA1tdgfCBytYjWC0oGW_YPjLVvRgjS',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': '.NET User Group - Minsk'},
#     'publishedAt': '2018-05-10T07:18:29.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/ti4f1HOwixU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/ti4f1HOwixU/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/ti4f1HOwixU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/ti4f1HOwixU/sddefault.jpg',
#       'width': 640}},
#     'title': '.NET User Group - Minsk'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/E2wUs4p5K8_7vtHJquYdjBVs1dk"',
#    'id': 'PLpVeA1tdgfCD5vCJvBlbUGTNd5KHO4AWL',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'RubyConfBY 2018'},
#     'publishedAt': '2018-05-08T09:07:36.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/DRdNavt5X9k/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/DRdNavt5X9k/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/DRdNavt5X9k/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/DRdNavt5X9k/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/DRdNavt5X9k/sddefault.jpg',
#       'width': 640}},
#     'title': 'RubyConfBY 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/xjaC4yBlDkhc55Eu8Yo8otSqUXc"',
#    'id': 'PLpVeA1tdgfCAIzokZiO3l9J84VRxSyhh4',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': 'Главная тема ITSpring 2018 — Декрет №\u20098 «О развитии цифровой экономики», который вступил в силу 28 марта 2018. \nКак документ повлияет на рынок IT и как компаниям использовать его новые возможности: крипторегулирование, институты английского права, условия для развития продуктовых ИТ-компаний, привлечения иностранного капитала и др. — все это в программе конференции. \n\nОрганизаторы: SPACE Production & REVERA.',
#     'localized': {'description': 'Главная тема ITSpring 2018 — Декрет №\u20098 «О развитии цифровой экономики», который вступил в силу 28 марта 2018. \nКак документ повлияет на рынок IT и как компаниям использовать его новые возможности: крипторегулирование, институты английского права, условия для развития продуктовых ИТ-компаний, привлечения иностранного капитала и др. — все это в программе конференции. \n\nОрганизаторы: SPACE Production & REVERA.',
#      'title': 'IT Spring Conference 2018'},
#     'publishedAt': '2018-05-02T12:24:59.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/K5-VnvSqtXk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/K5-VnvSqtXk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/K5-VnvSqtXk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/K5-VnvSqtXk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/K5-VnvSqtXk/sddefault.jpg',
#       'width': 640}},
#     'title': 'IT Spring Conference 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Hgkfvb_Q961Jrp_s09OeAfjde30"',
#    'id': 'PLpVeA1tdgfCDnAP_68oBaMIIOanRLI5Yf',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'FuncBy Meetup #7'},
#     'publishedAt': '2018-05-01T13:09:29.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/onXFxswZXXw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/onXFxswZXXw/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/onXFxswZXXw/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/onXFxswZXXw/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/onXFxswZXXw/sddefault.jpg',
#       'width': 640}},
#     'title': 'FuncBy Meetup #7'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fCnY7CHAC3PdruQGr5YwnAV1uhI"',
#    'id': 'PLpVeA1tdgfCDhfNrciRvKhKQn7OQfvsni',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'byGIS meetup #7'},
#     'publishedAt': '2018-04-28T11:32:55.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/v7D05g-oJwg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/v7D05g-oJwg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/v7D05g-oJwg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/v7D05g-oJwg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/v7D05g-oJwg/sddefault.jpg',
#       'width': 640}},
#     'title': 'byGIS meetup #7'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/d8dermSzyxN9XwaGrNSS_J9gqX8"',
#    'id': 'PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Open Data Science April Meetup'},
#     'publishedAt': '2018-04-19T07:01:41.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science April Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/v4Z7FMvTH3R1ysVf6LnfeeuwH7Q"',
#    'id': 'PLpVeA1tdgfCD_GPsu1kzOd_IS01EFIToE',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Python meetup by Kiwi.com'},
#     'publishedAt': '2018-04-18T13:46:21.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/rWJX8t6R6b8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/rWJX8t6R6b8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/rWJX8t6R6b8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/rWJX8t6R6b8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/rWJX8t6R6b8/sddefault.jpg',
#       'width': 640}},
#     'title': 'Python meetup by Kiwi.com'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/m68n7yGzPpqDHq3N_6py1WX--fE"',
#    'id': 'PLpVeA1tdgfCA-Xsx7dRQ2sA6hY3JaL-oq',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Salesforce Meetup #2'},
#     'publishedAt': '2018-04-18T12:47:37.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/1zrswpTpZ8Q/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/1zrswpTpZ8Q/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/1zrswpTpZ8Q/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/1zrswpTpZ8Q/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/1zrswpTpZ8Q/sddefault.jpg',
#       'width': 640}},
#     'title': 'Salesforce Meetup #2'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/DNKCF6Fht70nVa11kr_n38oNDKc"',
#    'id': 'PLpVeA1tdgfCBvo0I_u_EMvf1j5Un2G191',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'GoWay meetup v1.3'},
#     'publishedAt': '2018-04-18T12:21:05.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/cQgHt9V5mOE/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/cQgHt9V5mOE/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/cQgHt9V5mOE/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/cQgHt9V5mOE/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/cQgHt9V5mOE/sddefault.jpg',
#       'width': 640}},
#     'title': 'GoWay meetup v1.3'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/QYbJnjZEIN-SNlyfKhffxuE7JMU"',
#    'id': 'PLpVeA1tdgfCDqqSStGxoJGmchseT2X6Mz',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'In Product Manager Shoes #3'},
#     'publishedAt': '2018-04-05T10:12:12.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/CUHES72vO74/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/CUHES72vO74/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/CUHES72vO74/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/CUHES72vO74/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/CUHES72vO74/sddefault.jpg',
#       'width': 640}},
#     'title': 'In Product Manager Shoes #3'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/R-cQtiI05R1L6NBKCjmPvOTGBDM"',
#    'id': 'PLpVeA1tdgfCBc7P13LRapBji6w_3K3pgC',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Women Techmakers meetup #1'},
#     'publishedAt': '2018-03-28T09:24:40.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/trhujKXgjbA/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/trhujKXgjbA/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/trhujKXgjbA/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/trhujKXgjbA/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/trhujKXgjbA/sddefault.jpg',
#       'width': 640}},
#     'title': 'Women Techmakers meetup #1'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_TTUkIB72Ra2wSUNx4JO9S_E8Es"',
#    'id': 'PLpVeA1tdgfCAKCPoce5lATm2iT2EsUDwO',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'GDG Minsk March Meetup'},
#     'publishedAt': '2018-03-28T08:36:35.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/u0_4-nu5qAU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/u0_4-nu5qAU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/u0_4-nu5qAU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/u0_4-nu5qAU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/u0_4-nu5qAU/sddefault.jpg',
#       'width': 640}},
#     'title': 'GDG Minsk March Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BPse8qYbI_ofaVafYf1AYHsMyYo"',
#    'id': 'PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Open Data Science March Meetup #2'},
#     'publishedAt': '2018-03-27T10:40:51.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/5oqdfBqok94/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/5oqdfBqok94/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/5oqdfBqok94/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/5oqdfBqok94/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/5oqdfBqok94/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science March Meetup #2'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/9L2g4fwiRAECk7Q_go4GuSNJQPA"',
#    'id': 'PLpVeA1tdgfCDSyNzWHyqjOiNKhSHwsihm',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': '.NET Summit Belarus 2018'},
#     'publishedAt': '2018-03-18T10:50:17.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/mmemuZUVTEY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/mmemuZUVTEY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/mmemuZUVTEY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/mmemuZUVTEY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/mmemuZUVTEY/sddefault.jpg',
#       'width': 640}},
#     'title': '.NET Summit Belarus 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/exgFQxt1I8zgGSYfRSiZFqKQJlY"',
#    'id': 'PLpVeA1tdgfCAUk_wbOeUrFBz0WxZJ8s7y',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'PyConBy 2018'},
#     'publishedAt': '2018-03-13T18:18:24.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/CTFIsBF8xmU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/CTFIsBF8xmU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/CTFIsBF8xmU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/CTFIsBF8xmU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/CTFIsBF8xmU/sddefault.jpg',
#       'width': 640}},
#     'title': 'PyConBy 2018'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zccfrD6MnPR1va5nSsamdY_MBzs"',
#    'id': 'PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Open Data Science March Meetup'},
#     'publishedAt': '2018-03-12T13:00:40.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science March Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-Ljdh9yef-XSA5PmH4V64R4Kve0"',
#    'id': 'PLpVeA1tdgfCBqJ4oKg7pbMPFf0_fgwxY6',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'byGIS meetup #6'},
#     'publishedAt': '2018-02-28T20:02:54.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/h1Hmej5lHX4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/h1Hmej5lHX4/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/h1Hmej5lHX4/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/h1Hmej5lHX4/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/h1Hmej5lHX4/sddefault.jpg',
#       'width': 640}},
#     'title': 'byGIS meetup #6'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/P-3JXkG0f6JAq525jiuskxkE9_Y"',
#    'id': 'PLpVeA1tdgfCABL6RZD3OZ52_y5JbnymyI',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'GDG meetup'},
#     'publishedAt': '2018-02-27T20:21:32.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/RSG23I71GJg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/RSG23I71GJg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/RSG23I71GJg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/RSG23I71GJg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/RSG23I71GJg/sddefault.jpg',
#       'width': 640}},
#     'title': 'GDG meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rhr7OBnw-NGQ410KFaXSPhMqWdU"',
#    'id': 'PLpVeA1tdgfCCH-zF8PGlpI5w0RhxGMf0W',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'Salesforce Meetup'},
#     'publishedAt': '2018-02-09T08:45:25.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/lkOyb6gTtJw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/lkOyb6gTtJw/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/lkOyb6gTtJw/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/lkOyb6gTtJw/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/lkOyb6gTtJw/sddefault.jpg',
#       'width': 640}},
#     'title': 'Salesforce Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FCNp3pv_lCnNT6atgQcpzM-yLJQ"',
#    'id': 'PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'Open Data Science December Meetup'},
#     'publishedAt': '2018-01-08T15:19:58.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/sddefault.jpg',
#       'width': 640}},
#     'title': 'Open Data Science December Meetup'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/w9kO2rqKIPzcvZKwAETVgBB9yhY"',
#    'id': 'PLpVeA1tdgfCCUuAtFl0N5wzatXx0gWLKM',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': 'F(by) 2017 - Functional Programming Conference Minsk'},
#     'publishedAt': '2018-01-04T08:31:47.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/DebDaiYev2M/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/DebDaiYev2M/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/DebDaiYev2M/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/DebDaiYev2M/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/DebDaiYev2M/sddefault.jpg',
#       'width': 640}},
#     'title': 'F(by) 2017 - Functional Programming Conference Minsk'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PDiKZdr2ArwEIzmP2Q6nCwr9ZQA"',
#    'id': 'PLpVeA1tdgfCCLOgKAlqBWUEVxxEXEAVRW',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '',
#      'title': "In Product Manager's Shoes Meetup | Vol.2."},
#     'publishedAt': '2017-12-01T12:08:43.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/gU6KV8ZItzk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/gU6KV8ZItzk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/gU6KV8ZItzk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/gU6KV8ZItzk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/gU6KV8ZItzk/sddefault.jpg',
#       'width': 640}},
#     'title': "In Product Manager's Shoes Meetup | Vol.2."}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/dpKWRV4OKE0xcVz2fTXfmXiTKds"',
#    'id': 'PLpVeA1tdgfCBgpRzimaelATxeznwzXOKh',
#    'kind': 'youtube#playlist',
#    'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#     'channelTitle': 'EventSpaceBy Video',
#     'description': '',
#     'localized': {'description': '', 'title': 'GDG DevFest Minsk 2017'},
#     'publishedAt': '2017-12-01T09:36:33.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/6UesL9gf7ho/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/6UesL9gf7ho/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/6UesL9gf7ho/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/6UesL9gf7ho/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/6UesL9gf7ho/sddefault.jpg',
#       'width': 640}},
#     'title': 'GDG DevFest Minsk 2017'}}],
#  'kind': 'youtube#playlistListResponse',
#  'nextPageToken': 'CDEQAA',
#  'pageInfo': {'resultsPerPage': 49, 'totalResults': 78}}

# %%
js2['nextPageToken']
# Out:
# 'CDEQAA'

# %%
pl1 = [js['items'][i]  for i in range(len(js['items'])) if 'data' in js['items'][i]['snippet']['title'].lower()]

# %%
pl2 = [js2['items'][i] for i in range(len(js2['items'])) if 'data' in js2['items'][i]['snippet']['title'].lower()]

# %%
pl = pl1 + pl2

# %%
pl[0]['id']
# Out:
# 'PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1'

# %%
# Out:
# 11

# %%
jss = []
for p in pl:
    
    pl_id = p['id']
    print(p)
    
    r = requests.get(url_playlist.format(ID=pl_id, API_KEY=API))
    jss.append(json.loads(r.text))
    jj = 0
    
    while 'nextPageToken' in json.loads(r.text):
        jj += 1
        print(jj)

        r = requests.get(url_playlist.format(ID=pl_id, API_KEY=API) + \
                         '&pageToken={}'.format(json.loads(r.text)['nextPageToken']))
        jss.append(json.loads(r.text))
        sleep(10)
# Out:
# {'snippet': {'title': 'Open Data Science October Meetup', 'publishedAt': '2017-11-08T13:02:53.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/607N7GuTKzg/mqdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/607N7GuTKzg/default.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/607N7GuTKzg/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science October Meetup', 'description': ''}}, 'id': 'PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Jr5L2AMioygR_ftBhjKvkjMNtSU"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science Meetup#1', 'publishedAt': '2017-08-25T15:02:20.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/xZ6YSVrTBuY/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/xZ6YSVrTBuY/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/xZ6YSVrTBuY/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/xZ6YSVrTBuY/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/xZ6YSVrTBuY/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science Meetup#1', 'description': ''}}, 'id': 'PLpVeA1tdgfCCLSWY6fIfZe64U9K39tgQm', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wqHIbzAJZCU_TxOPLHYrbtOZcak"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Data Fest Belarus 2017', 'publishedAt': '2017-05-22T15:25:24.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/dCIM1EZ1WX4/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/dCIM1EZ1WX4/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/dCIM1EZ1WX4/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/dCIM1EZ1WX4/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/dCIM1EZ1WX4/hqdefault.jpg'}}, 'description': 'Data Fest is an informal conference that unites researchers, engineers and other data science folks.', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Data Fest Belarus 2017', 'description': 'Data Fest is an informal conference that unites researchers, engineers and other data science folks.'}}, 'id': 'PLpVeA1tdgfCCpxs5GTQ2G3xfyqw3xwh4p', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/WklofFdv2ZgIoQThl2eoZAjRfeg"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Data Ёлка в Минске 2018', 'publishedAt': '2018-12-12T09:27:21.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Data Ёлка в Минске 2018', 'description': ''}}, 'id': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/laqnYl6IyfWaWiZK5Qk-HM-TNtY"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science November Meetup', 'publishedAt': '2018-11-08T13:12:35.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/hqdefault.jpg'}}, 'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science November Meetup', 'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.'}}, 'id': 'PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rzbXRXRg70iajhRD_2QxEelyxn4"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science September Meetup', 'publishedAt': '2018-09-17T12:07:32.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science September Meetup', 'description': ''}}, 'id': 'PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wJA8gAcH47HcbXg_00edw92E_e8"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Data Fest² Minsk 2018', 'publishedAt': '2018-06-04T13:50:17.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Data Fest² Minsk 2018', 'description': ''}}, 'id': 'PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3dnACfSlP4xFuZ0Zr8IgGREGJmI"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science April Meetup', 'publishedAt': '2018-04-19T07:01:41.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science April Meetup', 'description': ''}}, 'id': 'PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/d8dermSzyxN9XwaGrNSS_J9gqX8"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science March Meetup #2', 'publishedAt': '2018-03-27T10:40:51.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/5oqdfBqok94/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/5oqdfBqok94/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/5oqdfBqok94/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/5oqdfBqok94/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/5oqdfBqok94/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science March Meetup #2', 'description': ''}}, 'id': 'PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BPse8qYbI_ofaVafYf1AYHsMyYo"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science March Meetup', 'publishedAt': '2018-03-12T13:00:40.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science March Meetup', 'description': ''}}, 'id': 'PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zccfrD6MnPR1va5nSsamdY_MBzs"', 'kind': 'youtube#playlist'}
# {'snippet': {'title': 'Open Data Science December Meetup', 'publishedAt': '2018-01-08T15:19:58.000Z', 'thumbnails': {'medium': {'height': 180, 'width': 320, 'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/mqdefault.jpg'}, 'maxres': {'height': 720, 'width': 1280, 'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/maxresdefault.jpg'}, 'default': {'height': 90, 'width': 120, 'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/default.jpg'}, 'standard': {'height': 480, 'width': 640, 'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/sddefault.jpg'}, 'high': {'height': 360, 'width': 480, 'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/hqdefault.jpg'}}, 'description': '', 'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA', 'channelTitle': 'EventSpaceBy Video', 'localized': {'title': 'Open Data Science December Meetup', 'description': ''}}, 'id': 'PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG', 'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FCNp3pv_lCnNT6atgQcpzM-yLJQ"', 'kind': 'youtube#playlist'}

# %%
video_items = []
for js in jss:
        for item in js['items']:
            video_items.append((item['snippet']['resourceId']['videoId'], 'Event Space by Video', item['snippet']['title'], item['snippet']['publishedAt'],
                               item['snippet']['description']))

# %%
len(video_items)
# Out:
# 55

# %%
import pandas as pd

# %%
# ?pd.DataFrame

# %%
pl1
# Out:
# [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/laqnYl6IyfWaWiZK5Qk-HM-TNtY"',
#   'id': 'PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Data Ёлка в Минске 2018'},
#    'publishedAt': '2018-12-12T09:27:21.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/FEzjzTSHlDs/sddefault.jpg',
#      'width': 640}},
#    'title': 'Data Ёлка в Минске 2018'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rzbXRXRg70iajhRD_2QxEelyxn4"',
#   'id': 'PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#    'localized': {'description': 'Ноябрьская встреча минского сообщества Open Data Science была посвящена Kaggle TGS Salt Identification Challenge – соревнованию по семантической сегментации.',
#     'title': 'Open Data Science November Meetup'},
#    'publishedAt': '2018-11-08T13:12:35.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/r7OuZ2aOHH0/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science November Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wJA8gAcH47HcbXg_00edw92E_e8"',
#   'id': 'PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science September Meetup'},
#    'publishedAt': '2018-09-17T12:07:32.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/_1EZOtu77w0/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science September Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3dnACfSlP4xFuZ0Zr8IgGREGJmI"',
#   'id': 'PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Data Fest² Minsk 2018'},
#    'publishedAt': '2018-06-04T13:50:17.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/H6zZGNAF2pU/sddefault.jpg',
#      'width': 640}},
#    'title': 'Data Fest² Minsk 2018'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/d8dermSzyxN9XwaGrNSS_J9gqX8"',
#   'id': 'PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Open Data Science April Meetup'},
#    'publishedAt': '2018-04-19T07:01:41.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/OFOp_zmljfg/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science April Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BPse8qYbI_ofaVafYf1AYHsMyYo"',
#   'id': 'PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science March Meetup #2'},
#    'publishedAt': '2018-03-27T10:40:51.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/5oqdfBqok94/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science March Meetup #2'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zccfrD6MnPR1va5nSsamdY_MBzs"',
#   'id': 'PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '', 'title': 'Open Data Science March Meetup'},
#    'publishedAt': '2018-03-12T13:00:40.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/80QO8TjuDBE/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science March Meetup'}},
#  {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FCNp3pv_lCnNT6atgQcpzM-yLJQ"',
#   'id': 'PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG',
#   'kind': 'youtube#playlist',
#   'snippet': {'channelId': 'UCX5g8IOR_tw1OkiFAzAZHaA',
#    'channelTitle': 'EventSpaceBy Video',
#    'description': '',
#    'localized': {'description': '',
#     'title': 'Open Data Science December Meetup'},
#    'publishedAt': '2018-01-08T15:19:58.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/hqdefault.jpg',
#      'width': 480},
#     'maxres': {'height': 720,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/maxresdefault.jpg',
#      'width': 1280},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/mqdefault.jpg',
#      'width': 320},
#     'standard': {'height': 480,
#      'url': 'https://i.ytimg.com/vi/Ozm0bEi5KaI/sddefault.jpg',
#      'width': 640}},
#    'title': 'Open Data Science December Meetup'}}]

# %%
data = [(item['id'], item['snippet']['title'], item['snippet']['publishedAt'], 
         item['snippet']['channelTitle']) for item in pl1+pl2]

# %%
df = pd.DataFrame(data, columns=['id', 'title', 'publishedAt', 'channelTitle'])

# %%
df
# Out:
#                                     id                               title  \
# 0   PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T             Data Ёлка в Минске 2018
# 1   PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh   Open Data Science November Meetup
# 2   PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT  Open Data Science September Meetup
# 3   PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_               Data Fest² Minsk 2018
# 4   PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk      Open Data Science April Meetup
# 5   PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y   Open Data Science March Meetup #2
# 6   PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke      Open Data Science March Meetup
# 7   PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG   Open Data Science December Meetup
# 8   PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1    Open Data Science October Meetup
# 9   PLpVeA1tdgfCCLSWY6fIfZe64U9K39tgQm          Open Data Science Meetup#1
# 10  PLpVeA1tdgfCCpxs5GTQ2G3xfyqw3xwh4p              Data Fest Belarus 2017
#
#                  publishedAt        channelTitle
# 0   2018-12-12T09:27:21.000Z  EventSpaceBy Video
# 1   2018-11-08T13:12:35.000Z  EventSpaceBy Video
# 2   2018-09-17T12:07:32.000Z  EventSpaceBy Video
# 3   2018-06-04T13:50:17.000Z  EventSpaceBy Video
# 4   2018-04-19T07:01:41.000Z  EventSpaceBy Video
# 5   2018-03-27T10:40:51.000Z  EventSpaceBy Video
# 6   2018-03-12T13:00:40.000Z  EventSpaceBy Video
# 7   2018-01-08T15:19:58.000Z  EventSpaceBy Video
# 8   2017-11-08T13:02:53.000Z  EventSpaceBy Video
# 9   2017-08-25T15:02:20.000Z  EventSpaceBy Video
# 10  2017-05-22T15:25:24.000Z  EventSpaceBy Video

# %%
url_playlist = 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet%2C+id&playlistId={ID}&key={API_KEY}&maxResults=49'

# %%
r = requests.get(url_playlist.format(ID='UUeq6ZIlvC9SVsfhfKnSvM9w', API_KEY=API))

# %%
js_vid = json.loads(r.text)

# %%
js_vid
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OR6tlgU8myYkTjIXsHHm1-wYRFc"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/u5BtJ_qNh7KOrpMCiQlW1yEFZh4"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LjkyQVFXQkw0d3JB',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Помните, как Google предлагал делать рукописные рисунки на заданную тему для сбора датасета? Так вот недавно на Kaggle завершился конкурс, в котором требовалось классифицировать эти изображения. Роман Власов рассказал, как он вместе со своей командой решал это соревнование и занял 4 место. Кстати, первое и пятое места заняли также члены OpenDataScience. Из видео вы сможете узнать про выбранные модели, трюки при их обучении и балансирование предсказаний.\n\nСлайды: https://gh.mltrainings.ru/presentations/Vlasov_KaggleQuickDraw_2019.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 0,
#     'publishedAt': '2019-02-04T16:48:57.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '92AQWBL4wrA'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/92AQWBL4wrA/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/92AQWBL4wrA/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/92AQWBL4wrA/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/92AQWBL4wrA/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/92AQWBL4wrA/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Quick, Draw! Doodle Recognition: классификация рукописных рисунков — Роман Власов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/z8_OAv3oj0FpwQm_X45nrbQTunY"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LlFidWpBVFZDbUFN',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Сергей Злобин рассказывает про задачу классификации космических объектов (Kaggle PLAsTiCC Astronomical Classification), в которой Сергею вместе с его командой не хватило всего одного места до золота. Из видео вы сможете узнать про признаки на основе подгонки кривых под точки, аугментацию астрономических данных и эвристические правки предсказаний отдельных классов. \n\nСлайды: https://gh.mltrainings.ru/presentations/Zlobin_KagglePlasticc_2019.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 1,
#     'publishedAt': '2019-02-03T16:28:08.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'QbujATVCmAM'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/QbujATVCmAM/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/QbujATVCmAM/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/QbujATVCmAM/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/QbujATVCmAM/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/QbujATVCmAM/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle PLAsTiCC: классификация космических объектов — Сергей Злобин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rRAEP5UPj2iWie51i65LJ896ygY"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkhPOHltakYtVVR3',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Дмитрий Буслов — Классификация паттернов белков (Kaggle Human Protein Atlas Image Classification)\nРоман Власов — Классификация рукописных рисунков (Kaggle Quick, Draw! Doodle Recognition Challenge)\nСергей Злобин — Классификация космических объектов (Kaggle PLAsTiCC Astronomical Classification)\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.С докладами выступают успешные участники последних соревнований на Kaggle — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 2,
#     'publishedAt': '2019-01-26T10:54:22.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'HO8ymjF-UTw'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/HO8ymjF-UTw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/HO8ymjF-UTw/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/HO8ymjF-UTw/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 26.01.19 | Kaggle Draw Doodle, Human Protein, PLAsTiCC'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/cCx6V_6tZjMeMviRUX0XUYDHJVU"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmZaUy1oOGZ3Uklr',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': '- Антон Кленицкий — Построение системы автоматического машинного обучения (SDSJ AutoML 2018)\n- Павел Остяков — Классификация изображений c применением на новый географический регион (Kaggle Inclusive Images Challenge)\n- Константин Гаврильчик, Евгений Кононенко — Детектирование кораблей на спутниковых снимках (Kaggle Airbus Ship Detection Challenge)\n\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом. С докладами выступают успешные участники последних соревнований на Kaggle — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 3,
#     'publishedAt': '2018-11-24T11:43:29.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fZS-h8fwRIk'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/fZS-h8fwRIk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/fZS-h8fwRIk/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/fZS-h8fwRIk/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 24.11.18 SDSJ AutoML, Kaggle Inclusive Images, Airbus Ship Detection'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ZuX7_QjS7LNQ5qC81VBXaGX8-Wg"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmNqb2ktUENjcGYw',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': '- Константин Гаврильчик (Сколтех), Артур Фаттахов (Umim) — Отборочный этап Data Science Game 2018\n- Евгений Кононенко (Сколтех), Василий Рязанов (МФТИ) — Финальный этап Data Science Game 2018\n- Дмитрий Симаков (Сбербанк, ФКН ВШЭ), Никита Чуркин (Сбербанк, ФКН ВШЭ) — Прогнозирование повышения работника (WNS Analytics Wizard 2018)\n- Иван Сосин (Лаборотория Касперского) — Сегментирование солевых отложений под поверхностью Земли (Kaggle TGS Salt Identification Challenge)\n\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.С докладами выступают успешные участники последних соревнований на Kaggle — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 4,
#     'publishedAt': '2018-10-27T11:31:47.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'cjoi-PCcpf0'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/cjoi-PCcpf0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/cjoi-PCcpf0/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/cjoi-PCcpf0/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 27.10.18 | Data Science Game, Kaggle TGS Salt, WNS Analytics'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/kpyLYO1hxCJ6coL1kt1-Ae6vhUs"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmEzc1NSbTBuU2hR',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Каждые две недели Яндекс проводит тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом. \n7 октября тренировка пройдет в кампусе МФТИ, и в начале программы - два обзорных доклада, которые будут интересны тем, кто только начинает свой путь в сфере анализа данных. Студентам расскажут, что такое соревновательное машинное обучение, какую пользу оно приносит участникам и индустрии, а также как ML-соревнования помогают стать настоящим data scientist.\nВо второй части нас ждёт традиционный разбор конкурсов.\nВ программе:\nЭмиль Каюмов — Соревнования по машинному обучению и трюки при их решении\nАртур Кузин — DL-соревнования — гуси, пайплайны, кулстори\nКонстантин Гаврильчик — Детектирование объектов и связей между ними на изображениях (Kaggle Google AI Open Images)\nДмитрий Кулагин — Могут ли люди предсказать курс Bitcoin? (Dbrain contest)',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 5,
#     'publishedAt': '2018-10-07T11:27:31.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'a3sSRm0nShQ'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/a3sSRm0nShQ/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/a3sSRm0nShQ/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/a3sSRm0nShQ/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 07.10.18 | Kaggle Google AI Open Images, Dbrain contest'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/x-QHBacd0brpTsEXoH0569TrTzU"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lkg0c2wzaU1UQ25z',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Рассказ о решении, занявшем 3 место на конкурсе Kaggle Home Credit default risk. Задачей соревнования было оценить вероятность невозврата кредита заемщиком. В выступлении рассматривается архитектура решения, подход к локальной валидации и отбору переменных, а также нестандартные подходы к построению скоринговой модели. В качестве бонуса  - рассказ о том, как хорошие результаты на Kaggle помогли начать карьеру дата-сайентиста.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 6,
#     'publishedAt': '2018-09-20T12:38:20.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'H4sl3iMTCns'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/H4sl3iMTCns/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/H4sl3iMTCns/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/H4sl3iMTCns/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/H4sl3iMTCns/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/H4sl3iMTCns/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Home Credit: определение риска дефолта по кредитам — Евгений Патеха'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/px2ga_e10oUHJyB4Xnx5DXQkUug"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkxORHIyR08zUGRZ',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Доклад о соревновании на Kaggle от банка Santander про предсказание размера транзакций потенциальных клиентов. В докладе рассказывалось про важность отработки лика в случае его нахождения в соревновании и про использование машинного обучения (блендинг моделей градиентного бустинга) для предсказания таргета, не обнаруженного в лике.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 7,
#     'publishedAt': '2018-09-20T12:37:36.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'LNDr2GO3PdY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/LNDr2GO3PdY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/LNDr2GO3PdY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/LNDr2GO3PdY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/LNDr2GO3PdY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/LNDr2GO3PdY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Santander: предсказание размера транзакций потенциальных клиентов — Анатолий Ильенков'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yZK1nSunKgpeUid_jG4eqz9QACE"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lk41ZXd3cTVUQ0dF',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Весной 2018 года проходил Retro Contest от OpenAI, который был посвящен обучению с подкреплением, meta learning и, конечно же, Sonic The Hedgehog. В докладе Сергей рассказал, в чем был особый интерес этого конкурса, и как их команда заняла 4 место. Не остались без внимания и подробности финального решения, а также обзор того, что было исследовано и испробовано в процессе.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 8,
#     'publishedAt': '2018-09-20T12:37:10.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'N5ewwq5TCGE'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/N5ewwq5TCGE/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/N5ewwq5TCGE/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/N5ewwq5TCGE/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/N5ewwq5TCGE/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/N5ewwq5TCGE/sddefault.jpg',
#       'width': 640}},
#     'title': 'OpenAI Retro: как казаки retro контест решали — Сергей Колесников'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/95bmOv0n62VHRlQy3LZDXYnl7JU"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkM5NUZnZWVrclN3',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Валерий рассказал, как он добился 118 места в мировом рейтинге Kaggle и стал грандмастером, а также про то, как участие в конкурсах помогло ему построить карьеру.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 9,
#     'publishedAt': '2018-09-20T12:36:29.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'C95FgeekrSw'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/C95FgeekrSw/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/C95FgeekrSw/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/C95FgeekrSw/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/C95FgeekrSw/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/C95FgeekrSw/sddefault.jpg',
#       'width': 640}},
#     'title': 'От новичка к мастеру, от хемометриста к Head of DS — Валерий Бабушкин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TtyH4qmX9TAGxFl4gNjHO9jNJkk"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmNGR0NxcE5YTjU0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Каждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\n\nС докладами выступают успешные участники последних соревнований на Kaggle — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.\n\nЭтой осенью мы запустили сезон выездных тренировок в профильных вузах, и первая пройдет на Факультете компьютерных наук Высшей школы экономики.\n\nВ программе:\n\nВалерий Бабушкин — От новичка к мастеру, от хемометриста к Head of DS\nСергей Колесников — OpenAI Retro Contest — Как заставить компьютер научиться играть в известную игру Sonic The Hedgehog на одних уровнях, чтобы успешно преодолеть новые\nАнатолий Ильенков — Kaggle Santander Value Prediction Challenge — Предсказание размера транзакций потенциальных клиентов\nЕвгений Патеха — Kaggle Home Credit Default Risk — Определение риска дефолта по кредитам\n\nПодробнее о мероприятии: https://events.yandex.ru/events/mltr/15-sept-2018/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 10,
#     'publishedAt': '2018-09-15T11:32:20.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'cFGCqpNXN54'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/cFGCqpNXN54/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/cFGCqpNXN54/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/cFGCqpNXN54/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 15.09.18 | OpenAI Retro Contest, Kaggle Home Credit, Santander'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/f4gOVBNRqLBVsTzgfoOvU6Ql16Q"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lkh0UTJSMVpGc1pj',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Глеб Стеркин и Владимир Алиев вместе со своей командой заняли 4 место в конкурсе Kaggle The 2nd YouTube-8M Video Understanding Challenge. Как и в прошлом году стояла задача в классификации большого объёма видео, но в этот раз с ограничениями на размер модели. В видео участники рассказывают про использованные модели, многоуровневый подход с нейронными сетями и градиентным бустингом, сравнивают различные подходы.\n\nСлайды: https://gh.mltrainings.ru/presentations/SterkinAliev_KaggleYT8M2_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 11,
#     'publishedAt': '2019-01-07T17:19:12.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'HtQ2R1ZFsZc'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/HtQ2R1ZFsZc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/HtQ2R1ZFsZc/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/HtQ2R1ZFsZc/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/HtQ2R1ZFsZc/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/HtQ2R1ZFsZc/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle YouTube-8M 2: классификация видео — Глеб Стеркин, Владимир Алиев'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rtgHXnNOYmrL6n-dPIhtVswEyTo"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lk1JYmV0TUFuQzA0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Артур Кузин рассказывает историю про найденный лик в Kaggle Airbus Ship Detection Challenge. Из видео вы сможете узнать:\n- Как попадаются лики в конкурсах, где нужно использовать нейросети\n- Где уже встречались лики в изображениях\n- Как искать похожие изображения\n- Можно ли скрывать успех от других участников соревнования\n- Что сделали с конкурсом дальше\n\nСлайды: https://gh.mltrainings.ru/presentations/Kuzin_KaggleAIrbusLeak_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 12,
#     'publishedAt': '2018-09-09T09:34:50.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'MIbetMAnC04'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/MIbetMAnC04/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/MIbetMAnC04/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/MIbetMAnC04/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/MIbetMAnC04/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/MIbetMAnC04/sddefault.jpg',
#       'width': 640}},
#     'title': 'История про лик в Kaggle Airbus Ship Detection — Артур Кузин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/gSCTu6L3VqPQ0PwKcnuP672htX0"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkpXeHJYT2k5Nlg0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'ПРОГРАММА\n\n1. Артур Фаттахов, Константин Гаврильчик — Трекинг частиц (Kaggle TrackML Particle Tracking)\n2. Артур Кузин (Dbrain) — История про лик в Kaggle Airbus\n3. Глеб Стеркин, Владимир Алиев — Классификация видео (Kaggle The 2nd YouTube-8M Video Understanding Challenge)\n\n\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\nМероприятия состоят из практической части и докладов. Задачи для первой берутся с Kaggle и других схожих площадок. С докладами выступают успешные участники последних соревнований — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 13,
#     'publishedAt': '2018-09-01T09:23:59.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'JWxrXOi96X4'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/JWxrXOi96X4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/JWxrXOi96X4/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/JWxrXOi96X4/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 01.09.18 | Kaggle YT8M, TrackML, OpenAI Retro Contest'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/I50j-1XzQCyKDAyjw2eJsUie_70"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LnFTZWhTVFdNWGFZ',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Тренировки по машинному обучению - это традиционные встречи в московском офисе Яндекса, на которых выступают успешные участники последних соревнований по анализу данных. В формате 20-минутных докладов они рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.\nПрограмма на сегодня: \nГригорий Рашков — Как создать чат-бота с личным профилем — DeepHack.Сhat (1-ое место).\nВиталий Давыдов, Сергей Колесников — Как не выиграть хакатон по чатботам — DeepHack.Сhat (2-ое место)\nСергей Белов, Александр Дроботов, Алексей Каюченко — Прогнозирование темпов продаж недвижимости — PIK Digital Day (2-ое место)\nНикита Шаповалов — Яндекс.Блиц, Машинное Обучение (2-ое место)\nПодробнее о мероприятии: https://events.yandex.ru/events/mltr/28-july-2018/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 14,
#     'publishedAt': '2018-07-28T11:04:31.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'qSehSTWMXaY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/qSehSTWMXaY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/qSehSTWMXaY/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/qSehSTWMXaY/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции тренировки ML 28.07.2018 | DeepHack.Сhat, PIK Digital Day, Яндекс.Блиц'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/n7ba-frx_W5073Y1XMFj6R9Jx9w"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LnFnRlJtbEtaYVNj',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Узнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 15,
#     'publishedAt': '2018-07-08T12:18:47.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'qgFRmlKZaSc'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/qgFRmlKZaSc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/qgFRmlKZaSc/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/qgFRmlKZaSc/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/qgFRmlKZaSc/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/qgFRmlKZaSc/sddefault.jpg',
#       'width': 640}},
#     'title': 'CVPR 2018 WAD: сегментация видео для автономных автомобилей – Азат Ахтямов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/sPuvGoryaAmJ2oeTxs4kZ9vao4c"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LnJhQjRfRFF2MnAw',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Узнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 16,
#     'publishedAt': '2018-07-08T12:15:15.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'raB4_DQv2p0'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/raB4_DQv2p0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/raB4_DQv2p0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/raB4_DQv2p0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/raB4_DQv2p0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/raB4_DQv2p0/sddefault.jpg',
#       'width': 640}},
#     'title': 'ODS Crowd как толпой зарешали Avito Demand Prediction – Дмитрий Дремов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5ISXM-2CxAzqMzwJ2d2EATvEgRQ"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkNySDN4ZVZPN3Jr',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Demand prediction based on classified ads,\n\nValentina Birukova talks about how her team placed second in the\nKaggle Avito Demand Prediction Challenge. \n\nYandex hosts biweekly training sessions on machine learning. \nThese meetings offer an opportunity for the participants of data analysis contests to meet, talk, and exchange experience. Each of these events is made up of a practical session and a report. The problems are taken from Kaggle and similar platforms. \nThe reports are given by successful participants of recent contests, who share their strategies and talk about the techniques used by their competitors.\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 17,
#     'publishedAt': '2018-07-08T12:10:49.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'CrH3xeVO7rk'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/CrH3xeVO7rk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/CrH3xeVO7rk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/CrH3xeVO7rk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/CrH3xeVO7rk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/CrH3xeVO7rk/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Avito Demand Prediction  - Valentina Biryukova'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PDophxn_5jfJKnB8ckIPlr_U4L8"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LktFZVhGWTBuMlZn',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Как обмануть алгоритм распознавания лиц\nMachines Can See 2018 Adversarial Attacks on Black Box Face Recognition\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 18,
#     'publishedAt': '2018-07-08T12:22:47.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'KEeXFY0n2Vg'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/KEeXFY0n2Vg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/KEeXFY0n2Vg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/KEeXFY0n2Vg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/KEeXFY0n2Vg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/KEeXFY0n2Vg/sddefault.jpg',
#       'width': 640}},
#     'title': 'Machines Can See 2018 Adversarial Attacks on Black Box Face Recognition – Татьяна Гайнцева'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3HBQbHhyNgZazpNwjSbWG_u6XEU"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LnpOVFJtSW9QTG5z',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Татьяна Гайнцева — Как обмануть алгоритм распознавания лиц, Machines Can See 2018\nВалентина Бирюкова — Оценка спроса по объявлению, Kaggle Avito Demand Prediction\nДмитрий Дремов — "ODS Crowd": как толпой зарешали Avito Demand Prediction\nАзат Ахтямов — Сегментация видео для автономных автомобилей, CVPR 2018 WAD Video Segmentation Challenge\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\nЗадачи берутся с Kaggle и других схожих площадок. С докладами выступают успешные участники последних соревнований — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 19,
#     'publishedAt': '2018-07-07T11:53:14.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'zNTRmIoPLns'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/zNTRmIoPLns/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/zNTRmIoPLns/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/zNTRmIoPLns/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции тренировки ML 07.07.2018 | MCS 2018, Kaggle Avito Demand Prediction, CVPR 2018 WAD'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Jh7IHcUztybE7kVcR6z5fSibPXc"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmZYbnpqSk1idWpj',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Pavel Pleskov shares five secrets to becoming a Kaggle grandmaster. This video discusses:\n— Whether you should strive to earn the title.\n— The difference between the academic and the business approach to machine learning contests.\n— What the best practical online course on neural networks is.\n— About teamwork and the Open Data Science community (ODS.ai).\n\nYou can find out about the current contests at http://mltrainings.ru/.\n\nNew training sessions and videos in our communities on Facebook (https://www.facebook.com/groups/1413405125598651/) and VK (https://vk.com/mltrainings)',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 20,
#     'publishedAt': '2018-07-19T14:23:37.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fXnzjJMbujc'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/fXnzjJMbujc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/fXnzjJMbujc/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/fXnzjJMbujc/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/fXnzjJMbujc/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/fXnzjJMbujc/sddefault.jpg',
#       'width': 640}},
#     'title': '5 secrets to becoming a Kaggle grandmaster — Pavel Pleskov'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3aMPVTZKaByEFaz1B2MfcRRidiY"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmdPVnVrYjFtQzhz',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Александр Паркин делает обзор adversarial атак и рассказывает про конкурс по атакам на модель распознавания. Из видео вы сможете узнать:\n- Виды white box и black box атак\n- Атаки в реальной жизни\n- Способы защиты от adversarial атак\n- Особенности соревнования по adversarial атакам\n\nСлайды: https://gh.mltrainings.ru/presentations/Parkin_AdversarialAttacks_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 21,
#     'publishedAt': '2018-09-05T06:01:45.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'gOVukb1mC8s'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/gOVukb1mC8s/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/gOVukb1mC8s/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/gOVukb1mC8s/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/gOVukb1mC8s/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/gOVukb1mC8s/sddefault.jpg',
#       'width': 640}},
#     'title': 'Обзор adversarial атак и конкурс по атакам на модель распознавания лиц — Александр Паркин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JNUmliQc0qI2RoOMMngnC7hljlA"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LldTaVBOQ3pTaFNZ',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Олег Акимов и Владимир Семенових рассказывают про задачу определения категорий покупок в чеке. Олег и Владимир заняли в соревновании два первых места. Из видео вы сможете узнать:\n- Откуда появился конкурс и только ли проходят соревнования от крупных компаний\n- Виды и способы получения признаков для модели\n- Препроцессинг данных и подход альтернативного решения\n\nСлайды: https://gh.mltrainings.ru/presentations/AkimovSemenovich_ReceipeCategorization_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 22,
#     'publishedAt': '2018-08-28T08:02:01.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'WSiPNCzShSY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/WSiPNCzShSY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/WSiPNCzShSY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/WSiPNCzShSY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/WSiPNCzShSY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/WSiPNCzShSY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Определение категорий покупок в чеке – Олег Акимов, Владимир Семенових'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0kS-fe6IW7-nSup75Xz14wqJ-yM"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LnVNUDJqS3FkN3A0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': '- Кирилл Романов — Предсказание доходности ценных бумаг (crowdAI IEEE Investment Ranking Challenge)\n- Павел Плесков — 5 секретов как стать кэггл грандмастером\n- Денис Логвиненко — Поиск фотографий с заданными достопримечательностями (Kaggle Google Landmark Retrieval Challenge)\n\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\nМероприятия состоят из практической части и докладов. Задачи для первой берутся с Kaggle и других схожих площадок. С докладами выступают успешные участники последних соревнований — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.\nМероприятие состоится в конференц-зале «Мулен Руж» с 12:00 до 15:00. Мы ждём опытных и начинающих участников конкурсов по машинному обучению.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 23,
#     'publishedAt': '2018-06-16T11:12:56.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'uMP2jKqd7p4'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/uMP2jKqd7p4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/uMP2jKqd7p4/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/uMP2jKqd7p4/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции тренировки ML 16.06.2018 | Investment Ranking, Kaggle Landmark Retrieval'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RIBj0rEcP3V95PLmRSsD9XrStAA"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LjBZZWZwcS1FX0tR',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Обзор новых соревнований по анализу данных от 26 мая 2018 года. Эмиль Каюмов рассказывает про актуальные соревнования, в которых можно принять участие. Календарь соревнований: http://mltrainings.ru/ \n\nСлайды: https://gh.mltrainings.ru/presentations/CompetitionDigest_2018-05-26.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 24,
#     'publishedAt': '2018-05-26T17:05:12.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '0Yefpq-E_KQ'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/0Yefpq-E_KQ/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/0Yefpq-E_KQ/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/0Yefpq-E_KQ/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/0Yefpq-E_KQ/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/0Yefpq-E_KQ/sddefault.jpg',
#       'width': 640}},
#     'title': 'Май 2018 | Дайджест соревнований по анализу данных'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/lJhOfAs8iw3eHd2OSYpb08dahdE"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LjRraFR5NFdyOWZv',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Описание:\nОлег Акимов, Владимир Семенових — Определение категорий покупок в чеке\nАлександр Паркин — Обзор adversarial атак и конкурс по атакам на модель распознавания лиц\nДайджест актуальных соревнований по машинному обучению\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\nМероприятия состоят из практической части и докладов. Задачи для первой берутся с Kaggle и других схожих площадок. С докладами выступают успешные участники последних соревнований — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 25,
#     'publishedAt': '2018-05-26T10:41:16.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '4khTy4Wr9fo'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/4khTy4Wr9fo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/4khTy4Wr9fo/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/4khTy4Wr9fo/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись тренировки ML 26.05.2018 | Категории покупок, adversarial атаки'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/s6uSDKyk68nMWspLWv7sJkSKD1E"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lnl4T2d0R3pvVGRr',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Сергей Гайдаенко рассказывает про задачу определение дома и работы клиента по банковским транзакциям, которая решалась в рамках контеста Boosters Raiffeisen Data Cup. Сергей показал наилучший результат в соревновании. Из видео вы сможете узнать:\n- Какие проблемы в данных существовали и как производилась фильтрация\n- Как рассчитывались признаки-агрегаты по окрестностям\n- Признаки по суммам, объектам, временам и какие из них оказались наиболее полезными\n\nСлайды: https://gh.mltrainings.ru/presentations/Gaidaenko_BoostersRaiffeisenDataCup_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 26,
#     'publishedAt': '2018-09-03T08:11:42.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'yxOgtGzoTdk'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/yxOgtGzoTdk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/yxOgtGzoTdk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/yxOgtGzoTdk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/yxOgtGzoTdk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/yxOgtGzoTdk/sddefault.jpg',
#       'width': 640}},
#     'title': 'Определение дома и работы клиента по банковским транзакциям – Сергей Гайдаенко'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BR7BCrNV8cIcANUr4-hHpPMN37Q"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lm9td2NIV1ZhM1dJ',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Ренат Баширов вместе со своей командой выиграл в задаче "Два стула" на хакатоне Whatever Hack. Участникам было необходимо детектировать на изображениях мебель 9 видов. В видео Ренат рассказывает про устройство популярных детекторов изображений, решение своей команды на основе нескольких из них и как они успели обучать все сети за одни выходные.\n\nСлайды: https://gh.mltrainings.ru/presentations/Bashirov_WhateverhachTask2_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 27,
#     'publishedAt': '2018-11-28T08:20:08.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'omwcHWVa3WI'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/omwcHWVa3WI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/omwcHWVa3WI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/omwcHWVa3WI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/omwcHWVa3WI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/omwcHWVa3WI/sddefault.jpg',
#       'width': 640}},
#     'title': 'Хакатон Whatever Hack, задача «Два стула» — Ренат Баширов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vXKyaE3FvlYM_Zn7ENPhLFT7MJM"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmFNbHBlRE9qaWI4',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
# ...
#     'channelTitle': 'Тренировки ML',
#     'description': 'Андрей Филимонов рассказывает про задачу предсказания продаж сети супермаркетов (Kaggle Corporación Favorita Grocery Sales Forecasting). Андрей занял в соревновании 3 место. Из видео вы сможете узнать:\n- Валидация в задачах со временем\n- Использование свёрточных нейронных сетей для предсказания продаж\n- Какие модели были применены в ансамбле и их качество\n- Не сработавшие идеи и интересные находки\n\nСлайды: https://gh.mltrainings.ru/presentations/Filimonov_KaggleCorporacionFavorita_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 41,
#     'publishedAt': '2018-03-19T08:43:06.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '_C_vXZ_y6W8'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/_C_vXZ_y6W8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/_C_vXZ_y6W8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/_C_vXZ_y6W8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/_C_vXZ_y6W8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/_C_vXZ_y6W8/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Corporación Favorita Grocery: предсказание продаж сети супермаркетов  — Андрей Филимонов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/B6dKPAUbSjIKekWheTUPNgPbRyM"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lld5c1hpbElXU2dB',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Азат Ахтямов рассказывает про задачу классификации спутниковых снимков на корабли и айсберги (Kaggle Statoil/C-CORE Iceberg Classifier Challenge). Азат занял в соревновании 6 место. Из видео вы сможете узнать:\n- Ещё один вид лика в конкурсах с изображениях и способе извлечь из него полезную информацию\n- Подход с псевдоразметкой изображения\n- Использование leaky-признаков вместе с изображения в одной нейронной сети\n- Решения других участников\n\nСлайды: https://gh.mltrainings.ru/presentations/Akhtyamov_KaggleIceberg_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 42,
#     'publishedAt': '2018-03-15T08:04:25.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'WysXilIWSgA'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/WysXilIWSgA/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/WysXilIWSgA/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/WysXilIWSgA/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/WysXilIWSgA/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/WysXilIWSgA/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Iceberg: классификация спутниковых снимков на корабли и айсберги — Азат Ахтямов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_rjpNbLfyw1cYqNCIt8H5GpcpN4"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Ljd1Z0xZR2Vicko4',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': "Василий Рубцов рассказывает про задачу предсказания повторного прослушивания композиции пользователем (Kaggle WSDM KKBox's Music Recommendation Challenge). Василий занял в соревновании 3 место. Из видео вы сможете узнать:\n- Разделение датасета для подсчёта признаков и обучения моделей\n- Использование supervised признаков через линейную регрессию и матричную факторизацию\n- Признаки и их сравнение по полезности\n\nСлайды: https://gh.mltrainings.ru/presentations/Rubtsov_KaggleWSDMKKBox_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/",
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 43,
#     'publishedAt': '2018-03-07T05:53:25.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '7ugLYGebrJ8'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/7ugLYGebrJ8/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/7ugLYGebrJ8/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/7ugLYGebrJ8/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/7ugLYGebrJ8/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/7ugLYGebrJ8/sddefault.jpg',
#       'width': 640}},
#     'title': "Kaggle WSDM KKBox's: предсказание повторного прослушивания композиции — Василий Рубцов"}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_hZRDzfi1Hf1XrSgJpKHIKHPetw"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3Lk13MnZkWXY0dXBz',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Pavel Ostyakov and Alexey Kharlamov share their solution of Kaggle Cdiscount’s Image Classification Challenge. In this competition, Kagglers were challenged to build a model that classifies the products based on their images. From this video you will learn:\n- How to decide which architectures to use\n- How to train networks faster\n- Problem with training second layer of classifiers\n- Errors while solving the problem\n- Ideas of other teams: using several images of product, ensembling and using kNN\n\nПавел Остяков и Алексей Харламов рассказывают про задачу классификации товаров по изображениям (Kaggle Cdiscount’s Image Classification Challenge). Павел и Алексей вместе со своей командой заняли в соревновании 5 место. Из видео вы сможете узнать:\n- Как принимается решение, какие архитектуры использовать\n- Способы ускорить обучение сетей\n- Сложности построения второго слоя классификаторов и способ решения\n- Ошибки, допущенные в процессе решения\n- Идеи других участников: использование нескольких изображений товара, ансамблирование и kNN\n\nYandex hosts biweekly training sessions on machine learning. \nThese meetings offer an opportunity for the participants of data analysis contests to meet, talk, and exchange experience. Each of these events is made up of a practical session and a report. The problems are taken from Kaggle and similar platforms. \nThe reports are given by successful participants of recent contests, who share their strategies and talk about the techniques used by their competitors.\nOn Dec. 9, we looked at Porto Seguro’s Safe Driver Prediction challenge on Kaggle.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 44,
#     'publishedAt': '2018-02-19T08:23:45.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Mw2vdYv4ups'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Mw2vdYv4ups/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Mw2vdYv4ups/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Mw2vdYv4ups/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Mw2vdYv4ups/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Mw2vdYv4ups/sddefault.jpg',
#       'width': 640}},
#     'title': 'Kaggle Cdiscount’s Image Classification Challenge — Pavel Ostyakov, Alexey Kharlamov'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-bw6kKrXrT-BmhIAQ0ohLTKntKs"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LjFNeGN5bHIzZGQ0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Максим Келаскин рассказывает про задачу предсказания кликов на шоу из поисковой выдачи сайта Ticketland (Boosters Ticketland ML Contest). Максим выиграл это соревнование. Из видео вы сможете узнать:\n- Какие признаки можно сгенерировать и какие можно использовать «из коробки»\n- Учёт поведения пользователей внутри сессии\n- Лик или особенность в данных, позволившая заметно увеличить результат\n\nСлайды: https://gh.mltrainings.ru/presentations/Kelaskin_BoostersTicketland_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 45,
#     'publishedAt': '2018-02-21T08:29:17.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '1Mxcylr3dd4'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/1Mxcylr3dd4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/1Mxcylr3dd4/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/1Mxcylr3dd4/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/1Mxcylr3dd4/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/1Mxcylr3dd4/sddefault.jpg',
#       'width': 640}},
#     'title': 'Boosters: предсказание кликов на шоу из поисковой выдачи сайта Ticketland — Максим Келаскин'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ra098Ogr3I0-LZ_xmi3k-1rGONM"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LkZhaFZ0YnhzRXpB',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Анзор Березгов рассказывает про задачу прогнозирования вероятности невозврата кредита (SAS competitions: Home Credit Bank). Анзор выиграл это соревнование. Из видео вы сможете узнать:\n- Подходы к агрегации сведений о различных кредитах пользователей и их качество\n- Построение признаков по различным группам кредитов\n- Какие признаки-агрегаторы можно использовать\n\nСлайды: https://gh.mltrainings.ru/presentations/Berezgov_SASHomeCredit_2018.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 46,
#     'publishedAt': '2018-02-14T08:12:34.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'FahVtbxsEzA'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/FahVtbxsEzA/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/FahVtbxsEzA/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/FahVtbxsEzA/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/FahVtbxsEzA/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/FahVtbxsEzA/sddefault.jpg',
#       'width': 640}},
#     'title': 'Home Credit Bank: Прогнозирование вероятности невозврата кредита —\xa0Анзор Березгов'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ay71nPmgtX2DlHEfrRMiW-UnRBY"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LjlNUUVFeVlEQ1Fj',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Азат Ахтямов — Корабль или айсберг? Классификация по спутниковым снимкам (Kaggle Statoil/C-CORE Iceberg Classifier Challenge)\nАндрей Филимонов — Предсказание продаж сети супермаркетов (Kaggle Corporación Favorita Grocery Sales Forecasting)\nАртём Трунов — Прогнозирование продаж компании (TrainMyData: Прогнозирование продаж Ascott group)\nКаждые две недели в Яндексе проходят тренировки по машинному обучению. Эти встречи помогают участникам конкурсов в сфере анализа данных пообщаться и обменяться опытом.\nМероприятия состоят из практической части и докладов. Задачи для первой берутся с Kaggle и других схожих площадок. С докладами выступают успешные участники последних соревнований — рассказывают о своих решениях и о том, какие техники и методы использовали их конкуренты.\nМероприятие состоится в конференц-зале «Мулен Руж» с 12:00 до 15:00. Мы ждём опытных и начинающих участников конкурсов по машинному обучению.',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 47,
#     'publishedAt': '2018-02-03T11:12:01.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '9MQEEyYDCQc'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/9MQEEyYDCQc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/9MQEEyYDCQc/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/9MQEEyYDCQc/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Запись трансляции ML тренировки 03.02.18 | Kaggle Iceberg, Grocery Sales, TrainMyData Ascott'}},
#   {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/qClf7n4rw6yfQEGCkEHwtR9JUGA"',
#    'id': 'VVVlcTZaSWx2QzlTVnNmaGZLblN2TTl3LmVOX2p4Zm9mQk9r',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCeq6ZIlvC9SVsfhfKnSvM9w',
#     'channelTitle': 'Тренировки ML',
#     'description': 'Александр Желубенков рассказывает про задачу определения релевантности вопроса параграфу (Sberbank Data Science Contest, задача А). Александр показал наилучший результат в данной задаче. Из видео вы сможете узнать:\n- Признаки для вопросов и пар вопросов-параграфов и идеи их появления\n- Зачем обучать модели на определение обучающей и тестовой выборки или как работать с искусственными данными\n- Сравнение качества разных подходов\n\nСлайды: https://gh.mltrainings.ru/presentations/Zhelubenkov_SberbankDataScienceContestA_2017.pdf\n\nУзнать о текущих соревнованиях можно на сайте http://mltrainings.ru/\nУзнать о новых тренировках и видео можно из групп:\nВКонтакте https://vk.com/mltrainings\nFacebook https://www.facebook.com/groups/1413405125598651/',
#     'playlistId': 'UUeq6ZIlvC9SVsfhfKnSvM9w',
#     'position': 48,
#     'publishedAt': '2018-02-01T09:00:16.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'eN_jxfofBOk'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/eN_jxfofBOk/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/eN_jxfofBOk/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/eN_jxfofBOk/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/eN_jxfofBOk/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/eN_jxfofBOk/sddefault.jpg',
#       'width': 640}},
#     'title': 'Sberbank Data Science Contest: определение релевантности вопроса параграфу  — Александр Желубенков'}}],
#  'kind': 'youtube#playlistItemListResponse',
#  'nextPageToken': 'CDEQAA',
#  'pageInfo': {'resultsPerPage': 49, 'totalResults': 158}}

# %%
len(js_videos['items'])
# Out:
# 5

# %%
from time import sleep

# %%
video_items = []
for IDX in df['id']:
    print(IDX)
    sleep(3)
    r = requests.get(url_playlist.format(ID=IDX, API_KEY=API))
    jss = [json.loads(r.text)]
    while 'nextPageToken' in json.loads(r.text):
        r = requests.get(url_playlist.format(ID=IDX, API_KEY=API) + \
                         '&nextPageToken={}'.format(json.loads(r.text)['nextPageToken']))
        jss.append(json.loads(r.text))
    
    for js in jss:
        for item in js['items']:
            video_items.append((item['id'], item['snippet']['title'], item['snippet']['publishedAt'],
                               item['snippet']['description'], item['snippet']['resourceId']['videoId']))
# Out:
# PLpVeA1tdgfCB0-kui8FRJDzO0f98aO05T
# PLpVeA1tdgfCDIvrN_vaNjQCoRM7Odrdxh
# PLpVeA1tdgfCDkQr5vOJYs5kIoLkTitAKT
# PLpVeA1tdgfCCUVsLVqHwegbsBBD1bhhR_
# PLpVeA1tdgfCDw8AP6VDQsiV02NJGwssCk
# PLpVeA1tdgfCDSUQpP2_CXHLh044lyXS3Y
# PLpVeA1tdgfCBTu5pPgyk2A88nIroYikke
# PLpVeA1tdgfCDx36rrLKpThbRurE0BGcGG
# PLpVeA1tdgfCCTcaKKlB9wplNfdop4E3C1
# PLpVeA1tdgfCCLSWY6fIfZe64U9K39tgQm
# PLpVeA1tdgfCCpxs5GTQ2G3xfyqw3xwh4p

# %%
df_vid = pd.DataFrame(video_items, columns=['id', 'title', 'publishedAt', 'description', 'youtube_id'])

# %%
df_vid.to_csv('ods_video_index.csv', index=None)

# %%
df_vid.columns
# Out:
# Index(['youtube_id', 'channel', 'title', 'publishedAt', 'description', 'url'], dtype='object')

# %%
transcripts = []
for idx in df_vid['youtube_id']:
    print(idx)
    sleep(2)
    transcripts.append(YouTubeTranscriptApi.get_transcript(idx))
# Out:
# aMlpeDOjib8
# WSiPNCzShSY
# LNDr2GO3PdY
# 7ugLYGebrJ8
# qgFRmlKZaSc
# eN_jxfofBOk
# JWxrXOi96X4
# HO8ymjF-UTw
# bi4xbnNNHeU
# WysXilIWSgA
# t1iw2zFb0U4
# N5ewwq5TCGE
# yxOgtGzoTdk
# omwcHWVa3WI
# N2WMVUKUt8I
# gOVukb1mC8s
# m4yxsBMBgtM
# Mw2vdYv4ups
# ETh8bJ_xKGA
# _C_vXZ_y6W8
# qSehSTWMXaY
# H4sl3iMTCns
# QFR0IHbzA30
# raB4_DQv2p0
# 4khTy4Wr9fo
# C95FgeekrSw
# 3mL9iP8g3fA
# KEeXFY0n2Vg
# MIbetMAnC04
# uMP2jKqd7p4
# fZS-h8fwRIk
# cjoi-PCcpf0
# PHqua4aW0UQ
# CrH3xeVO7rk
# 92AQWBL4wrA
# 1Mxcylr3dd4
# FahVtbxsEzA
# Cm70YLrzIuo
# 0Yefpq-E_KQ
# 9MQEEyYDCQc
# a3sSRm0nShQ
# fXnzjJMbujc
# QbujATVCmAM
# 9gRiMRvkI18
# gPvdCxz3ofI
# 2m1dbvH_Rhc
# cFGCqpNXN54
# zNTRmIoPLns
# HtQ2R1ZFsZc
# 2b8Bl8jvNcM
# u3CBW_59pZA

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript('92AQWBL4wrA')
# Out:
# [{'duration': 4.001, 'start': 5.569, 'text': 'меня зовут роман власов'},
#  {'duration': 5.01,
#   'start': 7.62,
#   'text': 'сегодня он собственно и расскажу про'},
#  {'duration': 5.19,
#   'start': 9.57,
#   'text': 'quick draw дул recognition чинить как'},
#  {'duration': 6.69,
#   'start': 12.63,
#   'text': 'видите довольно красивые картинки'},
#  {'duration': 7.349,
#   'start': 14.76,
#   'text': 'но по факту это не так вы этого дальше'},
#  {'duration': 5.759,
#   'start': 19.32,
#   'text': 'увидите вот собственно пару слов в'},
#  {'duration': 7.92,
#   'start': 22.109,
#   'text': 'команде в нашей команде было 5 человек'},
#  {'duration': 10.261,
#   'start': 25.079,
#   'text': 'я присоединился к ней прямо перед мерз'},
#  {'duration': 7.171,
#   'start': 30.029,
#   'text': 'дедлайном вот и нам также не повезло как'},
#  {'duration': 4.77,
#   'start': 35.34,
#   'text': 'и команде предыдущего докладчика нас'},
#  {'duration': 6.18,
#   'start': 37.2,
#   'text': 'немного шика пнула но наши капнула из'},
#  {'duration': 6.14,
#   'start': 40.11,
#   'text': 'мания а их из голда вот но мы заняли'},
#  {'duration': 5.3, 'start': 43.38, 'text': 'почетное четвертое место также'},
#  {'duration': 5.14,
#   'start': 46.25,
#   'text': 'соревнований был заметили тем то что'},
#  {'duration': 6.79,
#   'start': 48.68,
#   'text': 'евгений получил за него гранд-мастера'},
#  {'duration': 6.18,
#   'start': 51.39,
#   'text': 'иван получил мастера роман соловьев так'},
#  {'duration': 5.76,
#   'start': 55.47,
#   'text': 'остался гранд-мастером алекс тоже'},
#  {'duration': 6.18,
#   'start': 57.57,
#   'text': 'получил мастера я стал экспертом но'},
#  {'duration': 5.209,
#   'start': 61.23,
#   'text': 'самом деле сейчас мастер из протеин'},
#  {'duration': 5.7,
#   'start': 63.75,
#   'text': 'на самом деле даяна сейчас мастер и'},
#  {'duration': 7.801,
#   'start': 66.439,
#   'text': 'мастера я получил за протеин в который'},
#  {'duration': 7.64,
#   'start': 69.45,
#   'text': 'расскажет легче докладчик вот дальше'},
#  {'duration': 5.46, 'start': 74.24, 'text': 'чуть вообще такое за кафедру'},
#  {'duration': 4.72, 'start': 77.09, 'text': 'google это сервисы гугла google'},
#  {'duration': 3.849, 'start': 79.7, 'text': 'преследоваться преследовал цель'},
#  {'duration': 3.659,
#   'start': 81.81,
#   'text': 'попозировать искусственный интеллект и'},
#  {'duration': 3.231,
#   'start': 83.549,
#   'text': 'собственно этим сервисом он хотел'},
#  {'duration': 4.951, 'start': 85.469, 'text': 'показать как вообще'},
#  {'duration': 7.229,
#   'start': 86.78,
#   'text': 'нейронные сети работают в общем вы туда'},
#  {'duration': 9.059,
#   'start': 90.42,
#   'text': 'заходите клацать и кнопку вот stroll и'},
#  {'duration': 8.831,
#   'start': 94.009,
#   'text': 'вам вылезает новая страничка где вам'},
#  {'duration': 4.861,
#   'start': 99.479,
#   'text': 'говорят о нарисуйте мне зигзаг и вас на'},
#  {'duration': 4.409,
#   'start': 102.84,
#   'text': 'это есть 20 секунд вы пытаетесь'},
#  {'duration': 5.76,
#   'start': 104.34,
#   'text': 'нарисовать за 20 секунд zigzag ну как'},
#  {'duration': 7.531,
#   'start': 107.249,
#   'text': 'здесь пример если у вас все получается'},
#  {'duration': 6.269,
#   'start': 110.1,
#   'text': 'то сеть говорит о да это зигзаг и вы'},
#  {'duration': 5.039,
#   'start': 114.78,
#   'text': 'идете дальше и таких картинок всего'},
#  {'duration': 5.99,
#   'start': 116.369,
#   'text': 'шесть если собственно сеть от гугла не'},
#  {'duration': 5.61,
#   'start': 119.819,
#   'text': 'удалось распознать чего вы нарисовали'},
#  {'duration': 3.301,
#   'start': 122.359,
#   'text': 'вот-вот не видно наверное у вас просто'},
#  {'duration': 1.911, 'start': 125.429, 'text': 'на'},
#  {'duration': 7.2, 'start': 125.66, 'text': '[музыка]'},
#  {'duration': 8.91,
#   'start': 127.34,
#   'text': 'так вот здесь будет просто крестик вот'},
#  {'duration': 5.099,
#   'start': 132.86,
#   'text': 'но дальше расскажу если сеть распознал и'},
#  {'duration': 6.78,
#   'start': 136.25,
#   'text': 'не фсб основан что это дальнейшем будет'},
#  {'duration': 6.601,
#   'start': 137.959,
#   'text': 'значить вот таким образом этот сервис'},
#  {'duration': 4.819,
#   'start': 143.03,
#   'text': 'собрал довольно большое количество'},
#  {'duration': 5.7,
#   'start': 144.56,
#   'text': 'пользователей и все данные которые'},
#  {'duration': 4.691,
#   'start': 147.849,
#   'text': 'пользователь этого сервиса рисовали на'},
#  {'duration': 4.53,
#   'start': 150.26,
#   'text': 'не лагера вались вот и таким образом'},
#  {'duration': 7.14,
#   'start': 152.54,
#   'text': 'удалось собрать почти 50 миллионов'},
#  {'duration': 6.029,
#   'start': 154.79,
#   'text': 'картинок вот собственно и из этого'},
#  {'duration': 5.69, 'start': 159.68, 'text': 'формировалась'},
#  {'duration': 6.081,
#   'start': 160.819,
#   'text': 'trainee и дата для этого темпе тишина'},
#  {'duration': 4.81, 'start': 165.37, 'text': 'кстати'},
#  {'duration': 4.929,
#   'start': 166.9,
#   'text': 'количество данных в тесте и количество'},
#  {'duration': 4.47,
#   'start': 170.18,
#   'text': 'классов не зря выделены жирным шрифтом'},
#  {'duration': 6.541,
#   'start': 171.829,
#   'text': 'я об этом расскажу чуть попозже вот'},
#  {'duration': 5.79,
#   'start': 174.65,
#   'text': 'формат данных был следующим это не'},
#  {'duration': 7.05, 'start': 178.37, 'text': 'просто там эрго башни картинки'},
#  {'duration': 7.37,
#   'start': 180.44,
#   'text': 'а это грубо говоря блок всего то что там'},
#  {'duration': 6.62, 'start': 185.42, 'text': 'делал пользователь то есть'},
#  {'duration': 4.59,
#   'start': 187.81,
#   'text': 'тверд это собственно наш таргет country'},
#  {'duration': 4.62, 'start': 192.04, 'text': 'code'},
#  {'duration': 8.69,
#   'start': 192.4,
#   'text': 'это откуда чувак который рисовал тот или'},
#  {'duration': 6.78,
#   'start': 196.66,
#   'text': 'иной du du temps темп это время дальше'},
#  {'duration': 4.39,
#   'start': 201.09,
#   'text': 'выборе как нозетт это вот как раз'},
#  {'duration': 4.2,
#   'start': 203.44,
#   'text': 'показывает то то что сети google'},
#  {'duration': 5.25,
#   'start': 205.48,
#   'text': 'распознавал картинку которую человек'},
#  {'duration': 7.64,
#   'start': 207.64,
#   'text': 'нарисовал либо нет и собственно сам'},
#  {'duration': 8.94, 'start': 210.73, 'text': 'drawing это последовательность'},
#  {'duration': 8.2, 'start': 215.28, 'text': 'кругу аппроксимация кривой'},
#  {'duration': 8.33,
#   'start': 219.67,
#   'text': 'которую рисует пользователь точками и'},
#  {'duration': 8.22, 'start': 223.48, 'text': 'тайминги это тайминги'},
#  {'duration': 9.91,
#   'start': 228.0,
#   'text': 'строка тайминги здесь это время от'},
#  {'duration': 7.89,
#   'start': 231.7,
#   'text': 'начала рисование картинки вот так же'},
#  {'duration': 4.85,
#   'start': 237.91,
#   'text': 'данные были представлены в двух форматах'},
#  {'duration': 5.79,
#   'start': 239.59,
#   'text': 'это вот первый формат и второй формат'},
#  {'duration': 6.0,
#   'start': 242.76,
#   'text': 'так сказать упрощенный они оттуда'},
#  {'duration': 3.38, 'start': 245.38, 'text': 'выперли тайминги и'},
#  {'duration': 5.97,
#   'start': 249.269,
#   'text': 'аппроксимировать вот этот набор точек'},
#  {'duration': 4.979, 'start': 253.0, 'text': 'меньше набором точек растянет'},
#  {'duration': 5.021,
#   'start': 255.239,
#   'text': 'использовали алгоритм google спикер для'},
#  {'duration': 4.951,
#   'start': 257.979,
#   'text': 'этого на самом деле можете кипеть и'},
#  {'duration': 5.37,
#   'start': 260.26,
#   'text': 'посмотреть почитать о нем то есть у вас'},
#  {'duration': 4.14,
#   'start': 262.93,
#   'text': 'там большой набор точек который там'},
#  {'duration': 3.3,
#   'start': 265.63,
#   'text': 'аппроксимировать просто какую-то линию'},
#  {'duration': 3.42,
#   'start': 267.07,
#   'text': 'вы на самом деле можете эту линию'},
#  {'duration': 6.799,
#   'start': 268.93,
#   'text': 'проксиме ровать правда men точками вот'},
#  {'duration': 7.049, 'start': 270.49, 'text': 'это идея алгоритм так дальше'},
#  {'duration': 6.671,
#   'start': 275.729,
#   'text': 'данные были распределены следующим'},
#  {'duration': 6.271,
#   'start': 277.539,
#   'text': 'образом то есть как видите все может'},
#  {'duration': 5.489,
#   'start': 282.4,
#   'text': 'сказать равномерно есть некоторые'},
#  {'duration': 7.89,
#   'start': 283.81,
#   'text': 'выбросы но мы когда решали задачу этому'},
#  {'duration': 5.611,
#   'start': 287.889,
#   'text': 'внимание никакого это нужно это не'},
#  {'duration': 3.3,
#   'start': 291.7,
#   'text': 'смотреть главное что не было те классу'},
#  {'duration': 6.33,
#   'start': 293.5,
#   'text': 'которых реально мало и то есть нам не'},
#  {'duration': 6.77,
#   'start': 295.0,
#   'text': 'приходилось делать в эти центры и aver'},
#  {'duration': 5.55, 'start': 299.83, 'text': 'сэмплинг'},
#  {'duration': 6.51,
#   'start': 301.77,
#   'text': 'вот как вообще выглядели картинки то'},
#  {'duration': 4.43,
#   'start': 305.38,
#   'text': 'есть река грозит но это класс самолет и'},
#  {'duration': 4.889, 'start': 308.28, 'text': 'процент'},
#  {'duration': 5.07,
#   'start': 309.81,
#   'text': 'река грозит и анри как назад был где-то'},
#  {'duration': 5.841, 'start': 313.169, 'text': 'там восемь процентов 9'},
#  {'duration': 7.56,
#   'start': 314.88,
#   'text': 'то есть ну примерно ну не знаю я'},
#  {'duration': 4.18,
#   'start': 319.01,
#   'text': 'предположил что это самолет но not not'},
#  {'duration': 2.43, 'start': 322.44, 'text': 'recognized'},
#  {'duration': 3.42,
#   'start': 323.19,
#   'text': 'тут вообще туда же кто-то пытался'},
#  {'duration': 6.54, 'start': 324.87, 'text': 'написать самолет но это видимо'},
#  {'duration': 5.84,
#   'start': 326.61,
#   'text': 'по-французски был написан и вот вот как'},
#  {'duration': 3.89, 'start': 331.41, 'text': 'то так'},
#  {'duration': 6.16,
#   'start': 332.45,
#   'text': 'на самом деле большинство участников'},
#  {'duration': 8.58,
#   'start': 335.3,
#   'text': 'брали просто сетки и запихивали в них'},
#  {'duration': 11.64,
#   'start': 338.61,
#   'text': 'даны то есть из этой последовательности'},
#  {'duration': 10.33,
#   'start': 343.88,
#   'text': 'линий который представлял год они просто'},
#  {'duration': 7.56,
#   'start': 350.25,
#   'text': 'рисовали в rgb картинки собственно так'},
#  {'duration': 6.3,
#   'start': 354.21,
#   'text': 'от рисовал я это просто брал палитру'},
#  {'duration': 4.74, 'start': 357.81, 'text': 'цветов то есть первую строку и'},
#  {'duration': 4.95,
#   'start': 360.51,
#   'text': 'отрисовываем одним цветом последнюю'},
#  {'duration': 7.89,
#   'start': 362.55,
#   'text': 'другим все которые между ними просто'},
#  {'duration': 7.05,
#   'start': 365.46,
#   'text': 'делал интерполяцию по этой палитре это'},
#  {'duration': 5.82,
#   'start': 370.44,
#   'text': 'кстати давала лучший результат чем'},
#  {'duration': 8.279,
#   'start': 372.51,
#   'text': 'просто если вы будете рисовать как на'},
#  {'duration': 10.94,
#   'start': 376.26,
#   'text': 'самом первом слайде просто черным цветом'},
#  {'duration': 9.031,
#   'start': 380.789,
#   'text': 'их вот так же другие участники команды'},
#  {'duration': 4.69,
#   'start': 387.2,
#   'text': 'пробовали немного другие подходы к'},
#  {'duration': 4.83,
#   'start': 389.82,
#   'text': 'рисованию там одним каналом они просто'},
#  {'duration': 7.249,
#   'start': 391.89,
#   'text': 'рисовали серую картинку другим каналам'},
#  {'duration': 7.099,
#   'start': 394.65,
#   'text': 'делали вот примерно то же что и я но'},
#  {'duration': 6.3,
#   'start': 399.139,
#   'text': 'они делали инсталляции там каждой строки'},
#  {'duration': 8.551, 'start': 401.749, 'text': 'от 32 до 55 и'},
#  {'duration': 8.19,
#   'start': 405.439,
#   'text': 'и каждую строку тоже рисовали градиентом'},
#  {'duration': 6.389, 'start': 410.3, 'text': 'вот так же что было интересно'},
#  {'duration': 10.021,
#   'start': 413.629,
#   'text': 'алекс паринов также закидывал информацию'},
#  {'duration': 10.921,
#   'start': 416.689,
#   'text': 'в сеть по кантри коды вот так ну здесь'},
#  {'duration': 9.75,
#   'start': 423.65,
#   'text': 'вроде все метрика которая использовалась'},
#  {'duration': 8.91,
#   'start': 427.61,
#   'text': 'в соревновании это manager сезон 3 в чем'},
#  {'duration': 8.63,
#   'start': 433.4,
#   'text': 'вообще сути это метрики для соревнования'},
#  {'duration': 9.78,
#   'start': 436.52,
#   'text': 'у вас вы можете отдать 3 prediction а и'},
#  {'duration': 7.449,
#   'start': 442.03,
#   'text': 'если в этих трех prediction of нет'},
#  {'duration': 5.489,
#   'start': 446.3,
#   'text': 'правильно то вы получаете за тот или'},
#  {'duration': 5.211,
#   'start': 449.479,
#   'text': 'иной таргет 0 если есть правильный то'},
#  {'duration': 4.921,
#   'start': 451.789,
#   'text': 'учитывать своего порядок и собственно'},
#  {'duration': 4.449, 'start': 454.69, 'text': 'результат по таргету'},
#  {'duration': 6.0,
#   'start': 456.71,
#   'text': 'вычитаться как единицы деленное на'},
#  {'duration': 5.791,
#   'start': 459.139,
#   'text': 'порядок того предсказания которое вы'},
#  {'duration': 6.06,
#   'start': 462.71,
#   'text': 'сделали то есть например в этом сделали'},
#  {'duration': 5.91,
#   'start': 464.93,
#   'text': 'три prediction и правильно из них первым'},
#  {'duration': 2.549,
#   'start': 468.77,
#   'text': 'то вы едите на один получаете один скоро'},
#  {'duration': 3.419, 'start': 470.84, 'text': 'если'},
#  {'duration': 4.921,
#   'start': 471.319,
#   'text': 'prediction верный у вас иметь порядок 2'},
#  {'duration': 6.141,
#   'start': 474.259,
#   'text': 'то единицу делится на два получить 0 .'},
#  {'duration': 4.16, 'start': 476.24, 'text': 'ну и так далее вот'},
#  {'duration': 6.61,
#   'start': 481.16,
#   'text': 'что дальше чтобы решать и соревнования с'},
#  {'duration': 3.72,
#   'start': 486.66,
#   'text': 'данными мы немного предобработки'},
#  {'duration': 4.89,
#   'start': 487.77,
#   'text': 'определились как это рисовать картинки и'},
#  {'duration': 5.25, 'start': 490.38, 'text': 'так далее какие архитектуры мы'},
#  {'duration': 4.979,
#   'start': 492.66,
#   'text': 'использовали мы пытались использовать в'},
#  {'duration': 5.849,
#   'start': 495.63,
#   'text': 'первом жирной архитектура такие как как'},
#  {'duration': 5.28,
#   'start': 497.639,
#   'text': 'по нас нет ведь лардж сны такие сейчас'},
#  {'duration': 2.491,
#   'start': 501.479,
#   'text': 'уже как мне кажется стали классическими'},
#  {'duration': 4.581, 'start': 502.919, 'text': 'архитектурами'},
#  {'duration': 6.509,
#   'start': 503.97,
#   'text': 'съели знак они все больше и больше'},
#  {'duration': 10.149,
#   'start': 507.5,
#   'text': 'заходят в новых соревнованиях но также'},
#  {'duration': 9.93,
#   'start': 510.479,
#   'text': 'были сняты единственные собственно вы'},
#  {'duration': 5.13,
#   'start': 517.649,
#   'text': 'можете установить на графике это топ-1'},
#  {'duration': 5.671,
#   'start': 520.409,
#   'text': 'accuracy на имидже найти сеток и'},
#  {'duration': 4.191,
#   'start': 522.779,
#   'text': 'от количества операций которые надо этой'},
#  {'duration': 4.44, 'start': 526.08, 'text': 'сети обсчитать'},
#  {'duration': 5.47,
#   'start': 526.97,
#   'text': 'вот что интересно мне кажется тут пойдёт'},
#  {'duration': 4.17,
#   'start': 530.52,
#   'text': 'дальше развитие это папирусе на'},
#  {'duration': 4.79,
#   'start': 532.44,
#   'text': 'интернете станет еще больше и собственно'},
#  {'duration': 9.63,
#   'start': 534.69,
#   'text': 'и количество операций и тоже увеличится'},
#  {'duration': 11.2,
#   'start': 537.23,
#   'text': 'так что дальше как мы это все делал'},
#  {'duration': 6.15,
#   'start': 544.32,
#   'text': 'обучали все модели которые мы брали мы'},
#  {'duration': 6.09,
#   'start': 548.43,
#   'text': 'их брали сами pride обычными на и'},
#  {'duration': 4.53,
#   'start': 550.47,
#   'text': 'мужчины хотя данных много 50 миллионов'},
#  {'duration': 3.96, 'start': 554.52, 'text': 'картинок'},
#  {'duration': 4.92,
#   'start': 555.0,
#   'text': 'но все равно если вы берете там сеть'},
#  {'duration': 3.66,
#   'start': 558.48,
#   'text': 'pride обычной начинаете она показывала'},
#  {'duration': 4.49,
#   'start': 559.92,
#   'text': 'лучший результат чем если вы будете'},
#  {'duration': 5.4, 'start': 562.14, 'text': 'просто обучать ее from scratch'},
#  {'duration': 5.56,
#   'start': 564.41,
#   'text': 'дальше какие техники для обучения мы'},
#  {'duration': 5.13,
#   'start': 567.54,
#   'text': 'использовали это кассин и не ленкой в'},
#  {'duration': 6.48,
#   'start': 569.97,
#   'text': 'форме старт они я поговорю чуть попозже'},
#  {'duration': 5.94,
#   'start': 572.67,
#   'text': 'так эта техника которую я использую всех'},
#  {'duration': 4.56,
#   'start': 576.45,
#   'text': 'практически моих последних соревнованиях'},
#  {'duration': 6.71,
#   'start': 578.61,
#   'text': 'и с ним не получается довольно хорошо'},
#  {'duration': 8.34,
#   'start': 581.01,
#   'text': 'обучить сетки и достичь хорошего'},
#  {'duration': 7.36,
#   'start': 585.32,
#   'text': 'минимум вот дальше редис или он не'},
#  {'duration': 5.75,
#   'start': 589.35,
#   'text': 'крайтон плацу что это такое вы начинаете'},
#  {'duration': 6.69,
#   'start': 592.68,
#   'text': 'обучать эти сдаете какой-то определенный'},
#  {'duration': 5.799,
#   'start': 595.1,
#   'text': 'лёнинг рыть дальше и учтиво постепенно'},
#  {'duration': 4.5,
#   'start': 599.37,
#   'text': 'волос водится какому-то определенному'},
#  {'duration': 5.421,
#   'start': 600.899,
#   'text': 'значению вы в этой чекаете то есть у вас'},
#  {'duration': 5.1,
#   'start': 603.87,
#   'text': 'например на протяжении десяти и потом у'},
#  {'duration': 5.35,
#   'start': 606.32,
#   'text': 'вас вообще никак не поменялся вы'},
#  {'duration': 5.01,
#   'start': 608.97,
#   'text': 'уменьшать ваш ленин кроить на какое-то'},
#  {'duration': 3.93,
#   'start': 611.67,
#   'text': 'значение и продолжайте учить то есть у'},
#  {'duration': 4.52,
#   'start': 613.98,
#   'text': 'нас опять немного падает сходится'},
#  {'duration': 6.08,
#   'start': 615.6,
#   'text': 'какому-то минимум и так далее пока у вас'},
#  {'duration': 7.99,
#   'start': 618.5,
#   'text': 'ваша сеть окончательно не сойдется'},
#  {'duration': 7.02, 'start': 621.68, 'text': 'дальше интересная техника'},
#  {'duration': 5.49,
#   'start': 626.49,
#   'text': 'дом дикий за лене край тенге за ваш сайт'},
#  {'duration': 6.31,
#   'start': 628.7,
#   'text': 'кстати статья сын именно названием красы'},
#  {'duration': 5.85,
#   'start': 631.98,
#   'text': 'проток то есть когда вы обучаете сеть'},
#  {'duration': 6.87,
#   'start': 635.01,
#   'text': 'вам необязательно уменьшать или не крайт'},
#  {'duration': 8.67,
#   'start': 637.83,
#   'text': 'вы можете просто увеличивать почесать'},
#  {'duration': 9.48,
#   'start': 641.88,
#   'text': 'тем самым градиенты которые вы будете'},
#  {'duration': 9.42,
#   'start': 646.5,
#   'text': 'получать более точнее вписывать так'},
#  {'duration': 7.26,
#   'start': 651.36,
#   'text': 'сказать туру ваших данных вот эту'},
#  {'duration': 6.06,
#   'start': 655.92,
#   'text': 'технику кстати использовал алекс паринов'},
#  {'duration': 9.06,
#   'start': 658.62,
#   'text': 'и он начинал по моему с batch равному'},
#  {'duration': 8.37,
#   'start': 661.98,
#   'text': '400 8 и когда сеть у него там приходила'},
#  {'duration': 5.4,
#   'start': 667.68,
#   'text': 'на какой-то плата он его просто точность'},
#  {'duration': 6.96,
#   'start': 670.35,
#   'text': 'увеличивал два раза и так далее на самом'},
#  {'duration': 6.75,
#   'start': 673.08,
#   'text': 'деле я не помню до какого значения у'},
#  {'duration': 4.71,
#   'start': 677.31,
#   'text': 'него почти сошел ну что интересно были'},
#  {'duration': 4.35,
#   'start': 679.83,
#   'text': 'команды кегли которые использовали эту'},
#  {'duration': 3.93,
#   'start': 682.02,
#   'text': 'технику них граничным байк ваш сайт был'},
#  {'duration': 6.06, 'start': 684.18, 'text': 'порядка 10000'},
#  {'duration': 7.17,
#   'start': 685.95,
#   'text': 'вот ну кстати современные фромборке для'},
#  {'duration': 5.58,
#   'start': 690.24,
#   'text': 'де пленника такие как порча используя'},
#  {'duration': 5.37,
#   'start': 693.12,
#   'text': 'простой торт вот позволяет вам это очень'},
#  {'duration': 5.639,
#   'start': 695.82,
#   'text': 'просто делать то есть вы генерить и свой'},
#  {'duration': 6.089,
#   'start': 698.49,
#   'text': 'матч и подаете его в сеть не как он и'},
#  {'duration': 5.211,
#   'start': 701.459,
#   'text': 'есть целиком а делите его на чанки чтобы'},
#  {'duration': 4.711,
#   'start': 704.579,
#   'text': 'у вас все это вылезала вашу видеокарту'},
#  {'duration': 5.26,
#   'start': 706.67,
#   'text': 'считайте градиенты и после того как вы'},
#  {'duration': 3.6,
#   'start': 709.29,
#   'text': 'весь ваш большой большой batch says туда'},
#  {'duration': 2.969, 'start': 711.93, 'text': 'закинули у вас есть'},
#  {'duration': 4.98,
#   'start': 712.89,
#   'text': 'аппроксимация вашего градиента и вы'},
#  {'duration': 7.891,
#   'start': 714.899,
#   'text': 'просто делаете обновление ваших весов'},
#  {'duration': 7.11,
#   'start': 717.87,
#   'text': 'вот так а кстати в этом соревновании еще'},
#  {'duration': 5.91,
#   'start': 722.79,
#   'text': 'тоже захотели большие почитайте потому'},
#  {'duration': 9.54,
#   'start': 724.98,
#   'text': 'что данные были довольны шумными и'},
#  {'duration': 8.699,
#   'start': 728.7,
#   'text': 'большой почесать помогал вам проксиме'},
#  {'duration': 5.64,
#   'start': 734.52,
#   'text': 'ровать этот шум и задавать направление'},
#  {'duration': 6.721,
#   'start': 737.399,
#   'text': 'вашего клиента в правильную сторону вот'},
#  {'duration': 6.03,
#   'start': 740.16,
#   'text': 'так же использовался псевдо либлинг его'},
#  {'duration': 2.58,
#   'start': 744.12,
#   'text': 'по большей части использовала роман'},
#  {'duration': 2.65, 'start': 746.19, 'text': 'соловьев'},
#  {'duration': 6.79, 'start': 746.7, 'text': 'как он это делал'},
#  {'duration': 7.31,
#   'start': 748.84,
#   'text': 'в ботинке где-то половину данных из'},
#  {'duration': 8.61, 'start': 753.49, 'text': 'теста и'},
#  {'duration': 6.58,
#   'start': 756.15,
#   'text': 'на таких матчах обучал сетку вот размер'},
#  {'duration': 5.67, 'start': 762.1, 'text': 'картинок'},
#  {'duration': 6.9,
#   'start': 762.73,
#   'text': 'ну и играл значение то есть но в том то'},
#  {'duration': 4.26,
#   'start': 767.77,
#   'text': 'что вас данных многое вам надо очень'},
#  {'duration': 4.98,
#   'start': 769.63,
#   'text': 'долго обучать и если у вас размер'},
#  {'duration': 5.61,
#   'start': 772.03,
#   'text': 'картинки будет довольно большим то вы'},
#  {'duration': 7.14,
#   'start': 774.61,
#   'text': 'будете обучать очень долго вот но это'},
#  {'duration': 8.15,
#   'start': 777.64,
#   'text': 'приносило в качество вашего финального'},
#  {'duration': 6.6,
#   'start': 781.75,
#   'text': 'классико таро не так много потому что'},
#  {'duration': 5.14,
#   'start': 785.79,
#   'text': 'что стоило использовать такой некий'},
#  {'duration': 4.11,
#   'start': 788.35,
#   'text': 'трейдов и пробовали вот на таких'},
#  {'duration': 3.84,
#   'start': 790.93,
#   'text': 'картинках но причем как это все'},
#  {'duration': 4.73,
#   'start': 792.46,
#   'text': 'обучалась то есть сначала брались'},
#  {'duration': 5.25,
#   'start': 794.77,
#   'text': 'картинки маленького размера на них'},
#  {'duration': 4.36,
#   'start': 797.19,
#   'text': 'прогоняли лась несколько эпох это'},
#  {'duration': 3.42,
#   'start': 800.02,
#   'text': 'довольно быстро занимал по времени'},
#  {'duration': 3.78,
#   'start': 801.55,
#   'text': 'потому картинки давались большого'},
#  {'duration': 4.14,
#   'start': 803.44,
#   'text': 'размера сеть обучалась потом еще больше'},
#  {'duration': 4.2,
#   'start': 805.33,
#   'text': 'потом еще больше чтобы не обучать это'},
#  {'duration': 6.69,
#   'start': 807.58,
#   'text': 'все с нуля и не тратить очень много'},
#  {'duration': 9.33,
#   'start': 809.53,
#   'text': 'времени так дальше про optimizer и мы'},
#  {'duration': 6.39,
#   'start': 814.27,
#   'text': 'использовали с gd & adam вот таким'},
#  {'duration': 6.24, 'start': 818.86, 'text': 'способом можно было получить'},
#  {'duration': 8.25,
#   'start': 820.66,
#   'text': 'сингл модель которая давала скоро то-0'},
#  {'duration': 8.46,
#   'start': 825.1,
#   'text': '940 10 946 на паблик лидер борде'},
#  {'duration': 7.5,
#   'start': 828.91,
#   'text': 'что довольно неплохо вот дальше хотел'},
#  {'duration': 7.89,
#   'start': 833.56,
#   'text': 'рассказать про пусть in any link форме'},
#  {'duration': 7.28,
#   'start': 836.41,
#   'text': 'старт нет это чуть попозже дальше если'},
#  {'duration': 4.83, 'start': 841.45, 'text': 'вы за sampler уйти'},
#  {'duration': 6.13,
#   'start': 843.69,
#   'text': 'модели неким образом то вы получите'},
#  {'duration': 5.79, 'start': 846.28, 'text': 'где-то но 951'},
#  {'duration': 4.53,
#   'start': 849.82,
#   'text': 'если примените еще одну технику the'},
#  {'duration': 5.88,
#   'start': 852.07,
#   'text': 'final score вы получите на паблик барды'},
#  {'duration': 5.31,
#   'start': 854.35,
#   'text': '0 954 как получили мы вот но об этом'},
#  {'duration': 3.51,
#   'start': 857.95,
#   'text': 'чуть попозже я расскажу как мы и'},
#  {'duration': 6.51,
#   'start': 859.66,
#   'text': 'ассамбле равале модели и как такого'},
#  {'duration': 6.24,
#   'start': 861.46,
#   'text': 'финального скоро удалось добиться так но'},
#  {'duration': 3.21,
#   'start': 866.17,
#   'text': 'некоторые на самом деле называется кости'},
#  {'duration': 5.7,
#   'start': 867.7,
#   'text': 'наделив и в армию starts никто из такаси'},
#  {'duration': 7.59,
#   'start': 869.38,
#   'text': 'градиент десанте farmer старт ну это кру'},
#  {'duration': 5.43,
#   'start': 873.4,
#   'text': 'говоря не знаю как правильно в принципе'},
#  {'duration': 3.84,
#   'start': 876.97,
#   'text': 'optimizer вы можете засунуть любой но'},
#  {'duration': 3.48,
#   'start': 878.83,
#   'text': 'суть заключается в следующем если вы'},
#  {'duration': 5.88,
#   'start': 880.81,
#   'text': 'просто будете обучать одну сеть'},
#  {'duration': 7.98,
#   'start': 882.31,
#   'text': 'постепенный она будет у вас сходиться'},
#  {'duration': 5.73,
#   'start': 886.69,
#   'text': 'какому-то минимуму то все окей вас там'},
#  {'duration': 4.86, 'start': 890.29, 'text': 'получится относить делает нам'},
#  {'duration': 5.75,
#   'start': 892.42,
#   'text': 'определенные ошибки но вы можете ее'},
#  {'duration': 6.33,
#   'start': 895.15,
#   'text': 'обучать немного по-другому вы будете'},
#  {'duration': 4.5,
#   'start': 898.17,
#   'text': 'задавать какой-то начальный leading рейд'},
#  {'duration': 5.07, 'start': 901.48, 'text': 'и'},
#  {'duration': 8.859,
#   'start': 902.67,
#   'text': 'постепенную его понижать вот по данной'},
#  {'duration': 7.17,
#   'start': 906.55,
#   'text': 'формуле попасть то есть вы его не'},
#  {'duration': 5.341,
#   'start': 911.529,
#   'text': 'занижайте занижать у вас есть приходит к'},
#  {'duration': 7.34,
#   'start': 913.72,
#   'text': 'комнатам минимум дальше вы сохранить'},
#  {'duration': 6.6,
#   'start': 916.87,
#   'text': 'леса которые которым вы пришли дальше'},
#  {'duration': 3.76,
#   'start': 921.06,
#   'text': 'снова ставить ибо часть которая у вас'},
#  {'duration': 3.059, 'start': 923.47, 'text': 'была на начале обучения'},
#  {'duration': 3.75,
#   'start': 924.82,
#   'text': 'дни почти солью не crate который у вас'},
#  {'duration': 4.141,
#   'start': 926.529,
#   'text': 'был начали обучение тем самым вы из'},
#  {'duration': 6.39,
#   'start': 928.57,
#   'text': 'этого минимум выходите куда-то наверх и'},
#  {'duration': 7.37,
#   'start': 930.67,
#   'text': 'опять занижайте ваш ленинград вот тем'},
#  {'duration': 5.61,
#   'start': 934.96,
#   'text': 'самым вы можете посетить сразу несколько'},
#  {'duration': 5.47, 'start': 938.04, 'text': 'мемов в которых у вас'},
#  {'duration': 7.14,
#   'start': 940.57,
#   'text': 'лосс будет плюс минус одинаковым но факт'},
#  {'duration': 7.52,
#   'start': 943.51,
#   'text': 'в том то что сети с данными весами будут'},
#  {'duration': 6.48,
#   'start': 947.71,
#   'text': 'давать разные ошибки на вашей дате и'},
#  {'duration': 10.09,
#   'start': 951.03,
#   'text': 'средних их вы получите некую такую'},
#  {'duration': 11.25,
#   'start': 954.19,
#   'text': 'прокси мацию и скоро ваш будет выше вот'},
#  {'duration': 7.38,
#   'start': 961.12,
#   'text': 'как раз таки про то как мы симулировали'},
#  {'duration': 5.399,
#   'start': 965.44,
#   'text': 'наши модели в начале презентации я'},
#  {'duration': 5.4,
#   'start': 968.5,
#   'text': 'говорил то что обратите внимание на'},
#  {'duration': 5.191,
#   'start': 970.839,
#   'text': 'количество классов тесте и количество'},
#  {'duration': 7.23, 'start': 973.9, 'text': 'классов дело в том то что если'},
#  {'duration': 6.45,
#   'start': 976.03,
#   'text': 'количество таргет of the с этим вы'},
#  {'duration': 3.5, 'start': 981.13, 'text': 'прибавить единицу и поделить на'},
#  {'duration': 6.0,
#   'start': 982.48,
#   'text': 'количество классов и поручают получите'},
#  {'duration': 7.24,
#   'start': 984.63,
#   'text': 'число a330 и об этом писалось на форуме'},
#  {'duration': 5.94,
#   'start': 988.48,
#   'text': 'то что щеки писали все классы в тесте'},
#  {'duration': 5.55,
#   'start': 991.87,
#   'text': 'сбалансированы и чем можно было'},
#  {'duration': 5.609,
#   'start': 994.42,
#   'text': 'воспользоваться роман соловьев на основе'},
#  {'duration': 4.89,
#   'start': 997.42,
#   'text': 'этого придумал метрику мы ее называли'},
#  {'duration': 4.411,
#   'start': 1000.029,
#   'text': 'прокси скоро которая довольно хорошо'},
#  {'duration': 5.76, 'start': 1002.31, 'text': 'коррелировала с'},
#  {'duration': 8.77,
#   'start': 1004.44,
#   'text': 'лидер бордом в чем суть этой метрики'},
#  {'duration': 8.69,
#   'start': 1008.07,
#   'text': 'вы делаете prediction берете топ 1'},
#  {'duration': 6.61,
#   'start': 1013.21,
#   'text': 'ваших предикатов вот и считайте'},
#  {'duration': 5.04,
#   'start': 1016.76,
#   'text': 'количество классов которые вас в этом'},
#  {'duration': 4.56,
#   'start': 1019.82,
#   'text': 'получились и дальше каждый класс из'},
#  {'duration': 3.12,
#   'start': 1021.8,
#   'text': 'каждого класса вы вычитаете значение 3'},
#  {'duration': 5.1, 'start': 1024.38, 'text': 'из 3'},
#  {'duration': 8.01,
#   'start': 1024.92,
#   'text': 'и 330 и пьете просто абсолютное значение'},
#  {'duration': 5.49,
#   'start': 1029.48,
#   'text': 'их складывать вот собственно такие'},
#  {'duration': 5.57,
#   'start': 1032.93,
#   'text': 'значения получились и это нам помогало'},
#  {'duration': 6.3, 'start': 1034.97, 'text': 'не делать probing лидер барда'},
#  {'duration': 7.92,
#   'start': 1038.5,
#   'text': 'полироваться локально и подбирайте'},
#  {'duration': 8.66,
#   'start': 1041.27,
#   'text': 'коэффициенты для наших ансамбле вот'},
#  {'duration': 6.94, 'start': 1046.42, 'text': 'дальше ну окей'},
#  {'duration': 4.99,
#   'start': 1049.93,
#   'text': 'сансом блин вы могли получить такой'},
#  {'duration': 3.63,
#   'start': 1053.36,
#   'text': 'скоро чтобы еще сделать то есть'},
#  {'duration': 5.7,
#   'start': 1054.92,
#   'text': 'воспользовалась воспользовавшись'},
#  {'duration': 7.53,
#   'start': 1056.99,
#   'text': 'информацией о том то что классов'},
#  {'duration': 6.68,
#   'start': 1060.62,
#   'text': 'то есть и у вас сбалансировано эту'},
#  {'duration': 5.82,
#   'start': 1064.52,
#   'text': 'картинку и на самом деле украл из'},
#  {'duration': 7.47,
#   'start': 1067.3,
#   'text': 'дискуссий в как ли по 6 кого я думаю не'},
#  {'duration': 9.87,
#   'start': 1070.34,
#   'text': 'простит вот вы могли просто класс и'},
#  {'duration': 7.539,
#   'start': 1074.77,
#   'text': 'балансировать на самом деле балансировки'},
#  {'duration': 5.43,
#   'start': 1080.21,
#   'text': 'были разные то есть вариант наши'},
#  {'duration': 6.601,
#   'start': 1082.309,
#   'text': 'балансировки он отличался вот то как'},
#  {'duration': 5.61,
#   'start': 1085.64,
#   'text': 'балансировали чуваки на первом месте что'},
#  {'duration': 6.82,
#   'start': 1088.91,
#   'text': 'делали мы у нас балансировка было'},
#  {'duration': 8.91,
#   'start': 1091.25,
#   'text': 'довольно простая мы просто брали сначала'},
#  {'duration': 6.63,
#   'start': 1095.73,
#   'text': 'сортировали наши предсказания по топ-1 и'},
#  {'duration': 4.33, 'start': 1100.16, 'text': 'тем самым выбирали'},
#  {'duration': 4.069, 'start': 1102.36, 'text': 'кандидатов для'},
#  {'duration': 4.14, 'start': 1104.49, 'text': '[музыка]'},
#  {'duration': 3.851,
#   'start': 1106.429,
#   'text': 'кандидатов prediction а таким образом'},
#  {'duration': 4.409,
#   'start': 1108.63,
#   'text': 'чтобы количество классов не превышала'},
#  {'duration': 5.22,
#   'start': 1110.28,
#   'text': '330 то есть у вас таким образом просто'},
#  {'duration': 5.25,
#   'start': 1113.039,
#   'text': 'набирается некоторые пачка предикатов'},
#  {'duration': 4.409,
#   'start': 1115.5,
#   'text': 'для некоторых классов но для некоторых'},
#  {'duration': 5.401,
#   'start': 1118.289,
#   'text': 'классов у вас получается так то что'},
#  {'duration': 7.831,
#   'start': 1119.909,
#   'text': 'предикатов просто меньше чем 330 ok а'},
#  {'duration': 6.57,
#   'start': 1123.69,
#   'text': 'давайте было еще отсортируем по топ-2 и'},
#  {'duration': 4.62,
#   'start': 1127.74,
#   'text': 'таким таким же образом докинем в эти'},
#  {'duration': 2.96,
#   'start': 1130.26,
#   'text': 'классы предиктор ну и собственно также'},
#  {'duration': 7.46, 'start': 1132.36, 'text': 'по'},
#  {'duration': 10.319,
#   'start': 1133.22,
#   'text': 'топ-3 и мы брали помню тот 3 predict вот'},
#  {'duration': 6.7,
#   'start': 1139.82,
#   'text': 'чем наш плиссировка отличалась от'},
#  {'duration': 4.26,
#   'start': 1143.539,
#   'text': 'первого места они использовали'},
#  {'duration': 5.09, 'start': 1146.52, 'text': 'итеративный подход'},
#  {'duration': 8.171,
#   'start': 1147.799,
#   'text': 'брали самый популярный класс и уменьшали'},
#  {'duration': 6.73,
#   'start': 1151.61,
#   'text': 'вероятности для этого класса на какое-то'},
#  {'duration': 5.93,
#   'start': 1155.97,
#   'text': 'маленькое число до тех пор пока этот'},
#  {'duration': 5.88,
#   'start': 1158.34,
#   'text': 'класс становился не самым популярным'},
#  {'duration': 4.3,
#   'start': 1161.9,
#   'text': 'брать следующие самый популярный класс'},
#  {'duration': 5.91,
#   'start': 1164.22,
#   'text': 'итак дальше понижали понижали понижали'},
#  {'duration': 10.02,
#   'start': 1166.2,
#   'text': 'пока количество все классов не было не'},
#  {'duration': 11.46,
#   'start': 1170.13,
#   'text': 'остановилась равным вот собственно'},
#  {'duration': 7.35,
#   'start': 1176.22,
#   'text': 'все использовали плюс минус один подход'},
#  {'duration': 4.02, 'start': 1181.59, 'text': 'для обучения сетей но не все'},
#  {'duration': 3.66,
#   'start': 1183.57,
#   'text': 'использовали балансировку и использую'},
#  {'duration': 2.46,
#   'start': 1185.61,
#   'text': 'балансировку вам можно было там зайти в'},
#  {'duration': 5.88, 'start': 1187.23, 'text': 'gold или'},
#  {'duration': 8.91,
#   'start': 1188.07,
#   'text': 'затем они вот но хотел бы сейчас еще'},
#  {'duration': 6.299,
#   'start': 1193.11,
#   'text': 'поговорить о том как при процессе дат'},
#  {'duration': 4.02,
#   'start': 1196.98,
#   'text': 'все дату pride процессе лету стене'},
#  {'duration': 4.26, 'start': 1199.409, 'text': 'делали их интерфейс пытались'},
#  {'duration': 7.02,
#   'start': 1201.0,
#   'text': 'закодировать тайминги то есть разным'},
#  {'duration': 8.25,
#   'start': 1203.669,
#   'text': 'цветом штрихов и так далее и как раз про'},
#  {'duration': 5.49,
#   'start': 1208.02,
#   'text': 'это и говорил алексей ноздри ну'},
#  {'duration': 3.931,
#   'start': 1211.919,
#   'text': 'плотницкий который занял восьмое место'},
#  {'duration': 5.039,
#   'start': 1213.51,
#   'text': 'он делал по другому он говорил все это у'},
#  {'duration': 4.949,
#   'start': 1215.85,
#   'text': 'вас контракт сейчас это отстой так'},
#  {'duration': 6.571,
#   'start': 1218.549,
#   'text': 'делать не надо у вас сеть должна сама'},
#  {'duration': 7.141,
#   'start': 1220.799,
#   'text': 'все это выучивать и вместо того чтобы'},
#  {'duration': 5.64,
#   'start': 1225.12,
#   'text': 'делать микроsd фич из он придумал модули'},
#  {'duration': 3.56,
#   'start': 1227.94,
#   'text': 'которые делали привет обработку ваших'},
#  {'duration': 2.76, 'start': 1230.76, 'text': 'данных'},
#  {'duration': 4.0,
#   'start': 1231.5,
#   'text': 'обучаемый модули которые делали при'},
#  {'duration': 4.74,
#   'start': 1233.52,
#   'text': 'обработку ваших данных христиан у них'},
#  {'duration': 6.14,
#   'start': 1235.5,
#   'text': 'закидывал данные как вообще они были то'},
#  {'duration': 4.71,
#   'start': 1238.26,
#   'text': 'есть координаты ваших точек и тайминги'},
#  {'duration': 5.529, 'start': 1241.64, 'text': 'дальше'},
#  {'duration': 5.55,
#   'start': 1242.97,
#   'text': 'из по координатам он просто выбрал'},
#  {'duration': 5.191, 'start': 1247.169, 'text': 'разность а по'},
#  {'duration': 4.38,
#   'start': 1248.52,
#   'text': 'таймингом это все делал среднем и вас'},
#  {'duration': 3.179, 'start': 1252.36, 'text': 'получил'},
#  {'duration': 5.639,
#   'start': 1252.9,
#   'text': 'и у него получался такой довольно'},
#  {'duration': 3.51,
#   'start': 1255.539,
#   'text': 'длинный просто такая довольно длинная'},
#  {'duration': 4.781, 'start': 1258.539, 'text': 'матрица'},
#  {'duration': 7.301,
#   'start': 1259.049,
#   'text': 'который он применял 1d свертки'},
#  {'duration': 7.05,
#   'start': 1263.32,
#   'text': 'несколько раз для того чтобы получить'},
#  {'duration': 7.02,
#   'start': 1266.35,
#   'text': 'матрицу размер размеров 164 на индиану'},
#  {'duration': 6.65,
#   'start': 1270.37,
#   'text': 'это у вас общее количество точек a64'},
#  {'duration': 10.59,
#   'start': 1273.37,
#   'text': 'слизи он для того чтобы подать'},
#  {'duration': 9.16,
#   'start': 1277.02,
#   'text': 'полученную матрицу уже на вход любой из'},
#  {'duration': 3.33,
#   'start': 1283.96,
#   'text': 'сети которая принимает количество'},
#  {'duration': 2.94, 'start': 1286.18, 'text': 'каналов равно 64'},
#  {'duration': 3.69,
#   'start': 1287.29,
#   'text': 'то есть вас получилась такая у него'},
#  {'duration': 3.69, 'start': 1289.12, 'text': 'получалось такая матрица 640'},
#  {'duration': 5.79,
#   'start': 1290.98,
#   'text': 'дальше из этого нужно было составить'},
#  {'duration': 7.32,
#   'start': 1292.81,
#   'text': 'тендер какого-то размера но чтобы'},
#  {'duration': 10.32,
#   'start': 1296.77,
#   'text': 'количество каналов краски был 64 что он'},
#  {'duration': 12.12,
#   'start': 1300.13,
#   'text': 'делал он нормировать все точки x и y в'},
#  {'duration': 7.71,
#   'start': 1307.09,
#   'text': 'диапазоне от 0 до 32 чтобы составить'},
#  {'duration': 5.91,
#   'start': 1312.25,
#   'text': 'тендер размера 32 32 на самом деле я не'},
#  {'duration': 7.59,
#   'start': 1314.8,
#   'text': 'знаю почему он захотел 32 на 32 ну вот'},
#  {'duration': 7.5,
#   'start': 1318.16,
#   'text': 'так вот получилось вот и значение то'},
#  {'duration': 5.91,
#   'start': 1322.39,
#   'text': 'есть в этой круг говоря координате в эту'},
#  {'duration': 3.87,
#   'start': 1325.66,
#   'text': 'координату он засовывал просто кусок в'},
#  {'duration': 3.96, 'start': 1328.3, 'text': 'этой матрице'},
#  {'duration': 6.3,
#   'start': 1329.53,
#   'text': 'размер 40 и собственно таким образом он'},
#  {'duration': 5.49,
#   'start': 1332.26,
#   'text': 'просто получал тендер 32 на 32 64'},
#  {'duration': 6.41, 'start': 1335.83, 'text': 'который можно было засунуть'},
#  {'duration': 9.77,
#   'start': 1337.75,
#   'text': 'дальше вашу какой-либо там search носить'},
#  {'duration': 9.03,
#   'start': 1342.24,
#   'text': 'вот у меня вроде все противного не'},
#  {'duration': 3.75, 'start': 1347.52, 'text': 'какие-нибудь вопрос может'},
#  {'duration': 10.83,
#   'start': 1353.37,
#   'text': 'спасибо вопросы спасибо за доклад не'},
#  {'duration': 4.8, 'start': 1362.7, 'text': 'хотел задать два вопроса дел'},
#  {'duration': 6.27,
#   'start': 1364.2,
#   'text': 'разъясняющий один новый с интересом 1 3'},
#  {'duration': 5.85,
#   'start': 1367.5,
#   'text': 'сказал когда говорил про косинуса'},
#  {'duration': 6.0,
#   'start': 1370.47,
#   'text': 'образные learning рейд что мы падаем'},
#  {'duration': 8.82,
#   'start': 1373.35,
#   'text': 'локальные минимумы и усредняем потом я'},
#  {'duration': 7.62,
#   'start': 1376.47,
#   'text': 'не понял что мы встретим ну смотри ты'},
#  {'duration': 4.8,
#   'start': 1382.17,
#   'text': 'получил несколько весов то есть'},
#  {'duration': 6.6,
#   'start': 1384.09,
#   'text': 'несколько snapshot of дальше ты прогнал'},
#  {'duration': 5.88,
#   'start': 1386.97,
#   'text': 'всю свою дату получил логин дальше ты'},
#  {'duration': 3.619,
#   'start': 1390.69,
#   'text': 'можешь соединить логика и получить'},
#  {'duration': 5.22, 'start': 1392.85, 'text': 'какой-то prediction'},
#  {'duration': 5.381,
#   'start': 1394.309,
#   'text': 'среди логит это воткнулся в макс получил'},
#  {'duration': 4.8,
#   'start': 1398.07,
#   'text': 'вероятности и получу ковать prediction'},
#  {'duration': 5.04,
#   'start': 1399.69,
#   'text': 'либо ты получил логе ты получил от них'},
#  {'duration': 3.14,
#   'start': 1402.87,
#   'text': 'вероятностью среднему вероятностью здесь'},
#  {'duration': 4.199, 'start': 1404.73, 'text': 'есть два подхода'},
#  {'duration': 7.96,
#   'start': 1406.01,
#   'text': 'конкретно в этой задаче мы усреднять ну'},
#  {'duration': 6.541,
#   'start': 1408.929,
#   'text': 'я принял именно вероятность спасибо и'},
#  {'duration': 3.42, 'start': 1413.97, 'text': 'второй вопрос а вы не думали'},
#  {'duration': 4.11,
#   'start': 1415.47,
#   'text': 'использовать рынки потому что недавно'},
#  {'duration': 6.0,
#   'start': 1417.39,
#   'text': 'наткнулся воды сил статью где чуваки'},
#  {'duration': 6.39,
#   'start': 1419.58,
#   'text': 'делали им бединге с помощью рынке и там'},
#  {'duration': 5.07,
#   'start': 1423.39,
#   'text': 'скрещивали котика с поросенком'},
#  {'duration': 5.37,
#   'start': 1425.97,
#   'text': 'получалось довольно занятным а на самом'},
#  {'duration': 5.969,
#   'start': 1428.46,
#   'text': 'деле об этом писали на форуме наш'},
#  {'duration': 6.57,
#   'start': 1431.34,
#   'text': 'команды это не пробовала и писали то что'},
#  {'duration': 6.0,
#   'start': 1434.429,
#   'text': 'рнн в этой задачи не заходит и скоро на'},
#  {'duration': 7.649,
#   'start': 1437.91,
#   'text': 'них довольно низкий удалось выбить ну мы'},
#  {'duration': 7.551,
#   'start': 1440.429,
#   'text': 'даже это пробует не столь спасибо еще'},
#  {'duration': 2.421, 'start': 1445.559, 'text': 'вопросы'},
#  {'duration': 6.039,
#   'start': 1449.88,
#   'text': 'привет короткий вопрос ты говорил про'},
#  {'duration': 6.989,
#   'start': 1453.07,
#   'text': 'кодирование кантри кода в нутрь'},
#  {'duration': 5.971,
#   'start': 1455.919,
#   'text': 'свёрточная сетки как это делали на самом'},
#  {'duration': 6.301, 'start': 1460.059, 'text': 'деле я точно не уверен'},
#  {'duration': 5.94,
#   'start': 1461.89,
#   'text': 'потому что у нас взаимодействие я могу'},
#  {'duration': 4.47,
#   'start': 1466.36,
#   'text': 'сейчас рассказать не мог производить в'},
#  {'duration': 5.16,
#   'start': 1467.83,
#   'text': 'команде как мы взаимодействовали каждый'},
#  {'duration': 6.18,
#   'start': 1470.83,
#   'text': 'предел что-то у себя там на стороне и'},
#  {'duration': 7.62,
#   'start': 1472.99,
#   'text': 'просто выкидывал вероятности в общий'},
#  {'duration': 6.93,
#   'start': 1477.01,
#   'text': 'чатик который эти вероятность средне или'},
#  {'duration': 6.0,
#   'start': 1480.61,
#   'text': 'агрегировать и получали ответ вот по'},
#  {'duration': 4.32,
#   'start': 1483.94,
#   'text': 'поводу того как закинуть country code на'},
#  {'duration': 4.91,
#   'start': 1486.61,
#   'text': 'самом деле не знаю но могу предположить'},
#  {'duration': 6.26, 'start': 1488.26, 'text': 'то что это просто закидывала'},
#  {'duration': 10.899,
#   'start': 1491.52,
#   'text': 'вмб денги и уже по этим и петтингом'},
#  {'duration': 10.3,
#   'start': 1494.52,
#   'text': 'считались логит ты немножко рассказывал'},
#  {'duration': 4.471,
#   'start': 1502.419,
#   'text': 'про методику когда увеличится боровец я'},
#  {'duration': 4.38,
#   'start': 1504.82,
#   'text': 'вот про такт реализован на практике по'},
#  {'duration': 3.75,
#   'start': 1506.89,
#   'text': 'сути это то же самое что если ты вовремя'},
#  {'duration': 3.03,
#   'start': 1509.2,
#   'text': '3 глупо будешь просто пропускать'},
#  {'duration': 6.08,
#   'start': 1510.64,
#   'text': 'несколько патчей и степ делать например'},
#  {'duration': 4.49, 'start': 1512.23, 'text': 'через три большие 4 или до'}]

# %%
len(transcripts)
# Out:
# 51

# %%
id2trans = {}
for i, idx in enumerate(transcripts):
    id2trans[df_vid['youtube_id'][i]] = idx

# %%
import pickle
pickle.dump(id2trans, open('id2transcripts_1.pkl', 'wb'))

# %%
transcripts[1]
# Out:
# [{'duration': 5.35, 'start': 5.45, 'text': 'всем привет меня зовут владимир'},
#  {'duration': 5.641,
#   'start': 7.649,
#   'text': 'и мы расскажем о нашем решении точнее от'},
#  {'duration': 5.489,
#   'start': 10.8,
#   'text': 'двух решениях задачи по определению'},
#  {'duration': 6.48,
#   'start': 13.29,
#   'text': 'категорий покупок в чеке которая стояла'},
#  {'duration': 7.621,
#   'start': 16.289,
#   'text': 'в рамках третьего запуска cs10 прошу'},
#  {'duration': 6.63,
#   'start': 19.77,
#   'text': 'прощения цмр курс up on задачи снова'},
#  {'duration': 4.619,
#   'start': 23.91,
#   'text': 'была поставлена дмитрий кремовым при'},
#  {'duration': 4.049,
#   'start': 26.4,
#   'text': 'этом у отдельные то есть она и сейчас'},
#  {'duration': 8.521, 'start': 28.529, 'text': 'есть в породе в приложении'},
#  {'duration': 9.27,
#   'start': 30.449,
#   'text': 'где-то на просторах google market там'},
#  {'duration': 6.3,
#   'start': 37.05,
#   'text': 'суть задачи такая с недавнего времени на'},
#  {'duration': 6.541,
#   'start': 39.719,
#   'text': 'чеках вели штрих-коды пока qr-коды по'},
#  {'duration': 6.029,
#   'start': 43.35,
#   'text': 'которым можно зайти на сайт и посмотреть'},
#  {'duration': 9.27,
#   'start': 46.26,
#   'text': 'покупок для автоматизации собственно'},
#  {'duration': 9.691,
#   'start': 49.379,
#   'text': 'говоря расходов и для автоматической к'},
#  {'duration': 4.47,
#   'start': 55.53,
#   'text': 'активизации покупок непосредственно'},
#  {'duration': 2.43, 'start': 59.07, 'text': 'через приложение'},
#  {'duration': 3.539,
#   'start': 60.0,
#   'text': 'ну собственно говоря был осуществленный'},
#  {'duration': 4.019,
#   'start': 61.5,
#   'text': 'данный функционал основная сложность'},
#  {'duration': 4.471,
#   'start': 63.539,
#   'text': 'этого функционала состоит в том то что'},
#  {'duration': 7.021,
#   'start': 65.519,
#   'text': 'разные магазины совершенно произвольным'},
#  {'duration': 7.71,
#   'start': 68.01,
#   'text': 'образом заполняют название в своих базах'},
#  {'duration': 8.579,
#   'start': 72.54,
#   'text': 'данных и плюс зачастую мы встречаем с'},
#  {'duration': 8.67,
#   'start': 75.72,
#   'text': 'тем то что эти сосуды данных заполнение'},
#  {'duration': 6.121,
#   'start': 81.119,
#   'text': 'с людьми и можно встретить такие'},
#  {'duration': 4.589,
#   'start': 84.39,
#   'text': 'тривиальные ошибки как английская о'},
#  {'duration': 5.519,
#   'start': 87.24,
#   'text': 'вместо русской что соответственно'},
#  {'duration': 5.911,
#   'start': 88.979,
#   'text': 'усложняет некоторый процесс сами данные'},
#  {'duration': 5.371,
#   'start': 92.759,
#   'text': 'табличные выглядели примерно так то есть'},
#  {'duration': 4.64,
#   'start': 94.89,
#   'text': 'это по позициям чеком и непосредственно'},
#  {'duration': 5.58, 'start': 98.13, 'text': 'по'},
#  {'duration': 10.6,
#   'start': 99.53,
#   'text': 'пардоньте это две разные таблицы'},
#  {'duration': 7.979,
#   'start': 103.71,
#   'text': 'то есть вот она одна вторая название'},
#  {'duration': 4.89,
#   'start': 110.13,
#   'text': 'магазинов бывают совершенно разные'},
#  {'duration': 5.911,
#   'start': 111.689,
#   'text': 'причем также можно было ловить различны'},
#  {'duration': 4.949,
#   'start': 115.02,
#   'text': 'магазина франчайзинга то есть те же'},
#  {'duration': 7.89,
#   'start': 117.6,
#   'text': 'магазины пятерочка встречаются но под'},
#  {'duration': 7.591,
#   'start': 119.969,
#   'text': 'разными о и можно было отлавливать'},
#  {'duration': 4.98,
#   'start': 125.49,
#   'text': 'например под названием пакет пятёрочка в'},
#  {'duration': 9.23,
#   'start': 127.56,
#   'text': 'названии человека сейчас я передам слово'},
#  {'duration': 6.32,
#   'start': 130.47,
#   'text': 'олегу немножко про и да собственно'},
#  {'duration': 8.38,
#   'start': 138.02,
#   'text': 'добрый день для начала я расскажу о'},
#  {'duration': 8.05,
#   'start': 142.01,
#   'text': 'данных которые у нас были это было'},
#  {'duration': 6.6,
#   'start': 146.4,
#   'text': 'тренировочная выборка на 13 чем-то тысяч'},
#  {'duration': 5.73,
#   'start': 150.06,
#   'text': 'записей и щиков то есть это были и дичи'},
#  {'duration': 6.53,
#   'start': 153.0,
#   'text': 'к названию этого rosteco категория'},
#  {'duration': 4.95,
#   'start': 155.79,
#   'text': 'товара цена товара и количество товара'},
#  {'duration': 4.89, 'start': 159.53, 'text': 'тренировок'},
#  {'duration': 8.64,
#   'start': 160.74,
#   'text': 'тестовый сайт был на две тысячи записей'},
#  {'duration': 6.73,
#   'start': 164.42,
#   'text': 'ой на 3 тысяч записей и был файл с'},
#  {'duration': 3.72, 'start': 169.38, 'text': 'чеками в которых содержалась'},
#  {'duration': 5.87,
#   'start': 171.15,
#   'text': 'и де чикко название магазина время'},
#  {'duration': 7.64,
#   'start': 173.1,
#   'text': 'покупки и суммарная стоимость покупки'},
#  {'duration': 5.83,
#   'start': 177.02,
#   'text': 'также в дополнение был было три'},
#  {'duration': 5.29,
#   'start': 180.74,
#   'text': 'дополнительных каталога который в'},
#  {'duration': 7.56,
#   'start': 182.85,
#   'text': 'которых категории были близки к тем'},
#  {'duration': 7.2,
#   'start': 186.03,
#   'text': 'которые были в строении в тесте их было'},
#  {'duration': 6.299,
#   'start': 190.41,
#   'text': '250 тысяч товарных позиций в этих'},
#  {'duration': 6.78, 'start': 193.23, 'text': 'каталогах и были прайс-листы'},
#  {'duration': 6.801,
#   'start': 196.709,
#   'text': 'аптеки кафе строительного магазина и'},
#  {'duration': 6.81,
#   'start': 200.01,
#   'text': 'детского магазина при этом их содержание'},
#  {'duration': 6.31,
#   'start': 203.51,
#   'text': 'могло не совпадать с категориями которые'},
#  {'duration': 6.419,
#   'start': 206.82,
#   'text': 'находились в тренировочной выборки и в'},
#  {'duration': 9.69,
#   'start': 209.82,
#   'text': 'итоге по моему никто вот эти четыре'},
#  {'duration': 10.261,
#   'start': 213.239,
#   'text': 'прайс-листа не смог использовать с'},
#  {'duration': 6.21,
#   'start': 219.51,
#   'text': 'пользой для своего решения для начала я'},
#  {'duration': 6.5,
#   'start': 223.5,
#   'text': 'расскажу чуть и данных то есть было'},
#  {'duration': 4.28, 'start': 225.72, 'text': 'двадцать пять категорий самое'},
#  {'duration': 5.37,
#   'start': 232.17,
#   'text': 'самые популярные это были из продуктовых'},
#  {'duration': 7.621,
#   'start': 235.319,
#   'text': 'магазинов меньше всего было по'},
#  {'duration': 9.029,
#   'start': 237.54,
#   'text': 'компьютерной техники в дополнительных'},
#  {'duration': 6.5,
#   'start': 242.94,
#   'text': 'категориях большая часть товаров это'},
#  {'duration': 2.871, 'start': 246.569, 'text': 'были товары для дома'},
#  {'duration': 6.52,
#   'start': 250.55,
#   'text': 'дальше можно посмотреть распределение по'},
#  {'duration': 6.889,
#   'start': 253.53,
#   'text': 'ценам то есть в принципе большая часть'},
#  {'duration': 8.97,
#   'start': 257.07,
#   'text': 'товаров она была меньше 100 рублей'},
#  {'duration': 9.72,
#   'start': 260.419,
#   'text': 'стоимостью на тесте в принципе'},
#  {'duration': 8.939,
#   'start': 266.04,
#   'text': 'распределение было достаточно схожи и'},
#  {'duration': 6.491,
#   'start': 270.139,
#   'text': 'если посмотреть по категориям какие цены'},
#  {'duration': 7.051,
#   'start': 274.979,
#   'text': 'были для каждой категории то в принципе'},
#  {'duration': 14.43,
#   'start': 276.63,
#   'text': 'видно что по ценам должны некоторой'},
#  {'duration': 13.46,
#   'start': 282.03,
#   'text': 'категории различаться теперь уже ближе к'},
#  {'duration': 8.13,
#   'start': 291.06,
#   'text': 'вич инжинирингу для некоторых товаров'},
#  {'duration': 6.13,
#   'start': 295.49,
#   'text': 'количество была целая то есть были'},
#  {'duration': 4.14,
#   'start': 299.19,
#   'text': 'только целые значения без дробных это'},
#  {'duration': 5.09,
#   'start': 301.62,
#   'text': 'можно было использовать в решении то'},
#  {'duration': 6.68,
#   'start': 303.33,
#   'text': 'есть какие-нибудь компьютеры они всегда'},
#  {'duration': 8.579, 'start': 306.71, 'text': 'штуками животные тоже штуками'},
#  {'duration': 12.37,
#   'start': 310.01,
#   'text': 'ну и товары в аптеке например уже мясо'},
#  {'duration': 9.551,
#   'start': 315.289,
#   'text': 'там молочка они побывали дробные овощи и'},
#  {'duration': 8.13,
#   'start': 322.38,
#   'text': 'фрукты они по большей части дробные'},
#  {'duration': 9.11,
#   'start': 324.84,
#   'text': 'значения меры здесь собственно вот тоже'},
#  {'duration': 3.44, 'start': 330.51, 'text': 'распределение по категориям'},
#  {'duration': 5.97,
#   'start': 335.27,
#   'text': 'и далее то что я использовал своем'},
#  {'duration': 5.49,
#   'start': 338.18,
#   'text': 'решении это посмотреть какие товары'},
#  {'duration': 4.77,
#   'start': 341.24,
#   'text': 'могут находиться в рамках одного чека'},
#  {'duration': 6.21, 'start': 343.67, 'text': 'потому что у нас были'},
#  {'duration': 6.2,
#   'start': 346.01,
#   'text': 'айди чеков и мы могли понять какие'},
#  {'duration': 5.52,
#   'start': 349.88,
#   'text': 'продукты находятся в рамках одного чека'},
#  {'duration': 5.32,
#   'start': 352.21,
#   'text': 'то есть если посмотреть то есть'},
#  {'duration': 3.63,
#   'start': 355.4,
#   'text': 'категории который никогда не встречались'},
#  {'duration': 4.14, 'start': 357.53, 'text': 'в одном чеке если мы в итоге'},
#  {'duration': 9.48,
#   'start': 359.03,
#   'text': 'предсказываем товары из этих категорий в'},
#  {'duration': 10.83,
#   'start': 361.67,
#   'text': 'одном чеке там и наверняка ошибаемся мой'},
#  {'duration': 7.77,
#   'start': 368.51,
#   'text': 'подход к решению был джигу сна 7 группах'},
#  {'duration': 9.33,
#   'start': 372.5,
#   'text': 'признаков первое это было два мешка слов'},
#  {'duration': 6.35,
#   'start': 376.28,
#   'text': 'на основной выборки логистическая'},
#  {'duration': 3.54, 'start': 381.83, 'text': 'регрессия'},
#  {'duration': 7.81,
#   'start': 382.63,
#   'text': 'потом логистическая регрессия по'},
#  {'duration': 8.13,
#   'start': 385.37,
#   'text': 'дополнительным каталогом трем мульти но'},
#  {'duration': 5.28,
#   'start': 390.44,
#   'text': 'милана фбс на мешке словно основном'},
#  {'duration': 6.36,
#   'start': 393.5,
#   'text': 'каталоге и отдельно на дополнительных'},
#  {'duration': 8.88,
#   'start': 395.72,
#   'text': 'каталогах плюс усреднения вероятностей'},
#  {'duration': 7.83,
#   'start': 399.86,
#   'text': 'по всему чеку вероятности посчитано я на'},
#  {'duration': 5.55,
#   'start': 404.6,
#   'text': 'основной выборки и то же самое для'},
#  {'duration': 6.39,
#   'start': 407.69,
#   'text': 'дополнительных категорий ну и плюс я'},
#  {'duration': 6.45,
#   'start': 410.15,
#   'text': 'добавил одну фичу это количество товара'},
#  {'duration': 4.35,
#   'start': 414.08,
#   'text': 'в чеках то есть принципе было видно что'},
#  {'duration': 4.05,
#   'start': 416.6,
#   'text': 'в продуктовых магазинах как правило'},
#  {'duration': 6.77,
#   'start': 418.43,
#   'text': 'больше позиции люди набирают а например'},
#  {'duration': 4.55,
#   'start': 420.65,
#   'text': 'в компьютерном магазине меньше позиции'},
#  {'duration': 6.6, 'start': 425.71, 'text': 'теперь подробнее про'},
#  {'duration': 4.96,
#   'start': 429.39,
#   'text': 'то как я данный загружал то есть я'},
#  {'duration': 6.21,
#   'start': 432.31,
#   'text': 'посмотрел что на тренировочной выборки'},
#  {'duration': 6.45,
#   'start': 434.35,
#   'text': 'вообще вернее в тесте никогда нету но не'},
#  {'duration': 5.61,
#   'start': 438.52,
#   'text': 'было ни одной позиции больше 5000 рублей'},
#  {'duration': 6.87,
#   'start': 440.8,
#   'text': 'стоимостью при этом строении были товары'},
#  {'duration': 7.44,
#   'start': 444.13,
#   'text': 'по 70 тысяч я их посчитал выбросами и'},
#  {'duration': 5.97,
#   'start': 447.67,
#   'text': 'удалил потом 3 каталога дополнительных'},
#  {'duration': 5.1,
#   'start': 451.57,
#   'text': 'когда объединял их нужно было некоторые'},
#  {'duration': 4.98,
#   'start': 453.64,
#   'text': 'категории привести к одному названию'},
#  {'duration': 5.55,
#   'start': 456.67,
#   'text': 'потому что в одних каталогах были'},
#  {'duration': 6.87,
#   'start': 458.62,
#   'text': 'табачные изделия в других был табак и я'},
#  {'duration': 5.97,
#   'start': 462.22,
#   'text': 'удалил категории из дополнительного сета'},
#  {'duration': 4.71,
#   'start': 465.49,
#   'text': 'которая на мой взгляд в носили только'},
#  {'duration': 3.66,
#   'start': 468.19,
#   'text': 'шум то есть там было категория например'},
#  {'duration': 5.85,
#   'start': 470.2,
#   'text': 'аксессуары по которым была только одна'},
#  {'duration': 6.36,
#   'start': 471.85,
#   'text': 'позиция и были товары с непонятной'},
#  {'duration': 6.08,
#   'start': 476.05,
#   'text': 'категорию то есть когда их убрал это'},
#  {'duration': 8.28,
#   'start': 478.21,
#   'text': 'было не очень много товарных позиций и'},
#  {'duration': 9.58,
#   'start': 482.13,
#   'text': 'это сказалось положительно теперь'},
#  {'duration': 6.72,
#   'start': 486.49,
#   'text': 'подробнее о формировании групп признаков'},
#  {'duration': 2.96, 'start': 491.71, 'text': 'то есть первое это у меня был'},
#  {'duration': 5.06, 'start': 493.21, 'text': 'логистическая регрессия'},
#  {'duration': 6.73, 'start': 494.67, 'text': 'на вход я брал мешок слов'},
#  {'duration': 7.96,
#   'start': 498.27,
#   'text': 'дело count with a quick to raise рте pdf'},
#  {'duration': 5.85,
#   'start': 501.4,
#   'text': 'у меня не зашел ни на одном с этим то'},
#  {'duration': 6.8, 'start': 506.23, 'text': 'есть я взял'},
#  {'duration': 10.65,
#   'start': 507.25,
#   'text': 'отдельный мешок слов по словам при этом'},
#  {'duration': 9.16,
#   'start': 513.03,
#   'text': 'я писал свой таки найдер который сначала'},
#  {'duration': 5.51,
#   'start': 517.9,
#   'text': 'браун исходную строку потом делался'},
#  {'duration': 4.41, 'start': 522.19, 'text': 'steaming'},
#  {'duration': 5.86,
#   'start': 523.41,
#   'text': 'это объединялось в единую строку и потом'},
#  {'duration': 4.68,
#   'start': 526.6,
#   'text': 'уже делилась на токены то есть по сути у'},
#  {'duration': 6.24,
#   'start': 529.27,
#   'text': 'меня название товарной позиции она в два'},
#  {'duration': 8.73,
#   'start': 531.28,
#   'text': 'раза увеличивалась потом был мешок слов'},
#  {'duration': 6.96,
#   'start': 535.51,
#   'text': 'на n граммах по буквам длина от 2 до 5'},
#  {'duration': 4.74,
#   'start': 540.01,
#   'text': 'потому что если посмотреть данные там'},
#  {'duration': 5.04,
#   'start': 542.47,
#   'text': 'было очень много сокращений например в'},
#  {'duration': 4.77,
#   'start': 544.75,
#   'text': 'одном магазине могли писать шоколадное в'},
#  {'duration': 3.42,
#   'start': 547.51,
#   'text': 'другом шок и это нужно было желательно'},
#  {'duration': 3.46,
#   'start': 549.52,
#   'text': 'понимать что это одно и то же слово'},
#  {'duration': 4.61, 'start': 550.93, 'text': 'поэтому'},
#  {'duration': 5.64,
#   'start': 552.98,
#   'text': 'ingram именно на буквах давали очень'},
#  {'duration': 3.08,
#   'start': 555.54,
#   'text': 'хороший положительный результат'},
#  {'duration': 5.2,
#   'start': 558.86,
#   'text': 'потом я делал он хоть encoder по'},
#  {'duration': 5.101,
#   'start': 561.269,
#   'text': 'магазинам при этом я откинул магазины по'},
#  {'duration': 6.74,
#   'start': 564.06,
#   'text': 'которым было очень мало чеков то есть'},
#  {'duration': 7.17,
#   'start': 566.37,
#   'text': 'чтобы они не за шум ляют и магазин и'},
#  {'duration': 3.81,
#   'start': 570.8,
#   'text': 'отрезал только часть названия чтобы как'},
#  {'duration': 4.41, 'start': 573.54, 'text': 'раз'},
#  {'duration': 5.83,
#   'start': 574.61,
#   'text': 'отсечь магазина у которых одинаковое'},
#  {'duration': 5.46,
#   'start': 577.95,
#   'text': 'название ну которая по факту одинаковые'},
#  {'duration': 6.72,
#   'start': 580.44,
#   'text': 'но они могли быть отдельными магазинами'},
#  {'duration': 6.48,
#   'start': 583.41,
#   'text': 'это могло быть написано на подобии ашан'},
#  {'duration': 6.419,
#   'start': 587.16,
#   'text': 'там не знаю белая дача и какой-нибудь'},
#  {'duration': 6.12,
#   'start': 589.89,
#   'text': 'другой ашан и чтобы их чтобы это было'},
#  {'duration': 5.461,
#   'start': 593.579,
#   'text': 'как один магазин я урезал название'},
#  {'duration': 7.49,
#   'start': 596.01,
#   'text': 'магазинов плюс я добавляю ценовую'},
#  {'duration': 7.5,
#   'start': 599.04,
#   'text': 'категорию в принципе подбирал на глаз'},
#  {'duration': 6.13, 'start': 603.5, 'text': 'час и день недели'},
#  {'duration': 7.32,
#   'start': 606.54,
#   'text': 'то есть была некоторая зависимость по'},
#  {'duration': 6.269,
#   'start': 609.63,
#   'text': 'дням недели какие товары закупают и в'},
#  {'duration': 5.43,
#   'start': 613.86,
#   'text': 'какое время суток это все делают ну и'},
#  {'duration': 6.3,
#   'start': 615.899,
#   'text': 'цена и количество продуктов вторая'},
#  {'duration': 4.289, 'start': 619.29, 'text': 'группа признаков это был было'},
#  {'duration': 4.801, 'start': 622.199, 'text': 'логистическая регрессия на'},
#  {'duration': 9.111,
#   'start': 623.579,
#   'text': 'дополнительных каталогах то есть очень'},
#  {'duration': 5.69,
#   'start': 627.0,
#   'text': 'большой это сет на нем я считала только'},
#  {'duration': 7.959,
#   'start': 634.25,
#   'text': 'инграммы по буквам третья группа это'},
#  {'duration': 5.25,
#   'start': 639.42,
#   'text': 'было мальте на noun fps на основной'},
#  {'duration': 5.731,
#   'start': 642.209,
#   'text': 'выборки там был просто мешок слов вообще'},
#  {'duration': 6.39,
#   'start': 644.67,
#   'text': 'без каких-либо добавлений то есть'},
#  {'duration': 8.67,
#   'start': 647.94,
#   'text': 'например steaming как для тренировочной'},
#  {'duration': 11.45,
#   'start': 651.06,
#   'text': 'выборки там только портил и то же самое'},
#  {'duration': 7.14,
#   'start': 656.61,
#   'text': 'для дополнительных каталогов ну и потом'},
#  {'duration': 4.48, 'start': 662.51, 'text': 'был'},
#  {'duration': 7.41,
#   'start': 663.75,
#   'text': 'ну собственно анализ чеков в целом что'},
#  {'duration': 8.06,
#   'start': 666.99,
#   'text': 'дала очень сильный прирост качества то'},
#  {'duration': 6.06,
#   'start': 671.16,
#   'text': 'есть в принципе было несколько очень'},
#  {'duration': 4.76,
#   'start': 675.05,
#   'text': 'сильных моментов которые сильно'},
#  {'duration': 6.52, 'start': 677.22, 'text': 'добавляли это'},
#  {'duration': 7.38, 'start': 679.81, 'text': 'он был'},
#  {'duration': 5.07, 'start': 683.74, 'text': 'наивный боясь то есть он как я'},
#  {'duration': 4.8,
#   'start': 687.19,
#   'text': 'предполагаю какую-то определенную'},
#  {'duration': 8.969,
#   'start': 688.81,
#   'text': 'категорию он определял лучше чем'},
#  {'duration': 9.96,
#   'start': 691.99,
#   'text': 'логистическая регрессия и анализ чеков в'},
#  {'duration': 7.681,
#   'start': 697.779,
#   'text': 'целом то есть я брал предсказание'},
#  {'duration': 6.95,
#   'start': 701.95,
#   'text': 'вероятностей для train аж с помощью'},
#  {'duration': 6.21,
#   'start': 705.46,
#   'text': 'crosswalk predict чтобы понимать какие'},
#  {'duration': 5.26,
#   'start': 708.9,
#   'text': 'вероятности моя модель предсказывает для'},
#  {'duration': 5.63,
#   'start': 711.67,
#   'text': 'тренировочной выборки и усреднять то'},
#  {'duration': 7.29,
#   'start': 714.16,
#   'text': 'есть у меня получалось что-то наподобие'},
#  {'duration': 6.13,
#   'start': 717.3,
#   'text': 'средней категории чека то есть так можно'},
#  {'duration': 7.46,
#   'start': 721.45,
#   'text': 'было отделить там компьютерные магазины'},
#  {'duration': 11.28,
#   'start': 723.43,
#   'text': 'от магазинов продуктовых и так далее и'},
#  {'duration': 7.96,
#   'start': 728.91,
#   'text': 'то же самое я делал на предсказаниях'},
#  {'duration': 5.87,
#   'start': 734.71,
#   'text': 'вероятностей по дополнительным каталогам'},
#  {'duration': 6.719,
#   'start': 736.87,
#   'text': 'и в итоге добавления вот этих фич по'},
#  {'duration': 5.47,
#   'start': 740.58,
#   'text': 'анализу человека в целом дала очень'},
#  {'duration': 5.611,
#   'start': 743.589,
#   'text': 'сильные хорошие результаты очень большой'},
#  {'duration': 6.05,
#   'start': 746.05,
#   'text': 'скачок качества и добавил количество'},
#  {'duration': 5.37,
#   'start': 749.2,
#   'text': 'позиций в чеке и все это в итоге'},
#  {'duration': 7.33,
#   'start': 752.1,
#   'text': 'подавалась как мы это признаки выкажи'},
#  {'duration': 7.65,
#   'start': 754.57,
#   'text': 'boost вот собственно и все по моему'},
#  {'duration': 4.97,
#   'start': 759.43,
#   'text': 'подходу сейчас владимир расскажет второй'},
#  {'duration': 5.18,
#   'start': 762.22,
#   'text': 'подход к решению задачи которые делал он'},
#  {'duration': 3.0, 'start': 764.4, 'text': 'спасибо'},
#  {'duration': 9.4, 'start': 767.86, 'text': '[аплодисменты]'},
#  {'duration': 5.62,
#   'start': 772.27,
#   'text': 'так еще раз у меня была вообще 2 решение'},
#  {'duration': 3.93, 'start': 777.26, 'text': 'задачи'},
#  {'duration': 4.59,
#   'start': 777.89,
#   'text': 'одно из них стрельнула на паблике другой'},
#  {'duration': 4.14, 'start': 781.19, 'text': 'стране направите'},
#  {'duration': 5.43,
#   'start': 782.48,
#   'text': 'одно то что в один как раз момент кто'},
#  {'duration': 4.04,
#   'start': 785.33,
#   'text': 'вложил на паблик чернил где объединялись'},
#  {'duration': 5.19, 'start': 787.91, 'text': 'tf одев матрицы по'},
#  {'duration': 7.54,
#   'start': 789.37,
#   'text': 'характером и по после посимвольно и по'},
#  {'duration': 7.74,
#   'start': 793.1,
#   'text': 'словам что давало прирост и андрей'},
#  {'duration': 5.49,
#   'start': 796.91,
#   'text': 'лукьяненко там сидит очень интересный'},
#  {'duration': 4.38,
#   'start': 800.84,
#   'text': 'тоже третье место занял получил'},
#  {'duration': 5.91,
#   'start': 802.4,
#   'text': 'результат посредством неправильного'},
#  {'duration': 4.62,
#   'start': 805.22,
#   'text': 'подсчета среднего ну так получилось то'},
#  {'duration': 3.96,
#   'start': 808.31,
#   'text': 'есть считалось по четырем фонтан'},
#  {'duration': 5.19,
#   'start': 809.84,
#   'text': 'делилось на 5 но почему не дало'},
#  {'duration': 4.56, 'start': 812.27, 'text': 'результат основа'},
#  {'duration': 3.54,
#   'start': 815.03,
#   'text': 'но по-крайней мере моего решение это был'},
#  {'duration': 3.69,
#   'start': 816.83,
#   'text': 'довольно таки тонкий при processing'},
#  {'duration': 5.39,
#   'start': 818.57,
#   'text': 'работа с текстом то есть из текста можно'},
#  {'duration': 5.46,
#   'start': 820.52,
#   'text': 'было в принципе выделить коды товаров'},
#  {'duration': 3.4,
#   'start': 823.96,
#   'text': 'точнее но какой-то штрих-код либо'},
#  {'duration': 5.37,
#   'start': 825.98,
#   'text': 'внутренняя кодировка которая была'},
#  {'duration': 5.43,
#   'start': 827.36,
#   'text': 'непосредственно в текстовой строке и я'},
#  {'duration': 3.99,
#   'start': 831.35,
#   'text': 'заметил то что она относилась в сторону'},
#  {'duration': 4.95,
#   'start': 832.79,
#   'text': 'продуктовым магазинам потом второе это'},
#  {'duration': 4.92,
#   'start': 835.34,
#   'text': 'количество товара очень легко отделялся'},
#  {'duration': 4.38,
#   'start': 837.74,
#   'text': 'весовой товар то есть ну нельзя там'},
#  {'duration': 5.04,
#   'start': 840.26,
#   'text': 'купить оперативки два с половиной штуки'},
#  {'duration': 8.79,
#   'start': 842.12,
#   'text': 'или там килограммы если это не секрет'},
#  {'duration': 11.06,
#   'start': 845.3,
#   'text': 'конечно вот следующее это tf и дев был'},
#  {'duration': 8.13, 'start': 850.91, 'text': 'по 15 граммов на посимвольно'},
#  {'duration': 4.78,
#   'start': 856.36,
#   'text': 'что собственно говоря помогала но по'},
#  {'duration': 6.12,
#   'start': 859.04,
#   'text': 'крайней мере я так считаю решить'},
#  {'duration': 7.29,
#   'start': 861.14,
#   'text': 'проблему неполного написания слов то'},
#  {'duration': 10.89,
#   'start': 865.16,
#   'text': 'есть мол шок вместо шоколада и молока'},
#  {'duration': 9.63,
#   'start': 868.43,
#   'text': 'соответственно следующие я ноги не'},
#  {'duration': 5.07,
#   'start': 876.05,
#   'text': 'релаксе все всевозможные временные фичи'},
#  {'duration': 5.16,
#   'start': 878.06,
#   'text': 'связанные с агрегаты по магазинам по'},
#  {'duration': 4.65,
#   'start': 881.12,
#   'text': 'ценам по ценам от времени по магазину от'},
#  {'duration': 3.84,
#   'start': 883.22,
#   'text': 'времени потому что есть кафе отдельная'},
#  {'duration': 2.19,
#   'start': 885.77,
#   'text': 'категория которая бывает работу'},
#  {'duration': 2.67, 'start': 887.06, 'text': 'круглосуточно'},
#  {'duration': 4.65,
#   'start': 887.96,
#   'text': 'компьютерный магазин и редко работают'},
#  {'duration': 4.75, 'start': 889.73, 'text': 'круглосуточно потом была очень'},
#  {'duration': 3.909, 'start': 892.61, 'text': 'интересная фича'},
#  {'duration': 3.84,
#   'start': 894.48,
#   'text': 'ну иногда полезно для линейных моделей'},
#  {'duration': 4.411,
#   'start': 896.519,
#   'text': 'это косинус на и и синус на и'},
#  {'duration': 5.97,
#   'start': 898.32,
#   'text': 'преобразование времени тут фишка в том'},
#  {'duration': 6.209,
#   'start': 900.93,
#   'text': 'то что разница между там 15 и 16 часами'},
#  {'duration': 5.849,
#   'start': 904.29,
#   'text': 'ну или 15-18 часами не очень большая'},
#  {'duration': 5.611, 'start': 907.139, 'text': 'разница между 20 и тремя'},
#  {'duration': 4.861,
#   'start': 910.139,
#   'text': 'цифры и от 0 хотя по времени на на самом'},
#  {'duration': 4.199,
#   'start': 912.75,
#   'text': 'деле неважно но получается очень'},
#  {'duration': 4.56,
#   'start': 915.0,
#   'text': 'огромный копы это губит линейную модель'},
#  {'duration': 5.611,
#   'start': 916.949,
#   'text': 'а в sims но косинусом преобразование это'},
#  {'duration': 5.519,
#   'start': 919.56,
#   'text': 'довольно таки плавный переход это все'},
#  {'duration': 4.769,
#   'start': 922.56,
#   'text': 'объединялась со sports матрицей'},
#  {'duration': 6.841,
#   'start': 925.079,
#   'text': 'согласие не сото решения dance & sports'},
#  {'duration': 6.031,
#   'start': 927.329,
#   'text': 'матрицы объединять но сработала во'},
#  {'duration': 6.469, 'start': 931.92, 'text': 'первых во вторых это все еще'},
#  {'duration': 7.07,
#   'start': 933.36,
#   'text': 'дополнительно подавалась на выделялись'},
#  {'duration': 4.481, 'start': 938.389, 'text': 'кнр фичи'},
#  {'duration': 7.63,
#   'start': 940.43,
#   'text': 'код в принципе кому интересно можно'},
#  {'duration': 9.209,
#   'start': 942.87,
#   'text': 'посмотреть онлайн решение на гиа хаки'},
#  {'duration': 6.3,
#   'start': 948.06,
#   'text': 'мтс ну с небольшой предназ тройкой и на'},
#  {'duration': 4.861,
#   'start': 952.079,
#   'text': 'этом обучалась линейная модель на'},
#  {'duration': 5.61,
#   'start': 954.36,
#   'text': 'нескольких водах результаты у соединяясь'},
#  {'duration': 4.92,
#   'start': 956.94,
#   'text': 'как на трене так и на тесте то есть при'},
#  {'duration': 3.419,
#   'start': 959.97,
#   'text': 'подготовке мета фичей так и при готовке'},
#  {'duration': 4.5, 'start': 961.86, 'text': 'три новых метод печей так и при'},
#  {'duration': 6.06,
#   'start': 963.389,
#   'text': 'подготовке тестовых мета печей далее'},
#  {'duration': 5.7,
#   'start': 966.36,
#   'text': 'также было обучение на каталогах стоит'},
#  {'duration': 5.88,
#   'start': 969.449,
#   'text': 'отметить то что каталоге они содержали'},
#  {'duration': 7.95,
#   'start': 972.06,
#   'text': 'зачастую ну иногда схожий текст но более'},
#  {'duration': 6.181,
#   'start': 975.329,
#   'text': 'либо другого формата либо ну даже другие'},
#  {'duration': 3.75, 'start': 980.01, 'text': 'категории то есть'},
#  {'duration': 7.17,
#   'start': 981.51,
#   'text': 'обучалась линии ли линейная модель также'},
#  {'duration': 9.24,
#   'start': 983.76,
#   'text': 'натив одев матрицы посимвольно без'},
#  {'duration': 7.709,
#   'start': 988.68,
#   'text': 'ограничения на количество фич и делался'},
#  {'duration': 4.98, 'start': 993.0, 'text': 'прогноз на наш tray новый набор'},
#  {'duration': 4.231,
#   'start': 996.389,
#   'text': 'то есть в итоге мы получали ну порядка'},
#  {'duration': 6.479,
#   'start': 997.98,
#   'text': 'там там было по моему около 30 категорий'},
#  {'duration': 6.54,
#   'start': 1000.62,
#   'text': 'вместо 25 но делался прогноз на x и в'},
#  {'duration': 6.211,
#   'start': 1004.459,
#   'text': 'итоге это была еще одна следующая мета'},
#  {'duration': 4.38,
#   'start': 1007.16,
#   'text': 'фича стоит отметить то что каждая'},
#  {'duration': 3.359, 'start': 1010.67, 'text': 'линейная модель'},
#  {'duration': 6.81,
#   'start': 1011.54,
#   'text': 'при формировании методичен довольно-таки'},
#  {'duration': 9.891,
#   'start': 1014.029,
#   'text': 'долго подбирал по гипер параметрам также'},
#  {'duration': 5.57, 'start': 1018.35, 'text': 'стоит отметить это и о египте'},
#  {'duration': 5.41,
#   'start': 1025.12,
#   'text': 'тренировался через хайпе рот ох ох ой'},
#  {'duration': 9.0, 'start': 1027.56, 'text': 'пирог очень долго потому что'},
#  {'duration': 8.7,
#   'start': 1030.53,
#   'text': 'но цель была не перри обучиться на на'},
#  {'duration': 5.73,
#   'start': 1036.56,
#   'text': 'паблике более кому построить более менее'},
#  {'duration': 4.98,
#   'start': 1039.23,
#   'text': 'обобщающую модель следовательно chopper'},
#  {'duration': 4.89,
#   'start': 1042.29,
#   'text': 'опционе на отложенные выборки обучался'},
#  {'duration': 4.71,
#   'start': 1044.21,
#   'text': 'через кросс валидацию кто решает как не'},
#  {'duration': 5.55,
#   'start': 1047.18,
#   'text': 'советую это делать именно сервере это'},
#  {'duration': 7.77,
#   'start': 1048.92,
#   'text': 'обучается уже восьмой день но есть'},
#  {'duration': 6.86,
#   'start': 1052.73,
#   'text': 'наметки на и на решение и собственно'},
#  {'duration': 4.47,
#   'start': 1056.69,
#   'text': 'говоря если так делать с небольшой как'},
#  {'duration': 4.24, 'start': 1059.59, 'text': 'конкурента'},
#  {'duration': 5.91,
#   'start': 1061.16,
#   'text': 'ну более-менее тонкая обработка данных и'},
#  {'duration': 7.53,
#   'start': 1063.83,
#   'text': 'настройках гипер параметров моделей'},
#  {'duration': 7.79,
#   'start': 1067.07,
#   'text': 'усреднения на на прогнозах что'},
#  {'duration': 6.09,
#   'start': 1071.36,
#   'text': 'собственно говоря давала эффект но'},
#  {'duration': 5.89,
#   'start': 1074.86,
#   'text': 'обычного агрегирования моделей то есть'},
#  {'duration': 6.3,
#   'start': 1077.45,
#   'text': 'ансамбле рование дало профит причем'},
#  {'duration': 5.16,
#   'start': 1080.75,
#   'text': 'достаточно неплохой кстати забыл'},
#  {'duration': 7.35,
#   'start': 1083.75,
#   'text': 'отметить то что некоторые использованные'},
#  {'duration': 9.38,
#   'start': 1085.91,
#   'text': 'фичи при построении мета фичей также уже'},
#  {'duration': 8.4,
#   'start': 1091.1,
#   'text': 'комета печам добавляясь при обучении и'},
#  {'duration': 6.46,
#   'start': 1095.29,
#   'text': 'густо то есть такие как наличие веса там'},
#  {'duration': 5.11,
#   'start': 1099.5,
#   'text': 'количество товара и еще что-то уже не'},
#  {'duration': 7.31,
#   'start': 1101.75,
#   'text': 'помню так что спасибо за внимание'},
#  {'duration': 6.65, 'start': 1104.61, 'text': '[аплодисменты]'},
#  {'duration': 2.98,
#   'start': 1109.06,
#   'text': 'дмитрий демонов рассказывал откуда'},
#  {'duration': 3.9, 'start': 1111.26, 'text': 'данные'},
#  {'duration': 7.05,
#   'start': 1112.04,
#   'text': 'люди ты откуда разметка появилась'},
#  {'duration': 8.34,
#   'start': 1115.16,
#   'text': 'насколько знаю разведка ручная вы'},
#  {'duration': 7.59,
#   'start': 1119.09,
#   'text': 'кажется что дмитрий сам делал все это и'},
#  {'duration': 6.98,
#   'start': 1123.5,
#   'text': 'сам и приложение приложение дмитрий дел'},
#  {'duration': 8.46,
#   'start': 1126.68,
#   'text': 'да она на google поесть да это я слышал'},
#  {'duration': 7.51,
#   'start': 1130.48,
#   'text': 'ни 8 а откуда вопрос там столько чеков и'},
#  {'duration': 4.92,
#   'start': 1135.14,
#   'text': 'что вручную размечены но учеке они'},
#  {'duration': 6.18,
#   'start': 1137.99,
#   'text': "сканируются поо'керр коду получается"},
#  {'duration': 5.67,
#   'start': 1140.06,
#   'text': 'список да да да я про то что сам вряд ли'},
#  {'duration': 3.96,
#   'start': 1144.17,
#   'text': 'мог столько человеку в собрать из'},
#  {'duration': 5.15,
#   'start': 1145.73,
#   'text': 'секретировать нанялась топится выше'},
#  {'duration': 7.7,
#   'start': 1148.13,
#   'text': 'китайцев и пожалуйста на краудфандинге'},
#  {'duration': 4.95,
#   'start': 1150.88,
#   'text': 'разметка ешь можно заказать вопросы'},
#  {'duration': 4.63,
#   'start': 1158.69,
#   'text': 'привет пасе большой закат вопрос'},
#  {'duration': 3.899,
#   'start': 1161.25,
#   'text': 'соответственно сколько было в итоге в'},
#  {'duration': 3.54,
#   'start': 1163.32,
#   'text': 'итоговом ансамбля печей и на ком жалеть'},
#  {'duration': 3.331,
#   'start': 1165.149,
#   'text': 'и вы обучались и сколько времени вы'},
#  {'duration': 5.24,
#   'start': 1166.86,
#   'text': 'просто не до конца опять рассказали'},
#  {'duration': 7.079,
#   'start': 1168.48,
#   'text': 'пасибо я гадала получили по очереди до'},
#  {'duration': 7.86,
#   'start': 1172.1,
#   'text': 'но я обучался локально на своем ноутбуке'},
#  {'duration': 10.73,
#   'start': 1175.559,
#   'text': 'в принципе достаточно на слабом железе'},
#  {'duration': 10.87,
#   'start': 1179.96,
#   'text': 'свечей было но получается это если было'},
#  {'duration': 9.161,
#   'start': 1186.289,
#   'text': 'семь групп каждая примерно по 20 25'},
#  {'duration': 10.29,
#   'start': 1190.83,
#   'text': 'вещей то есть это получается в районе'},
#  {'duration': 13.199,
#   'start': 1195.45,
#   'text': 'порядка 150 которые вошли вот уже в'},
#  {'duration': 9.2,
#   'start': 1201.12,
#   'text': 'другую ну в моем случае это семь 4790 32'},
#  {'duration': 5.01, 'start': 1208.649, 'text': 'гигов оперативки'},
#  {'duration': 5.25,
#   'start': 1210.32,
#   'text': 'при обучении линейных моделей на tf одев'},
#  {'duration': 5.931, 'start': 1213.659, 'text': 'матрицы это у нас было'},
#  {'duration': 7.15,
#   'start': 1215.57,
#   'text': 'если не ошибаюсь порядка 250 тысяч печей'},
#  {'duration': 5.559,
#   'start': 1219.59,
#   'text': 'соответственно обучалась этапа ну на'},
#  {'duration': 3.6,
#   'start': 1222.72,
#   'text': 'самом деле обучалась минут десять потом'},
#  {'duration': 5.071, 'start': 1225.149, 'text': 'это успешно пик лилась'},
#  {'duration': 7.05,
#   'start': 1226.32,
#   'text': 'и восстанавливалась обратно и как же'},
#  {'duration': 5.28,
#   'start': 1230.22,
#   'text': 'boost обучался на ну если прикинуть то'},
#  {'duration': 4.59,
#   'start': 1233.37,
#   'text': 'есть это по каталогам примерно тридцать'},
#  {'duration': 5.22,
#   'start': 1235.5,
#   'text': 'шесть свечей мета печей предсказанных'},
#  {'duration': 4.65,
#   'start': 1237.96,
#   'text': 'вероятности категорий по основным'},
#  {'duration': 4.679,
#   'start': 1240.72,
#   'text': 'каталогом это 25 соответственно'},
#  {'duration': 4.319,
#   'start': 1242.61,
#   'text': 'получается 57 и плюс некоторое'},
#  {'duration': 2.331,
#   'start': 1245.399,
#   'text': 'количество полнить ну примерно 60'},
#  {'duration': 3.511, 'start': 1246.929, 'text': 'вообщем фичей'},
#  {'duration': 7.649,
#   'start': 1247.73,
#   'text': 'обучалась на финальной модели как же'},
#  {'duration': 9.859,
#   'start': 1250.44,
#   'text': 'пустом но из-за подворотом параметров'},
#  {'duration': 7.03, 'start': 1255.379, 'text': 'если не ошибаюсь на 4 или 3'},
#  {'duration': 4.091,
#   'start': 1260.299,
#   'text': 'максимальной глубине деревьев потому что'},
#  {'duration': 5.221, 'start': 1262.409, 'text': 'в принципе на'},
#  {'duration': 5.49,
#   'start': 1264.39,
#   'text': 'прям ансамбле раване использовать'},
#  {'duration': 5.37,
#   'start': 1267.63,
#   'text': 'глубокие деревья не не есть хорошо'},
#  {'duration': 9.92,
#   'start': 1269.88,
#   'text': 'обучалась ну минут также 5 то есть не'},
#  {'duration': 6.8, 'start': 1273.0, 'text': 'очень долго еще вопросы'},
#  {'duration': 5.41,
#   'start': 1285.02,
#   'text': 'сколько всего было класса в итоге и'},
#  {'duration': 7.95,
#   'start': 1287.52,
#   'text': 'метрика качество какая была всего'},
#  {'duration': 5.879,
#   'start': 1290.43,
#   'text': 'классов было 25 метрика рукава меня нет'},
#  {'duration': 6.51, 'start': 1295.47, 'text': 'волос'},
#  {'duration': 11.641,
#   'start': 1296.309,
#   'text': 'алла господа и в итоге лучший результат'},
#  {'duration': 8.73,
#   'start': 1301.98,
#   'text': 'какой получился вот владимира и я'},
#  {'duration': 5.79,
#   'start': 1307.95,
#   'text': 'рассказала что меня было два решения'},
#  {'duration': 6.469,
#   'start': 1310.71,
#   'text': 'одно страну латам если бруно если вам'},
#  {'duration': 7.23,
#   'start': 1313.74,
#   'text': 'скажет что-нибудь цифра это было'},
#  {'duration': 8.101,
#   'start': 1317.179,
#   'text': '031 что-то в этом роде стрельнул другая'},
#  {'duration': 8.18,
#   'start': 1320.97,
#   'text': 'модель которая прыгнула на две тысячных'},
#  {'duration': 8.08, 'start': 1325.28, 'text': 'да хорошая идея'},
#  {'duration': 6.34,
#   'start': 1329.15,
#   'text': 'собственно вот потом я проверил late'},
#  {'duration': 4.29,
#   'start': 1333.36,
#   'text': 'совмещены просто побоялся использовать'},
#  {'duration': 5.46, 'start': 1335.49, 'text': 'лишний сами так было два'},
#  {'duration': 5.82,
#   'start': 1337.65,
#   'text': 'выборе и вот другой мат другой подход'},
#  {'duration': 6.33, 'start': 1340.95, 'text': 'использовал при добавлении'},
#  {'duration': 5.73,
#   'start': 1343.47,
#   'text': 'фичи weight к остальные метров и чем при'},
#  {'duration': 5.49,
#   'start': 1347.28,
#   'text': 'добавлю добавление как же boost'},
#  {'duration': 7.04,
#   'start': 1349.2,
#   'text': 'прирост дала еще одна тысячная то есть в'},
#  {'duration': 3.47,
#   'start': 1352.77,
#   'text': 'принципе довольно таки сильный прирост'},
#  {'duration': 3.58,
#   'start': 1360.32,
#   'text': 'просто больше нет давайте через'},
#  {'duration': 6.879, 'start': 1362.61, 'text': 'поговорим докладчиков'},
#  {'duration': 5.589, 'start': 1363.9, 'text': '[аплодисменты]'}]

# %%
texts = [p['text'] for p in transcripts[0]]

# %%
texts
# Out:
# ['всем привет меня зовут kati константин я',
#  'работаю до это sands там компании кнопка',
#  'жизни студента физфака',
#  'и высшей школы бизнеса мгу сегодня я с',
#  'коллегами',
#  'игорем галицким и алексеем нас к вам',
#  'расскажем вам о соревновании такси камин',
#  'классификация челлендж котором наша',
#  'команда disease in guys заняло десятое',
#  'место среди',
#  '4000 с лишним других команд поехали',
#  'онлайн обсуждение тем которые важны для',
#  'нас может быть затруднено оскорбление',
#  'агрессия домогательства которое',
#  'происходит онлайн часто заставляет',
#  'многих людей отказаться от поиска',
#  'различных интересующих их различных',
#  'адекватных мнений по интересующему их',
#  'вопросу отказываются от выражение самих',
#  'себя многие платформы',
#  'борются за эффективно борется за',
#  'эффективное общение онлайн',
#  'однако часто это прадик тому что многие',
#  'сообщество просто напросто полностью',
#  'закрывает комментарии пользователей',
#  '1 исследовательская группа из гугла еще',
#  'какой-то компании работает над',
#  'инструментами которые как раз таки',
#  'помогают улучшить',
#  'онлайн обсуждения одной из фокусов на',
#  'котором на которых они фокусируют ну на',
#  'которых они концентрируются это изучение',
#  'негативных онлайновых поведений таких',
#  'как токсичные комментарии то есть это те',
#  'комментарии которые могут быть',
#  'оскорбительными неуважительными',
#  'и могут просто напросто заставить',
#  'пользователя покинуть обсуждение к',
#  'настоящему моменту это группа',
#  'разработала публичная api',
#  'которое в частности может определять',
#  'степень токсичности комментарии',
#  'но текущей их модели по-прежнему',
#  'совершают ошибки и в этом соревновании',
#  'нам келлером был брошен вызов',
#  'построить модель которая способна',
#  'выявлять комментарии содержащие угрозы',
#  'ненависть оскорбления ну и тому подобное',
#  'причем в идеале эта модель должна быть',
#  'лучше чем текущей модели их описки что',
#  'мы имеем имеем следующую задачу',
#  'естественно обработки текста выявить а',
#  'затем классифицировать токсичные',
#  'комментарии в качестве обучающие и теста',
#  'и выборок были предоставлены комментарии',
#  'со страниц обсуждение статей википедии о',
#  'строении порядка 160 тысяч комментариев',
#  'было в тесте',
#  '153000 обучающая выборка было размечена',
#  'следующим образом каждому комментарию',
#  'соответствует 6 меток метки принимают',
#  'значения равны единице или нолику один',
#  'если в комментарии есть данный тип',
#  'токсичности ноль иначе',
#  'причем может быть так что все метки',
#  'нулевые то есть случае нормального',
#  'адекватного комментария а может быть так',
#  'что 1 комментарий содержит несколько',
#  'типов токсичности там например угрозу',
#  'сразу и непристойность в силу того что',
#  'мы находимся в эфире я к сожалению не',
#  'могу вам продемонстрировать конкретный',
#  'пример этих классов вот касательно тесты',
#  'выборки нужно было собственно для',
#  'каждого комментария',
#  'предсказать вероятность наличия каждого',
#  'типа токсичности метрика качество это',
#  'усредненный по типам токсичности рока uk',
#  'ну то есть средняя арифметическая рока',
#  'укол для каждого класса в отдельности на',
#  'этом слайде приведенного распределения',
#  'объектов по классам в обучающей выборке',
#  'видно что данные сильно не',
#  'сбалансированы но',
#  'сразу скажу что наша команда как бы',
#  'скажем так забила на пробу методов по',
#  'работе с несбалансированные данным',
#  'например аверс эмп лингам или андерсен',
#  'пилингом при построении модели и я',
#  'использую',
#  'я использовал тух этапную предобработки',
#  'данных',
#  'первый этап это базовая предобработки',
#  'данных это преобразование вида как вы',
#  'видите на слайде это приведение текста к',
#  'нижнему регистру удаление ссылок',
#  'айпи адресов удаление цифр и удаление',
#  'пунктуации для всех моделей',
#  'использовалась это базовый предобработки',
#  'данных который одел затем на втором',
#  'этапе',
#  'проводилась частично до предобработки',
#  'данных это замена смайликов на',
#  'соответствующие слова расшифровка',
#  'сокращений исправление опечаток не в',
#  'нормативной лексики',
#  'приведение различного сорта маток одному',
#  'и тому же виду и еще удаление',
#  'изображений ну в смысле не в некоторых',
#  'комментарии были указаны сроки нас на',
#  'изображении мы просто их убирали',
#  'для каждой из моделей используют как я',
#  'уже сказал частично',
#  'а частично я приду пред обработка данных',
#  'то есть разные элементы все это делать',
#  'ради того чтобы базовые модели для того',
#  'чтобы уменьшить взаимную корреляцию',
#  'между базовыми моделями при построении',
#  'дальнейшей композиции но теперь перейдем',
#  'к самому интересному это строению модели',
#  'я сразу же отказался от классического',
#  'подхода мишка слов почему в силу того',
#  'что в этом подходе каждое слово это',
#  'отдельный признак слова в этом подходе',
#  'не учитывается общий порядок слов',
#  'предполагается что слова независимы',
#  'таком подходе',
#  'генерация текста происходит следующим',
#  'образом что существует некоторое',
#  'распределение на словах',
#  'из этого распределение случайно',
#  'выбирается слова и она вставляется текст',
#  'можно конечно есть конечно и другие',
#  'более там сложные порождающие процесса',
#  'не как я примитивно сказал но суть дела',
#  'от этого не меняется этот этот подход',
#  'все равно не меня это основной концепции',
#  'не учитывает он никак не учитывать общий',
#  'порядок слов можно конечно перейти на',
#  'пример пин граммам но опять же там будет',
#  'учитываться только скажем так оконный',
#  'порядок слов они общий порядок слов',
#  'поэтому мы понимали что я понимал и мои',
#  'партнеры по команде по команде понимали',
#  'что нужно использовать что-то более',
#  'умное первое что пришло',
#  'умная мне в голову это использовать',
#  'векторное представление с помощью да кто',
#  'века до кто век это во рту век плюс',
#  'вектор учитывающий',
#  'уникальность конкретного документа в',
#  'исходная статья этот вектор называется',
#  'как параграф айди далее по такому',
#  'векторному представлению обучалась',
#  'логистическая регрессия где каждый',
#  'документ был где каждый документ',
#  'представлялся 10000 на 10000 10000 на',
#  'мерным вектором оценка качества',
#  'проводилось на',
#  'кросс валидации по 10 фолдом она была',
#  'стратифицированные и что важно отметить',
#  'логистическая регрессия обучалась по',
#  'каждому классу то есть 6 задач',
#  'классификации отдельно решалась ну и на',
#  'выходе в итоге получалось распределим',
#  'вероятности по классам логистическая',
#  'регрессия очень долго обучалась моей мне',
#  'вообще в оперативку не помещалась я на',
#  'мощностях игоря ну чтобы получить',
#  'результат который вы видите на слайде ну',
#  'где-то день где-то день мы потратили по',
#  'этой причине мы сразу же отказались от',
#  'звания дуг . в силу большого ожидания',
#  'хотя и можно было улучшить там на одну',
#  'тысячу если например в комментарии с',
#  'дополнительной',
#  'перед обработкой данных сделать более',
#  'умное',
#  'что мы использовали и другие участники',
#  'команды и другие участники соревнования',
#  'использовали это',
#  'рекурентные нейронные сети они на вход',
#  'последовательно получает слова обновляя',
#  'свое скрытое состояние после каждого',
#  'слова я с игорем использовал',
#  'рекуррентная сеть грунт по word mb',
#  'деньгу фастекс для получения word абедин',
#  'га фастекс чем он особенный тем что там',
#  'решается множество независимых бинарных',
#  'задач классификации предсказать',
#  'независимо предсказать наличие или',
#  'отсутствие контекстного слова оценку',
#  'качества мы здесь также проводили на',
#  'кросс валидации по 10 фолдом она не было',
#  'кстати здесь стратифицированные и здесь',
#  'уже распределение вероятностей сразу мы',
#  'получали по классам то есть не отдельно',
#  'решали каждую задачку бинарной',
#  'классификации а сразу же гонерилья 6',
#  'мерный вектор и это была наша одна из',
#  'лучших моделей',
#  'единичных лучших моделей и вот как то',
#  'так',
#  'спросите вообщем же сюда стоял секрет',
#  'успеха ну он состоял в брендинге его',
#  'было невероятно много стыке нге',
#  'и в подходе над working подход над',
#  'worked можно изобразить в виде',
#  'ориентированного графа вначале',
#  'соревнования команда диси джинкой',
#  'состояло из двух человек меня и игоря',
#  'галицкого',
#  'затем павел песков слегка нальет с',
#  'наверно многие из вас из этого канала',
#  'здесь присутствует выразил желание что',
#  'он хочет объединиться с',
#  'им нибудь из топ-200 мы как раз таки',
#  'тогда находились где-то на сто пятьдесят',
#  'седьмом месте и павел песков там повод',
#  'то ли на сто пятьдесят четвертом ну по',
#  'соседству',
#  'игорь заметил его желания присоединиться',
#  'я собственно пригласил в команду затем к',
#  'нам присоединился',
#  'андрей литвинов потом павел пригласил',
#  'гранд мастер алексей носкова к нам в',
#  'команду игорь евгению и последним',
#  'партнером нашей команды стал болгар',
#  'атанас атанасов и вот такой у нас',
#  'получился человеческие международные',
#  'ансамбль а сейчас игорь галицкий',
#  'расскажет нам как он обучал групп более',
#  'подробную чем я расскажет о идеях и',
#  'подходах павла близкого андрея литвинова',
#  'и атанаса атанасова игорь спасибо',
#  'константин меня зовут галицкий игорь я',
#  'дата-сайентистов компании epoch 8 и',
#  'сейчас я расскажу о ну большинстве',
#  'архитектур который мы использовали ну',
#  'все началось с стандартные directional',
#  'игру с двумя слоями',
#  'она наверное все практически из команды',
#  'ей пользовались то есть ну и в качестве',
#  'b-king был фас текст вот функция',
#  'активации ел он тут особенно сказать',
#  'ничего как бы просто архитектура',
#  'достаточно без каких-либо изысков',
#  'но почему она нам дала как бы такие',
#  'неплохие результаты с которым мы',
#  'достаточно долго там держались в топ 150',
#  'это просто хорошая предобработки у нас',
#  'была ли текст вот и нам нужно было',
#  'двигаться дальше и что то делать ну',
#  'собственно у павла был свой подход',
#  'который изображен на слоя после',
#  'брендинга с нашим это дало',
#  'существенный прирост вот надо этого у',
#  'нас акция к сожалению низко у нас был',
#  'бледен как раз таки игру и',
#  'модели на борту we',
#  'доктор веках вот она давала 61 рыб так',
#  'далее я расскажу о подходах',
#  'атанас атанасова он прямо даст',
#  'всяких новых статей ну в частности вот',
#  'здесь у нас изображена сейчас груз',
#  'intent с attention им тоже собственно',
#  'все параметры есть на слайде',
#  'сразу хочется сказать что меня было',
#  'очень много крутых подходов реально',
#  'крутых но он до последнего момента',
#  'использовал свою предобработки и поэтому',
#  'это все весь профит он нивелировалось а',
#  'за счет того что за счет предобработки',
#  'то есть ну как бы скоро указано на',
#  'слайде',
#  'вот дальше у нас был иерархическая',
#  'эротический attention он показал даже',
#  'немножко худшие результаты потому что',
#  'изначально это конечно же сеть это для',
#  'классификации у нас документов которые',
#  'из предложений состоят вот он это все',
#  'как-то прикрутил но подход получился не',
#  'очень',
#  'потом в дании в конце презентации я',
#  'мы можем обсудить поподробнее дальше был',
#  'тоже такой интересный подход то есть',
#  'изначально мы можем доставать из',
#  'предложения фичи сначала из конца вот',
#  'сначала с помощью канва люция цветочных',
#  'слоев у нас отдельно достаются',
#  'фичи вот но лево и право это дерево это',
#  'сначала конца предложение потом они',
#  'нежатся и опять пускаются через гру',
#  'вот следующий подход это также игру с',
#  'отличным блоком так ну это вот та тоже',
#  'одна из лучших направить я была она',
#  'достаточно такая глубокая сеть показал',
#  'хорошие результаты',
#  'следующий подход это как бы как можно',
#  'еще больше выделить вещей мы после',
#  'слоя рекуррентной сети еще делаем три',
#  'параллельных слоты слоя канва люция вот',
#  'и фишка в том что здесь ну как раз таки',
#  'мы брали не такую большую длину',
#  'предложением то есть обрезали на 250 но',
#  'за счет вот этих трех convallis это дало',
#  'неплохой результат это была самая',
#  'глубокая сеть',
#  'как сказал сам это нас вон просто хотел',
#  'что-то очень-очень большой интересное',
#  'обучить вот но результаты как бы это',
#  'обычная собственно просто свёрточная',
#  'сетка которая училась на текстовых вещах',
#  'ну результаты как бы ничего особенно',
#  'дальше вот это достаточно интересный',
#  'новый подход',
#  'это в семнадцатом году была статья на',
#  'эту тему оно использовалось для',
#  'имоджен это и там что-то позволило',
#  'улучшить на 25 процентов предыдущий',
#  'результат это короче и основная фишка в',
#  'том что как бы параллельно свёрточная',
#  'блока упускается как бы такой маленький',
#  'слой которую нас учат',
#  'vesa для каждой свертки в этом блоке ну',
#  'и она дала тоже очень крутой подход',
#  'неправильно небольшое описание',
#  'предложений тут проблема в том что',
#  'максимально вообще длина предложение ну',
#  'количество слов предложений в этих',
#  'задачах потом доходила до полутора тысяч',
#  'то есть были очень большие комментарии и',
#  'вот у других команд тоже возникали мысли',
#  'как вообще поймать где в этом большом',
#  'предложение по что все засовывать как то',
#  'не очень а вот как найти и многие',
#  'сказали что в конце предложения была',
#  'очень важная инфа к сожалению вот в этих',
#  'всех подходах она не учитывать после',
#  'здесь бралась сначала возможно это дало',
#  'еще дальнейший прирост',
#  'и здесь архитектура который называется и',
#  'себе stm ее суть в том что помимо вот',
#  'если не нижние как бы разделение на две',
#  'части там у нас помимо атеш на там еще',
#  'но точно это как бы у нас умный pulling',
#  'а вот параллели ним еще идет обычно это',
#  'потом все контролируется но тоже',
#  'неплохие результаты этого вот и это нас',
#  'весь в этот зоопарк моделей',
#  'он потом это все очень классно смешивал',
#  'точно помимо самих модель еще добавлял',
#  'какие-то фичи и тексты вон то есть там',
#  'обычно там длина количество больших букв',
#  'там количество каких-то плохих слов',
#  'количество символов вот это вот все',
#  'добавлял просто валидацию 5 фунтов и',
#  'получались уже отлично в принципе',
#  'результаты то есть направят lb до 99 867',
#  'вот и второй у него был подход это он с',
#  "другими м'бенга мучил",
#  'но результат получить похуже но сносе',
#  'использовались текст вот так ну то также',
#  'хотелось сказать про подход другого',
#  'нашего коллеги это андреа',
#  'у него николай в одессе',
#  'он про но он как бы зашел немножко с',
#  'другой стороны он обучал очень много',
#  'public ермилов то есть он прямых там 100',
#  'кого как не в себе просто и это реально',
#  'тоже дало очень классно результат то',
#  'есть можно было вот это вот все в',
#  'принципе не делать а можно было просто',
#  'взять кучу паблике румов там различных',
#  'там даже нато fdf вот есть гру там',
#  'всякие тоже конвекционные на 10 файлах',
#  'это паста кати было все отлично и вот у',
#  'него один из лучших подходов был с',
#  'которым мы долго держались там в топ-15',
#  'пока к нам не присоединился собственно',
#  'алексей и это нас это он сбрендил этом',
#  'сбрендил короче blending is taking',
#  'вот этого всего вот а также очень очень',
#  'крутой момент который как я понял вообще',
#  'не практически ни одна из команд не',
#  'использовали мы просто потом еще делали',
#  'фичи',
#  'из результатов опишите организмов вот ну',
#  'про это я дальше расскажет алексей до',
#  'окей привет тесная дальше рассказываю',
#  'про немножко свой подход который я',
#  'использовал и чем в общем все завершили',
#  'у меня все было достаточно просто 10',
#  'фунтов кросс валидации модели при добыче',
#  'на различных стресс на векторах и с',
#  'различным при процессингом чтобы у них',
#  'был побольше диверсии в ансамбле и в',
#  'общем да немножко аргументация который я',
#  'еще расскажу и два таких циклы',
#  'разработки первые который в начале в',
#  'основном работал это',
#  'обучил там какое-то количество моделей',
#  'посмотрела ошибки на кросс валидации на',
#  'каких примерах там она делает очевидные',
#  'ошибки исправил исходя этого как правило',
#  'при processing потому что там как раз',
#  'понятнее как их пофиксить ну и второй',
#  'подход который больше использовался в',
#  'конце это обучил какой-то набор моделей',
#  'посмотрел на корреляции',
#  'нашел какие-то блоки модели которые',
#  'слабо scary ли раваны с другими',
#  'усилил стс настоящих часть вот это в',
#  'общем то матрица корреляции по кроссу',
#  'лизации между моими моделями',
#  'тут видно что она имеет такую местами',
#  'блочную структуру то есть как раз',
#  'некоторые модели при том что имели',
#  'хорошие качества были весьма слабо из',
#  'коррелирована с остальными и весьма',
#  'хорошие результаты давала то что я брал',
#  'эти модели в костю основы',
#  'обучал несколько различных вариаций',
#  'отличающихся',
#  'там различными и про параметрами или при',
#  'процессингом и добавлял потом стресс на',
#  'в ансамбль для гвинта ции больше всего',
#  'зажгла',
#  'идея которую опубликовала на форуме',
#  'попалась тюков которое стало в том что',
#  'мы можем убрать комментарий переводить',
#  'его на какой-то другой язык а затем',
#  'обратно в результате такого двойного',
#  'перевода получается какая-то реформу ли',
#  'ровка что там немножко теряется но в',
#  'целом получается какой-то похожий',
#  'немного другой текст который также можно',
#  'классифицировать и тем самым расширить',
#  'это сет и второй подход который я не так',
#  'сильно помогал на тоже помог это то что',
#  'можно попытаться взять два произвольных',
#  'комментариях ну как правило не очень',
#  'длинных склеить их и взять в качестве',
#  'лейбла на таргет',
#  'объединение лэйбл af или там ну немножко',
#  'запустить там где только один из них',
#  'содержал лейбл',
#  'оба эти подхода они хорошо работали если',
#  'стресс на их применить',
#  'не заранее ко всему trainz эту а менять',
#  'набору',
#  'естественно примеров которые мы',
#  'применять админ тации каждую эпоху то',
#  'есть каждую эпоху просто в процессе',
#  'формирования бача мы выбираем там',
#  'какое-то количество допустим 30',
#  'процентов примеров которые прогоняем',
#  'через переводы ну то есть не прогоняй мы',
#  'уже заранее все',
#  'где-то лежит паралельно в памяти просто',
#  'выбираем версию на основе перевода и',
#  'добавляем в batch при обучении и также',
#  'еще интересным отличием были модели',
#  'обычно на bpm',
#  'что это такое есть такое и send and',
#  'peace это кино и сыр от гугла для них',
#  'сетей которые я позволяет в общем-то',
#  'разбить на токены в которых не будет',
#  'умка вообще то есть ограниченный словарь',
#  'в котором любая строка разобьётся на',
#  'какие-то такими случае если там',
#  'разумеется больше в реальном тексте',
#  'количество слов больше чем от целевой',
#  'размер словаря то они начинают',
#  'разбиваться на некоторые более мелкие',
#  'кусочки и получается такой промежуточный',
#  'подход между чертил диавол его рулем',
#  'моделями там используется два основных',
#  'алгоритма в строении то бы по июнь играм',
#  'я не буду вдаваться сейчас подробности',
#  'что это такое важно что в общем-то для',
#  'алгоритма бпф сети достаточно легко было',
#  'найти за причиненные бединге',
#  'естесно с некоторым фиксированным',
#  'словарем у меня хорошо как раз заработал',
#  'словарь 50к можно было обучить еще набор',
#  'модели которые там давали',
#  'неплохое качество чуть чуть похуже',
#  'конечно чем обычные на false тексте но',
#  'зато они были очень слабы с',
#  'коррелировали со всеми остальными',
#  'и давали хороший boost ну соответственно',
#  'да здесь нарисована классическая схема',
#  'стептинга',
#  'я как правило большую часть',
#  'соревнования по сути до объединения',
#  'использовал просто blending секс моих',
#  'моделей без весов это давало наилучшие',
#  'результаты но после объединения',
#  'я в общем-то смог завести чуть более',
#  'сложную схему которая в конце дала',
#  'неплохой boost это то что у меня большое',
#  'очень количество моделей было различных',
#  'простых все скидывать в какой-то степени',
#  'был бы работало не очень хорошо перри',
#  'обучался но поскольку',
#  'модели представляли из себя группы',
#  'которые были достаточно сильного такс',
#  'коррелированы я их просто брал',
#  'объединяла в эти группы внутри каждой',
#  'группы',
#  'усреднил и там получал где-то по моему',
#  '5-7 групп очень похожих моделей от',
#  'которых в качестве печей для следующего',
#  'уровня использовал уже усредненные',
#  'значения ну и после этого разумеется',
#  'обучал на это мой г-н богов 20 запусков',
#  'с различными',
#  'с сэмплами закидывал немного мета фичей',
#  'аналогично тому что делал это нас и в',
#  'общем в конце это в итоге стала наконец',
#  'работать давать некоторые boost поверх',
#  'простого усреднения но больше всего в',
#  'общем то в итоге',
#  'добавила api которая нашел андрей',
#  'которая содержит собственно сходный',
#  'немного набор лейблов которые',
#  'для которых построили модель и',
#  'организаторы изначально но поскольку он',
#  'изначально отличался то поэтому',
#  'участники похоже его особенно не',
#  'использовали нельзя было так просто их',
#  'сопоставить с теми которые нам',
#  'необходимо было предсказать но зато если',
#  'это закидывал ась в качестве мета фичей',
#  'хорошо работающий sticking to это давало',
#  'замечательный boost особенно на классе',
#  'toxic который как раз судя по всему был',
#  'наиболее сложным на лидер борде',
#  'и собственно в конце там нам позволило',
#  'на несколько мест подпрыгнуть буквально',
#  'в последний день мы обнаружили что это',
#  'хорошо работает ну и собственно для',
#  'финального',
#  'совместно поскольку мы вот буквально',
#  'день назад обнаружили что у нас так',
#  'хорошо работает степень copy',
#  'но мы немного сомневались в том',
#  'насколько хорошо вообще это',
#  'перенесется направит потому что работала',
#  'уж очень хорошо подозрительно поэтому мы',
#  'выбрали 2 совместно по следующему',
#  'принципу',
#  'один это blind моделей только цифры',
#  'перепутаны кей 1 ст с на это бленда',
#  'модели без api который был получен до',
#  'этого',
#  'плюс ответственности кинг смета фичами и',
#  'запив это у нас получилось 9880 на',
#  'паблике',
#  'и 98 74 направите здесь к сожалению',
#  'перепутаны похоже вид отметки у меня нос',
#  'тесно и 2 а это блин моделей я просто',
#  'без api без использования стейки нга и',
#  'без использования',
#  'ольга б м потому что ну без',
#  'использования пик потому что были',
#  'опасения что это у нас какое-то',
#  'небольшое переобучение под паблик и мы',
#  'можем сильно слететь с этим но в',
#  'общем-то обошлось не слетели и в итоге',
#  'да с результатом 98 76 направить а мы',
#  'получили десятую позицию в конце всем',
#  '[аплодисменты]',
#  'спасибо вопросы',
#  'здравствуйте доклад',
#  'а не могли бы вы рассказать о тех кто',
#  'повыше блоки они подходят использовали',
#  'если что-то было там почему них лучше',
#  'получилось да я думаю сейчас мы тогда',
#  'скажем кто что помнит первое что я могу',
#  'вспомнить из классных вещей',
#  'народ во первых значительно сильнее',
#  'использовал аргументации с переводом я',
#  'то есть их использовал только во время',
#  'train time',
#  'первое что делали люди это использовали',
#  'их и во время train и во время теста то',
#  'есть во время теста мы можем взять',
#  'комментарий прогнать его там четыре',
#  'через четыре различных варианта перевода',
#  'получить prediction и усреднить это',
#  'давало еще больший boost второе это то',
#  'что с переводом можно было только',
#  'переводить на какой другой язык допустим',
#  'там с английского на французский и взять',
#  'при допущенные им бединге для',
#  'французского',
#  'не собственно тренировать модель на',
#  'французском тут тоже получился',
#  'замечательный эффект потому что во',
#  'первых',
#  'ну да мы получаем как ругали нотацию от',
#  'перевода а во вторых еще дополнительный',
#  'диверсии в ансамбле за того что',
#  'используем вообще совершенно другие им',
#  'бединге и модель которая там другой',
#  'структуре языка',
#  'работает вот это первое стал что я помню',
#  'дальше по моему у людей хорошо заходила',
#  'об сердолик биллинг который у нас делал',
#  'павел но я не помню подробности',
#  'насколько',
#  'противление прокачено что в частности',
#  'греки которые заняли второе место и',
#  'кто-то еще третье место кстати русский',
#  'был те кто заняли третье место не в',
#  'принципе тоже использовали рекуррентной',
#  'нейронной сети ну и так понял из его',
#  'писания так быстро пробежался по',
#  'архитектуре он достаточно много времени',
#  'потратил на оптимизацию архитектуры и',
#  'они получили достаточно сильную базовую',
#  'модель вот у них базовый модель давала',
#  'на',
#  'лидер борде публичном да ты горе мне',
#  'подсказывать 98 72 мусора единиц наши',
#  '54 ну видно насколько она лучше плюс',
#  'понятно эти ребята также знают об',
#  'лендинг и стринги они все это делали',
#  'греки кстати мы греков приглашали к нам',
#  'команду они в итоге они сказали мы',
#  'сначала подумаем',
#  'когда там уже будет дедлайн по',
#  'объединению подумаем потом скажем смотрю',
#  'не молчат но в итоге',
#  'нет давайте ребятам вам сами вот греки',
#  'они в итоге заняли второе место они из',
#  'особенного из таких экзотических',
#  'использование каких-то подходов это у',
#  'них был во рту века не используя во рту',
#  'век также использовали тех же',
#  'рекурентные нейронные сети и различные',
#  'им бединге',
#  'вот это все что я помню стать верхушки и',
#  'есть что дабы',
#  'да если не ошибаюсь они еще',
#  'конкретизировали инбридинге то есть',
#  'различные вместе и это потом все',
#  'засовываю вот и',
#  'ну в принципе наверно все ну вот самое',
#  'главное что а фишка никто не использую',
#  'еще вопросы не зовут юрий',
#  'как вы технически решали вопрос',
#  'переводов то есть вы искали синонимы вы',
#  'искали язык ну как бы использовать',
#  'программу для перевода комментарии на',
#  'другой язык чтобы ну как просто операций',
#  'а просто',
#  'спасибо',
#  'еще был вопрос из части к а может ли',
#  'ваша модель',
#  'детектировать троллинг знаем и не',
#  'пробовали но я думаю что да у нашей',
#  'модели хорошая пообщаешься способности я',
#  'просто в общем той из этих лэйбл af',
#  'ближе всего к троллингу это то что toxic',
#  'да что я понимал турник он уже может',
#  'быть хитрым такси да да но не всегда же',
#  'оболочники при местами и просто еще одну',
#  'добавим класс еще дорасти не хотел',
#  'спросить чего делали с разными языками',
#  'вы делали по одной модели на каждый язык',
#  'или универсальную поскольку разных',
#  'языков',
#  'отличающихся от английского на самом',
#  'деле было очень мало принц египта сети',
#  'там тоже чуть-чуть побольше',
#  'то мы просто не делали с ними и вовсе',
#  'ничего просто использовали обычную',
#  'английскую модель но на этих примерах',
#  'видимо работы',
#  'а насколько хуже получалось вот эта',
#  'общая модель на других нет на не',
#  'английских языках не смотрели смотрели',
#  'их было вообще очень мало я вот хочу',
#  'добавить что да многие говорили что там',
#  'встречаются там комментарии каких-то',
#  'необычных языках но на самом деле это',
#  'просто',
#  'когда засовывали в api google translate',
#  'он говорил что-то например какой-то язык',
#  'на самом деле это просто какой-то',
#  'корявый английский и поэтому там других',
#  'языков было очень мало ну то есть это',
#  'практически нигде не рассматривал',
#  'и все к вот появиться вопросы можете',
#  'задать их перерыве давайте еще раз',
#  'поговорим докладчиков',
#  '[аплодисменты]']

# %%
df = pd.read_csv('ods_video_index.csv')

# %%
id2title = {idx:title for idx, title in df[['youtube_id', 'title']].values}

pickle.dump(id2title, open('id2title.pkl', 'wb'))

# %%
index2id = {i:idx for i, (idx, _, _) in enumerate(pieces)}

pickle.dump(index2id, open('index2id.pkl', 'wb'))

# %%
texts = [p[1] for p in pieces]

pickle.dump(texts, open('texts.pkl', 'wb'))

# %%
times = [round(p[2]) for p in pieces]

pickle.dump(times, open('times.pkl', 'wb'))

# %%
transcripts = pickle.load(open('id2transcripts.pkl', 'rb'))

# %%
pieces = []

for key in transcripts:
    text = []
    duration = 0
    start = None
    for piece in transcripts[key]:
        text.append(piece['text'])
        duration += piece['duration']
        if not start:
            start = piece['start']
        
        if duration > 30:
            pieces.append((key, ' '.join(text), start, ))
            text = []
            duration = 0
            start = None

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_distances

tfidf = TfidfVectorizer()
svd = TruncatedSVD(50)

index = svd.fit_transform(tfidf.fit_transform([p[1] for p in pieces]))

# %%
cosine_distances(svd.transform(tfidf.transform(['соль'])), index).argsort()
# Out:
# array([[1143, 6348, 4295, ..., 2506, 3305,  869]])
